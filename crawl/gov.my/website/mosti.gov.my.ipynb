# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
from requests_html import HTMLSession, AsyncHTMLSession

# %%
rejected = [
    'wa.link',
    'mailto:',
    't.me',
    'tally.so',
    'discord.gg',
    'arxiv.org',
    'javascript:'
]

# %%
async def get_html(url):
    session = AsyncHTMLSession(verify = False)
    result = None
    try:
        
        r = await session.get(url, verify = False, timeout = 10)
        await r.html.arender(timeout = 10)
        
        result = r.html.html
    except Exception as e:
        pass
    
    await session.close()
    return result


def get_links(html):
    soup = BeautifulSoup(html, 'html.parser')
    links = []
    for link in soup.find_all('a'):
        links.append(link.get('href'))
    return links

# %%
import asyncio

visited_pages = set(['https://www.mosti.gov.my/'])

async def crawl(base_url):
    if base_url.endswith('.pdf'):
        return
    
    html = await get_html(base_url)
    
    if html is None:
        return

    visited_pages.add(base_url)
    links = get_links(html)
    for link in links:
        try:
            if any([r in link for r in rejected]):
                continue

            if not link.startswith('http'):
                link = urljoin(base_url, link)

            link = link.split('#')[0]
            link = link.split('?')[0]

            if link not in visited_pages:
                visited_pages.add(link)
        except Exception as e:
            pass

# %%
from tqdm import tqdm

batch_size = 10

for no in range(3):
    l = list(visited_pages)
    print(no, len(l))
    for i in tqdm(range(0, len(l), batch_size)):
        b = l[i: i + batch_size]
        await asyncio.gather(*[crawl(url) for url in b])
# Out:
# 0 1
# 100%|█████████████████████████████████████████████| 1/1 [00:06<00:00,  6.21s/it]
# 1 172
#  89%|██████████████████████████████████████▏    | 16/18 [02:32<00:19,  9.65s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
# 100%|███████████████████████████████████████████| 18/18 [02:45<00:00,  9.22s/it]
# 2 3581
#   0%|                                                   | 0/359 [00:00<?, ?it/s]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#   2%|▉                                        | 8/359 [01:35<1:08:15, 11.67s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
#   7%|██▊                                       | 24/359 [04:03<47:22,  8.48s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#   8%|███▏                                    | 29/359 [04:58<1:03:57, 11.63s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#   8%|███▎                                    | 30/359 [05:08<1:01:27, 11.21s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#   9%|███▊                                    | 34/359 [05:50<1:00:28, 11.17s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
#  12%|█████▏                                    | 44/359 [07:22<44:40,  8.51s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  14%|█████▉                                    | 51/359 [08:30<51:34, 10.05s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  14%|██████                                    | 52/359 [08:43<55:39, 10.88s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  15%|██████▍                                   | 55/359 [09:13<53:33, 10.57s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  18%|███████▋                                  | 66/359 [11:11<44:14,  9.06s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  19%|███████▉                                  | 68/359 [11:37<53:57, 11.13s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  20%|████████▎                                 | 71/359 [12:03<49:57, 10.41s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  28%|███████████▌                             | 101/359 [17:43<58:12, 13.54s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  31%|████████████▉                            | 113/359 [20:03<42:56, 10.47s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  33%|█████████████▌                           | 119/359 [21:10<47:45, 11.94s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  34%|█████████████▊                           | 121/359 [21:35<49:15, 12.42s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  37%|███████████████▏                         | 133/359 [24:00<39:28, 10.48s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  38%|███████████████▍                         | 135/359 [24:19<38:46, 10.38s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  38%|███████████████▋                         | 137/359 [24:47<43:27, 11.75s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  40%|████████████████▌                        | 145/359 [26:27<45:09, 12.66s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  43%|█████████████████▍                       | 153/359 [27:49<36:53, 10.74s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  44%|██████████████████▏                      | 159/359 [29:10<43:22, 13.01s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  50%|████████████████████▍                    | 179/359 [33:25<38:41, 12.90s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  54%|██████████████████████▏                  | 194/359 [35:56<28:14, 10.27s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  56%|██████████████████████▊                  | 200/359 [36:47<21:41,  8.19s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  57%|███████████████████████▏                 | 203/359 [37:22<29:13, 11.24s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  66%|██████████████████████████▉              | 236/359 [44:04<33:11, 16.19s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  72%|█████████████████████████████▌           | 259/359 [47:57<17:04, 10.24s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  74%|██████████████████████████████▍          | 266/359 [49:21<16:57, 10.94s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  77%|███████████████████████████████▍         | 275/359 [51:12<18:04, 12.91s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  78%|████████████████████████████████         | 281/359 [52:31<15:45, 12.13s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  79%|████████████████████████████████▍        | 284/359 [53:12<15:04, 12.07s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  84%|██████████████████████████████████▍      | 301/359 [56:45<12:30, 12.94s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  90%|███████████████████████████████████    | 323/359 [1:00:09<06:22, 10.62s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  91%|███████████████████████████████████▍   | 326/359 [1:00:37<05:19,  9.68s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
#  94%|████████████████████████████████████▌  | 336/359 [1:02:17<03:42,  9.67s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  96%|█████████████████████████████████████▎ | 343/359 [1:03:26<02:29,  9.37s/it]Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.sendMessageToTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.sendMessageToTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
#  97%|█████████████████████████████████████▊ | 348/359 [1:04:15<01:55, 10.54s/it]connection unexpectedly closed
# Task exception was never retrieved
# future: <Task finished name='Task-388446' coro=<Connection._async_send() done, defined at /home/husein/.local/lib/python3.8/site-packages/pyppeteer/connection.py:69> exception=InvalidStateError('invalid state')>
# Traceback (most recent call last):
#   File "/home/husein/.local/lib/python3.8/site-packages/websockets/legacy/protocol.py", line 968, in transfer_data
#     message = await self.read_message()
#   File "/home/husein/.local/lib/python3.8/site-packages/websockets/legacy/protocol.py", line 1038, in read_message
#     frame = await self.read_data_frame(max_size=self.max_size)
#   File "/home/husein/.local/lib/python3.8/site-packages/websockets/legacy/protocol.py", line 1113, in read_data_frame
#     frame = await self.read_frame(max_size)
#   File "/home/husein/.local/lib/python3.8/site-packages/websockets/legacy/protocol.py", line 1170, in read_frame
#     frame = await Frame.read(
#   File "/home/husein/.local/lib/python3.8/site-packages/websockets/legacy/framing.py", line 69, in read
#     data = await reader(2)
#   File "/usr/lib/python3.8/asyncio/streams.py", line 721, in readexactly
#     raise exceptions.IncompleteReadError(incomplete, n)
# asyncio.exceptions.IncompleteReadError: 0 bytes read on a total of 2 expected bytes
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/husein/.local/lib/python3.8/site-packages/pyppeteer/connection.py", line 73, in _async_send
#     await self.connection.send(msg)
#   File "/home/husein/.local/lib/python3.8/site-packages/websockets/legacy/protocol.py", line 635, in send
#     await self.ensure_open()
#   File "/home/husein/.local/lib/python3.8/site-packages/websockets/legacy/protocol.py", line 944, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: no close frame received or sent
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/husein/.local/lib/python3.8/site-packages/pyppeteer/connection.py", line 79, in _async_send
#     await self.dispose()
#   File "/home/husein/.local/lib/python3.8/site-packages/pyppeteer/connection.py", line 170, in dispose
#     await self._on_close()
#   File "/home/husein/.local/lib/python3.8/site-packages/pyppeteer/connection.py", line 151, in _on_close
#     cb.set_exception(_rewriteError(
# asyncio.exceptions.InvalidStateError: invalid state
# 100%|███████████████████████████████████████| 359/359 [1:06:18<00:00, 11.08s/it]

# %%
import json

with open('url-mosti.gov.my.json', 'w') as fopen:
    json.dump(list(visited_pages), fopen)
