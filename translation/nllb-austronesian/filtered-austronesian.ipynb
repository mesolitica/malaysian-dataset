# %%
from tqdm import tqdm
import json

# %%
with open('filtered-bjn_Latn-eng_Latn', 'w') as fopen_l:
    with open('bjn_Latn-eng_Latn') as fopen:
        for row in tqdm(fopen):
            splitted = row.split('\t')
            if float(splitted[2]) >= 1.06:
                if len(splitted[0].split()) < 256 and len(splitted[1].split()) < 256:
                    fopen_l.write(f'{json.dumps(splitted[:2])}\n')
            else:
                break
        
#         if len(x) == 10:
#             break

# %%
with open('filtered-bjn_Latn-ind_Latn', 'w') as fopen_l:
    with open('bjn_Latn-ind_Latn') as fopen:
        for row in tqdm(fopen):
            splitted = row.split('\t')
            if float(splitted[2]) >= 1.06:
                if len(splitted[0].split()) < 256 and len(splitted[1].split()) < 256:
                    fopen_l.write(f'{json.dumps(splitted[:2])}\n')
            else:
                break
# Out:
# 545212it [00:02, 267848.68it/s]

# %%
with open('filtered-bjn_Latn-jav_Latn', 'w') as fopen_l:
    with open('bjn_Latn-jav_Latn') as fopen:
        for row in tqdm(fopen):
            splitted = row.split('\t')
            if float(splitted[2]) >= 1.06:
                if len(splitted[0].split()) < 256 and len(splitted[1].split()) < 256:
                    fopen_l.write(f'{json.dumps(splitted[:2])}\n')
            else:
                break
# Out:
# 31555it [00:00, 257918.24it/s]

# %%
with open('filtered-ind_Latn-jav_Latn', 'w') as fopen_l:
    with open('ind_Latn-jav_Latn') as fopen:
        for row in tqdm(fopen):
            splitted = row.split('\t')
            if float(splitted[2]) >= 1.06:
                if len(splitted[0].split()) < 256 and len(splitted[1].split()) < 256:
                    fopen_l.write(f'{json.dumps(splitted[:2])}\n')
            else:
                break
# Out:
# 553347it [00:02, 271928.01it/s]

# %%
# !wget https://storage.googleapis.com/allennlp-data-bucket/nllb/bjn_Latn-eng_Latn.gz
# !gzip -d bjn_Latn-eng_Latn.gz
# !wc -l bjn_Latn-eng_Latn
# Out:
# 766894 bjn_Latn-eng_Latn

# %%
# !wget https://storage.googleapis.com/allennlp-data-bucket/nllb/bjn_Latn-jav_Latn.gz
# !gzip -d bjn_Latn-jav_Latn.gz
# !wc -l bjn_Latn-jav_Latn
# Out:
# 116244 bjn_Latn-jav_Latn

# %%
# !wget https://storage.googleapis.com/allennlp-data-bucket/nllb/bjn_Latn-ind_Latn.gz
# !gzip -d bjn_Latn-ind_Latn.gz
# !wc -l bjn_Latn-ind_Latn
# Out:
# 1455384 bjn_Latn-ind_Latn

# %%
# !wget https://storage.googleapis.com/allennlp-data-bucket/nllb/ind_Latn-jav_Latn.gz
# !gzip -d ind_Latn-jav_Latn.gz
# !wc -l ind_Latn-jav_Latn
# Out:
# 1929462 ind_Latn-jav_Latn

# %%
# !ls *ind_Latn-jav_Latn
# Out:
# ind_Latn-jav_Latn

# %%
bjn_Latn-eng_Latn
bjn_Latn-jav_Latn
bjn_Latn-ind_Latn

# %%
# !split -l 500000 -d --additional-suffix=.splitted filtered-eng_Latn-jav_Latn filtered-eng_Latn-jav_Latn

# %%
# !head -n 542 filtered-eng_Latn-jav_Latn00.splitted
# Out:
# ["I had no knowledge of the chiefs on high when they disputed;", "Aku ora duweni kaweruh ing ngalam dhuwur nalikane para malaikat padha bantah - bantahan (bab nabi Adam biyen)."]
# ["[A/I'mran 3:74] \"He chooses by His mercy, whomever He wills; and Allah is the Owner of Great Munificence.\"", "Gusti Alloh iku dzat kang nikel-nikelak\u00e9 ganjaran marang wong kang di kersa'ak\u00e9, Alloh moho jembar lan wicaksono.\""]
# ["God used the sorrows of Joseph's life to shape him into the man he desired him to become.", "\"Gusti Allah njembarak\u00e9 rezki lan ngrupekak\u00e9 marang sapa wah\u00e9 kang Panjenengan\u00e9 kersakak\u00e9."]
# ["Indeed, that is a sign for a people who give thought.", "Sanyata iki dadi tanda yektining Pangeran tumrap wong-wong kang gelem mikir."]
# ...
