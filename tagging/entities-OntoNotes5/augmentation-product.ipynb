# %%
# !wget https://f000.backblazeb2.com/file/malay-dataset/tagging/ontonotes5/processed-ontonotes5.json

# %%
import json
from sklearn.model_selection import train_test_split
import random

# %%
with open('processed-ontonotes5.json') as fopen:
    data = json.load(fopen)

# %%
from collections import defaultdict

entities = defaultdict(list)
for i in data:
    entities['text'].append(i[0])
    entities['label'].append(i[1])

# %%
car = """
RM15438 / Month
Model2018TypeCoupeEngine1.5LCylinder3 CylindersTrans.6ATFuel32 LitresFuel Eco1.8 L/100 kmPower374 HpTorque320 NmSafety-Air Bag6 AirbagStatusAvailableimage-6847
BMW M5 (2018)
From RM1,010,800

RM11076 / Month
Model2018TypeSedanEngine4.4LCylinder8 CylindersTrans.8ATFuel76 LitresFuel Eco10.5 L/100 kmPower600 HpTorque750 NmSafety-Air Bag6 AirbagStatusAvailableimage-6791
BMW M4 Coupe (2017)
From RM772,800

RM8468 / Month
Model2017TypeCoupeEngine3.0LCylinder6 CylindersTrans.7ATFuel60 LitresFuel Eco8.3 L/100 KmPower431 HpTorque550 NmSafety-Air Bag6 AirbagStatusAvailableimage-6771
BMW X3 xDrive30i Luxury (2018)
From RM313,800

RM3438 / Month
Model2018TypeSUVEngine2.0LCylinder4 CylindersTrans.8ATFuel65 LitresFuel Eco7.6 L/100 KmPower252 HpTorque350 NmSafety-Air Bag6 AirbagStatusAvailableimage-6749
BMW X2 sDrive20i M Sport (2018)
From RM328,800

RM3603 / Month
Model2018TypeSUVEngine2.0LCylinder4 CylindersTrans.7ATFuel51 LitresFuel Eco5.9 L/100 KmPower192 HpTorque280 NmSafety-Air Bag6 AirbagStatusAvailableimage-6740
BMW X1 sDrive20i Sport (2015)
From RM227,800

RM2496 / Month
Model2015TypeSUVEngine2.0LCylinder4 CylindersTrans.8ATFuel51 LitresFuel Eco5.9 L/100 KmPower192 HpTorque280 NmSafety-Air Bag6 AirbagStatusAvailableimage-6719
BMW X5 xDrive40e M Sport (2016)
From RM390,800

RM4282 / Month
Model2016TypeSUV HybridEngine2.0LCylinder4 CylindersTrans.8ATFuel85 LitresFuel Eco3.3 L/100 KmPower308 HpTorque450 NmSafety-Air Bag6 AirbagStatusAvailableimage-6687
BMW 740Le xDrive (2017)
From RM594,800

RM6518 / Month
Model2017TypeSedan HybridEngine2.0LCylinder4 CylindersTrans.8ATFuel78 LitresFuel Eco2.5 L/100 KmPower258 HpTorque400 NmSafety-Air Bag6 AirbagStatusAvailableimage-6679
BMW 630i GT (2018)
From RM450,000

RM4931 / Month
Model2018TypeSedanEngine2.0LCylinder4 CylindersTrans.8ATFuel68 LitresFuel Eco6.6 L/100 KmPower258 HpTorque400 NmSafety-Air Bag6 AirbagStatusAvailableimage-6650
BMW 530i M Sport (2017)
From RM379,800

RM4161 / Month
Model2017TypeSedanEngine2.0LCylinder4 CylindersTrans.8ATFuel68 LitresFuel Eco5.8 L/100 KmPower252 HpTorque350 NmSafety★★★★★Air Bag6 AirbagStatusAvailableimage-6629
BMW 530e Sport (2018)
From RM328,800

RM3603 / Month
Model2018TypeSedan HybridEngine2.0LCylinder4 CylindersTrans.8ATFuel46 LitresFuel Eco2.0 L/100 KmPower248 HpTorque420 NmSafety★★★★★Air Bag6 AirbagStatusAvailableimage-6610
BMW 430i Coupe M Sport (2017)
From RM424,800

RM4655 / Month
Model2017TypeCoupeEngine2.0LCylinder4 CylindersTrans.8ATFuel60 LitresFuel Eco5.8 L/100 KmPower252 HpTorque350 NmSafety-Air Bag6 AirbagStatusAvailableimage-6586
BMW 420i Coupe Sport (2017)
From RM351,800

RM3855 / Month
Model2017TypeCoupeEngine2.0LCylinder4 CylindersTrans.8ATFuel60 LitresFuel Eco5.8 L/100 KmPower184 HpTorque270 NmSafety-Air Bag6 AirbagStatusAvailableimage-6554
BMW 330e M Sport (2017)
From RM258,800

RM2836 / Month
Model2017TypeSedan HybridEngine2.0LCylinder4 CylindersTrans.8ATFuel41 LitresFuel Eco2.1 L/100 KmPower184 HpTorque290 NmSafety★★★★★Air Bag6 AirbagStatusAvailableimage-6534
BMW 318i Luxury (2015)
From RM202,800

RM2222 / Month
Model2015TypeSedanEngine1.5LCylinder3 CylindersTrans.8ATFuel60 LitresFuel Eco5.1 L/100 KmPower136 HpTorque220 NmSafety★★★★★Air Bag6 AirbagStatusAvailableimage-6517
BMW 118i M Sport (2015)
From RM188,800

RM1192 / Month
Model2019TypeSUV / SUV HybridEngine1.8L / 1.5LCylinder4 CylindersTrans.CVT / 7DCTFuel50 LitresFuel Eco6.6 L/100 kmPower140 HpTorque172 NmSafety★★★★★Air Bag6 AirbagsStatusAvailableimage-4577
Honda Accord (2016)
From RM148,512

RM1627 / Month
Model2016TypeSedanEngine2.0L / 2.4LCylinder4 CylindersTrans.5ATFuel65 LitresFuel Eco-Power172 HpTorque225 NmSafety★★★★Air Bag6 AirbagsStatusAvailableimage-4560
Honda Civic Type R (2017)
From RM330,002

RM3616 / Month
Model2017TypeSedanEngine2.0L TurboCylinder4 CylindersTrans.6MTFuel47 LitresFuel Eco8.8 L/100 KmPower305 HpTorque400 NmSafety-Air Bag6 AirbagsStatusAvailableimage-4537
Honda City (2017)
From RM73,836

RM809 / Month
Model2017TypeSedanEngine1.5LCylinder4 CylindersTrans.CVTFuel40 LitresFuel Eco-Power118 HpTorque145 NmSafety★★★★★Air Bag6 AirbagsStatusAvailableimage-4516
Honda Civic (2016)
From RM108,165

RM1185 / Month
Model2016TypeSedanEngine1.5L / 1.8LCylinder4 CylindersTrans.CVTFuel47 LitresFuel Eco5.8 L/100 KmPower170 HpTorque220 NmSafety★★★★★Air Bag6 AirbagsStatusAvailableimage-4493
Honda CR-V (2017)
From RM137,469

RM1506 / Month
Model2017TypeSUVEngine1.5L / 2.0LCylinder4 CylindersTrans.CVTFuel57 LitresFuel Eco7.1 L/100 KmPower190 HpTorque243 NmSafety★★★★★Air Bag6 AirbagsStatusAvailableimage-4339
Honda Jazz (2017)
From RM70,242

RM769 / Month
Model2017TypeHatchbackEngine1.5LCylinder4 CylindersTrans.CVTFuel40 LitresFuel Eco-Power118 HpTorque145 NmSafety★★★★★Air Bag6 AirbagsStatusAvailableimage-3904
Honda Odyssey (2018)
From RM258,896

RM2837 / Month
Model2018TypeMPVEngine2.4LCylinder4 CylindersTrans.CVTFuel55 LitresFuel Eco-Power172.5 HpTorque225 NmSafety★★★★★Air Bag6 AirbagsStatusAvailableimage-3836
Honda BR-V (2017)
From RM80,989

RM887 / Month
Model2017TypeSUVEngine1.5LCylinder4 CylindersTrans.CVTFuel42 LitresFuel Eco-Power120 HpTorque145 NmSafety★★★★★Air Bag2 AirbagsStatusAvailableimage-804
Honda HR-V (2015)
From RM92,545

RM1014 / Month
Model2015TypeSUVEngine1.8LCylinder4-CylinderTrans.CVTFuel50 LitresFuel Eco6.6 L/100 KmPower140 HpTorque172 NmSafety★★★★★Air Bag6 AirbagsStatusAvailableimage-798No Longer On Sale
Honda Stream (2009)
From RM154,699

RM1001 / Month
Model2016TypePickupEngine2.2L / 3.2LCylinder4 CylindersTrans.6AT / MTFuel80 LitresFuel Eco-Power200 HpTorque470 NmSafety★★★★★Air Bag2 AirbagStatusAvailableimage-6485
Mazda MX-5 (2015)
From RM222,277

RM2435 / Month
Model2015TypeConvertibleEngine2.0LCylinder4 CylindersTrans.6ATFuel45 LitresFuel Eco-Power158 HpTorque200 NmSafety★★★★★Air Bag4 AirbagStatusAvailableimage-6472
Mazda CX-9 (2017)
From RM288,610

RM3162 / Month
Model2017TypeSUVEngine2.5L TurboCylinder4 CylindersTrans.6ATFuel72 LitresFuel Eco8.98 L/100 KmPower228 HpTorque420 NmSafety★★★★★Air Bag6 AirbagsStatusAvailableimage-6448
Mazda CX-5 (2017)
From RM131,018

RM1435 / Month
Model2017TypeSUVEngine2.0L / 2.2L / 2.5LCylinder4 CylindersTrans.6ATFuel56 LitresFuel Eco5.9 L/100 KmPower173 HpTorque420 NmSafety★★★★★Air Bag6 AirbagsStatusAvailableimage-6398
Mazda CX-3 (2018)
From RM128,159

RM1404 / Month
Model2018TypeSUVEngine2.0LCylinder4 CylindersTrans.6ATFuel48 LitresFuel Eco6.3 L/100 KmPower154 HpTorque206 NmSafety★★★★★Air Bag6 AirbagStatusAvailableimage-6405
Mazda 3 (2017)
From RM106,994

RM1172 / Month
Model2017TypeSedan / HatchbackEngine2.0LCylinder4 CylindersTrans.7ATFuel51 LitresFuel Eco-Power162 HpTorque210 NmSafety★★★★★Air Bag6 AirbagsStatusAvailableimage-1372
Mazda 6 (2015)
From RM162,215

RM1777 / Month
Model2015TypeSedan / WagonEngine2.0L / 2.2L / 2.5LCylinder4-CylinderTrans.6ATFuel62 LitresFuel Eco-Power185 HpTorque250 NmSafety★★★★★Air Bag6 AirbagsStatusAvailableimage-1278
Mazda 2 (2015)
From RM74,670

RM818 / Month
Model2015TypeSedan / HatchbackEngine1.5LCylinder4-CylinderTrans.6ATFuel44 LitresFuel Eco5.2L / 100KmPower114 HpTorque148 NmSafety★★★★Air Bag2 AirbagsStatusAvailableimage-1341No Longer On Sale
Mazda 5 (2014)
From RM157,549

RM3341 / Month
Model2018TypeSedanEngine2.0LCylinder4 CylindersTrans.9ATFuel66 LitresFuel Eco6.9 L/100 kmPower258 HpTorque370 NmSafety★★★★★Air Bag7 AirbagStatusAvailableimage-6904
Mercedes-Benz A250 AMG Line (2018)
From RM263,888

RM2891 / Month
Model2018TypeHatchbackEngine2.0LCylinder4 CylindersTrans.Dual Clutch ATFuel51 LitresFuel Eco6.6 L/100 kmPower224 HpTorque350 NmSafety-Air Bag7 AirbagStatusAvailableimage-6887
Mercedes-Benz A200 Progressive Line (2018)
From RM227,888

RM940 / Month
Model2015TypePickupEngine2.5 LCylinder4-CylinderTrans.6MT / 7ATFuel80 LitresFuel Eco-Power160 HpTorque403 NmSafety★★★★★Air Bag7 AirbagsStatusAvailableimage-6333
Nissan Serena S-Hybrid (2018)
From RM131,800

RM1444 / Month
Model2018TypeMPVEngine2.0LCylinder4-CylinderTrans.CVTFuel60 LitresFuel Eco-Power147 HpTorque200 NmSafety-Air Bag6 AirbagsStatusAvailableimage-1001
Nissan Almera (2015)
From RM64,639

RM1466 / Month
Model2015TypeSUVEngine2.0L / 2.5LCylinder4-CylinderTrans.CVTFuel60 LitresFuel Eco10L / 100KmPower168 HpTorque233 NmSafety★★★★★Air Bag2 AirbagsStatusAvailableimage-1067
Nissan Grand Livina (2013)
From RM82,194

RM2670 / Month
Model2018TypeSUVEngine2.0LCylinder4 CylindersTrans.6ATFuel60 LitresFuel Eco7.6 L/100 kmPower228 HpTorque350 NmSafety-Air Bag2 AirbagsStatusAvailableimage-7416
Toyota Yaris (2019)
From RM70,888

RM776 / Month
Model2019TypeHatchbackEngine1.5LCylinder4 CylindersTrans.CVTFuel42 LitresFuel Eco-Power105 hpTorque140 NmSafety★★★★★Air Bag7 AirbagsStatusAvailableimage-6218
Toyota C-HR (2018)
From RM150,000

RM1019 / Month
Model2018TypeSUVEngine1.8LCylinder4 CylindersTrans.CVTFuel50 LitresFuel Eco-Power138 HpTorque171 NmSafety★★★★★Air Bag7 AirbagsStatusAvailableimage-6205
Toyota Rush (2018)
From RM93,000

RM1019 / Month
Model2018TypeSUVEngine1.5LCylinder4 CylindersTrans.4ATFuel45 LitresFuel Eco-Power103 HpTorque136 NmSafety★★★★★Air Bag6 AirbagsStatusAvailableimage-6183
Toyota Hilux (2018)
From RM90,000

RM968 / Month
Model2018TypePickupEngine2.4L / 2.8LCylinder4 CylindersTrans.6MT / 6ATFuel80 LitresFuel Eco-Power174 HpTorque450 NmSafety★★★★★Air Bag7 AirbagsStatusAvailableimage-6160
Toyota Fortuner (2016)
From RM170,500

RM1868 / Month
Model2016TypeSUVEngine2.4L / 2.7LCylinder4 CylindersTrans.6ATFuel80 LitresFuel Eco-Power147 HpTorque245 NmSafety★★★★★Air Bag7 AirbagsStatusAvailableimage-6145
Toyota Vellfire (2018)
From RM362,000

RM3966 / Month
Model2018TypeMPVEngine2.5LCylinder4 CylindersTrans.CVTFuel75 LitresFuel Eco-Power179 HpTorque235 NmSafety★★★★★Air Bag7 AirbagsStatusAvailableimage-6137
Toyota Alphard (2018)
From RM443,000

RM4854 / Month
Model2018TypeMPVEngine3.5LCylinder6 CylindersTrans.8ATFuel75 LitresFuel Eco-Power296 HpTorque361 NmSafety-Air Bag7 AirbagsStatusAvailableimage-6118
Toyota Sienta (2016)
From RM101,900

RM1116 / Month
Model2016TypeMPVEngine1.5LCylinder4 CylindersTrans.CVTFuel42 LitresFuel Eco-Power105 HpTorque140 NmSafety★★★★★Air Bag3 AirbagsStatusAvailableimage-6099
Toyota Innova (2016)
From RM115,280

RM1263 / Month
Model2016TypeMPVEngine2.0LCylinder4 CylindersTrans.6ATFuel55 LitresFuel Eco-Power136 HpTorque183 NmSafety★★★★★Air Bag7 AirbagsStatusAvailableimage-6063
Toyota Corolla Altis (2016)
From RM120,000

RM1315 / Month
Model2016TypeSedanEngine1.8L / 2.0LCylinder4 CylindersTrans.CVTFuel55 LitresFuel Eco-Power143 HpTorque187 NmSafety★★★★★Air Bag7 AirbagsStatusAvailableimage-6035
Toyota Vios (2018)
From RM77,200

RM845 / Month
Model2018TypeSedanEngine1.5LCylinder4 CylindersTrans.CVTFuel42 LitresFuel Eco-Power105 HpTorque140 NmSafety★★★★★Air Bag7 AirbagsStatusAvailableimage-6015
Toyota Avanza (2015)
From RM80,500

RM882 / Month
Model2015TypeMPVEngine1.5LCylinder4 CylindersTrans.4ATFuel45 LitresFuel Eco-Power103 HpTorque136NmSafety★★★★Air Bag2 AirbagsStatusAvailableimage-5999
Toyota Camry (2018)
From RM189,900

RM2080 / Month
Model2018TypeSedanEngine2.4LCylinder4 CylindersTrans.6ATFuel60 LitresFuel Eco-Power181 HpTorque235 NmSafety-Air Bag7 AirbagsStatusAvailableimage-869No Longer On Sale
Toyota Previa (2013)
From RM247,237
"""

# %%
car = car.split('\n')
cars = []
for i in range(3, len(car), 5):
    cars.append(car[i])
    
len(cars)
# Out:
# 52

# %%
motorcycle = """
image-7451
Honda CBR650R (2019)
From RM45,499

Model2019TypeSports BikeEngine4-Stroke, DOHCCylinder4-CylinderTrans.6-SpeedFuel15.4 LitersFuel Eco-Power94 hpTorque64 NmCC649 CCSpeed-StatusAvailableimage-7431
Honda CB650R (2019)
From RM43,499

Model2019TypeNakedEngine4-Stroke, DOHCCylinder4 CylinderTrans.6-SpeedFuel15.4 LitersFuel Eco-Power94 hpTorque64 NmCC649 CCSpeed-StatusAvailableimage-2451
Honda CBR250R (2017)
From RM21,940

Model2017TypeSport BikeEngine4-Stroke, DOHCCylinder1-CylinderTrans.6-SpeedFuel13 LitersFuel Eco-Power27.1 hpTorque23.3 NmCC249.67 CCSpeed-StatusAvailableimage-2454
Honda CBR1000RR (2017)
From RM144,054

Model2017TypeSport BikeEngine4-Stroke, DOHCCylinder4-CylinderTrans.6-SpeedFuel17.7 LitersFuel Eco5.57L/100kmPower175.6 hpTorque112 NmCC999.8 CCSpeed-StatusAvailableimage-2441
Honda NSS300 (2017)
From RM30,727

Model2017TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.AutomaticFuel11.6 LitersFuel Eco-Power25.4 hpTorque26 NmCC279 CCSpeed-StatusAvailableimage-2433
Honda NC750X (2014)
From RM54,998

Model2014TypeTouringEngine4-Stroke, SOHCCylinder2-CylinderTrans.6-SpeedFuel14.1 LitersFuel Eco28.9 km/LPower54 hpTorque68 NmCC745 CCSpeed-StatusAvailableimage-2420
Honda Rebel (2017)
From RM31,798

Model2017TypeCruiserEngine4-Stroke, DOHCCylinder2-CylinderTrans.6-SpeedFuel11.2 LitersFuel Eco-Power45.4 hpTorque44.7 NmCC471.03 CCSpeed-StatusAvailableimage-2408
Honda Air Blade (2013)
From RM7,700

Model2013TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.AutomaticFuel4.1 LitersFuel Eco-Power10.99 hpTorque11.2 NmCC124.88 CCSpeed-StatusAvailableimage-2398
Honda Spacy (2016)
From RM4,999

Model2016TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.AutomaticFuel5.2 LitersFuel Eco41.5 km/LPower8.6 hpTorque8.27 NmCC108 CCSpeed-StatusAvailableimage-2296
Honda Beat (2018)
From RM5,724

Model2018TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.AutomaticFuel4.0 LitersFuel Eco-Power8.0 hpTorque9.14 NmCC108.20 CCSpeed-StatusAvailableimage-2338
Honda MSX-125 (2017)
From RM11,128

Model2017TypeNakedEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel5.7 LitresFuel Eco-Power9.7 hpTorque11 NmCC125 CCSpeed-StatusAvailableimage-2233
Honda PCX (2017)
From RM11,658

Model2017TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.AutomaticFuel8.0 LitersFuel Eco45 - 50 km/LPower12.5 hpTorque13 NmCC149 CCSpeed110 km/jStatusAvailableimage-2224
Honda Wave 125i (2017)
From RM6,263

Model2017TypeUnderboneEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel5.4 LitersFuel Eco55 km/LPower9.1 hpTorque10.08 NmCC124.9 CCSpeed111 km/jStatusAvailableimage-2215
Honda Wave Dash (2017)
From RM5,860

Model2017TypeUnderboneEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel4.0 LitersFuel Eco61.1 km/LPower8.5 hpTorque11.61 NmCC109 CCSpeed100 - 110 km/jStatusAvailableimage-2207
Honda Wave Alpha (2017)
From RM4,535

Model2017TypeUnderboneEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel3.7 LitersFuel Eco53 km/LPowerTorqueCC109.17 CCSpeed100 - 105 km/jStatusAvailableimage-2070
Honda Future FI (2016)
From RM6,072

image-3886
Modenas Dominar D400 (2018)
From RM14,615

Model2018TypeTouringEngine4-stroke, SOHCCylinder1-CylinderTrans.6-speedFuel13 LitersFuel Eco-Power34.5 hpTorque35 NmCC373.3 CCSpeed-StatusAvailableimage-2283
Modenas Kriss MR2 (2017)
From RM4,123

Model2017TypeUnderboneEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel4.5 LitersFuel Eco48 km/LPower8.3 hpTorque8.2 NmCC109.2 CCSpeed100 km/jStatusAvailableimage-2269
Modenas V15 (2017)
From RM5,989

Model2017TypeCruiserEngine4-Stroke, SOHCCylinder1-CylinderTrans.5-SpeedFuel13 LitersFuel Eco57 km/LPower11.80 bhpTorque13 NmCC149.5 CCSpeed110 - 120 km/jStatusAvailableimage-2256
Modenas Pulsar RS200 (2017)
From RM11,342

Model2017TypeSport BikeEngine4-Stroke, SOHCCylinder1-CylinderTrans.6-SpeedFuel13 LitersFuel Eco50 km/LPower24.2 hpTorque18.6 NmCC199.5 CCSpeed148 - 153 km/jStatusAvailableimage-2243
Modenas Pulsar NS200 (2017)
From RM9,222

Model2017TypeNakedEngine4-Stroke, SOHCCylinder1-CylinderTrans.6-SpeedFuel12 LitersFuel Eco50 km/LPower24.2 hpTorque18.6 NmCC199.5 CCSpeed148 - 153 km/jStatusAvailableimage-1500
Modenas CT115s (2015)
From RM4,988

Model2015TypeUnderboneEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel4.8 LitersFuel Eco2.14L / 100KmPowerTorqueCC114.8 CCSpeedStatusAvailableimage-1487
Modenas CT110 (2009)
From RM3,888

Model2009TypeUnderboneEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel5.3 LitersFuel Eco2.13L / 100KmPowerTorqueCC111 CCSpeedStatusAvailableimage-1477
Modenas Karisma 125 (2017)
From RM5,278

Model2017TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.CVTFuel4.6 LitersFuel Eco-PowerTorqueCC124.66 CCSpeedStatusAvailableimage-1452
Modenas Elegan 250 (2017)
From RM13,599

Model2017TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.CVTFuel12.5 LitresFuel Eco-PowerTorqueCC249.1 CCSpeedStatusAvailableimage-1133
Modenas MR1 (2011)
From RM3,300

Model2011TypeUnderboneEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel4.3 LitresFuel Eco2.2L / 100KmPowerTorqueCC97.2 CCSpeedStatusAvailableimage-1128
Modenas CT100 (2011)
From RM3,800

Model2011TypeUnderboneEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel5.5 LitresFuel Eco2.1L / 100KmPowerTorqueCC97.2 CCSpeedStatusAvailableimage-1118
Modenas DINAMIK (2011)
From RM6,600

Model2011TypeUnderboneEngine2-Stroke, SOHCCylinder1-CylinderTrans.6-SpeedFuel4.6 LitresFuel Eco-PowerTorqueCC118 CCSpeedStatusAvailableimage-1115
Modenas GT128 (2013)
From RM5,600

Model2013TypeUnderboneEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel4.3 LitresFuel Eco1.6L / 100KmPowerTorqueCC130 CCSpeedStatusAvailableimage-1111
Modenas ACE 115 (2012)
From RM5,000

Model2012TypeUnderboneEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel5.3 LitresFuel Eco2.2L / 100KmPowerTorqueCC120 CCSpeedStatusAvailableimage-1078
Modenas ACE 115 (2013)
From RM5,200

image-1758
Suzuki Belang 150
From RM8,211

Model2009TypeUnderboneEngine4-Stroke, DOHCCylinder1-CylinderTrans.6-SpeedFuel4.9 LitersFuel Eco-Power16 HP / 9.5K rpmTorque12.7 Nm / 9.5K rpmCC147 CCSpeedStatusAvailableimage-1745
Suzuki Shogun Axelo 125
From RM5,358

Model2013TypeUnderboneEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel4.1 LitersFuel Eco-Power-Torque-CC124 CCSpeedStatusAvailableimage-1733
Suzuki Step 125
From RM5,050

Model2010TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.CVTFuel3.7 LitersFuel Eco-Power-Torque-CC124 CCSpeedStatusAvailableimage-1722
Suzuki Gladius
From RM39,900

Model2015TypeNakedEngine4-Stroke, DOHCCylinder2-Cylinder, V-TwinTrans.6-SpeedFuel14.5 LitersFuel Eco-Power71 HP / 9.0K rpmTorque63.1 Nm / 7.6K rpmCC645 CCSpeedStatusAvailableimage-1712
Suzuki GSR-750
From RM53,888

Model2014TypeNakedEngine4-Stroke, DOHCCylinder4-CylinderTrans.6-SpeedFuel17.5 LitersFuel Eco5.2 L/100 kmPowerTorqueCC749 CCSpeedStatusAvailableimage-1701
Suzuki V-Strom 650
From RM41,900

Model2015TypeTouringEngine4-Stroke, DOHCCylinder2-Cylinder, V-TwinTrans.6-SpeedFuel20 LitersFuel Eco-PowerTorqueCC645 CCSpeedStatusAvailableimage-1622
Suzuki V-Strom 1000
From RM79,999

Model2014TypeTouringEngine4-Stroke, DOHCCylinder2-Cylinder, V-TwinTrans.6-SpeedFuel20 LitersFuel Eco5.7 L / 100 kmPowerTorqueCC1037 CCSpeedStatusAvailableimage-1570
Suzuki GSX-R1000
From RM96,900

Model2014TypeSport BikeEngine4-Stroke, DOHCCylinder4-CylinderTrans.6-SpeedFuel17.5 LitersFuel Eco-PowerTorqueCC999 CCSpeedStatusAvailableimage-1582
Suzuki GSX-1250FA
From RM72,900

Model2014TypeSport BikeEngine4-Stroke, DOHCCylinder4-CylinderTrans.6-SpeedFuel19 LitersFuel Eco-PowerTorqueCC1255 CCSpeedStatusAvailableimage-1599
Suzuki GSX-S1000 / S1000F
From RM68,400

Model2015TypeNaked, Sport BikeEngine4-Stroke, DOHCCylinder4-CylinderTrans.6-SpeedFuel17 LitersFuel Eco-PowerTorqueCC999 CCSpeedStatusAvailableimage-1609
Suzuki V-Strom 650XT
From RM43,900

Model2015TypeTouringEngine4-Stroke, DOHCCylinder2-Cylinder, V-TwinTrans.6-SpeedFuel20 LitersFuel Eco-PowerTorqueCC645 CCSpeedStatusAvailableimage-1555
Suzuki Nex
From RM4,218

Model2012TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.CVTFuel3.5 LitersFuel Eco-PowerTorqueCC113 CCSpeedStatusAvailableimage-1545
Suzuki Skydrive 125
From RM5,796

Model2014TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.CVTFuel4.0 LitersFuel Eco-PowerTorqueCC124 CCSpeedStatusAvailableimage-1537
Suzuki Address
From RM4,778

Model2015TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.CVTFuel5.2 LitersFuel Eco1.94L / 100KmPowerTorqueCC113 CCSpeedStatusAvailableimage-1512
Suzuki SV650A
From RM41,128

Model2017TypeNakedEngine4-Stroke, DOHCCylinder2-Cylinder, V-TwinTrans.6-SpeedFuel14.5 LitersFuel Eco3.84L / 100KmPowerTorqueCC645 CCSpeedStatusAvailableimage-1508
Suzuki Hayabusa 2014
From RM99,000

image-7377
Yamaha Y15ZR (2019)
From RM8,168

Model2019TypeUnderbone / MopedEngine4-Stroke, DOHCCylinder1 CylinderTrans.5-SpeedFuel4.2 LitersFuel Eco-Power15.15 hpTorque13.8 NmCC150 CCSpeed-StatusAvailableimage-7284
Yamaha YZF-R25 (2019)
From RM19,998

Model2019TypeSports BikeEngine4-Stroke, DOHCCylinder2 CylinderTrans.6-SpeedFuel14.3 LitersFuel Eco-Power36 hpTorque22.6 NmCC249 CCSpeed-StatusAvailableimage-2039
Yamaha Ego Avantiz (2016)
From RM5,700

Model2016TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.AutomaticFuel4.2 LitersFuel Eco-Power9.4 hpTorque9.6 Nm CC124 CCSpeed-StatusAvailableimage-2028
Yamaha Ego Solariz (2017)
From RM5,548

Model2017TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.AutomaticFuel4.2 LitersFuel Eco-Power9.4 hpTorque9.6 Nm CC125 CCSpeed-StatusAvailableimage-2016
Yamaha NMAX (2016)
From RM8,812

Model2016TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.CVTFuel6.6 LitersFuel Eco-Power14.8 hpTorque14.4 NmCC155 CCSpeed-StatusAvailableimage-2004
Yamaha NVX (2017)
From RM10,500

Model2017TypeScooterEngine4-Stroke, SOHCCylinder1-CylinderTrans.AutomaticFuel4.6 LitersFuel Eco-Power14.7 hpTorque13.8 NmCC155 CCSpeed-StatusAvailableimage-1976
Yamaha 135LC (2016)
From RM7,068

Model2016TypeUnderboneEngine4-StrokeCylinder1-CylinderTrans.4-SpeedFuel4.0 LitersFuel Eco-Power12 hpTorque11.79 NmCC134 CCSpeed-StatusAvailableimage-1964
Yamaha 125ZR (2017)
From RM8,361

Model2017TypeUnderboneEngine2-StrokeCylinder1-CylinderTrans.6-SpeedFuel5.5 LitersFuel Eco-Power17.2 hpTorque16.1 NmCC124.3 CCSpeed-StatusAvailableimage-1954
Yamaha Lagenda 115z (2017)
From RM5,683

Model2017TypeUnderboneEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel4.05 LitersFuel Eco-Power9.9 hpTorque9.9 NmCC113.7 CCSpeed-StatusAvailableimage-1943
Yamaha E115M (2015)
From RM4,800

Model2015TypeUnderboneEngine4-Stroke, SOHCCylinder1-CylinderTrans.4-SpeedFuel4.2 LitersFuel Eco-Power7.6 hpTorque8.0 NmCC114 CCSpeed-StatusAvailableimage-1919
Yamaha FZ150i (2014)
From RM9,126

Model2014TypeNakedEngine4-Stroke, SOHCCylinder1-CylinderTrans.5-SpeedFuel12 LitersFuel Eco-Power16.3 hpTorque14.5 NmCC149.8 CCSpeed-StatusAvailableimage-1904
Yamaha XV950R Bolt (2015)
From RM52,500

Model2015TypeCruiserEngine4-Stroke, SOHCCylinder2-CylinderTrans.5-SpeedFuel12 LitersFuel Eco-Power51.4 hpTorque79.5 NmCC942 CCSpeed-StatusAvailableimage-1890
Yamaha MT-09 Tracer (2017)
From RM52,000

Model2017TypeTouringEngine4-Stroke, DOHCCylinder3-CylinderTrans.6-SpeedFuel18 LitersFuel Eco-Power113 hpTorque87.5 NmCC847 CCSpeed-StatusAvailableimage-1880
Yamaha MT-09 (2016)
From RM44,653

Model2016TypeNakedEngine4-Stroke, DOHCCylinder3-CylinderTrans.6-SpeedFuel14 LitersFuel Eco-Power113.4 hpTorque87.5 NmCC847 CCSpeed-StatusAvailableimage-1869
Yamaha MT-07 (2017)
From RM36,795

Model2017TypeNakedEngine4-Stroke, DOHCCylinder2-CylinderTrans.6-SpeedFuel14 LitersFuel Eco-Power73.7 hpTorque68.0 NmCC689 CCSpeed-StatusAvailableimage-1862
Yamaha XJ6 Diversion F (2013)
From RM39,800
"""

# %%
motorcycle = motorcycle.split('\n')
motorcycles = []
for i in range(3, len(motorcycle), 5):
    motorcycles.append(motorcycle[i])
    
len(motorcycle)
# Out:
# 253

# %%
malay = {
    'ambuyat',
    'asam pedas',
    'ayam bakar',
    'ayam goreng',
    'ayam masak kicap',
    'ayam masak merah',
    'bubur asyura',
    'bubur kacang hijau',
    'bubur lambuk',
    'bubur pedas',
    'gulai',
    'ikan bakar',
    'ikan goreng',
    'kangkung belacan',
    'ketupat',
    'laksa',
    'lemang',
    'lontong',
    'mee bandung muar',
    'nasi ambeng',
    'nasi campur',
    'nasi dagang',
    'nasi goreng',
    'nasi goreng pattaya',
    'nasi kerabu',
    'nasi lemak',
    'nasi tumpang',
    'nasi ulam',
    'otak otak',
    'pulot tartal',
    'rendang',
    'rojak',
    'roti jala',
    'satay',
    'satay celup',
    'sup kambing',
    'ulam',
    'nasi ayam',
}

chinese = {
    'bak kut teh',
    'bakkwa',
    'banmian',
    'bean sprouts chicken',
    'bubur pulut hitam',
    'chai tow kway',
    'char kway teow',
    'char siu',
    'chee cheong fun',
    'chwee kueh',
    'claypot chicken rice',
    'duck soup noodles',
    'economy rice',
    'fish ball',
    'hae mee',
    'hainanese chicken rice',
    'hokkien mee',
    'kaya toast',
    'kolo mee',
    'loh bak',
    'lor mee',
    'mee pok',
    'mixed rice',
    'oyster omelette',
    'pan mee',
    'pao',
    'popiah',
    'tong sui',
    'wonton mee',
    'yong tau foo',
    'you char kway',
    'yusheng',
    'asam laksa',
    'bubur cha cha',
    'cap cai',
    'curry mee',
    'laksa lemak',
    'mee siam',
    'nyonya bak chang',
}

indian = {
    'adhirasam',
    'appam',
    'bajji',
    'banana leaf rice',
    'chapati',
    'curd rice',
    'dalcha',
    'dosai',
    'fish head curry',
    'fish molee',
    'idli',
    'korma',
    'maggi goreng',
    'mamak',
    'mee goreng',
    'mee goreng mamak',
    'mee rebus',
    'murtabak',
    'murukku',
    'naan',
    'nasi biryani',
    'nasi kandar',
    'paniyaram',
    'papadum',
    'pasembur',
    'payasam',
    'pongal',
    'puliyodarai',
    'puri',
    'putu mayam',
    'rasam',
    'rojak',
    'roti canai',
    'roti prata',
    'roti tissue',
    'sambar',
    'sup kambing',
    'upma',
    'vadai',
}

sabah_sarawak = {
    'bosou',
    'hinava',
    'linatan',
    'linongot',
    'manok pansoh',
    'midin',
    'nasi kombos',
    'nasi laru',
    'nasik aruk',
    'sinalau bakas',
    'tonokon',
    'tuhau',
    'umai',
}

kuih = {
    'ang ku',
    'bahulu',
    'kek batik',
    'heong peng',
    'kek sarawak',
    'amplang',
    'lekor',
    'mee siput muar',
    'rempeyek',
    'apam balik',
    'bingka',
    'borasa',
    'cakoi',
    'kuih cincin',
    'cucur',
    'dodol',
    'kuih gelang',
    'kuih jala',
    'kuih jelurut',
    'kuih jemput jemput',
    'karipap',
    'kuih kelupis',
    'kochi',
    'penyaram',
    'pisang goreng',
    'kuih gulung',
    'kuih kasturi',
    'kuih lapis',
    'kuih lidah',
    'kuih makmur',
    'ondeh ondeh',
    'otokon',
    'kuih pais',
    'pie tee',
    'pulut inti',
    'pulut panggang',
    'putu bambu',
    'putu bumbong',
    'putu mangkuk',
    'kuih gulong',
    'kuih kapit',
    'kuih sapit',
    'seri muka',
}

dessert = {'lamban', 'punjung', 'tapai', 'wajid'}

unique_beverage = {
    'ais kacang',
    'asam boi',
    'leng chee kang',
    'barley ais',
    'tau hua',
    'cendol',
    'bubur cha bha',
    'tong sui',
    'tealive',
    'bubble tea',
    'milk tea',
    'chatime',
    'boba',
    'laici kang',
}

indonesian = {
    'acar',
    'ayam bakar',
    'ayam goreng',
    'ayam kecap',
    'bubur ayam',
    'bubur kacang hijau',
    'bubur ketan hitam',
    'gado gado',
    'ikan asin',
    'ikan bakar',
    'ikan goreng',
    'ketupat',
    'lontong',
    'nasi bakar',
    'nasi campur',
    'nasi goreng',
    'nasi kuning',
    'otak otak',
    'perkedel',
    'pindang',
    'rijsttafel',
    'rujak',
    'sambal',
    'sambal goreng udang',
    'sate',
    'semur',
    'sop buntut',
    'soto',
    'soto mie',
    'tahu goreng',
    'telur pindang',
    'tempeh goreng',
    'tempe goreng',
    'tumis kangkung',
}

acehnese = {'mie aceh', 'mie caluk', 'nasi gurih', 'roti canai', 'timphan'}

balinese = {'babi guling', 'betutu', 'lawar', 'nasi bali', 'sate lilit'}

bataknese = {
    'arsik',
    'babi panggang',
    'bentidali ni horbo',
    'dengke mas na niura',
    'itak gurgur',
    'lampet',
    'manuk napinadar',
    'na nidugu',
    'na tinombur',
    'ombusombus',
    'pohulpohul',
    'saksang',
    'sambal',
    'sasagun',
    'tanggotanggo',
    'tipatipa',
    'tuktuk',
}

betawi = {
    'asinan betawi',
    'kerak telor',
    'ketoprak',
    'ketupat sayur',
    'laksa betawi',
    'mie kangkung',
    'nasi uduk',
    'nasi ulam',
    'soto betawi',
}

bugis_makassar = {
    'burasa',
    'coto makassar',
    'gogos',
    'kapurung',
    'konro',
    'pallubasa',
    'sop saudara',
}

cirebonese = {
    'docang',
    'empal gentong',
    'mie koclok',
    'sega jamblang',
    'sega lengko',
    'tahu gejrot',
}

chinese_peranakan = {
    'babi kecap',
    'bakmi',
    'bakpau',
    'bakso',
    'cap cai',
    'fu yung hai',
    'i fu mie',
    'kepiting saus tiram',
    'kwetiau goreng',
    'laksa',
    'lontong cap go meh',
    'lumpia',
    'mie ayam',
    'mie goreng',
    'mie kering',
    'mun tahu',
    'nasi tim',
    'sapo tahu',
    'sekba',
    'siomay',
    'swikee',
}

javanese = {
    'ayam penyet',
    'botok',
    'buntil',
    'gudeg',
    'iga penyet',
    'krechek',
    'kuluban',
    'mie jawa',
    'mie rebus',
    'nasi ambeng',
    'nasi bogana',
    'nasi kucing',
    'nasi liwet',
    'nasi pecel',
    'opor',
    'pecel',
    'pecel lele',
    'rambak petis',
    'rawon',
    'sayur lodeh',
    'selat solo',
    'serundeng',
    'tahu campur',
    'tongseng',
    'trancam',
    'tumpeng',
    'urap',
}

minangkabau = {
    'asam pedas',
    'balado',
    'dendeng',
    'galamai',
    'gulai',
    'kepiting saus padang',
    'keripik sanjay',
    'lemang',
    'nasi kapau',
    'nasi padang',
    'rendang',
    'sate padang',
    'soto padang',
    'udang balado',
}

palembang = {
    'burgo',
    'laksan',
    'lakso',
    'mie celor',
    'nasi minyak',
    'pempek',
    'pindang',
    'tekwan',
    'tempoyak',
}

sasak = {'ayam taliwang', 'beberuk terong', 'plecing kangkung'}

sundanese = {
    'asinan bogor',
    'bandung',
    'batagor',
    'empal gepuk',
    'karedok',
    'kupat tahu',
    'laksa bogor',
    'lalab',
    'mie kocok',
    'nasi timbel',
    'oncom',
    'pepes',
    'sate bandeng',
    'sayur asem',
    'seblak',
    'soto',
    'tahu sumedang',
    'tauge goreng',
}

middle_eastern = {
    'hummus',
    'manakeesh',
    'halloumi',
    'meddamas',
    'falafel',
    'tabouleh',
    'moutabal',
    'ghanoush',
    'fattoush',
    'ummali',
    'shanklish',
    'shawarma',
    'tawook',
    'dolma',
    'kofta',
    'quwarmah',
    'mansaf',
    'kebab',
    'baklava',
    'knafeh',
    'masgouf',
}

american = {
    'hotdog',
    'pie',
    'cookie',
    'cobbler',
    'nacho',
    'stew',
    'barbecue',
    'lime pie',
    'tots',
    'tater',
    'sourdough',
    'cobb',
    'salad',
    'pot roast',
    'twinkies',
    'jerky',
    'fajitas',
    'banana split',
    'cornbread',
    'jambalaya',
    'steak',
    'salmon',
    'meatloaf',
    'grit',
    'macaroni',
    'cheese',
    'crabcake',
    'chip',
    'cioppino',
    'bean',
    'popcorn',
    'ayam goreng',
    'fried chicken',
    'waffle',
}

italian = {
    'pizza',
    'focaccia',
    'carbonara',
    'pizza',
    'risotto',
    'pasta',
    'noodle',
    'tiramisu',
    'lasagne',
}

malaysian_food = malay | chinese | indian | sabah_sarawak | kuih | dessert

indonesian_food = (
    indonesian
    | acehnese
    | balinese
    | bataknese
    | betawi
    | bugis_makassar
    | cirebonese
    | chinese_peranakan
    | javanese
    | minangkabau
    | palembang
    | sasak
    | sundanese
)

data = (
    malaysian_food | indonesian_food | american | italian | middle_eastern
)

total_foods = list(data)
total_foods.extend([i.title() for i in data])
len(total_foods)
# Out:
# 778

# %%
results = []
i = 0
while i < len(entities['label']):
    r = []
    if entities['label'][i] == 'PRODUCT':
        while entities['label'][i] == 'PRODUCT':
            r.append(i)
            i += 1
        results.append(r)
    i += 1
    
len(results)
# Out:
# 1071

# %%
product = total_foods + motorcycles + cars

# %%
import math
import numpy as np

def generate_index(l, name, texts, labels, length):
    cp, indices = [], []
    b = length - len(l)
    left = math.ceil(b / 2)
    right = b - left
    minus = l[0] - left
    if minus < 0:
        absolute = np.abs(minus)
        right += absolute
        left -= absolute

    for i in range(l[0] - left, l[0]):
        cp.append(texts[i])
        indices.append(labels[i])

    cp.extend(name)
    indices.extend([labels[l[0]] for _ in range(len(name))])
    try:
        for i in range(l[-1] + 1, l[-1] + right + 1):
            cp.append(texts[i])
            indices.append(labels[i])
    except Exception as e:
        print(e)
        pass
    
    return cp, indices

# %%
train_results, test_results = train_test_split(results, test_size = 0.2)
train_product, test_product = train_test_split(product, test_size = 0.2)

# %%
train_X, train_Y = [], []

repeat = 10
for t in train_product:
    for i in range(repeat):
        x, y = generate_index(train_results[random.randint(0, len(train_results) - 1)], 
                              t.split(), entities['text'], entities['label'], 50)
        if len(x) != len(y):
            print('len not same')
            continue
        train_X.append(x)
        train_Y.append(y)
            
len(train_X)
# Out:
# 7040

# %%
test_X, test_Y = [], []

repeat = 10
for t in test_product:
    for i in range(repeat):
        x, y = generate_index(test_results[random.randint(0, len(test_results) - 1)], 
                              t.split(), entities['text'], entities['label'], 50)
        if len(x) != len(y):
            print('len not same')
            continue
        test_X.append(x)
        test_Y.append(y)
            
len(test_X)
# Out:
# 1760

# %%
len(train_X), len(test_X)
# Out:
# (7040, 1760)

# %%
with open('augmentation-product-ontonotes5.json', 'w') as fopen:
    json.dump({'train_X': train_X, 'train_Y': train_Y,
              'test_X': test_X, 'test_Y': test_Y}, fopen)
