# %%
# !wget https://f000.backblazeb2.com/file/malay-dataset/tagging/ontonotes5/processed-ontonotes5.json

# %%
import json
from sklearn.model_selection import train_test_split
import random

# %%
with open('processed-ontonotes5.json') as fopen:
    data = json.load(fopen)

# %%
from collections import defaultdict

entities = defaultdict(list)
for i in data:
    entities['text'].append(i[0])
    entities['label'].append(i[1])

# %%
# !wget https://raw.githubusercontent.com/nizulzaim/json-malaysia-postalcode/master/postalcode.json

# %%
with open('postalcode.json') as fopen:
    postal = json.load(fopen)

# %%
def generate_address(row):
    return [f"{row['place']}, {row['code']}, {row['city']}",
           f"{row['place']}, {row['code']}, {row['city']} {row['state']}"]

# %%
addresses = []

for row in postal['data']:
    addresses.extend(generate_address(row))
    
addresses = list(set(addresses))
    
len(addresses)
# Out:
# 108056

# %%
addresses
# Out:
# ['Jalan Pasir Belanda, 11920, Bayan Lepas',
#  'Serian - Beg Berkunci, 94709, Serian Sarawak',
#  'Jalan (U1/89A - U1/89E), 40150, Shah Alam Selangor',
#  'Kampung Telaga Gajah, 15350, Kota Bharu',
#  'Persiaran Stonor, 50450, Kuala Lumpur WP Kuala Lumpur',
#  'Bintangor - Beg Berkunci, 96509, Bintangor Sarawak',
#  'Bintulu - Peti Surat \xa0(2501 - 3000), 97012, Bintulu',
#  'Kampung Lanterom, 06050, Bukit Kayu Hitam',
#  'Lengkok Harimau, 31400, Ipoh Perak',
#  'Ladang St Helier, 72100, Bahau Negeri Sembilan',
#  'Taman Jalan Galing, 25250, Kuantan',
#  'Taman Segamat Baru, 85000, Segamat Johor',
#  'Kampung Padang, 09100, Baling',
#  'Kampung Sukamari Lubok Merbau, 06710, Pendang Kedah',
#  'Kampung Tanjong (Tawang), 16020, Bachok Kelantan',
#  'Jalan 1/108C (Salak Selatan), 57100, Kuala Lumpur WP Kuala Lumpur',
#  'Taman Ulu Bendol, 71500, Tanjong Ipoh',
#  'Taman Bukit Indah (Fasa H & Fasa E), 07000, Langkawi',
#  'Bersia (Km 10), 33320, Gerik',
#  'Jalan Cempaka SD 12/5, 52200, Kuala Lumpur WP Kuala Lumpur',
#  'Seri Menanti - Beg berkunci, 71559, Tanjong Ipoh',
#  'Parit Pulai, 83500, Parit Sulong',
#  'Jalan Satu Tanjong Tokong, 10470, Pulau Pinang Pulau Pinang',
#  'Kampung Losong Haji Wan Nawang, 21000, Kuala Terengganu Terengganu',
#  'Kampung Tali Ayer, 32600, Bota',
#  'Seri Taman, 31100, Sungai Siput Perak',
#  'Kampung Padang Wat, 06250, Alor Setar',
#  'Kampung Binjai Badang, 15350, Kota Bharu',
#  'Jalan Pulau Semut, 78300, Masjid Tanah Melaka',
#  'Taman Dahlia Indah, 71700, Mantin',
#  'Ampang Prima Condominium, 68000, Ampang Selangor',
#  'Kampung Sedu, 08200, Sik Kedah',
#  'Kampung Tanjong Siam, 06300, Kuala Nerang',
#  'Kampung Chong, 08200, Sik Kedah',
#  'Lorong Penaga 34, 13100, Penaga',
#  'Bukit Rotan (Km 1), 45700, Bukit Rotan',
#  'Kampung Sungai Kering, 06910, Yan Kedah',
#  'Taman Aman, 25250, Kuantan Pahang',
#  'Kampung Lahar Yooi, 13300, Tasek Gelugor',
#  'Perumahan Pelindung Maju, 26100, Kuantan Pahang',
#  'Kampung Ratau, 88450, Kota Kinabalu',
#  'Kampung Tanjong Paya, 20000, Kuala Terengganu',
#  'Kampung Kuala Sedim, 09400, Padang Serai',
#  'Padang Lembu, 08330, Gurun Kedah',
#  'Kampung Cheh Melayu, 31250, Tanjong Rambutan Perak',
#  'Jalan Belatuk, 14300, Nibong Tebal Pulau Pinang',
#  'Lintang Penawar (1 - 3), 11600, Jelutong Pulau Pinang',
#  'Taman Rumpon Bahagia, 75300, Melaka Melaka',
#  'Taman Sonia, 93050, Kuching',
#  'Taman Perindustrian Selayang Indah , 68100, Batu Caves',
#  'Bakar Arang, 08000, Sungai Petani Kedah',
#  'Taman Senibena Ph 1 Dan Ph 2, 88300, Kota Kinabalu Sabah',
#  'Jalan Asa, 80350, Johor Bahru',
#  'Taman Kota Mas, 83700, Yong Peng',
#  'Lorong Chelagi, 50490, Kuala Lumpur WP Kuala Lumpur',
#  'Apartment Bay Shore, 88400, Kota Kinabalu',
#  'Lorong Birch, 10250, Pulau Pinang',
#  'Taman Koh Cheng San, 85000, Segamat Johor',
#  'Jalan Tugu, 50050, Kuala Lumpur',
#  'Kampung Badengan, 96400, Mukah Sarawak',
#  'Taman Damai RPA 2, 33100, Pengkalan Hulu',
#  'Ketari, 28700, Bentong Pahang',
#  'Kampung Paya Kemian (Kedah), 14200, Sungai Jawi',
#  'Lorong Oh Cheng Kiat, 30350, Ipoh Perak',
#  'Jabatan Penilaian Harta, 10593, Pulau Pinang Pulau Pinang',
#  'Kampung Lepan Rambai, 16800, Pasir Puteh',
#  'Kampung Sungai Semut, 34100, Selama',
#  'Jalan Sejat 8/10, 40000, Shah Alam',
#  'Taman Nusa Indah Tropicana, 79100, Nusajaya',
#  'Kampung Ng Malong, 95400, Saratok',
#  'Kampung Kepala Pulau, 36800, Kampung Gajah',
#  'Jalan Abiad (1-8), 80400, Johor Bahru',
#  'Kampung Pulau Tapak, 72200, Batu Kikir Negeri Sembilan',
#  'Jalan 15, 88000, Kota Kinabalu Sabah',
#  'Wayton Flat, 11600, Jelutong',
#  'Jalan Mohd Noor, 80000, Johor Bahru',
#  'Kampung Parit Pasir Lama, 81500, Pekan Nenas Johor',
#  'Taman Beting Indah, 84000, Muar',
#  'Kompleks Sukan Bangsar, 59100, Kuala Lumpur WP Kuala Lumpur',
#  'Kampung Tengah, 71900, Labu',
#  'Batu 8, Jalan Pekan, 25150, Kuantan',
#  'Kampung Batu Tiga, 05460, Alor Setar',
#  'Kampung Belia, 34800, Trong',
#  'Kampung Batu 17 3/4, 84600, Pagoh',
#  'Jalan Dutamas 1, 50480, Kuala Lumpur WP Kuala Lumpur',
#  'Ladang Sungai Burung, 81500, Pekan Nenas Johor',
#  'Kampung Banggol Che Dol, 17000, Pasir Mas Kelantan',
#  'Jalan Sri Indah, 13200, Kepala Batas',
#  'Jalan Belakang Klinik, 16050, Bachok Kelantan',
#  'Kampung Stesyen, 16200, Tumpat',
#  'Kampung Binjai, 16800, Pasir Puteh Kelantan',
#  'Ladang Johol, 73100, Johol',
#  'Tambun \xa0Indah, 14100, Simpang Ampat',
#  'Jalan Kubur Kadok, 16450, Ketereh Kelantan',
#  'Gunung Mesah Hilir, 31600, Gopeng',
#  'Jalan Merak, 41050, Klang Selangor',
#  'Jalan Bunga Raya, 77300, Merlimau Melaka',
#  'Lorong Bintang, 13000, Butterworth Pulau Pinang',
#  'Lembaga Tembakau Negara, 20400, Kuala Terengganu',
#  'Taman Rotan Tunggal, 27600, Raub',
#  'Jalan Cegar, 14100, Simpang Ampat Pulau Pinang',
#  'Melaka - Peti surat 225 - 299, 75750, Melaka Melaka',
#  'Kampung Bachang Pasir Putih, 75350, Melaka Melaka',
#  'Jalan Low Hee Kong, 75050, Melaka',
#  'Kampung Kertas Pulas, 23050, Dungun Terengganu',
#  'Kampung Sungai Puloh, 42100, Klang',
#  'Taman Judy, 88450, Kota Kinabalu Sabah',
#  'Kampung Laut, 21080, Kuala Terengganu',
#  'Jalan Menteri, 30020, Ipoh',
#  'Jalan Negeri Sembilan, 50480, Kuala Lumpur WP Kuala Lumpur',
#  'YAB Menteri Besar Pahang, 25502, Kuantan Pahang',
#  'Taman Pantai Timur, 86800, Mersing',
#  'Bakong, 96500, Bintangor Sarawak',
#  'Jalan Manan, 16800, Pasir Puteh',
#  'Kampung Padang Mengkali, 16400, Melor',
#  'Taman Sri Mahkota, 26070, Kuantan',
#  'Labuan - Peti surat 81701 - 81800, 87027, Labuan',
#  'Puncak Tambun Indah, 31400, Ipoh Perak',
#  'Jalan Ikhlas, 80100, Johor Bahru',
#  'Taman Nering Jaya, 17200, Rantau Panjang',
#  'Parit Osman Kanan, 84300, Bukit Pasir Johor',
#  'Ladang Sungai Rinching, 43500, Semenyih Selangor',
#  'Taman Permata, 16800, Pasir Puteh Kelantan',
#  'Kampung Kubang Keli, 17060, Pasir Mas Kelantan',
#  'Kampung Aman, 16310, Bachok',
#  'Parit Haji Ahmad, 82100, Ayer Baloi Johor',
#  'Parit 6 Sungai Balai Baroh, 36100, Bagan Datoh',
#  'Jalan Raja Nala, 45000, Kuala Selangor',
#  'Taman Tiara 1, 84900, Tangkak Johor',
#  'Jalan Tengku Zainon Rashid, 41000, Klang',
#  'Jalan PJS 8/15, 46150, Petaling Jaya',
#  'Taman Cowin, 14300, Nibong Tebal Pulau Pinang',
#  'Lorong Haji Taib, 36600, Chenderong Balai Perak',
#  'Taman Umikalthom, 16450, Ketereh Kelantan',
#  'Pudu - Peti surat 6101, 55910, Kuala Lumpur',
#  'Jalan Tunku Dalam, 50480, Kuala Lumpur',
#  'Kampung Sekor, 26600, Pekan Pahang',
#  'Jalan Jambu, 41100, Klang Selangor',
#  'Kampung Duyun Haji Umar, 21300, Kuala Terengganu',
#  'Kampung Tepoh, 21060, Kuala Terengganu Terengganu',
#  'Jalan Merbuk, 14300, Nibong Tebal Pulau Pinang',
#  'Bandar Ayer, 36810, Kampung Gajah',
#  'Kampung Kedap, 17200, Rantau Panjang',
#  'Lebuh Melayu, 10100, Pulau Pinang Pulau Pinang',
#  'Taman Sunrise, 31400, Ipoh',
#  'Kampung Peris, 21800, Ajil Terengganu',
#  'Bahagian Pelesenan - Kementerian Penerangan, 40610, Shah Alam Selangor',
#  'Kampung Telok Baharu, 26060, Kuantan Pahang',
#  'Kampung Krisna, 84600, Pagoh Johor',
#  'Sentul - Peti surat 1 & ke atas, 51700, Kuala Lumpur',
#  'Jalan Cengkerik, 81200, Johor Bahru',
#  'Tenang, 85000, Segamat',
#  'Kota Kinabalu - Peti surat 13271 - 13360, 88837, Kota Kinabalu Sabah',
#  'Institut Tahfiz, 73200, Gemencheh',
#  'Kampung Bukit Damar, 27200, Kuala Lipis',
#  'Medan Kikik (1 - 3), 13600, Perai',
#  'Lorong Bukit Ubi 16, 25200, Kuantan',
#  'Kampung Felcra Kok, 07000, Langkawi Kedah',
#  'Jalan Sungai Pari (Buntong), 30100, Ipoh',
#  'Batu Settlement, 51100, Kuala Lumpur WP Kuala Lumpur',
#  'Kampung Embun, 28000, Temerloh Pahang',
#  'Taman Mewah, 31400, Ipoh Perak',
#  'Titi Tiga, 33000, Kuala Kangsar Perak',
#  'Jalan Tenang Dua 25/54B, 40400, Shah Alam',
#  'Taman Summerglades, 63000, Cyberjaya',
#  'Taman Indah, 14000, Bukit Mertajam',
#  'Kampung Parit Gantong, 83000, Batu Pahat Johor',
#  'Jalan Nibung 18/36, 40200, Shah Alam Selangor',
#  'Batas Ban Jalan Baru, 14320, Nibong Tebal',
#  'Jalan Serindit, 51100, Kuala Lumpur WP Kuala Lumpur',
#  'Taman Desa Anggerik, 09100, Baling',
#  'Taman Perindustrian 3, 14300, Nibong Tebal Pulau Pinang',
#  'Lebuh Masjid, 10200, Pulau Pinang',
#  'Jalan Rokam, 31350, Ipoh Perak',
#  'Kampung Simpang Sekolah Batu 8, 35950, Behrang Stesen',
#  'Lorong Nuri, 05100, Alor Setar Kedah',
#  'Jalan Limau Purut 4/4D, 40000, Shah Alam Selangor',
#  'Jalan Danau Lumayan, 56000, Kuala Lumpur',
#  'Lorong Chetty, 10300, Pulau Pinang Pulau Pinang',
#  'Kampung Tok Sumbing, 01000, Kangar Perlis',
#  'Taman Sejati, 85300, Labis',
#  'Lengkok Batu Bungkal, 30250, Ipoh Perak',
#  'Tingkat Cantik (1- 10), 13400, Butterworth Pulau Pinang',
#  'Bukit Keladang, 28200, Bandar Bera',
#  'Taman Permai, 72000, Kuala Pilah',
#  'Kampung Sengkang (A - C), 71250, Si Rusa',
#  'Kaw. Perdagangan Bebas Senai, 81400, Senai Johor',
#  'Taman Desa Harta Ria, 82000, Pontian',
#  'Kampung Lubok Pukul, 16150, Kota Bharu',
#  'Kampung Paya Menanti, 75460, Melaka Melaka',
#  'Jalan Kolam Air, 81900, Kota Tinggi',
#  'Sekolah Menengah Muadzam Shah, 26700, Muadzam Shah',
#  'Kampung Padang Nyior, 17200, Rantau Panjang',
#  'Jawi Sempit, 14100, Simpang Ampat',
#  'Jalan Nagasari, 13600, Perai Pulau Pinang',
#  'Taman Chit Long, 35500, Bidor Perak',
#  'Lorong Industri (1, 2, 12), 14000, Bukit Mertajam',
#  'Taman Sri Jenerih, 17500, Tanah Merah',
#  'Kampung Sungai Landak, 70400, Seremban Negeri Sembilan',
#  'Lembaga Pelesenan Pengangkutan Jalan, 50653, Kuala Lumpur WP Kuala Lumpur',
#  'Kampung Tok Ga, 16450, Ketereh Kelantan',
#  'Lorong Merdeka, 05400, Alor Setar',
#  'Sungai Ati, 33700, Padang Rengas Perak',
#  'Kampung Raja Besut, 22200, Kampung Raja',
#  'Taman Intan, 09110, Kuala Pegang Kedah',
#  'Kampung Kedup, 17200, Rantau Panjang Kelantan',
#  'Tanjong Leman, 86800, Mersing Johor',
#  'Jalan Kemuning Bayu 33/32A, 40400, Shah Alam Selangor',
#  'Jalan Carey, 46000, Petaling Jaya',
#  'Taman Bukit Serdang Seksyen 11, 43300, Seri Kembangan Selangor',
#  'Jalan Bukit Tempurung 27/85, 40400, Shah Alam',
#  'Tawau - Peti surat 61001 - 61100, 91020, Tawau',
#  'Kampung Kolopis, 89500, Penampang Sabah',
#  'Kampung Sempadan, 81750, Masai Johor',
#  'Taman Puteri, 84900, Tangkak Johor',
#  'Taman Selesa, 14300, Nibong Tebal Pulau Pinang',
#  'Jalan Besi Kawi, 80200, Johor Bahru',
#  'Kampung Naiteh, 06300, Kuala Nerang Kedah',
#  'Taman Indah (Sungai Abong), 84000, Muar',
#  'Taman Murni Jalan Pengkalan Chepa, 15400, Kota Bharu',
#  'Tingkat Berani Dua, 12300, Butterworth Pulau Pinang',
#  'Lorong IKS Bukit Tengah, 14000, Bukit Mertajam Pulau Pinang',
#  'Jalan Pulau Angsa (U10/36A - U10/36E), 40170, Shah Alam Selangor',
#  'Kampung Lor, 31100, Sungai Siput Perak',
#  'Kampung Padang Ubi, 09010, Kulim Kedah',
#  'Batu Gelugor, 34510, Batu Kurau Perak',
#  'Jalan Sutradara U2/16, 40150, Shah Alam Selangor',
#  'Jalan Seri Nibong, 42100, Klang Selangor',
#  'Kampung Bongek Tengah, 71300, Rembau',
#  'Kampung Ulu Pauh, 02600, Arau Perlis',
#  'Taman Selera, 14000, Bukit Mertajam',
#  'Taman Jelutang Fasa 2, 06300, Kuala Nerang',
#  'Jalan Jintan Putih 16/10C, 40200, Shah Alam Selangor',
#  'Taman Kantan Permata, 43000, Kajang Selangor',
#  'Jalan Platinum (7/43A 7/43E), 40000, Shah Alam Selangor',
#  'Kampung Cherakoh, 33030, Kuala Kangsar Perak',
#  'Lorong Kubur Bunut, 15200, Kota Bharu',
#  'Jalan Sepat Satu 17/57A, 40200, Shah Alam Selangor',
#  'Jalan Bachok, 16050, Bachok Kelantan',
#  'Sebak Sena, 84400, Sungai Mati',
#  'Kampung Jaya Setia, 31100, Sungai Siput Perak',
#  'Kampung Bukit Pegoh, 75460, Melaka Melaka',
#  'Kampung Belukar Cabang, 15150, Kota Bharu Kelantan',
#  'Kampung Tangkoh Hilir, 73100, Johol Negeri Sembilan',
#  'South Fence Road, 52000, Kuala Lumpur',
#  'Kampung Lepan Kala, 18000, Kuala Krai',
#  'Taman Kayu Manis, 71770, Seremban',
#  'Kampung Tok Hamid, 13220, Kepala Batas',
#  'Kampung Baru, 73400, Gemas',
#  'Jalan SS 7/26, 47301, Petaling Jaya',
#  'Kampung Pagar Sasak, 27100, Padang Tengku',
#  'Kampung Titip, 42800, Tanjong Sepat',
#  'Bay View Height, 88400, Kota Kinabalu',
#  'Tok Kong Batu Tangga, 73100, Johol Negeri Sembilan',
#  'Jalan Rama-Rama Enam 20/2F, 40300, Shah Alam',
#  'Sungai Gerisek Darat, 83600, Semerah Johor',
#  'Kuala Pilah - Peti surat, 72007, Kuala Pilah',
#  'Jalan Balai Polis (Sungai Besi), 57000, Kuala Lumpur WP Kuala Lumpur',
#  'Lembaga Pelabuhan Teluk Sepagar, 88450, Kota Kinabalu',
#  'Taman Muhibah, 30100, Ipoh Perak',
#  'Lebuh Hishamudin, 42000, Pelabuhan Klang',
#  'Jalan Ladang Juru, 14100, Simpang Ampat Pulau Pinang',
#  'Kampung Sungai Durian, 26090, Bukit Goh Pahang',
#  'Kampung Mahkota, 26070, Kuantan',
#  'Taman Abadi Indah, 58100, Kuala Lumpur WP Kuala Lumpur',
#  'Kampung Lembah, 47190, Puchong',
#  'Jalan Tey Ching Swee, 85000, Segamat Johor',
#  'Kawasan Perusahan IGB, 31200, Chemor',
#  'Jalan Kunang-Kunang 20/8, 40300, Shah Alam Selangor',
#  'Jalan Sungai Duri, 14200, Sungai Jawi',
#  'Taman Mata Air 3 (RPA), 02500, Kangar Perlis',
#  'Taman Mesra, 16100, Kota Bharu',
#  'Parit Belukar China, 84000, Muar Johor',
#  'Lorong Rani, 30350, Ipoh Perak',
#  'Kampung Ulu Rembang Panas, 72500, Kuala Pilah',
#  'Jalan Gajah Mati, 14020, Bukit Mertajam Pulau Pinang',
#  'Kampung Pasir Debu, 34950, Bandar Baharu',
#  'Kampung Bukit Haji Omar, 08400, Merbok',
#  'Sungai Malau, 34130, Selama',
#  'Kampung Plang, 33310, Gerik',
#  'Kampung Panchor, 32600, Bota Perak',
#  'Perumahan Cempaka Aman, 26060, Kuantan',
#  'Kampung Ceruk Merbau, 33100, Pengkalan Hulu Perak',
#  'Kampung Temin Tengah, 31100, Sungai Siput',
#  'Lorong 1 - 4 (Ujong Pasir), 75050, Melaka Melaka',
#  'Jalan Foo Aun Choon, 31650, Ipoh',
#  'Taman Tiara, 81800, Ulu Tiram',
#  'Kampung Lubok Kiab, 08000, Sungai Petani',
#  'Kampung Tandop, 09100, Baling',
#  'Tingkat Haji Ahmad, 11600, Jelutong',
#  'Kampung Pulai Api, 21800, Ajil Terengganu',
#  'Taman Sri Lalang, 81900, Kota Tinggi',
#  'Kampung Parit Khalil, 86100, Ayer Hitam',
#  'Jalan Nangka (Batu Lintang), 93200, Kuching Sarawak',
#  'Pangsapuri Tasek Barat, Hang Tuah Jaya, 75350, Melaka',
#  'Taman Kinta, 30250, Ipoh',
#  'Kampung Changkat Jering (Kuala Dipang), 31850, Jeram Perak',
#  'Lorong Perdana, 41300, Klang Selangor',
#  'Jalan Pipit, 14300, Nibong Tebal',
#  'Jalan Puisi U2/27, 40150, Shah Alam Selangor',
#  'Jalan Chan Ah Wing, 55100, Kuala Lumpur',
#  'Felda Nitar Timur, 86800, Mersing Johor',
#  'Kampung Krisna, 84600, Pagoh',
#  'Kampung Pauh, 21700, Kuala Berang',
#  'Aked Esplanad Bukit Jalil, 57000, Kuala Lumpur',
#  'Taman Melati, 84150, Parit Jawa',
#  'Kampung Baru Semerbok, 71350, Kota Negeri Sembilan',
#  'Rapat Setia, 31350, Ipoh',
#  'Taman Timah, 05150, Alor Setar Kedah',
#  'Kampung Batu 8, 34850, Changkat Jering',
#  'Majlis Bandaraya Ipoh, 30644, Ipoh Perak',
#  'Jalan Tengah, 41300, Klang Selangor',
#  'Jalan Hilir Cabang 4 Binjai, 16150, Kota Bharu Kelantan',
#  'Pegawai Kemajuan Negeri, 15674, Kota Bharu Kelantan',
#  'Jalan Sijangkang 28/17, 40400, Shah Alam',
#  'Lorong Pendita, 82000, Pontian Johor',
#  'Kampung Baru Terusan Seberang, 72500, Kuala Pilah',
#  'Bukit Tuan Karia, 78000, Alor Gajah',
#  'Jalan Krisoberil Satu 7/20A, 40000, Shah Alam',
#  'Kampung Bagan Serai, 13500, Permatang Pauh',
#  'Kampung Cina, 86700, Kahang Johor',
#  'Kampung Pinang, 22200, Kampung Raja Terengganu',
#  'Jalan Kelab, 30000, Ipoh Perak',
#  'Lorong 2, 83300, Seri Gading Johor',
#  'Lorong Rahmat, 84000, Muar Johor',
#  'Taman Desa Permai, 43650, Bandar Baru Bangi',
#  'Kampung Melaka, 48200, Serendah',
#  'Lahad Datu - Beg berkunci, 91109, Lahad Datu Sabah',
#  'Sidam Kiri, 09400, Padang Serai',
#  'Tanjung Dawai, 08200, Sik',
#  'Taman Sri Menanti, 06010, Changloon Kedah',
#  'Kampung Langkor, 33010, Kuala Kangsar Perak',
#  'Taman Koperasi Serkam Darat, 77300, Merlimau',
#  'Jalan Cyber Point 6, 63000, Cyberjaya',
#  'Jalan Bawal Lapan 17/3H, 40200, Shah Alam',
#  'Jalan Lembah (1 - 45), 81100, Johor Bahru',
#  'Lorong Kubur Pinang, 15100, Kota Bharu',
#  'RPA Bukit Keteri, 02400, Kangar',
#  'Perumahan Seberang Balok Jaya, 26100, Kuantan Pahang',
#  'Kampung Lubok Agor, 17500, Tanah Merah',
#  'Batu 2 1/2 Bunut Payong, 15150, Kota Bharu Kelantan',
#  'Taman Sri Makmur, 85000, Segamat Johor',
#  'Lorong Brunei (1 - 3), 55100, Kuala Lumpur WP Kuala Lumpur',
#  'Jalan Singa 20/1, 40300, Shah Alam',
#  'Titi Serong Mk. 5, 11000, Balik Pulau',
#  'Tampin - Peti surat, 73007, Tampin Negeri Sembilan',
#  'Jalan Delapan, 51100, Kuala Lumpur WP Kuala Lumpur',
#  'Kampung Seberang Lalang, 24300, Kerteh',
#  'Belukar Jalan Tar, 16450, Ketereh Kelantan',
#  'Balik Bukit, 14120, Simpang Ampat',
#  'Taman East Dragon, 25250, Kuantan',
#  'Lorong Bernam (1 - 2), 88300, Kota Kinabalu Sabah',
#  'Taman Bukit Dumbar, 11700, Gelugor Pulau Pinang',
#  'Medan Betik, 14000, Bukit Mertajam',
#  'Taman Naga Utama, 83200, Senggarang Johor',
#  'Jalan Angsana, 48200, Serendah Selangor',
#  'Kampung Gong Lapan, 16800, Pasir Puteh',
#  'Kampung Sungai Kelong, 16800, Pasir Puteh',
#  'Majlis Perbandaran Kuantan, 25644, Kuantan',
#  'Kampung Pegoh, 78000, Alor Gajah Melaka',
#  'Ramuan China Besar, 78300, Masjid Tanah Melaka',
#  'Kampung Wat Padang Pusing, 06700, Pendang Kedah',
#  'Taman Jelita, 11010, Balik Pulau Pulau Pinang',
#  'Taman Desa Bintang, 32000, Sitiawan Perak',
#  'Taman Delima, 24000, Cukai',
#  'Kuala Muda, 13110, Penaga',
#  'Jalan Habib Abdullah, 30100, Ipoh',
#  'Jalan Kinabalu, 43200, Cheras',
#  'Parit Guntong Daratan, 83600, Semerah',
#  'Taman Biru, 32400, Ayer Tawar',
#  'Jalan Bukit Indah, 28000, Temerloh',
#  'Jalan Mihrab U8/3, 40150, Shah Alam',
#  'Lorong Sapat, 88400, Kota Kinabalu Sabah',
#  'Bagan Buaya, 14300, Nibong Tebal',
#  'Taman Kijang Indah, 14000, Bukit Mertajam',
#  'Taman Masai Utama, 81750, Masai Johor',
#  'Taman Mesra, 40150, Shah Alam Selangor',
#  'Kampung Seelong, 81000, Kulai',
#  'Jalan Datuk Sim Kheng Hong, 93300, Kuching Sarawak',
#  'Medan Chin Ho, 10150, Pulau Pinang Pulau Pinang',
#  'Taman Bukit Mewah, 56100, Kuala Lumpur WP Kuala Lumpur',
#  'Perumahan Bukit Goh Perdana, 26050, Bukit Goh',
#  'Jalan Besar Paka, 23100, Paka',
#  'Felda Tembangau, 28380, Kemayan Pahang',
#  'Kampung Tok Pulut, 34350, Kuala Kurau',
#  'Jalan WM 3/13 - Jalan WM 3/18, 35950, Behrang Stesen Perak',
#  'Jalan DM 1B, 40160, Shah Alam Selangor',
#  'Jalan 3/101C, 56100, Kuala Lumpur',
#  'Kampung Ldg Ong Chin Seong, 32500, Changkat Keruing',
#  'Kampung Changkat Ayer, 33010, Kuala Kangsar',
#  'Jalan Segambut Atas, 51200, Kuala Lumpur WP Kuala Lumpur',
#  'Jalan Berkok, 51100, Kuala Lumpur',
#  'Pejabat Dewan Undangan Negeri Pengkalan Kubor, 16080, Tumpat',
#  'Kampung Tanjong Limau Purut, 71500, Tanjong Ipoh Negeri Sembilan',
#  'Alor Setar - Beg berkunci, 05990, Alor Setar Kedah',
#  'Guar Tuan Syed, 13100, Penaga Pulau Pinang',
#  'Jalan 16/1 - 16/18, 46350, Petaling Jaya Selangor',
#  'Lebuh Nangka, 14000, Bukit Mertajam Pulau Pinang',
#  'Taman Desa Utama, 45600, Batang Berjuntai',
#  'Solok Merbau Indah (1, 2, 3, 4, 6, 7), 13800, Butterworth Pulau Pinang',
#  'Lorong Stesen Pemancar RTM, 21000, Kuala Terengganu Terengganu',
#  'Taman Sentosa, 41200, Klang Selangor',
#  'Taman Impian Indah, 14000, Bukit Mertajam Pulau Pinang',
#  'Fettes Park, 11200, Tanjong Bungah',
#  'Taman Seri Kepayan, 88200, Kota Kinabalu Sabah',
#  'Jalan Merah Delima Tiga U9/7C, 40150, Shah Alam Selangor',
#  'Kampung Keladang, 15100, Kota Bharu Kelantan',
#  'Jalan Kelesa 17/4, 40200, Shah Alam Selangor',
#  'Pengkalan Batu, 75150, Melaka Melaka',
#  'Istana Pahang, 50200, Kuala Lumpur WP Kuala Lumpur',
#  'Pusat Perhubungan Telekom, 16500, Kem Desa Pahlawan',
#  'Kampung Salak Utara, 31050, Sungai Siput',
#  'Parit (2/7R - 3/7R), 36600, Chenderong Balai Perak',
#  'Goodwood Estate, 73500, Rompin',
#  'Taman Mata Kuching, 75400, Melaka Melaka',
#  'Jalan Undan, 30020, Ipoh',
#  'Jalan Merbah, 30020, Ipoh',
#  'Taman Mutiara Melaka, Hang Tuah Jaya, 75350, Melaka',
#  'Lengkok Cumarasami, 51100, Kuala Lumpur WP Kuala Lumpur',
#  'Kampung Beta, 17010, Pasir Mas',
#  'Taman Pusing, 31550, Pusing',
#  'Taman Suria Setapak, 53000, Kuala Lumpur WP Kuala Lumpur',
#  'Telok Manan, 13110, Penaga Pulau Pinang',
#  'Teluk Bakong, 84400, Sungai Mati',
#  'Jabatan Pendidikan, 40604, Shah Alam',
#  'Jalan Pipit, 14300, Nibong Tebal Pulau Pinang',
#  'Lendu, 78000, Alor Gajah Melaka',
#  'Kampung Huma, 06250, Alor Setar',
#  'Kampung Kelompang (Mukim Derga), 05400, Alor Setar',
#  'Taman Rambai Murni, 75260, Melaka Melaka',
#  'Medan Perhentian (Kidd), 30200, Ipoh',
#  'Taman Kot Tai, 32000, Sitiawan Perak',
#  'Perumahan Belukar Bukit Sawa, 18500, Machang',
#  'Taman Muhibbah, 86200, Simpang Rengam',
#  'Jambusan, 94000, Bau',
#  'Jalan Abdullah Liew, 31400, Ipoh',
#  'Mupong, 96200, Daro',
#  'Kampung Tersusun Jelapang Jaya, 30020, Ipoh Perak',
#  'Jalan Canton, 30250, Ipoh Perak',
#  'Kampung Telaga Mas, 06400, Pokok Sena Kedah',
#  'Jalan Selamat, 41250, Klang',
#  'Taman Seri Murni, 68100, Batu Caves',
#  'Jalan Baserah, 25250, Kuantan Pahang',
#  'Taman Kenanga (Seksyen 1), 75200, Melaka Melaka',
#  'Jalan Lobak 1 - 2, 81900, Kota Tinggi',
#  'Kampung Sri Wangi, 83700, Yong Peng',
#  'Kampung Chenaga, 73000, Tampin Negeri Sembilan',
#  'Jalan Firasat U2/13, 40150, Shah Alam Selangor',
#  'Kati, 33020, Kuala Kangsar Perak',
#  'Kampung Tulang Gajah, 84600, Pagoh',
#  'Lorong Kiju, 88400, Kota Kinabalu Sabah',
#  'Kampung Cik Zainal, 31200, Chemor',
#  'Jalan Philips, 11600, Jelutong Pulau Pinang',
#  'Lorong Kampung Sembulan, 88100, Kota Kinabalu Sabah',
#  'Jalan Kubis 24/30, 40300, Shah Alam',
#  'Taman Melor, 81200, Johor Bahru Johor',
#  'Jalan Bukit, 41050, Klang Selangor',
#  'Kampung Selang Datok, 27010, Jerantut',
#  'Parit Bengkok, 86400, Parit Raja',
#  'Jalan Permata 7/1, 40000, Shah Alam Selangor',
#  'Kampung Gurindam, 06150, Ayer Hitam',
#  'Lorong Cenderawasih, 25200, Kuantan Pahang',
#  'Taman Maju Indah Fasa 2, 36000, Teluk Intan Perak',
#  'Jalan Padang Golf, 44000, Kuala Kubu Baru',
#  'Taman JP Perdana, 81100, Johor Bahru',
#  'Kampung Jalan Si Puteh, 32800, Parit',
#  'Kampung Bukit Panchor, 93010, Kuching',
#  'Jalan Bulan CA U5/CA, 40150, Shah Alam Selangor',
#  'Jalan Hup Kee, 93250, Kuching',
#  'Taman Mesra Rim 2, 77000, Jasin Melaka',
#  'Lebuhraya Batu Maung, 11960, Batu Maung Pulau Pinang',
#  'Kampung Empittied, 98850, Lawas',
#  'Jalan Sungai Besi, 57100, Kuala Lumpur',
#  'Persiaran Kerjaya U1/8, 40150, Shah Alam Selangor',
#  'Jalan Tun Mamat, 75300, Melaka Melaka',
#  'Taman Mangga, 14100, Simpang Ampat Pulau Pinang',
#  'Taman Ultra, 93250, Kuching Sarawak',
#  'Kampung Baru Sungai Labu, 45400, Sekinchan',
#  'Kampung Keriang Pulau, 05400, Alor Setar Kedah',
#  'Lorong Kenanga, 13000, Butterworth Pulau Pinang',
#  'Kampung Jalan Bukit Taban, 34950, Bandar Baharu Kedah',
#  'Kampung Suprayan, 31000, Batu Gajah',
#  'Kampung Pinang, 78300, Masjid Tanah',
#  'Kampung Seneng, 16070, Bachok Kelantan',
#  'Kampung Bagan Sungai Besar, 45300, Sungai Besar Selangor',
#  'Krians Estate, 14300, Nibong Tebal Pulau Pinang',
#  'Sekolah Kebangsaan Bendar, 16600, Pulai Chondong',
#  'Felda Air Tawar 5, 81920, Ayer Tawar 2 Johor',
#  'Taman Sitiawan Maju, 32000, Sitiawan Perak',
#  'Jalan Deshon, 93100, Kuching',
#  'Relau Indah, 11900, Bayan Lepas',
#  'Taman Sri Perkasa, 93050, Kuching',
#  'Taman Bukit Bidor, 35500, Bidor',
#  'Kampung Stenggang, 94000, Bau',
#  'Kampung Banggol, 06700, Pendang Kedah',
#  'Taman Bukit Kerajaan, 33000, Kuala Kangsar Perak',
#  'Jalan Permatang Gunung, 06570, Alor Setar',
#  'Taman Bunga Raya, 33000, Kuala Kangsar Perak',
#  'Pusat Bandar Gateway Puchong, 47110, Puchong',
#  'Kampung Baru Tambun, 31400, Ipoh',
#  'Rumah Saing, 95300, Roban',
#  'Taman Setia Ecohili, 43500, Semenyih Selangor',
#  'Taman Seri Mewah 1, 41000, Klang Selangor',
#  'Jalan Naka (Batu 18 1/2), 06350, Pokok Sena',
#  'Taman Masjid Tanah, 78300, Masjid Tanah',
#  'Bukit Bayan, 75450, Ayer Keroh Melaka',
#  'Kampung Pengkalan Kota, 84600, Pagoh',
#  'Jalan Songket 10/5, 40100, Shah Alam Selangor',
#  'Jalan Rata 8/1F, 40000, Shah Alam',
#  'Jalan Terengganu, 10460, Pulau Pinang Pulau Pinang',
#  'Jalan Tengku Badar, 42000, Pelabuhan Klang',
#  'Kuala Besut, 22300, Kuala Besut Terengganu',
#  'Kampung Ladang Baharu, 77000, Jasin Melaka',
#  'Kampung Banggol Setor, 21500, Sungai Tong',
#  'Ipoh - Peti Surat 218 - 225, 30730, Ipoh Perak',
#  'Persiaran Madge, 55000, Kuala Lumpur',
#  'Lorong Imam Moksen, 76300, Sungai Udang',
#  'Kampung Seberang Alor Repek, 17070, Pasir Mas',
#  'Lorong Tempua, 14100, Simpang Ampat',
#  'Kampung Sekayu, 21700, Kuala Berang Terengganu',
#  'Jalan Perusahaan 1, 13600, Perai Pulau Pinang',
#  'Jalan 1/8A, 46000, Petaling Jaya',
#  'Lorong Bunga Kemunting, 88100, Kota Kinabalu',
#  'Jalan Imam Zakaria 3 (KU 13), 42200, Kapar Selangor',
#  'Taman Bayang, 93350, Kuching Sarawak',
#  'Reko Sentral, 43000, Kajang',
#  'Kampung Pengkalan Setar, 20050, Kuala Terengganu Terengganu',
#  'Kampung Tengah, 47150, Puchong Selangor',
#  'Kampung Pondok Lama, 17500, Tanah Merah Kelantan',
#  'Jalan Marmar 7/30, 40000, Shah Alam',
#  'Batang Nyamor, 71350, Kota Negeri Sembilan',
#  'Taman Suria, 84000, Muar',
#  'Taman Saujana, 73500, Rompin Negeri Sembilan',
#  'Kampung Suak Padi, 32600, Bota',
#  'Jalan Ragum 15/17, 40200, Shah Alam Selangor',
#  'Lingkungan Ikan Emas, 56000, Kuala Lumpur',
#  'Lorong Haji Jamil, 20100, Kuala Terengganu Terengganu',
#  'Lorong Ayer Telaga, 53200, Kuala Lumpur WP Kuala Lumpur',
#  'Lorong Berhala, 50470, Kuala Lumpur WP Kuala Lumpur',
#  'Jalan Kampung Puteh, 15150, Kota Bharu',
#  'Taman Putera Park, 93250, Kuching Sarawak',
#  'Lorong Melati, 76200, Kem Trendak Melaka',
#  'Kampung Gong Kerengga, 16080, Tumpat',
#  'Taman Tengku Yakoob, 05400, Alor Setar Kedah',
#  'Kampung Pasir Kubu, 36800, Kampung Gajah',
#  'Jalan Masjid Taqwa, 16700, Cherang Ruku',
#  'Lebuhraya Pantai Bayan Lepas, 11900, Bayan Lepas Pulau Pinang',
#  'Taman Desa Jaya 2, 26400, Bandar Pusat Jengka Pahang',
#  'Kampung Lubok Merbau, 06300, Kuala Nerang Kedah',
#  'Lorong Kalsom, 82000, Pontian',
#  'Kampung Patiambun, 98700, Limbang Sarawak',
#  'Ketua Audit Negeri, 70518, Seremban',
#  'Kampung Rengas, 18500, Machang Kelantan',
#  'Blok Tumpat, 17700, Ayer Lanas',
#  'Jalan Jelutong, 45700, Bukit Rotan Selangor',
#  'Jalan Mewah 25/63, 40400, Shah Alam',
#  'Cukai - Beg berkunci, 24009, Cukai Terengganu',
#  'Selat Klang, 42000, Pelabuhan Klang Selangor',
#  'Taman Seri Makmur, 06000, Jitra',
#  'Jalan Pondok Upeh Mk. 6, 11000, Balik Pulau',
#  'Kampung Dalam Terus, 36800, Kampung Gajah Perak',
#  'Lorong Melati, 88200, Kota Kinabalu Sabah',
#  'Jalan Bandar, 50000, Kuala Lumpur WP Kuala Lumpur',
#  'Jalan Taman Cantik, 11500, Ayer Itam',
#  'Ipoh - Peti Surat 76 - 92, 30710, Ipoh',
#  'Pangsapuri Adalia, Taman Bukit Sungai Long, 43000, Kajang',
#  'Taman Desa Mulia Jalan Kampung Banjar, 36000, Teluk Intan Perak',
#  'Kampung Changkat Pinang, 33500, Sauk',
#  'Kampung Jawi, 14200, Sungai Jawi Pulau Pinang',
#  'Ladang Chembong, 71300, Rembau Negeri Sembilan',
#  'Kampung Sungai Mekong, 17600, Jeli Kelantan',
#  'Kampung Padang Star, 21700, Kuala Berang Terengganu',
#  'Jalan Nagor, 05000, Alor Setar Kedah',
#  'Lorong Selamat, 30350, Ipoh',
#  'Kampung Uma Belur, 96950, Belaga Sarawak',
#  'Kampung Raja Ward, 33000, Kuala Kangsar',
#  'Jalan Dang Anom, 81100, Johor Bahru Johor',
#  'Jalan Sekolah Menengah, 16150, Kota Bharu',
#  'Lengkok Paya Terubung, 11060, Pulau Pinang',
#  'Perkampungan Pelindung, 25050, Kuantan Pahang',
#  'Jalan Pulau, 75050, Melaka Melaka',
#  'Jalan Biru U9/9, 40150, Shah Alam',
#  'Kampung Bukit Asahan, 77100, Asahan',
#  'Lorong Permatang Gharu (Kampung Kem), 26060, Kuantan',
#  'Lorong Tembusu Selatan, 50480, Kuala Lumpur WP Kuala Lumpur',
#  'Lorong Mawar, 75150, Melaka Melaka',
#  'Taman Timur Enstek, 71760, Bandar Enstek Negeri Sembilan',
#  'Jalan Tembusu (Kampung Melayu Subang), 40150, Shah Alam',
#  'Rumah Pangsa Bercam, 31400, Ipoh Perak',
#  'Kampung Lintang, 31100, Sungai Siput',
#  'Kampung Lalang Panjang, 36800, Kampung Gajah Perak',
#  'Jalan Kubu, 98700, Limbang Sarawak',
#  'Kampung Padang Lalang, 84900, Tangkak Johor',
#  'Persiaran Bayan Indah (1 - 3), 11900, Bayan Lepas Pulau Pinang',
#  'Kampung Kolong Pahat, 26200, Sungai Lembing Pahang',
#  'Kampung Sungai Udang Atas, 06900, Yan',
#  'Pekeliling Belatok, 14300, Nibong Tebal Pulau Pinang',
#  'Jalan Serimuka Dua 22/2B, 40460, Shah Alam Selangor',
#  'Kampung Bukit Terang, 71550, Tanjong Ipoh Negeri Sembilan',
#  'Kampung \xa0Paya Besar, 85000, Segamat',
#  'Kampung Liang Batu, 84600, Pagoh',
#  'Lorong Langgat, 88450, Kota Kinabalu',
#  'No. 8 Bangunan Lian Hoe, 47410, Petaling Jaya Selangor',
#  'Taman Cenderawasih, 25200, Kuantan',
#  'Jalan Shaik Adam, 14000, Bukit Mertajam Pulau Pinang',
#  'Taman Baru Bukit Tengah, 14000, Bukit Mertajam Pulau Pinang',
#  'Kampung Bumi Hijau, 36400, Hutan Melintang',
#  'Taman Desa Jaya, 84300, Bukit Pasir Johor',
#  'Lorong Patin, 88400, Kota Kinabalu Sabah',
#  'Jalan Pisang Raja, 11500, Ayer Itam Pulau Pinang',
#  'Jalan Datok Lundang, 15200, Kota Bharu',
#  'Kampung Sungai Kandis, 40460, Shah Alam',
#  'Kampung Bendang Darat, 09100, Baling',
#  'Pulau Lang Kanan, 26800, Kuala Rompin Pahang',
#  'Sungai Petani - Peti surat, 08007, Sungai Petani',
#  'Jalan Kesemak, 81200, Johor Bahru Johor',
#  'Jalan Tun Teja, 81100, Johor Bahru Johor',
#  'UKK Air Kala, 33300, Gerik',
#  'Lorong Kapas, 88300, Kota Kinabalu',
#  'Pos Malaysia Berhad, 25670, Kuantan Pahang',
#  'Lembaga Hasil Dalam Negeri, 75600, Melaka',
#  'Taman Bakti, 42700, Banting Selangor',
#  'Taman Pengkalan Assam, 01000, Kangar Perlis',
#  'Lengkok Perindustrian Bukit Minyak 1, 14100, Simpang Ampat',
#  'Kampung Kelembang, 71600, Kuala Klawang Negeri Sembilan',
#  'Lorong Penaga, 11600, Jelutong Pulau Pinang',
#  'Felcra Gugusan Serting, 72200, Batu Kikir Negeri Sembilan',
#  'Jalan Lengkongan, 42000, Pelabuhan Klang',
#  'Jalan Jelapang, 30100, Ipoh',
#  'Jalan 2/27A Wangsa Maju, 53300, Kuala Lumpur WP Kuala Lumpur',
#  'Lorong Che Gu Batu 3, 15150, Kota Bharu Kelantan',
#  'Lorong Kubur Pak Dogol, 15200, Kota Bharu',
#  'Taman Sri Naga, 06200, Kepala Batas Kedah',
#  'Lebuh Relau (2 - 8), 11900, Bayan Lepas Pulau Pinang',
#  'Kampung Bechah Tembusu, 16400, Melor Kelantan',
#  'Taman Gembira, 42600, Jenjarom Selangor',
#  'Jalan KKIP Timur, 88460, Kota Kinabalu',
#  'Gerbang Muhibbah, 14000, Bukit Mertajam',
#  'Kampung Chenderong Batu, 16250, Wakaf Bharu',
#  'Tang Dynasty Hotel, 88000, Kota Kinabalu',
#  'Desa Rahmat 1 & 2, 15200, Kota Bharu Kelantan',
#  'Lorong Wanita, 82000, Pontian',
#  'Taman Muhibbah, 45200, Sabak Bernam',
#  'Kampung Air Pasir, 86700, Kahang Johor',
#  'Kampung Tanjong Tokong, 10470, Pulau Pinang Pulau Pinang',
#  'Kampung Sinong, 97000, Bintulu',
#  'Pelak, 26650, Pekan Pahang',
#  'Jalan Keruing 3/5, 40000, Shah Alam',
#  'Kampung Sedili Kecil, 81900, Kota Tinggi',
#  'Kompleks Tiara Crest, 47301, Petaling Jaya',
#  'Kampung Padang Kechik, 15200, Kota Bharu',
#  'Desa Madura, 11900, Bayan Lepas Pulau Pinang',
#  'Kampung Selayang Baru, 68100, Batu Caves Selangor',
#  'Kampung Ulu Pulai, 81500, Pekan Nenas',
#  'Wisma Damansara, 50490, Kuala Lumpur',
#  'Pasir Gudang Bussiness Park, 81700, Pasir Gudang Johor',
#  'Kampung Sungai Tengar, 45100, Sungai Ayer Tawar',
#  'Kelanang, 42700, Banting Selangor',
#  'Taman Kulai Baru, 81000, Kulai Johor',
#  'Rumah Murah, 39200, Ringlet',
#  'Kampung Datok, 15100, Kota Bharu',
#  'Kampung Seterpa, 16400, Melor',
#  'Kampung Lapan Bola, 17510, Tanah Merah Kelantan',
#  'Jalan Mohd Noor, 80000, Johor Bahru Johor',
#  'Taman Seri Panglima (Fasa 1 & 2), 42500, Telok Panglima Garang Selangor',
#  'Desa Clarissa, 11900, Bayan Lepas',
#  'Taman Veerasamy, 31100, Sungai Siput',
#  'Lorong Bahagia, 16800, Pasir Puteh',
#  'Kampung Sekolah Perempuan, 33400, Lenggong Perak',
#  'Taman Universiti, 47300, Petaling Jaya',
#  'Taman Melor 4 Fasa 2, 23000, Dungun',
#  'Taman Muhibbah, 45300, Sungai Besar Selangor',
#  'Lebuhraya Merdeka, 30100, Ipoh Perak',
#  'Taman Seri Utama, 06000, Jitra',
#  'Jalan Platinum 7/49A, 40000, Shah Alam',
#  'Kampung Setia Jaya, 53100, Kuala Lumpur WP Kuala Lumpur',
#  'Taman Bukit Lentang (Gemas Baru), 73400, Gemas',
#  'Taman Bukit Nuri Indah, 70300, Seremban Negeri Sembilan',
#  'Jalan Keledang Raya, 30020, Ipoh Perak',
#  'Parit Sikom Dalam, 82000, Pontian',
#  'Kampung Kok Lentang, 16090, Bachok',
#  'Lorong Tepus, 88300, Kota Kinabalu Sabah',
#  'Taman Perwira (Gombak), 53100, Kuala Lumpur',
#  'Kampung Damat, 16300, Bachok Kelantan',
#  'Kampung Medan Batu Muda, 51100, Kuala Lumpur WP Kuala Lumpur',
#  'Taman Foo Lin Kong, 32300, Pangkor',
#  'Kampung Baru (Jalan Pendang), 06800, Kota Sarang Semut',
#  'Kampung Konchang, 17020, Pasir Mas Kelantan',
#  'Taman Seri Asa, 35900, Tanjong Malim Perak',
#  'Jalan Titi Panjang, 32200, Lumut',
#  'Taman Malaysia, 05250, Alor Setar',
#  'Jalan Tok Enteh (Tanjung Dahan), 78200, Kuala Sungai Baru',
#  'Wakaf Tok Kassim, 16100, Kota Bharu Kelantan',
#  'Parit Sri Merlong, 83100, Rengit Johor',
#  'Jalan Temenggong, 86800, Mersing Johor',
#  'Tingkat Batu Maung 1, 11960, Batu Maung Pulau Pinang',
#  'Permatang Sungai Dua, 13200, Kepala Batas',
#  'Jalan Plumbum Q /7Q, 40000, Shah Alam Selangor',
#  'Majlis Belia, 15200, Kota Bharu',
#  'Nanga Mepi, 95900, Lubok Antu',
#  'Jalan Penghulu 44/3A, 43200, Cheras Selangor',
#  'Taman Pantai Port Dickson, 71050, Si Rusa Negeri Sembilan',
#  'Kampung Ayer Leleh, 75050, Melaka Melaka',
#  'Taman Seri Rampai, 15200, Kota Bharu Kelantan',
#  'Taman Puchong Indah 2, 47170, Puchong Selangor',
#  'Penasihat Undang-Undang Negeri, 75512, Melaka',
#  'Taman Radin Mas, 45500, Tanjong Karang',
#  'Taman Sri Pernama, 16800, Pasir Puteh Kelantan',
#  'Telekom Malaysia Berhad, 40672, Shah Alam',
#  'Jalan 17/1A - 17/48C, 46400, Petaling Jaya Selangor',
#  'Jalan Hala Pasar Baru, 30300, Ipoh',
#  'Lorong Bakap, 14200, Sungai Jawi',
#  'Taman Kopi, 36000, Teluk Intan',
#  'Lorong Limau, 21000, Kuala Terengganu',
#  'Kota Kinabalu - Peti surat 14871 - 15000, 88855, Kota Kinabalu Sabah',
#  'Chemor Setia 1 - 7, 31200, Chemor Perak',
#  'Kampung Bagan Tunjang, 45200, Sabak Bernam',
#  'Lorong Sang Suria, 88450, Kota Kinabalu',
#  'Kampung Dato Penglima Perang, 20000, Kuala Terengganu Terengganu',
#  'Taman Ipoh Baru, 31400, Ipoh Perak',
#  'Lapangan Terbang Sultan Abdul Aziz, 47200, Subang Jaya',
#  'Jalan Cengal 3/14, 40000, Shah Alam',
#  'Lorong Rembia, 88300, Kota Kinabalu',
#  'Kampung Balik Bukit, 02500, Kangar Perlis',
#  'Kampung Ladang Lepan Kabu, 18000, Kuala Krai',
#  'Parit (3/L - 4/6L), 36600, Chenderong Balai Perak',
#  'Jalan Saudagar U1/16, 40150, Shah Alam Selangor',
#  'Bahagian Pinjaman Perumahan Perbendaharaan Malaysia, 50592, Kuala Lumpur',
#  'Jabatan Bomba & Penyelamat, 50648, Kuala Lumpur WP Kuala Lumpur',
#  'Kampung Batu Burong, 27100, Padang Tengku Pahang',
#  'Menara Petronas, 88100, Kota Kinabalu',
#  'Taman Mutiara, 88300, Kota Kinabalu',
#  'Jalan Lumba Kuda, 30350, Ipoh Perak',
#  'Jalan Janggus (1 - 4), 13500, Permatang Pauh',
#  'Kuala Klawang, 71600, Kuala Klawang',
#  'Kampung Sungai Tebak, 09100, Baling Kedah',
#  'Kampung Bukit Hangus, 17500, Tanah Merah Kelantan',
#  'Taman Acbe, 72100, Bahau Negeri Sembilan',
#  'Simpang Pasir Gembor, 77300, Merlimau',
#  'Kampung Juara, 86800, Mersing Johor',
#  'Jalan Penyiaran, 81200, Johor Bahru',
#  'Taman Ros Setia, 72500, Kuala Pilah Negeri Sembilan',
#  'Kawasan Pejabat, 27030, Damak',
#  'Taman Angsana, 43500, Semenyih',
#  'Kampung Takir Dalam, 18500, Machang',
#  'Taman Jaya Diri, 83500, Parit Sulong Johor',
#  'Kampung Razak, 30020, Ipoh',
#  'Jalan Pari 17/16, 40200, Shah Alam',
#  'Rumah Keretapi Tebong, 77500, Selandar',
#  'Taman Kota Jaya, 81900, Kota Tinggi',
#  'Taman Tambak Paya Indah, 75460, Melaka Melaka',
#  'Lorong Tentera, 81100, Johor Bahru Johor',
#  'Taman Nilai, 71800, Nilai',
#  'Kampung Kemudu Bongkok, 16800, Pasir Puteh',
#  'Kampung Chatin Bawah, 28400, Mentakab Pahang',
#  'IKS Selandar, 77500, Selandar',
#  'Nanga Dap, 96700, Kanowit Sarawak',
#  'Kampung Seberang Paya, 09400, Padang Serai Kedah',
#  'Taman Patin Indah, 70300, Seremban Negeri Sembilan',
#  'Kampung Palembang Dalam, 86000, Kluang',
#  'Kampung Bubang Panjang, 33010, Kuala Kangsar Perak',
#  'Taman Antara Gapi, 48200, Serendah Selangor',
#  'Kampung Tualang Tinggi Dalam, 16810, Selising',
#  'Lorong Merak (1 - 2), 11700, Gelugor Pulau Pinang',
#  'Taman Impiana, 71800, Nilai',
#  'Jalan Tanah Wakaf, 76300, Sungai Udang Melaka',
#  'Kampung Tobiar, 13210, Kepala Batas',
#  'Ladang Yam Seng, 34020, Taiping Perak',
#  'Kampung Parit Kangkar, 86100, Ayer Hitam',
#  'Lorong Seri Segar, 13400, Butterworth',
#  'Taman Desa Anjung Putra, 43000, Kajang Selangor',
#  'Ipoh - Peti Surat 976 - 1050, 30820, Ipoh Perak',
#  'Jalan Air Puteh, 24000, Cukai',
#  'Kampung Baru, 45200, Sabak Bernam',
#  'Lubok Kawah, 17000, Pasir Mas Kelantan',
#  'Kampung Gunung Mesah Hulu, 31600, Gopeng Perak',
#  'Jalan Labuk (Batu 36), 90000, Sandakan',
#  'Parit Zain, 84200, Muar',
#  'Jalan PJU 1A/2, 47301, Petaling Jaya',
#  'PPRT Tok Kuning, 02000, Kuala Perlis',
#  'Taman Industri Sungai Buloh, 47000, Sungai Buloh Selangor',
#  'Kompleks Niaga Utama, 59000, Kuala Lumpur',
#  'Kampung Tengah Ibok, 24100, Kijal',
#  'Kawasan Kilang Cheng TTC, 75260, Melaka',
#  'Taman Satria Phase 2, 88450, Kota Kinabalu Sabah',
#  'Taman Bukit Indah, 85000, Segamat',
#  'Parit 804, 34300, Bagan Serai Perak',
#  'Tan Toh Guan Block, 71000, Port Dickson Negeri Sembilan',
#  'Kuala Lumpur - Peti surat 10916 - 10921, 50730, Kuala Lumpur',
#  'Jalan Chow Kit, 50350, Kuala Lumpur WP Kuala Lumpur',
#  'Taman Temiang Indah, 84000, Muar',
#  'Ladang Berapit, 33700, Padang Rengas',
#  'Kampung Petani, 09010, Kulim Kedah',
#  'Kampung Gong Chengal, 16070, Bachok Kelantan',
#  'Kampung Pak Kancil, 22100, Permaisuri',
#  'Kampung Charok Tala, 08320, Jeniang Kedah',
#  'Kampung Lindongan Raja, 09700, Karangan Kedah',
#  'Taman Jaya, 27000, Jerantut Pahang',
#  'Kampung Semeba Jalan Semeba, 93250, Kuching',
#  'Kampung Piong, 35800, Slim River',
#  'Kampung Baru Kanan, 24100, Kijal',
#  'Jabor, 26150, Balok Pahang',
#  'Labuan - Peti surat 80601 - 80700, 87016, Labuan',
#  'Bahagian Perlesenan - Kementerian Penerangan, 01610, Kangar',
#  'Kampung Dato Ahmad Said Tambahan 3, 30020, Ipoh',
#  'Pajak Song, 13200, Kepala Batas Pulau Pinang',
#  'Jalan Sesenduk, 41050, Klang',
#  'Kampung Sungai Sekah, 71800, Nilai Negeri Sembilan',
#  'Lahar Tambun, 13300, Tasek Gelugor',
#  'Matang Kubu, 34900, Pantai Remis',
#  'Taman Lembah Tupai, 34000, Taiping',
#  'Guar Chempedak, 08800, Gurun Kedah',
#  'Kampung Telok Gelam, 06000, Jitra Kedah',
#  'Lengkok Vethavanam, 51100, Kuala Lumpur WP Kuala Lumpur',
#  'Taman Nyior Hijau, 70100, Seremban Negeri Sembilan',
#  'Ladang Bukit Dinding, 28600, Karak Pahang',
#  'Taman Darulaman Jaya (1 & 2), 06000, Jitra Kedah',
#  'Lintang Abdullah Ariff, 11400, Pulau Pinang',
#  'Kampung Bechah Salak, 18000, Kuala Krai',
#  'Kampung Sungai Petai, 34850, Changkat Jering Perak',
#  'Taman Pekerti, 45800, Jeram',
#  'Salak Selatan, 57100, Kuala Lumpur',
#  'Kampung Dok, 84900, Tangkak',
#  'Jalan Bakau 27/79, 40400, Shah Alam',
#  'Lorong Dewan, 88000, Kota Kinabalu Sabah',
#  'Taman Temiang baru, 84300, Bukit Pasir Johor',
#  'Kampung Pelet, 14400, Kubang Semang',
#  'Kampung Gumai, 28100, Chenor',
#  'Solok Sungai Pinang, 11600, Jelutong',
#  'Jalan Nehru, 30200, Ipoh',
#  'Asas Parade, 14100, Simpang Ampat',
#  'Bangunan Graha Maju, 75300, Melaka Melaka',
#  'Jalan Dian (1 - 22), 81200, Johor Bahru Johor',
#  'Jalan Marmar Empat 7/30D, 40000, Shah Alam',
#  'Jalan Sungai Chandong, 42920, Pulau Indah',
#  'Jalan Syed Putra, 50460, Kuala Lumpur WP Kuala Lumpur',
#  'Kampung Jawa Batu Masjid, 35350, Temoh',
#  'Taman Bernam Permai, 35900, Tanjong Malim Perak',
#  'Parit Abd Rahman, 83500, Parit Sulong',
#  'Taman Sri Aman, 07000, Langkawi',
#  'Talang Tengah, 31100, Sungai Siput',
#  'Kampung Padang Layang, 15100, Kota Bharu',
#  'Selasar Chateau, 30250, Ipoh',
#  'Kampung Bawah Lembah, 15050, Kota Bharu',
#  'Lorong Tembikai (1 - 8), 14000, Bukit Mertajam Pulau Pinang',
#  'Kedai Menanti, 16400, Melor',
#  'Kampung Belengka, 28000, Temerloh',
#  'Kampung Kuala Cenerai Bat, 09110, Kuala Pegang Kedah',
#  'Kampung Baru Jalan Hamzah, 15050, Kota Bharu Kelantan',
#  'Jalan Raja Mahadi, 45000, Kuala Selangor Selangor',
#  'Jalan PJU 1A/1, 47301, Petaling Jaya Selangor',
#  'Bukit Tuan Sheikh, 71000, Port Dickson',
#  'Kampung Pasu, 28050, Kuala Krau',
#  'Lebuh Bakau, 11600, Jelutong',
#  'Putatan - Peti Surat 50081 - 50300, 88722, Putatan',
#  'Desa Aman, 27200, Kuala Lipis Pahang',
#  'Kampung Bukit Pagar, 18000, Kuala Krai Kelantan',
#  'Jalan Bilal, 77500, Selandar Melaka',
#  'Kampung Sedili Besar, 81900, Kota Tinggi Johor',
#  'Lorong Tosa Raya, 88300, Kota Kinabalu',
#  'Kampung Telok Manis, 32800, Parit',
#  'Kampung Charok Tilam, 09100, Baling Kedah',
#  'Taman Bersatu, 06300, Kuala Nerang Kedah',
#  'Kampung Pak Kuja, 16400, Melor',
#  'Kampung Titi Besi, 06200, Kepala Batas Kedah',
#  'Jalan Tengku Muhamad, 25050, Kuantan Pahang',
#  'Banggol Penyengat, 09700, Karangan',
#  'Lorong Ayer Kuning (1 - 6), 53200, Kuala Lumpur WP Kuala Lumpur',
#  'Kampung Salak Tinggi, 43900, Sepang',
#  'Jalan Durian, 41100, Klang',
#  'Pangsapuri Melaka Baru, Hang Tuah Jaya, 75350, Melaka',
#  'Kondominium Lisola, Jalan SS 16/1, 47500, Subang Jaya Selangor',
#  'Kampung Bandar Tua Hulu, 36800, Kampung Gajah',
#  'Kampung Kakai, 94700, Serian Sarawak',
#  'Kampung Salor, 17600, Jeli Kelantan',
#  'Ladang Mantai, 77100, Asahan',
#  'Taman Maju Indah, 36000, Teluk Intan',
#  'Kampung Tengah (Teluk Bagan), 05400, Alor Setar Kedah',
#  'Flat Kenanga B, 81930, Bandar Penawar',
#  'Taman Sahabat, 73400, Gemas',
#  'Kampung Lentang Kubang Jawi, 06250, Alor Setar Kedah',
#  'Taman Rozy, 84000, Muar',
#  'Taman Aman, 31100, Sungai Siput Perak',
#  'Jalan Bukit Lemon, 70000, Seremban',
#  'Taman Alias, 78300, Masjid Tanah Melaka',
#  'Kampung Baru Kura, 08320, Jeniang Kedah',
#  'Kampung Datok Abdullah, 06800, Kota Sarang Semut Kedah',
#  'Kampung Aji Hulu, 32600, Bota Perak',
#  'Jalan Melur, 12300, Butterworth Pulau Pinang',
#  'Lorong Teberau, 88300, Kota Kinabalu',
#  'Kampung Kutai, 95900, Lubok Antu',
#  'Lintang Asas Tani (1 - 3), 13300, Tasek Gelugor Pulau Pinang',
#  'Kampung Baru Stesen Keretapi, 35600, Sungkai Perak',
#  'Lorong Noning, 14000, Bukit Mertajam',
#  'Jalan Indah, 14000, Bukit Mertajam Pulau Pinang',
#  'Bandar Tun Hussein Onn, 43200, Cheras Selangor',
#  'Parit Yaakob, 84200, Muar Johor',
#  'Lorong Iqrak, 15100, Kota Bharu Kelantan',
#  'Kem Hobart, 08300, Gurun Kedah',
#  'Kampung Melayu Skudai, 81300, Johor Bahru',
#  'Kampung Permatang Pelangu, 02800, Simpang Ampat',
#  'Kampung Jias, 16450, Ketereh',
#  'Kampung Baru Labu Banting, 13310, Tasek Gelugor',
#  'Taman Kit Seong, 14300, Nibong Tebal Pulau Pinang',
#  'Taman Noor Mansur, 15150, Kota Bharu Kelantan',
#  'Persiaran Batai Tepi, 50490, Kuala Lumpur WP Kuala Lumpur',
#  'Taman Pagoh Indah, 84600, Pagoh',
#  'Taman Alma, 14000, Bukit Mertajam',
#  'Jabatan Kesihatan, 75590, Melaka',
#  'Lorong Matap, 82000, Pontian Johor',
#  'Alor Melintang Gunung, 05150, Alor Setar Kedah',
#  'Desa Samudra, 25200, Kuantan Pahang',
#  'Jalan Mutiara 2/7, 43500, Semenyih',
#  'Taman Cheras Idaman, 43000, Kajang Selangor',
#  'Jalan Changkat, 46000, Petaling Jaya',
#  'Taman Setia Durian Burong, 20050, Kuala Terengganu Terengganu',
#  'Kampung Desa Pewira, 81100, Johor Bahru Johor',
#  'Taman Pinggiran Zaharah, 18500, Machang',
#  'Petaling Jaya - Seksyen SS 1 - SS 3, 47300, Petaling Jaya',
#  'Jalan Gambus, 41200, Klang Selangor',
#  'Kampung Bukit Sekolah, 33400, Lenggong Perak',
#  'Dewan Hang Tuah, 75300, Melaka Melaka',
#  'Kampung Changkat Panjang, 36800, Kampung Gajah',
#  'Jalan Angkasawan U1/39, 40150, Shah Alam',
#  'Jalan Pokok Mangga, 75250, Melaka',
#  'Taman Milinneum, 88200, Kota Kinabalu',
#  'Lenga, 84600, Pagoh Johor',
#  'Kuala Parit, 36800, Kampung Gajah',
#  'Jalan Permaisuri, 55100, Kuala Lumpur WP Kuala Lumpur',
#  'Kampung Baru Bukit Chabang, 02100, Padang Besar Perlis',
#  'Kampung Keling, 16150, Kota Bharu Kelantan',
#  'Sama Gagah, 13500, Permatang Pauh',
#  'Jalan Desa Duyong (18, 18A, 18B), 75460, Melaka Melaka',
#  'Kampung Tersusun Pungai, 81600, Pengerang',
#  'Lorong Segamal (1 - 7), 13400, Butterworth',
#  'Parit Mat Amin, 36200, Selekoh Perak',
#  'Kuching - Peti Surat (651 - 750), 93714, Kuching Sarawak',
#  'Kampung Charok Bunting, 09100, Baling',
#  'Kampung Parit Pasir Lama, 81500, Pekan Nenas',
#  'Jalan Beting Dua 8/13B, 40000, Shah Alam',
#  'Kampung Jagoh, 33300, Gerik Perak',
#  'Kampung Alor Selising, 17070, Pasir Mas',
#  'Laman Sierramas West, 47000, Sungai Buloh',
#  'Hock Ann Estate, 58100, Kuala Lumpur',
#  'Kampung Dusun Gani, 09100, Baling',
#  'Kampung Becah Hangus, 16450, Ketereh Kelantan',
#  'Kampung Berkat, 26500, Maran Pahang',
#  'Chabang Tiga Bakong, 17000, Pasir Mas',
#  'Jalan Seloka U2/30, 40150, Shah Alam',
#  'Tenaga Nasional Berhad, 70673, Seremban',
#  'Taman Scenery Villa, 93350, Kuching',
#  'Taman Sentosa Jaya, 17030, Pasir Mas',
#  'Rumah Ramping, 95300, Roban',
#  'Kampung Ketil, 16080, Tumpat',
#  'Kampung Bakar Bata, 09100, Baling',
#  'Taman Merbok, 14300, Nibong Tebal',
#  'Jalan Muhibbah, 75460, Melaka Melaka',
#  'Kampung Parit Haji Hassan, 83300, Seri Gading Johor',
#  'Kampung Pulau Sa, 16800, Pasir Puteh Kelantan',
#  'Taman Sawit Jaya, 81000, Kulai',
#  'Kampung Kuala Kedua, 09100, Baling',
#  'Taman Aman, 12200, Butterworth',
#  'Taman Timur Jaya, 25050, Kuantan Pahang',
#  'Ayer Puteh (Batu 13), 73100, Johol',
#  'Kampung Manan, 17020, Pasir Mas',
#  'Jalan Chan Koon Cheng, 75000, Melaka Melaka',
#  'Sarang Buaya Laut, 83600, Semerah Johor',
#  'Asing, 21600, Marang Terengganu',
#  'Jalan Jentayu 1, 47170, Puchong Selangor',
#  'Kampung Sungai Merab, 43000, Kajang',
#  'Taman Semanggol Indah, 34400, Simpang Ampat Semanggol Perak',
#  'Perbadanan Taman Negara, 79575, Nusajaya Johor',
#  'Bukit Minyak, 14020, Bukit Mertajam Pulau Pinang',
#  'Kompleks Niaga Melaka Perdana, 75450, Ayer Keroh Melaka',
#  'Bukit Berapit Kuak, 33400, Lenggong Perak',
#  'Kampung Permatang Tengah, 08500, Kota Kuala Muda Kedah',
#  'Kampung Jeram Hilir, 21060, Kuala Terengganu Terengganu',
#  'Kampung Bukit Katil, 75450, Ayer Keroh Melaka',
#  'Perumahan Pandan Damai, 26070, Kuantan Pahang',
#  'Seri Melaka, 84800, Bukit Gambir',
#  'Jalan Bukit Vor, 88200, Kota Kinabalu Sabah',
#  'Kampung Baru Elmina, 40160, Shah Alam',
#  'Taman Mas Merah, 84000, Muar',
#  'Jalan Sukacita, 58200, Kuala Lumpur',
#  'Jalan Pos Baru, 41300, Klang Selangor',
#  'Jalan Pangkor, 50400, Kuala Lumpur WP Kuala Lumpur',
#  'Taman Kepong 2, 84600, Pagoh',
#  'Jalan Menteri, 45300, Sungai Besar',
#  'Taman Bunga Cempaka, 02100, Padang Besar',
#  'Parit Haji Tahir, 34200, Parit Buntar',
#  'Jalan Syed Zain, 86000, Kluang Johor',
#  'Taman Sri Bayu, 86800, Mersing',
#  'Jalan 23, 88000, Kota Kinabalu',
#  'Kampung Gertak Kechupu, 16150, Kota Bharu',
#  'Kampung Changkat, 31900, Kampar',
#  'Kampung Sematang Bogak, 06250, Alor Setar',
#  'Kuala Lumpur - Peti surat 10049, 50902, Kuala Lumpur WP Kuala Lumpur',
#  'Kampung Pulau Rumput, 26640, Pekan Pahang',
#  'Lorong Bunga Tanjung, 13400, Butterworth',
#  'Taman Manggis, 09000, Kulim Kedah',
#  ...]

# %%
import pandas as pd

df = pd.read_csv('senarai-anak-syarikat-kplb.csv')['ALAMAT SYARIKAT'].dropna()
company_address = df.tolist()
company_address = [c.split('TEL')[0].strip() for c in company_address]
company_address = [c.split('Tel')[0].strip().title() for c in company_address]

# %%
df = pd.read_csv('penganjur-acara.csv')
for i in range(len(df)):
    row = df.iloc[i]
    l = row['Alamat 1'].replace('\n', ' ').strip().title()
    r = row['Alamat 2'].replace('\n', ' ').strip().title()
    company_address.extend([l, f'{l}, {r}'])

# %%
df = pd.read_csv('maklumat-syarikat-jualan-langsung.csv')['ALAMAT TERKINI (TELEFON & FAKS)'].dropna()
company_address.extend(df.tolist())

company_address = list(set(company_address))

# %%
import re

company_address = [r.strip().title() for r in company_address]
company_address = [t.split('(T')[0].split('( Tel')[0].split('( T')[0].split('(0')[0].strip() for t in company_address]
company_address = [re.sub(r'[ ]+', ' ', t).strip() for t in company_address]
company_address = [t[:-1] if t[-1] == '.' else t for t in company_address]
len(company_address)
# Out:
# 1781

# %%
results = []
i = 0
while i < len(entities['label']):
    r = []
    if entities['label'][i] == 'LOC':
        while entities['label'][i] == 'LOC':
            r.append(i)
            i += 1
        results.append(r)
    i += 1

# %%
import math

def generate_index(l, name, texts, labels, length):
    cp, indices = [], []
    b = length - len(l)
    left = math.ceil(b / 2)
    right = b - left
    minus = l[0] - left
    if minus < 0:
        absolute = np.abs(minus)
        right += absolute
        left -= absolute

    for i in range(l[0] - left, l[0]):
        cp.append(texts[i])
        indices.append(labels[i])

    cp.extend(name)
    indices.extend(['ADDRESS' for _ in range(len(name))])
    try:
        for i in range(l[-1] + 1, l[-1] + right + 1):
            cp.append(texts[i])
            indices.append(labels[i])
    except Exception as e:
        print(e)
        pass
    
    return cp, indices

# %%
train_results, test_results = train_test_split(results, test_size = 0.2)
train_addresses, test_addresses = train_test_split(addresses, test_size = 0.2)

# %%
train_X, train_Y = [], []
repeat = 8

for t in company_address:
    for i in range(repeat):
        x, y = generate_index(train_results[random.randint(0, len(train_results) - 1)], 
                              t.split(), entities['text'], entities['label'], 50)
        if len(x) != len(y):
            print('len not same')
            continue
        train_X.append(x)
        train_Y.append(y)
            
len(train_X)
# Out:
# 14248

# %%
repeat = 1
for t in train_addresses:
    for i in range(repeat):
        if random.random() > 0.5:
            x, y = generate_index(train_results[random.randint(0, len(train_results) - 1)], 
                                  t.split(), entities['text'], entities['label'], 50)
            if len(x) != len(y):
                print('len not same')
                continue
            train_X.append(x)
            train_Y.append(y)
            
len(train_X)
# Out:
# 57502

# %%
test_X, test_Y = [], []
repeat = 1

for t in test_addresses:
    for i in range(repeat):
        if random.random() > 0.3:
            x, y = generate_index(test_results[random.randint(0, len(test_results) - 1)], 
                                  t.split(), entities['text'], entities['label'], 50)
            if len(x) != len(y):
                print('len not same')
                continue
            test_X.append(x)
            test_Y.append(y)
            
len(test_X)
# Out:
# 15106

# %%
len(train_X), len(test_X)
# Out:
# (57502, 15106)

# %%
with open('augmentation-address-ontonotes5.json', 'w') as fopen:
    json.dump({'train_X': train_X, 'train_Y': train_Y,
              'test_X': test_X, 'test_Y': test_Y}, fopen)
