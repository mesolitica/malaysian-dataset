# %%
# !pip3 install google-cloud-texttospeech

# %%
import os
import json
from tqdm import tqdm

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'huseinhouse-17445d9b2ea7.json'

# %%
from google.cloud import texttospeech

client = texttospeech.TextToSpeechClient()
audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3,
    effects_profile_id=['headphone-class-device'],
)
voice = texttospeech.VoiceSelectionParams(
    language_code="ms-MY", name = 'ms-MY-Wavenet-D',
)

# %%
directory = '/home/husein/ssd2/ms-MY-Wavenet-D'
# !rm -rf {directory}
# !mkdir {directory}
# Out:
# E0119 16:48:02.583560577  937064 fork_posix.cc:70]           Fork support is only compatible with the epoll1 and poll polling strategies

# %%
with open('gtts-text.json') as fopen:
    texts = json.load(fopen)

# %%
for no in tqdm(range(len(texts))):
    t = texts[no]
    filename = f'{no}.mp3'
    filename = os.path.join(directory, filename)
    if os.path.exists(filename):
        continue
    
    synthesis_input = texttospeech.SynthesisInput(text=t)
    
    response = client.synthesize_speech(
        input=synthesis_input, voice=voice, audio_config=audio_config
    )

    # The response's audio_content is binary.
    with open(filename, "wb") as out:
        # Write the response to the output file.
        out.write(response.audio_content)
# Out:
#  19%|██████▋                             | 5777/31069 [08:52<1:27:51,  4.80it/s]

# %%
# !ls -lh /home/husein/ssd2/ms-MY-Wavenet-D/1.mp3
# Out:
# E0119 16:48:15.530031653  937064 fork_posix.cc:70]           Fork support is only compatible with the epoll1 and poll polling strategies
# -rw-r--r-- 1 husein husein 31K Jan  19 16:48 /home/husein/ssd2/ms-MY-Wavenet-D/1.mp3

# %%
import IPython.display as ipd
ipd.Audio('/home/husein/ssd2/ms-MY-Wavenet-D/5777.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
