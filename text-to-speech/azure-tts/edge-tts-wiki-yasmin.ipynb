# %%
# !~/.local/bin/edge-tts --list-voices
# ms-MY-OsmanNeural, ms-MY-YasminNeural
# !~/.local/bin/edge-tts --voice ms-MY-OsmanNeural --text "saya suka makan ayam." --write-media test.wav

# %%
# !wget https://huggingface.co/datasets/huseinzol05/Malay-TTS-Yasmin/resolve/main/populated-parliament.json

# %%
import os

os.environ['CUDA_VISIBLE_DEVICES'] = ''
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
import json

with open('populated-wiki.json') as fopen:
    data = json.load(fopen)

# %%
data[0]['text']
# Out:
# 'Pelepasan tahap akhir zanpakutonya tidak diketahui.'

# %%
import malaya

normalizer = malaya.normalize.normalizer()
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.5.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.6.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.8/site-packages/tensorflow_addons/utils/resource_loader.py:72: UserWarning: You are currently using TensorFlow 2.6.0 and trying to load a custom op (custom_ops/seq2seq/_beam_search_ops.so).
# TensorFlow Addons has compiled its custom ops against TensorFlow 2.4.0, and there are no compatibility guarantees between the two versions.
# This means that you might get segfaults when loading the custom op, or other kind of low-level errors.
#  If you do, do not file an issue on Github. This is a known limitation.
#
# It might help you to fallback to pure Python ops with TF_ADDONS_PY_OPS . To do that, see https://github.com/tensorflow/addons#gpucpu-custom-ops
#
# You can also change the TensorFlow version installed on your system. You would need a TensorFlow version equal to or above 2.4.0 and strictly below 2.5.0.
#  Note that nightly versions of TensorFlow, as well as non-pip TensorFlow like `conda install tensorflow` or compiled from source are not supported.
#
# The last solution is to find the TensorFlow Addons version that has custom ops compatible with the TensorFlow installed on your system. To do that, refer to the readme: https://github.com/tensorflow/addons
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.8/site-packages/malaya_boilerplate/frozen_graph.py:35: UserWarning: Cannot import beam_search_ops from Tensorflow Addons, ['malaya.jawi_rumi.deep_model', 'malaya.phoneme.deep_model', 'malaya.rumi_jawi.deep_model', 'malaya.stem.deep_model'] will not available to use, make sure Tensorflow Addons version >= 0.12.0
#   warnings.warn(

# %%
directory = 'yasmin-wiki-edge-tts'
directory_text = 'yasmin-wiki-edge-tts-text'

# %%
# os.system(f'rm -rf {directory}')
# os.system(f'rm -rf {directory_text}')

# %%
os.makedirs(directory, exist_ok = True)
os.makedirs(directory_text, exist_ok = True)

# %%
def generate_tts(text, filename):
    text = text.replace('"', r'\"').replace("'", r'\'')
    command = f'~/.local/bin/edge-tts --voice ms-MY-YasminNeural --text "{text}" --write-media {filename}'
    # print(command)
    os.system(command)

# %%
data[-10:]
# Out:
# [{'text': '=== Pusingan kedua === Perlawanan pertama dilangsungkan pada 29 dan 30 Julai, manakala perlawanan kedua pada dan Ogos 2008.',
#   'cleaned': '=== Pusingan kedua === Perlawanan pertama dilangsungkan pada 29 dan 30 Julai , manakala perlawanan kedua pada dan Ogos 2008.'},
#  {'text': 'Kubica menyertai pasukan Renault pada tahun 2010.',
#   'cleaned': 'Kubica menyertai pasukan Renault pada tahun 2010.'},
#  {'text': "'' ''Ya Sami', walau tiada siapa yang mendengar rintihanku, ku yakin sepenuhnya Engkau tetap sudi mendengar ku.",
#   'cleaned': "'' '' Ya Sami ', walau tiada siapa yang mendengar rintihanku , ku yakin sepenuhnya Engkau tetap sudi mendengar ku ."},
#  {'text': "Hikayat '''Raja Tambikbaya''' merupakan sebuah hikayat lama Melayu yang terpengaruh oleh corak kesusasteraan Hindu.",
#   'cleaned': "Hikayat ''' Raja Tambikbaya ''' merupakan sebuah hikayat lama Melayu yang terpengaruh oleh corak kesusasteraan Hindu ."},
#  {'text': 'Journalists and publishers were fined or sentenced to death.',
#   'cleaned': 'Journalists and publishers were fined or sentenced to death .'},
#  {'text': 'Anjing itu mati di angkasa dan merupakan haiwan hidup pertama yang memasuki angkasa.',
#   'cleaned': 'Anjing itu mati di angkasa dan merupakan haiwan hidup pertama yang memasuki angkasa .'},
#  {'text': 'Tokyo merupakan pusat kerajaan Jepun dan Istana Diraja, dan juga tempat bersemayam Wangsa Diraja Jepun.',
#   'cleaned': 'Tokyo merupakan pusat kerajaan Jepun dan Istana Diraja , dan juga tempat bersemayam Wangsa Diraja Jepun .'},
#  {'text': 'Dalam penggunaan kini, nama yang digunakan untuk rum sering berdasarkan tempat asal rum itu.',
#   'cleaned': 'Dalam penggunaan kini , nama yang digunakan untuk rum sering berdasarkan tempat asal rum itu .'},
#  {'text': "Terdapat juga sejumlah tempat keramat ''Gongbei'' yang berpusat sekeliling kubur tuan-tuan guru sufi.",
#   'cleaned': "Terdapat juga sejumlah tempat keramat '' Gongbei '' yang berpusat sekeliling kubur tuan - tuan guru sufi ."},
#  {'text': "Dekad '''1280-an SM''' merupakan tahun-tahun dari 1289 SM hingga 1280 SM.",
#   'cleaned': "Dekad '''1280- an SM ''' merupakan tahun - tahun dari 1289 SM hingga 1280 SM ."}]

# %%
n = normalizer.normalize('Daripada jumlah tersebut , / sebanyak RM5.82 bilion telah diagihkan kepada JPN Sabah untuk suku tahun pertama 2016 .',
                    normalize_entity = False)['normalize']

# %%
import re

def postprocessing(string):
    string = string.replace('/', ' ').replace('*', ' ').replace('=', ' ')
    return re.sub(r'[ ]+', ' ', string).strip()

postprocessing(n)
# Out:
# 'Daripada jumlah tersebut , sebanyak lima bilion lapan ratus dua puluh juta ringgit telah diagihkan kepada JPN Sabah untuk suku tahun pertama dua ribu enam belas .'

# %%
n = normalizer.normalize('=== hidup === --', normalize_entity = False)['normalize']
n = postprocessing(n)
n
# Out:
# 'hidup - -'

# %%
generate_tts('A', 'test.mp3')

# %%
import IPython.display as ipd
ipd.Audio('test.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from tqdm import tqdm

for i in tqdm(range(len(data))):
    try:
        
        filename = os.path.join(directory, f'{i}.mp3')
        filename_text = os.path.join(directory_text, f'{i}.json')
        
        if os.path.exists(filename_text):
            continue
            
        n = normalizer.normalize(data[i]['text'], normalize_entity = False)['normalize']
        n = postprocessing(n)
        if len(n):
            generate_tts(n, filename)
            with open(filename_text, 'w') as fopen:
                json.dump({'original': data[i]['text'], 'normalized': n}, fopen)
    except Exception as e:
        print(e)
# Out:
#  21%|█████████████████▉                                                                   | 25239/120000 [00:00<00:00, 132981.69it/s]
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
/s]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
#  59%|██████████████████████████████████████████████████▌                                   | 70521/120000 [46:34<13:55:17,  1.01s/it]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
#  59%|██████████████████████████████████████████████████▋                                   | 70641/120000 [48:36<15:13:13,  1.11s/it]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
#  59%|██████████████████████████████████████████████████▋                                   | 70719/120000 [49:55<11:14:57,  1.22it/s]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
#  59%|██████████████████████████████████████████████████▋                                   | 70766/120000 [50:41<12:25:07,  1.10it/s]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
#  59%|██████████████████████████████████████████████████▋                                   | 70813/120000 [51:26<13:27:15,  1.02it/s]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
#  59%|██████████████████████████████████████████████████▊                                   | 70828/120000 [51:40<13:22:35,  1.02it/s]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
#  59%|██████████████████████████████████████████████████▊                                   | 70927/120000 [53:14<15:06:42,  1.11s/it]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
#  59%|██████████████████████████████████████████████████▊                                   | 70976/120000 [54:02<12:05:26,  1.13it/s]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
#  59%|██████████████████████████████████████████████████▉                                   | 70997/120000 [54:20<10:23:13,  1.31it/s]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
#  59%|██████████████████████████████████████████████████▉                                   | 71019/120000 [54:40<12:45:49,  1.07it/s]
# string index out of range
#  59%|██████████████████████████████████████████████████▉                                   | 71071/120000 [55:26<11:24:21,  1.19it/s]Traceback (most recent call last):
# ...
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
#  99%|████████████████████████████████████████████████████████████████████████████████████▍| 119280/120000 [14:55:59<12:12,  1.02s/it]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
# 100%|████████████████████████████████████████████████████████████████████████████████████▌| 119468/120000 [14:59:28<09:14,  1.04s/it]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
# 100%|████████████████████████████████████████████████████████████████████████████████████▋| 119474/120000 [14:59:34<08:38,  1.02it/s]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
# 100%|████████████████████████████████████████████████████████████████████████████████████▋| 119490/120000 [14:59:50<08:27,  1.01it/s]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
# 100%|████████████████████████████████████████████████████████████████████████████████████▋| 119508/120000 [15:00:11<09:05,  1.11s/it]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
# 100%|████████████████████████████████████████████████████████████████████████████████████▋| 119522/120000 [15:00:23<06:37,  1.20it/s]sh: 1: Syntax error: EOF in backquote substitution
# 100%|████████████████████████████████████████████████████████████████████████████████████▋| 119553/120000 [15:01:02<09:04,  1.22s/it]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
# 100%|████████████████████████████████████████████████████████████████████████████████████▋| 119628/120000 [15:02:18<07:10,  1.16s/it]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
# 100%|████████████████████████████████████████████████████████████████████████████████████▊| 119719/120000 [15:03:45<03:46,  1.24it/s]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
# 100%|████████████████████████████████████████████████████████████████████████████████████▊| 119808/120000 [15:05:21<03:29,  1.09s/it]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
# 100%|████████████████████████████████████████████████████████████████████████████████████▉| 119873/120000 [15:06:29<02:05,  1.01it/s]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
# 100%|████████████████████████████████████████████████████████████████████████████████████▉| 119923/120000 [15:07:17<01:13,  1.04it/s]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
# 100%|████████████████████████████████████████████████████████████████████████████████████▉| 119976/120000 [15:08:07<00:22,  1.07it/s]Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 337, in run
#     metadata_duration = metadata["Metadata"][0]["Data"][
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/bin/edge-tts", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 154, in main
#     asyncio.get_event_loop().run_until_complete(_main())
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 147, in _main
#     await _tts(args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/util.py", line 33, in _tts
#     async for i in tts.run(
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/edge_tts/communicate.py", line 341, in run
#     raise ValueError(
# ValueError: The metadata doesn't contain a Duration field. This usually happens when SentenceBoundary metadata type is sent.
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 120000/120000 [15:08:29<00:00,  2.20it/s]

# %%
# from pydub import AudioSegment
# sound = AudioSegment.from_mp3("test.mp3")
# sound.export("test.wav", format="wav")

# %%
from glob import glob
mp3s = glob(os.path.join(directory, '*.mp3'))
jsons = glob(os.path.join(directory_text, '*.json'))
len(mp3s)
# Out:
# 119858

# %%
import IPython.display as ipd
ipd.Audio(mp3s[-1000])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mp3s[-1000]
# Out:
# 'yasmin-wiki-edge-tts/616.mp3'

# %%
# !cat osman-wiki-edge-tts-text/616.json
# Out:
# {"original": "Beliau berpindah ke Kuala Lumpur ketika berumur 12 tahun.", "normalized": "Beliau berpindah ke Kuala Lumpur ketika berumur dua belas tahun ."}
