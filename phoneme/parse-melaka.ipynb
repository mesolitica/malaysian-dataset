# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
import json
import pandas as pd
from bs4 import BeautifulSoup

# %%
# !wget https://raw.githubusercontent.com/huseinzol05/malay-dataset/master/dictionary/dialect/melaka.csv

# %%
df = pd.read_csv('melaka.csv')
df
# Out:
#                                                     0  \
# 0                                         angen gadai
# 1                                               jelat
# 2   2. berkenaan dengan orang atau haiwan yang mem...
# 3   2. terpaksa melakukan sesuatu pekerjaan yang m...
# 4   2. mendukung seseorang di bahagian belakang ba...
# 5   2. menakik-nakik sesuatu yang keras seperti ta...
# 6                                           penanggah
# 7   2. kayu penahan yang dipasang di kiri kanan ti...
# 8                                           mempisang
# 9   2. tempat meletakkan hidangan di luar rumah ya...
# 10                                         menyelanak
# 11                                           cangcang
# 12                                              recak
# 13                                          rumah ibu
#
#                                                     1  \
# 0                                      [A.Nen gA.dAj]
# 1                                           [dZ«.lAt]
# 2           Jelat beno budak ni, nasik basi pon abes.
# 3         Menyelanak aku kene buat kerje terok-terok.
# 4   Meh atuk cangcang engkau, boleh jalan cepat si...
# 5   Cobe kau recak pangkal pokok pisang ni, biau s...
# 6                                        [p«.nAN.gAh]
# 7   Kau nak pasang kayu mempisang kene kiri kanan ...
# 8                                        [m«m.pi.sAN]
# 9   Eh, penanggah kau tak siap lagi ke, mana nak l...
# 10                          [m«.ø«.lA.nA/] kata kerja
# 11                                        [tSAN.tSAN]
# 12                                          [Ä«.tSA/]
# 13                                      [Äu.mAh i.bu]
#
#                                                     2  \
# 0   angin yang bertiup kencang dan laut yang berom...
# 1                                       kata adjektif
# 2    [dZ«.lAt b«.n bu.dA/ ni nA.si/ bA.si pon A.bes]
# 3   [m«.ø«.lA.nA/ A.ku k«.n« bu.wAt k«Ä.dZ« t«.Äo/...
# 4   [meh A.tu/ tSAN.tSAN «N.kAw bo.leh dZA.lAn tS«...
# 5   [tSo.b« kAw Ä«.tSA/ pAN.kAl po.ko/ pi.sAN ni b...
# 6                                           kata nama
# 7   [kAw nA/ pA.sAN kA.ju m«m.pi.sAN k«.n« ki.Äi k...
# 8                                           kata nama
# 9   [eh p«.nAN.gAh kAw tA/ si.jAp lA.gi k« mA.nA n...
# 10                                         kata kerja
# 11                                         kata kerja
# 12                                         kata kerja
# 13  bahagian rumah yang paling besar yang mempunya...
#
#                                                     3  \
# 0   Nampaknye kite tak boleh ke laot, angen gadai ...
# 1                              1. degil; himol, baut.
# 2    Jelat benar budak ini, nasi basi pun dimakannya.
# 3         Menyelanak aku kena buat kerja teruk-teruk.
# 4   Mari atuk dukung engkau di belakang, boleh jal...
# 5   Cuba engkau recak pangkal pokok pisang ni, bia...
# 6   1. orang yang membantu melayan tetamu dalam ke...
# 7   Kau nak pasang kayu mempisang kene kiri kanan ...
# 8   1. kayu kecil yang dipasang memanjang dari kem...
# 9   Eh, penanggah engkau tidak siap lagikah? Di ma...
# 10  1. melakukan aktiviti lasak yang tidak berfaed...
# 11                               1. agak atau anggar.
# 12  1. menakik-nakik hujung buah durian untuk menc...
# 13  Bapak kau kalau buat rumah ibu, buat le bilekn...
#
#                                                     4  \
# 0   [nAm.pA/.ø« ki.t« tA/ bo.leh k« lAot A.Nen gA....
# 1                                 Kau ni jelat betol.
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6       Semue penanggah kite beri kue dan bunge telo.
# 7                                                 NaN
# 8   Kau kene pasang mempisang, nanti sapan perahu ...
# 9                                                 NaN
# 10   Menyelanak aje keje engkau, kan dah dekat pekse.
# 11  Cobe cangcang, berape gantang beras nak gune k...
# 12  Durian ni kulet tebal, kena recak banyak kali,...
# 13  [bA.pAk kAw kA.lAw bu.wAt Äu.mAh i.bu bu.wAt l...
#
#                                                     5  \
# 0   Nampaknya kita tak boleh ke laut, angin gadai ...
# 1                             [kAw ni dZ«.lAt b«.tol]
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   [s«.mu.w« p«.nAN.gAh ki.t« b«.Äi kue dAn bu.N«...
# 7                                                 NaN
# 8   [kAw k«.n« pA.sAN m«m.pi.sAN nAn.ti sA.pAn p«....
# 9                                                 NaN
# 10  [m«.ø«.lA.nA/ A.dZ« k«.dZ« «N.kAw kAn dAh d«.k...
# 11  [tSo.b« tSAN.tSAN b«.ÄA.p« gAn.tAN b«.ÄAs nA/ ...
# 12  [du.Äi.jAn ni ku.let t«.bAl k«.nA Ä«.tSA/ bA.ø...
# 13  Bapak kau kalau buat rumah ibu, buatlah bilikn...
#
#                                                     6
# 0                                                 NaN
# 1                                 Kau ni degil betul.
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6     Semua penanggah kita beri kuih dan bunga telur.
# 7                                                 NaN
# 8   Kau kena pasang mempisang, nanti rosak perahu ...
# 9                                                 NaN
# 10  Menyelanak sahaja kerja engkau ini, kan dah na...
# 11  Cuba anggar, berapa gantang beras diperlukan s...
# 12  Durian ini berkulit tebal, kena recak banyak k...
# 13                                                NaN

# %%
import malaya
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.5.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.6.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.8/site-packages/tensorflow_addons/utils/resource_loader.py:72: UserWarning: You are currently using TensorFlow 2.6.0 and trying to load a custom op (custom_ops/seq2seq/_beam_search_ops.so).
# TensorFlow Addons has compiled its custom ops against TensorFlow 2.4.0, and there are no compatibility guarantees between the two versions.
# This means that you might get segfaults when loading the custom op, or other kind of low-level errors.
#  If you do, do not file an issue on Github. This is a known limitation.
#
# It might help you to fallback to pure Python ops with TF_ADDONS_PY_OPS . To do that, see https://github.com/tensorflow/addons#gpucpu-custom-ops
#
# You can also change the TensorFlow version installed on your system. You would need a TensorFlow version equal to or above 2.4.0 and strictly below 2.5.0.
#  Note that nightly versions of TensorFlow, as well as non-pip TensorFlow like `conda install tensorflow` or compiled from source are not supported.
#
# The last solution is to find the TensorFlow Addons version that has custom ops compatible with the TensorFlow installed on your system. To do that, refer to the readme: https://github.com/tensorflow/addons
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.8/site-packages/malaya_boilerplate/frozen_graph.py:28: UserWarning: Cannot import beam_search_ops from Tensorflow Addons, `deep_model` for stemmer will not available to use, make sure Tensorflow Addons version >= 0.12.0
#   warnings.warn(

# %%
columns = [1, 2, 4, 5]

# %%
results = {}
for c in columns:
    for i in range(len(df)):
        try:
            stripped = df.iloc[i, c].strip()
            if stripped[0] == '[' and stripped[-1] == ']':
                before = df.iloc[i, c - 1].strip()
                splitted = malaya.text.function.split_into_sentences(before, minimum_length = 4)
                if len(splitted) > 1:
                    stripped_splitted = stripped.split('] [')[0]
                    before = splitted[0]
                    stripped = stripped_splitted + ']'
                results[before] = stripped[1:-1]
        except Exception as e:
            print(e)
# Out:
# 'float' object has no attribute 'strip'
# 'float' object has no attribute 'strip'
# 'float' object has no attribute 'strip'
# 'float' object has no attribute 'strip'
# 'float' object has no attribute 'strip'
# 'float' object has no attribute 'strip'
# 'float' object has no attribute 'strip'
# 'float' object has no attribute 'strip'
# 'float' object has no attribute 'strip'
# 'float' object has no attribute 'strip'
# 'float' object has no attribute 'strip'
# 'float' object has no attribute 'strip'

# %%
results
# Out:
# {'angen gadai': 'A.Nen gA.dAj',
#  'jelat': 'dZ«.lAt',
#  'penanggah': 'p«.nAN.gAh',
#  'mempisang': 'm«m.pi.sAN',
#  'cangcang': 'tSAN.tSAN',
#  'recak': 'Ä«.tSA/',
#  'rumah ibu': 'Äu.mAh i.bu',
#  'Jelat beno budak ni, nasik basi pon abes.': 'dZ«.lAt b«.n\x8d bu.dA/ ni nA.si/ bA.si pon A.bes',
#  'Menyelanak aku kene buat kerje terok-terok.': 'm«.ø«.lA.nA/ A.ku k«.n« bu.wAt k«Ä.dZ« t«.Äo/.t«.Äo/',
#  'Meh atuk cangcang engkau, boleh jalan cepat sikit.': 'meh A.tu/ tSAN.tSAN «N.kAw bo.leh dZA.lAn tS«.pAt si.ket',
#  'Cobe kau recak pangkal pokok pisang ni, biau subo.': 'tSo.b« kAw Ä«.tSA/ pAN.kAl po.ko/ pi.sAN ni bi.jAw su.bo',
#  'Kau nak pasang kayu mempisang kene kiri kanan baru kuat.': 'kAw nA/ pA.sAN kA.ju m«m.pi.sAN k«.n« ki.Äi kA.nAn bA.Äu ku.wAt',
#  'Eh, penanggah kau tak siap lagi ke, mana nak letak makanan.': 'eh p«.nAN.gAh kAw tA/ si.jAp lA.gi k« mA.nA nA/ l«.tA/ mA.kA.nAn',
#  'Nampaknye kite tak boleh ke laot, angen gadai kencang.': 'nAm.pA/.ø« ki.t« tA/ bo.leh k« lAot A.Nen gA.dAj k«n.tSAN',
#  'Bapak kau kalau buat rumah ibu, buat le bileknye sekali': 'bA.pAk kAw kA.lAw bu.wAt Äu.mAh i.bu bu.wAt l« bi.le/.ø« s«.kA.li',
#  'Kau ni jelat betol.': 'kAw ni dZ«.lAt b«.tol',
#  'Semue penanggah kite beri kue dan bunge telo.': 's«.mu.w« p«.nAN.gAh ki.t« b«.Äi kue dAn bu.N« t«.lo',
#  'Kau kene pasang mempisang, nanti sapan perahu kau.': 'kAw k«.n« pA.sAN m«m.pi.sAN nAn.ti sA.pAn p«.Ä«.hu kAw',
#  'Menyelanak aje keje engkau, kan dah dekat pekse.': 'm«.ø«.lA.nA/ A.dZ« k«.dZ« «N.kAw kAn dAh d«.kAt pe/.s«',
#  'Cobe cangcang, berape gantang beras nak gune kenduri tu nanti.': 'tSo.b« tSAN.tSAN b«.ÄA.p« gAn.tAN b«.ÄAs nA/ gu.n« k«n.du.Äi tu nAn.ti',
#  'Durian ni kulet tebal, kena recak banyak kali, baru boleh bukak.': 'du.Äi.jAn ni ku.let t«.bAl k«.nA Ä«.tSA/ bA.øA/ kA.li bA.Äu bo.leh bu.kA/'}

# %%
results
# Out:
# {'angen gadai': 'A.Nen gA.dAj',
#  'jelat': 'dZ«.lAt',
#  'penanggah': 'p«.nAN.gAh',
#  'mempisang': 'm«m.pi.sAN',
#  'cangcang': 'tSAN.tSAN',
#  'recak': 'Ä«.tSA/',
#  'rumah ibu': 'Äu.mAh i.bu',
#  'Jelat beno budak ni, nasik basi pon abes.': 'dZ«.lAt b«.n\x8d bu.dA/ ni nA.si/ bA.si pon A.bes',
#  'Menyelanak aku kene buat kerje terok-terok.': 'm«.ø«.lA.nA/ A.ku k«.n« bu.wAt k«Ä.dZ« t«.Äo/.t«.Äo/',
#  'Meh atuk cangcang engkau, boleh jalan cepat sikit.': 'meh A.tu/ tSAN.tSAN «N.kAw bo.leh dZA.lAn tS«.pAt si.ket',
#  'Cobe kau recak pangkal pokok pisang ni, biau subo.': 'tSo.b« kAw Ä«.tSA/ pAN.kAl po.ko/ pi.sAN ni bi.jAw su.bo',
#  'Kau nak pasang kayu mempisang kene kiri kanan baru kuat.': 'kAw nA/ pA.sAN kA.ju m«m.pi.sAN k«.n« ki.Äi kA.nAn bA.Äu ku.wAt',
#  'Eh, penanggah kau tak siap lagi ke, mana nak letak makanan.': 'eh p«.nAN.gAh kAw tA/ si.jAp lA.gi k« mA.nA nA/ l«.tA/ mA.kA.nAn',
#  'Nampaknye kite tak boleh ke laot, angen gadai kencang.': 'nAm.pA/.ø« ki.t« tA/ bo.leh k« lAot A.Nen gA.dAj k«n.tSAN',
#  'Bapak kau kalau buat rumah ibu, buat le bileknye sekali': 'bA.pAk kAw kA.lAw bu.wAt Äu.mAh i.bu bu.wAt l« bi.le/.ø« s«.kA.li',
#  'Kau ni jelat betol.': 'kAw ni dZ«.lAt b«.tol',
#  'Semue penanggah kite beri kue dan bunge telo.': 's«.mu.w« p«.nAN.gAh ki.t« b«.Äi kue dAn bu.N« t«.lo',
#  'Kau kene pasang mempisang, nanti sapan perahu kau.': 'kAw k«.n« pA.sAN m«m.pi.sAN nAn.ti sA.pAn p«.Ä«.hu kAw',
#  'Menyelanak aje keje engkau, kan dah dekat pekse.': 'm«.ø«.lA.nA/ A.dZ« k«.dZ« «N.kAw kAn dAh d«.kAt pe/.s«',
#  'Cobe cangcang, berape gantang beras nak gune kenduri tu nanti.': 'tSo.b« tSAN.tSAN b«.ÄA.p« gAn.tAN b«.ÄAs nA/ gu.n« k«n.du.Äi tu nAn.ti',
#  'Durian ni kulet tebal, kena recak banyak kali, baru boleh bukak.': 'du.Äi.jAn ni ku.let t«.bAl k«.nA Ä«.tSA/ bA.øA/ kA.li bA.Äu bo.leh bu.kA/'}

# %%
with open('melaka-phoneme.json', 'w') as fopen:
    json.dump(results, fopen)
