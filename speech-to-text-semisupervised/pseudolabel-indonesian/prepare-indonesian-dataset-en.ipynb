# %%
from glob import glob
from tqdm import tqdm
import json
import numpy as np
import os
from transformers import AutoTokenizer, WhisperConfig
from sklearn.feature_extraction.text import CountVectorizer

config = WhisperConfig.from_pretrained('openai/whisper-large-v3')
maxlen = config.max_length - 3

# %%
tokenizer = AutoTokenizer.from_pretrained('openai/whisper-large-v3')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
from datasets import Audio

sr = 16000
audio = Audio(sampling_rate=sr)

# %%
files = sorted(glob('output-indonesian-v2/*.json'), key = lambda x: int(x.split('-')[-1].replace('.json', '')))
len(files)
# Out:
# 10328

# %%
import re

pattern_pair = r'<\|(\d+\.\d+)\|>(.*?)<\|(\d+\.\d+)\|>'
matches = re.findall(pattern_pair, '<|0.00|> kerajaan persekutuan<|1.46|><|1.46|> dan banyak masalah hubungan<|3.96|><|3.96|> antara kerajaan negeri dan')
matches
# Out:
# [('0.00', ' kerajaan persekutuan', '1.46'),
#  ('1.46', ' dan banyak masalah hubungan', '3.96')]

# %%
import string

punct = set(string.punctuation)

def remove_punct(s):
    return ''.join([c for c in s if c not in punct])

def remove_duplicate(string, n = 3):
    splitted = string.split()
    n = [splitted[i: i + n] for i in range(0, len(splitted), n)]
    already = set()
    dedup = []
    for n_ in n:
        original_n = ' '.join(n_)
        n_ = ' '.join(n_).lower()
        n_ = remove_punct(n_)
        if n_ not in already:
            dedup.append(original_n)
            already.add(n_)
    return ' '.join(dedup)

# %%
import math

def round_to_nearest_0_02(number):
    return round(number * 50) / 50

# %%
selected = [
    'terima kasih kerana menonton',
    'terima kasih',
]

# %%
# tokenizer.decode(d[0]['predict_en'], decode_with_timestamps = True)

# %%
len(files)
# Out:
# 10328

# %%
from huggingface_hub import hf_hub_download

# %%
f = hf_hub_download(
    repo_id="mesolitica/pseudolabel-indonesian-large-v3-timestamp", 
    filename="translated-indonesian-en.json",
    repo_type = 'dataset'
)

# %%
with open(f) as fopen:
    translation = json.load(fopen)

len(translation)
# Out:
# 326191

# %%
keys = list(translation.keys())

# %%
translation[keys[0]]
# Out:
# "criminals for society How to not be affected by this turn I swear <> you talk a day after talking about what is difficult is still difficult, those who do not get justice are still not <> get it so rest, better focus on your life, your family, your environment, don't be"

# %%
keys[0]
# Out:
# ' penjahat-penjahat untuk masyarakat Bagaimana tidak terpengaruhi dengan giliran tadi sumpah <> lu sehari habis nyobrol yang susah tetap susah yang yang nggak dapet keadilan tetap masih nggak <> dapet jadi santai mending fokus kehidup lu keluarga lu lingkungan lu jangan jangan jadi'

# %%
popped = []
for k in list(keys):
    v = translation[k]
    v = re.sub(r'\s-', '-', v)
    v = v.replace('< >', '<>').replace(' >', '<>')
        
    translation[k] = v
    k_split = k.split('<>')
    v_split = v.split('<>')
    
    if len(k_split) != len(v_split):
        translation.pop(k, None)
        popped.append((k_split, v_split, k, v))

# %%
len(popped)
# Out:
# 39590

# %%
popped[0]
# Out:
# ([' Hari raya dapat juga tunjangan ',
#   ' Kita melihat loh ya ',
#   ' Cewek-cewek begitu tuh ',
#   ' Mereka tuh bener-bener menjaga penampilan ',
#   ' Terus all out ',
#   ' Dalam melayani tamu ',
#   ' Karena kalau gak all out terdepak ',
#   ' Istilahnya mereka tuh ',
#   ' Melakukan sepenuh hati ',
#   ' Atas ',
#   ' Passionnya mereka ',
#   ' Atau memang mereka ',
#   ' Sesuatu yang ',
#   ' Yaudah untuk uang aja ',
#   ' Gimana tuh'],
#  ["Even if it's a holiday, you can get an allowance. Let's see a girl like that. Take care of her appearance. Keep going all the way. In treating guests, they will be kicked out if they don't finish it. In other words, they do it with all their heart. Because of the passion. Or are they something that is good for money. So what?"],
#  ' Hari raya dapat juga tunjangan <> Kita melihat loh ya <> Cewek-cewek begitu tuh <> Mereka tuh bener-bener menjaga penampilan <> Terus all out <> Dalam melayani tamu <> Karena kalau gak all out terdepak <> Istilahnya mereka tuh <> Melakukan sepenuh hati <> Atas <> Passionnya mereka <> Atau memang mereka <> Sesuatu yang <> Yaudah untuk uang aja <> Gimana tuh',
#  "Even if it's a holiday, you can get an allowance. Let's see a girl like that. Take care of her appearance. Keep going all the way. In treating guests, they will be kicked out if they don't finish it. In other words, they do it with all their heart. Because of the passion. Or are they something that is good for money. So what?")

# %%
import mp
import copy

minimum_score = 5

def loop(files):
    
    tokenizer = AutoTokenizer.from_pretrained('openai/whisper-large-v3')
    
    files, _ = files
    results = []
    for f in tqdm(files):
        try:
            with open(f) as fopen:
                data = json.load(fopen)
        except:
            continue
        f_split = os.path.split(f)[-1].replace('.json', '')
        for i in range(len(data)):
            
            audio_filename = data[i]['filename']
            if not os.path.exists(audio_filename):
                continue
                
            y = audio.decode_example(audio.encode_example(audio_filename))['array']
            len_y = len(y) / sr
            if len_y > 30:
                continue
                
            rounded_num = f'<|{round_to_nearest_0_02(len_y):.2f}|>'
                    
            
            if data[i]['score_id'] > minimum_score:
                
                a = tokenizer._decode_asr(
                [{'tokens': np.array([data[i]['predict_id']])}], 
                return_timestamps = True, return_language = 'id', 
                time_precision = 0.02)[1]['chunks']
            
                a = [a_['text'] for a_ in a]
                
                t = ' <>'.join(a)
                if t not in translation:
                    continue
                    
                t_translated = translation[t]
                t_translated_splitted = t_translated.split('<>')
                if len(t_translated_splitted) != len(a):
                    continue
                
                mapping = {}
                for k in range(len(a)):
                    s = t_translated_splitted[k].strip()
                    if a[k][0] == ' ':
                        s = ' ' + s
                    if a[k][-1] == ' ':
                        s = s + ' '
                    mapping[a[k]] = s
            
                a = np.array(data[i]['predict_id'])
                a = a[a != 50257].tolist() + [50257]
                t = tokenizer.decode(a, skip_special_tokens = True, decode_with_timestamps = True).strip()
                if t.split('|>')[-1] != '':
                    t += rounded_num
                
                matches = re.findall(pattern_pair, t)
                rs = []
                for match in matches:
                    l = float(match[0])
                    r = float(match[2])
                    t_ = match[1]
                    rt_ = re.sub('[^a-z ]+', '', t_.lower()).strip()
                    
                    if (r - l > 3) and any([s == rt_ for s in selected]):
                        # print(audio_filename, t_)
                        t_ = ''
                    else:
                        if t_ in mapping:
                            t_ = mapping[t_]
                        else:
                            t_ = ''
                    
                    splitted = t_.split()
                    if len(splitted):
                        ratio = (len(set(splitted)) / len(splitted))
                        if len(t_) > 100 and ratio < 0.5:
                            t_ = remove_duplicate(t_)
                    if len(t_) and t_[0] != ' ':
                        t_ = ' ' + t_
                        
                    rs.append(f'<|{match[0]}|>{t_}<|{match[2]}|>')
                rs = ''.join(rs)
                t = f'<|startoftranscript|><|en|><|transcribe|>{rs}<|endoftext|>'
                d = {
                    'new_text': t,
                    'audio_filename': audio_filename,
                }
                results.append(d)
    return results

# %%
results = loop((files[:10], 0))
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#  70%|███████   | 7/10 [00:12<00:03,  1.20s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 100%|██████████| 10/10 [00:14<00:00,  1.49s/it]

# %%
len(results)
# Out:
# 289

# %%
results[0]
# Out:
# {'new_text': "<|startoftranscript|><|en|><|transcribe|><|0.00|> That's what always<|3.00|><|3.00|> That sometimes<|4.00|><|4.00|> The wrong thing we always<|6.82|><|6.82|> There is always<|8.92|><|8.92|> That's why I said just about to return<|11.14|><|11.14|> In that sense I'm grateful<|13.00|><|13.00|> The term is when I<|14.92|><|14.92|> Have an example<|16.98|><|16.98|> Like Instagram or YouTube or something<|18.68|><|18.68|> It's more of me, I just want<|20.78|><|20.78|> It's like sharing<|23.40|><|23.40|> Because if I want to focus<|25.20|><|25.20|> Just for conflicts and so on<|26.96|><|26.96|> The problem is my problem in the world of health<|29.24|><|endoftext|>",
#  'audio_filename': 'split-indonesian/0-1-44160000.mp3'}

# %%
tokenizer = AutoTokenizer.from_pretrained('openai/whisper-medium')
ori_tokenizer = AutoTokenizer.from_pretrained('openai/whisper-large-v3')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
tokenizer.tokenize(results[-1]['new_text'])
# Out:
# ['<|startoftranscript|>',
#  '<|en|>',
#  '<|transcribe|>',
#  '<|0.00|>',
#  'ĠIt',
#  "'s",
#  'Ġdifficult',
#  ',',
#  'Ġthe',
#  'Ġproposal',
#  'Ġis',
#  'Ġover',
#  '<|1.96|>',
#  '<|1.96|>',
#  'Ġhow',
#  'Ġmany',
#  '<|3.20|>',
#  '<|3.20|>',
#  'Ġthere',
#  'Ġare',
#  'Ġ23',
#  ',',
#  'ĠI',
#  'Ġsaid',
#  '<|5.84|>',
#  '<|5.84|>',
#  'ĠPe',
#  'bi',
#  'Ġwants',
#  'Ġto',
#  'Ġbring',
#  'Ġ25',
#  ',',
#  'Ġcan',
#  'ĠI',
#  '<|7.98|>',
#  '<|7.98|>',
#  'Ġokay',
#  'ĠI',
#  "'ll",
#  'Ġlook',
#  'Ġfor',
#  'Ġit',
#  'Ġlater',
#  ',',
#  'ĠI',
#  "'ll",
#  'Ġadd',
#  'Ġit',
#  '<|10.08|>',
#  '<|10.08|>',
#  'ĠAl',
#  'ham',
#  'dul',
#  'illah',
#  ',',
#  'Ġso',
#  'Ġshe',
#  'Ġgot',
#  'Ġmarried',
#  '<|11.90|>',
#  '<|11.90|>',
#  'Ġdoesn',
#  "'t",
#  'Ġbother',
#  'Ġme',
#  ',',
#  'Ġmy',
#  '<|14.36|>',
#  '<|14.36|>',
#  'Ġinspirational',
#  'Ġwoman',
#  ',',
#  'Ġif',
#  'Ġasked',
#  '<|16.04|>',
#  '<|16.04|>',
#  'Ġproblem',
#  ',',
#  'ĠI',
#  'Ġwould',
#  'Ġdefinitely',
#  'Ġcry',
#  ',',
#  'ĠI',
#  'Ġremember',
#  '<|17.82|>',
#  '<|17.82|>',
#  'ĠOh',
#  'ĠAllah',
#  ',',
#  'Ġso',
#  'Ġwhere',
#  'Ġdoes',
#  '<|20.06|>',
#  '<|20.06|>',
#  'Ġshe',
#  'Ġlive',
#  '?',
#  'ĠSo',
#  'Ġat',
#  'Ġfirst',
#  'ĠI',
#  'Ġrented',
#  '<|22.12|>',
#  '<|22.12|>',
#  'Ġin',
#  'ĠP',
#  'ab',
#  'u',
#  'aran',
#  ',',
#  'Ġfrom',
#  'ĠP',
#  'ab',
#  'u',
#  'aran',
#  '<|23.78|>',
#  '<|23.78|>',
#  'ĠI',
#  'Ġmoved',
#  'Ġto',
#  'Ġthe',
#  'Ġback',
#  'Ġof',
#  'ĠRS',
#  'UD',
#  '<|26.04|>',
#  '<|26.04|>',
#  'Ġnow',
#  'Ġin',
#  'ĠGang',
#  'k',
#  'ant',
#  'il',
#  '.',
#  '<|27.74|>',
#  '<|endoftext|>']

# %%
results = mp.multiprocessing(files, loop, cores = 50)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/206 [00:00<?, ?it/s]Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   3%|▎         | 7/206 [00:03<01:31,  2.18it/s]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   0%|          | 1/206 [00:05<20:12,  5.91s/it]]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   0%|          | 1/206 [00:09<33:35,  9.83s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   0%|          | 1/206 [00:12<42:40, 12.49s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   2%|▏         | 4/206 [00:14<12:20,  3.67s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   2%|▏         | 5/206 [00:17<10:55,  3.26s/it]]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   1%|          | 2/206 [00:18<29:57,  8.81s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   1%|          | 2/206 [00:21<37:44, 11.10s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   1%|          | 2/206 [00:24<41:42, 12.27s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   6%|▌         | 12/206 [00:28<20:32,  6.35s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   1%|▏         | 3/206 [00:29<34:16, 10.13s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   5%|▍         | 10/206 [00:31<08:35,  2.63s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   1%|▏         | 3/206 [00:32<37:56, 11.22s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   2%|▏         | 4/206 [00:37<32:37,  9.69s/it]]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   6%|▋         | 13/206 [00:40<25:32,  7.94s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   6%|▋         | 13/206 [00:40<09:16,  2.89s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   2%|▏         | 4/206 [00:41<36:50, 10.94s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   2%|▏         | 5/206 [00:42<28:25,  8.48s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   7%|▋         | 14/206 [00:42<08:28,  2.65s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   2%|▏         | 4/206 [00:45<38:37, 11.47s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   7%|▋         | 15/206 [00:46<09:25,  2.96s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   2%|▏         | 4/206 [00:47<39:42, 11.80s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   2%|▏         | 5/206 [00:49<34:28, 10.29s/it]]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   3%|▎         | 6/206 [00:51<28:36,  8.58s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   8%|▊         | 17/206 [00:51<08:23,  2.66s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   9%|▊         | 18/206 [00:54<08:50,  2.82s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   2%|▏         | 5/206 [00:56<37:32, 11.21s/it]]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   2%|▏         | 5/206 [00:58<39:00, 11.65s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   3%|▎         | 6/206 [01:02<35:25, 10.63s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   7%|▋         | 15/206 [01:02<31:01,  9.75s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   3%|▎         | 6/206 [01:07<37:56, 11.38s/it]]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   3%|▎         | 6/206 [01:08<38:20, 11.50s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   3%|▎         | 6/206 [01:10<39:05, 11.73s/it]]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   3%|▎         | 7/206 [01:12<34:44, 10.47s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   3%|▎         | 7/206 [01:13<33:28, 10.09s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   3%|▎         | 7/206 [01:14<36:28, 11.00s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   3%|▎         | 7/206 [01:17<35:12, 10.62s/it]]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   3%|▎         | 7/206 [01:18<36:35, 11.03s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   3%|▎         | 7/206 [01:20<38:02, 11.47s/it]]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   3%|▎         | 7/206 [01:20<37:39, 11.35s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   3%|▎         | 7/206 [01:21<38:04, 11.48s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   4%|▍         | 8/206 [01:26<34:32, 10.47s/it]]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#   4%|▍         |
/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 100%|██████████| 206/206 [36:48<00:00, 10.72s/it]
# 100%|██████████| 206/206 [36:49<00:00, 10.73s/it]
# 100%|██████████| 206/206 [36:49<00:00, 10.73s/it]
# 100%|██████████| 206/206 [36:49<00:00, 10.73s/it]
# 100%|██████████| 206/206 [36:50<00:00, 10.73s/it]
# 100%|██████████| 206/206 [36:51<00:00, 10.74s/it]
# 100%|██████████| 206/206 [36:51<00:00, 10.73s/it]
# 100%|██████████| 206/206 [36:51<00:00, 10.73s/it]
# 100%|██████████| 206/206 [36:53<00:00, 10.74s/it]
# 100%|██████████| 206/206 [36:52<00:00, 10.74s/it]
# 100%|██████████| 206/206 [36:53<00:00, 10.74s/it]
# 100%|██████████| 206/206 [36:53<00:00, 10.74s/it]
# 100%|██████████| 206/206 [36:54<00:00, 10.75s/it]
# 100%|██████████| 206/206 [36:53<00:00, 10.74s/it]
# 100%|██████████| 206/206 [36:54<00:00, 10.75s/it]
# 100%|██████████| 206/206 [36:55<00:00, 10.75s/it]
# 100%|██████████| 206/206 [36:55<00:00, 10.76s/it]
# 100%|█████████▉| 205/206 [36:55<00:03,  3.18s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 100%|██████████| 206/206 [36:56<00:00, 10.76s/it]
# 100%|██████████| 206/206 [36:56<00:00, 10.76s/it]
# 100%|██████████| 206/206 [36:56<00:00, 10.76s/it]
# 100%|██████████| 206/206 [36:58<00:00, 10.77s/it]
# 100%|██████████| 206/206 [36:58<00:00, 10.77s/it]

# %%
len(results)
# Out:
# 301763

# %%
results[0]
# Out:
# {'new_text': "<|startoftranscript|><|en|><|transcribe|><|0.00|> That's what always<|3.00|><|3.00|> That sometimes<|4.00|><|4.00|> The wrong thing we always<|6.82|><|6.82|> There is always<|8.92|><|8.92|> That's why I said just about to return<|11.14|><|11.14|> In that sense I'm grateful<|13.00|><|13.00|> The term is when I<|14.92|><|14.92|> Have an example<|16.98|><|16.98|> Like Instagram or YouTube or something<|18.68|><|18.68|> It's more of me, I just want<|20.78|><|20.78|> It's like sharing<|23.40|><|23.40|> Because if I want to focus<|25.20|><|25.20|> Just for conflicts and so on<|26.96|><|26.96|> The problem is my problem in the world of health<|29.24|><|endoftext|>",
#  'audio_filename': 'split-indonesian/0-1-44160000.mp3'}

# %%
import IPython.display as ipd
ipd.Audio(results[0]['audio_filename'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
with open('prepared-indonesian-en.jsonl', 'w') as fopen:
    for r in tqdm(results):
        fopen.write(f'{json.dumps(r)}\n')
# Out:
# 100%|██████████| 301763/301763 [00:01<00:00, 240039.63it/s]

# %%
# !ls -lh prepared-indonesian-en.jsonl
# Out:
# -rw-r--r-- 1 ubuntu ubuntu 173M Apr 25 15:27 prepared-indonesian-en.jsonl
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
from huggingface_hub import HfApi
api = HfApi()

# %%
api.upload_file(
    path_or_fileobj='prepared-indonesian-en.jsonl',
    path_in_repo='prepared-indonesian-en.jsonl',
    repo_id='mesolitica/pseudolabel-indonesian-large-v3-timestamp',
    repo_type='dataset',
)
# Out:
# 'https://huggingface.co/datasets/mesolitica/pseudolabel-indonesian-large-v3-timestamp/blob/main/prepared-indonesian-en.jsonl'

# %%
results[:10]
# Out:
# [{'new_text': "<|startoftranscript|><|en|><|transcribe|><|0.00|> That's what always<|3.00|><|3.00|> That sometimes<|4.00|><|4.00|> The wrong thing we always<|6.82|><|6.82|> There is always<|8.92|><|8.92|> That's why I said just about to return<|11.14|><|11.14|> In that sense I'm grateful<|13.00|><|13.00|> The term is when I<|14.92|><|14.92|> Have an example<|16.98|><|16.98|> Like Instagram or YouTube or something<|18.68|><|18.68|> It's more of me, I just want<|20.78|><|20.78|> It's like sharing<|23.40|><|23.40|> Because if I want to focus<|25.20|><|25.20|> Just for conflicts and so on<|26.96|><|26.96|> The problem is my problem in the world of health<|29.24|><|endoftext|>",
#   'audio_filename': 'split-indonesian/0-1-44160000.mp3'},
#  {'new_text': '<|startoftranscript|><|en|><|transcribe|><|0.00|> In the world of health, no matter what we are right<|2.18|><|2.18|> He is wrong, when we show him<|4.28|><|4.28|> our truth, and we<|5.94|><|5.94|> As if we are swollen others<|7.34|><|7.34|> That is if there is a term, the old days. the era of<|9.40|><|9.40|> Roman statesman whose name is Cicero<|11.50|><|11.50|> If you have heard, he once wrote<|13.14|><|13.14|> One, not poetry<|15.52|><|15.52|> But some kind of writing he said<|17.76|><|17.76|> Six mistakes of a man<|18.94|><|18.94|> So the first mistake of a man, this is the most popular<|21.64|><|21.64|> That is, just an illusion<|23.98|><|23.98|> When when you<|25.30|><|25.30|> To make you feel better<|27.80|><|27.80|> You need to destroy others<|28.90|><|endoftext|>',
#   'audio_filename': 'split-indonesian/0-1-44640000.mp3'},
#  {'new_text': "<|startoftranscript|><|en|><|transcribe|><|0.00|> Why? Because the concept is like this, sis.<|1.50|><|1.60|> Brother, for example, is 160 tall.<|3.62|><|4.46|> But brother, I feel like being looked down upon by someone else.<|7.16|><|7.48|> So, for example, someone who is higher than you,<|9.96|><|10.10|> it's like you're pressing them down so they go down.<|12.50|><|12.90|> Just so that you're higher than him, brother is still 160.<|15.90|><|16.78|> Well, the point I want to convey is,<|18.46|><|18.92|> we have a tendency every day.<|20.50|><|20.72|> Well, that's called a man's mistake.<|22.26|><|22.26|> So it's already a habit, a human mistake that we often do.<|26.30|><|26.72|> So we want to lift ourselves up by destroying others.<|29.86|><|endoftext|>",
#   'audio_filename': 'split-indonesian/0-1-45120000.mp3'},
#  {'new_text': "<|startoftranscript|><|en|><|transcribe|><|0.00|> Do we destroy his reputation<|2.18|><|2.18|> Do we destroy his behavior and so on<|5.26|><|5.26|> So I think we study there<|7.52|><|7.52|> For us to say that is like yes yes<|9.16|><|9.16|> That's what satiam is called<|10.64|><|10.64|> As if honest with yourself<|12.36|><|12.36|> Self study is something Fun<|14.18|><|14.18|> I said earlier<|15.18|><|15.18|> Like communicating with myself<|17.04|><|17.04|> But back again<|17.90|><|17.90|> If I look at it, yes<|19.30|><|19.30|> If I say someone is arrogant, there is no<|21.16|><|21.16|> Indeed more about his lack of needs<|24.06|><|24.06|> Regarding the importance<|25.60|><|25.60|> If you have heard his writing<|28.14|><|28.14|> Tony Robbins for example<|29.52|><|endoftext|>",
#   'audio_filename': 'split-indonesian/0-1-45600000.mp3'},
#  {'new_text': "<|startoftranscript|><|en|><|transcribe|><|0.00|> There is a name<|1.18|><|1.18|> Six human needs<|2.84|><|2.84|> One is called<|5.58|><|5.58|> Definiteness<|7.02|><|7.02|> Two, uncertainty<|8.34|><|8.34|> Three, importance<|11.20|><|11.20|> Four, love and relationship<|12.42|><|12.42|> Then five, growth<|14.76|><|14.76|> Six, contribution<|15.92|><|15.92|> Well that means you can see there actually<|18.34|><|18.34|> When you see someone singing<|20.24|><|20.24|> Maybe it's their wit, their wealth<|23.20|><|23.20|> Or maybe<|24.00|><|24.00|> Their appearance, their beauty<|26.56|><|26.56|> It actually means if you think about it<|28.02|><|endoftext|>",
#   'audio_filename': 'split-indonesian/0-1-46080000.mp3'},
#  {'new_text': "<|startoftranscript|><|en|><|transcribe|><|0.00|> He lacks needs because of his lack of interests.<|3.44|><|3.56|> That's why he needs people to respect him.<|6.18|><|7.40|> Instead, there are others who, for example, corrupt.<|9.96|><|10.60|> In the end, he must corrupt.<|11.74|><|11.82|> In the end, now, for example, there are our friends too.<|14.06|><|14.22|> Maybe he became an officer.<|15.16|><|15.24|> It didn't happen intentionally so it must be corrupt.<|16.20|><|16.94|> We say basic, evil, taking other people's rights.<|19.64|><|19.76|> But if we can be honest.<|21.68|><|21.82|> We want to get into it.<|23.00|><|23.08|> We can see his analogy.<|24.26|><|24.66|> There is a need for less certainty.<|26.58|><|27.04|> I need money for this.<|29.16|><|29.26|> Need to do so.<|29.92|><|endoftext|>",
#   'audio_filename': 'split-indonesian/0-1-46560000.mp3'},
#  {'new_text': "<|startoftranscript|><|en|><|transcribe|><|0.00|> In fact, it's like jamming<|1.80|><|1.80|> Jamming people on the streets are the same<|3.34|><|3.34|> So the need for certainty is less<|6.96|><|6.96|> Now on the other hand there are adventurers<|9.40|><|9.40|> For example maybe<|10.84|><|10.84|> Can be a business<|12.60|><|12.60|> Can be drugs, can be alcohol<|14.48|><|14.48|> Can be anything<|15.52|><|15.52|> Less uncertainty<|18.34|><|18.34|> So less adventure<|20.14|><|20.14|> Fun<|21.82|><|21.82|> Less fun in life<|24.04|><|24.04|> So imagine if we<|25.72|><|25.72|> Can have such understanding<|27.50|><|27.50|> it's good<|28.78|><|endoftext|>",
#   'audio_filename': 'split-indonesian/0-1-47040000.mp3'},
#  {'new_text': "<|startoftranscript|><|en|><|transcribe|><|0.00|> everything when we see people singing hong hong<|2.04|><|2.04|> we don't at all<|3.64|><|3.64|> consider that as<|5.26|><|5.26|> because the spell of most people<|7.98|><|7.98|> in Indonesia is like if you wake up<|9.78|><|9.78|> you know what, bro?<|10.62|><|10.90|> okay the spell is that if you wake up in the morning<|13.92|><|13.92|> like this, what can make me<|15.90|><|15.90|> offended today?<|16.78|><|17.12|> well that he didn't realize<|20.18|><|20.18|> so he would be offended by anyone<|22.38|><|22.38|> like that, that's spell<|24.12|><|24.12|> like that, so you open the news directly<|25.80|><|25.80|> look for the news, how are you today?<|27.72|><|27.72|> What can I be offended today?<|29.14|><|endoftext|>",
#   'audio_filename': 'split-indonesian/0-1-47520000.mp3'},
#  {'new_text': '<|startoftranscript|><|en|><|transcribe|><|0.00|> There is interferon, there is intestinal bacteria, microbiome.<|4.28|><|4.40|> Well, but actually the gateway to our immune system is the nervous system.<|8.90|><|9.82|> Well, the nervous system is back, it is influenced if we talk about the autonomous nervous system.<|15.10|><|15.58|> There is something called a sympathetic and parasimpatetic nervous system.<|18.74|><|19.26|> Well, as long as we live with fear and anxiety,<|23.28|><|endoftext|>',
#   'audio_filename': 'split-indonesian/0-1-4800000.mp3'},
#  {'new_text': "<|startoftranscript|><|en|><|transcribe|><|0.00|> can i comment on that<|1.14|><|1.14|> good when we get offended by that at that moment<|4.08|><|4.08|> people will be low in our eyes<|5.72|><|5.72|> and we will be high at that moment we experience<|7.80|><|7.80|> that is called self-savage, right' t it<|9.30|><|9.30|> instantly very relieved, right<|11.74|><|11.74|> because i got<|13.28|><|13.28|> dopamine like that at that moment<|16.24|><|16.24|> we will feel like<|17.90|><|17.90|> that is me<|19.26|><|19.26|> I am a better person than him<|21.40|><|21.40|> wow<|22.30|><|22.30|> this is amazing<|27.98|><|27.98|> this is amazing<|29.68|><|endoftext|>",
#   'audio_filename': 'split-indonesian/0-1-48000000.mp3'}]
