# %%
# !wget https://huggingface.co/mesolitica/conformer-medium-malay-whisper/resolve/main/malay-stt.model
# !wget https://gist.githubusercontent.com/huseinzol05/98974ae8c6c7a65d4bc0af9f5003786a/raw/2e06e71ef7349a57bc58cc9913ae6bae1f9f8447/mp.py

# %%
from glob import glob
import json
import soundfile as sf
from tqdm import tqdm
import mp
import os
import sentencepiece as spm
import malaya_speech
import numpy as np

sp_model = spm.SentencePieceProcessor(model_file='malay-stt.model')
sr = 16000
# Out:
# /home/husein/.local/lib/python3.8/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.15) or chardet (5.2.0)/charset_normalizer (2.0.7) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# /home/husein/.local/lib/python3.8/site-packages/whisper/timing.py:58: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def backtrace(trace: np.ndarray):
# `pyaudio` is not available, `malaya_speech.streaming.pyaudio` is not able to use.

# %%
filtered = []

with open('pseudolabel.jsonl') as fopen:
    for l in fopen:
        l = json.loads(l)
        f = l['audio_filename']
        if not os.path.exists(f):
            continue
        t_ms = l['predict_ms'][41:-13].strip()
        t_en = l['predict_en'][41:-13].strip()
        filtered.append((f, t_ms, t_en))
        
len(filtered)
# Out:
# 2221856

# %%
filtered = [(no, f) for no, f in enumerate(filtered)]

# %%
# !mkdir processed-audio processed
# !rm processed-audio/* processed/*
# Out:
# mkdir: cannot create directory ‘processed-audio’: File exists
# mkdir: cannot create directory ‘processed’: File exists
# /bin/bash: /usr/bin/rm: Argument list too long

# %%
def loop(rows):
    rows, index = rows
    for row in tqdm(rows):
        i, row = row
        filename = os.path.join('force-alignment', f'{i}.json')
        if not os.path.exists(filename):
            continue
        try:
            with open(filename) as fopen:
                data = json.load(fopen)
                
            if 'fatihah' in data['p_ms']:
                continue
                
            f_json = os.path.join('processed', f'{index}-{i}.json')
            if os.path.exists(f_json):
                continue
                
            y, sr = malaya_speech.load(row[0])
            
            split, temp = [], []
            if data['diag_ms'] is not None:
                diag = data['diag_ms']
                for no, r in enumerate(data['subwords_alignment_ms']):
                    if r['score'] >= 0.05 or diag[no] > 0.2:
                        temp.append(r)

                    else:
                        if len(temp):
                            split.append(temp)
                            temp = []

                if len(temp):
                    split.append(temp)
            
            if data['diag_en'] is not None:
                diag = data['diag_en']
                for no, r in enumerate(data['subwords_alignment_en']):
                    if r['score'] >= 0.05 or diag[no] > 0.2:
                        temp.append(r)

                    else:
                        if len(temp):
                            split.append(temp)
                            temp = []

                if len(temp):
                    split.append(temp)

            selected = []
            for s in split:
                start = s[0]['start']
                end = s[-1]['end'] + 0.1
                if end - start >= 1.0:
                    seq = [s__['text'] for s__ in s]
                    merged = sp_model.Decode(sp_model.PieceToId(seq))
                    selected.append((merged, start, end))
            
            if not len(selected):
                continue
                
            filtered = []
            for no, s in enumerate(selected):
                f = os.path.join('processed-audio', f'{index}-{i}-{no}.mp3')
                start = int(s[1] * sr)
                end = int(s[2] * sr)
                sf.write(f, y[start: end], sr)
                filtered.append(
                    {
                        'text': s[0],
                        'start': s[1],
                        'end': s[2],
                        'audio_filename': f,
                        'original_audio_filename': row[0],
                    }
                )
                
            with open(f_json, 'w') as fopen:
                json.dump(filtered, fopen)
            
        except Exception as e:
            print(e)
            pass

# %%
loop((filtered[:20], 0))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 202.72it/s]

# %%
files = glob('processed-audio/*.mp3')
len(files)
# Out:
# 391143

# %%
files
# Out:
# ['processed-audio/4-1779205-4.mp3',
#  'processed-audio/6-1349719-2.mp3',
#  'processed-audio/5-1115858-4.mp3',
#  'processed-audio/3-696992-4.mp3',
#  'processed-audio/3-673782-7.mp3',
#  'processed-audio/3-669664-2.mp3',
#  'processed-audio/3-674626-2.mp3',
#  'processed-audio/3-681258-3.mp3',
#  'processed-audio/6-1346184-0.mp3',
#  'processed-audio/1-230642-1.mp3',
#  'processed-audio/9-2019598-0.mp3',
#  'processed-audio/4-1788075-2.mp3',
#  'processed-audio/9-2008250-2.mp3',
#  'processed-audio/6-1335604-1.mp3',
#  'processed-audio/4-891318-4.mp3',
#  'processed-audio/6-1337210-0.mp3',
#  'processed-audio/3-690569-0.mp3',
#  'processed-audio/3-699860-0.mp3',
#  'processed-audio/7-1556205-2.mp3',
#  'processed-audio/0-28096-0.mp3',
#  'processed-audio/3-673140-1.mp3',
#  'processed-audio/5-1124165-0.mp3',
#  'processed-audio/5-1137588-0.mp3',
#  'processed-audio/6-1345855-0.mp3',
#  'processed-audio/0-7975-1.mp3',
#  'processed-audio/9-2018090-1.mp3',
#  'processed-audio/1-226828-2.mp3',
#  'processed-audio/9-2016076-2.mp3',
#  'processed-audio/0-268-4.mp3',
#  'processed-audio/0-15634-0.mp3',
#  'processed-audio/8-1796503-1.mp3',
#  'processed-audio/2-460716-3.mp3',
#  'processed-audio/6-1342326-1.mp3',
#  'processed-audio/8-1786888-0.mp3',
#  'processed-audio/3-695835-0.mp3',
#  'processed-audio/3-1333992-0.mp3',
#  'processed-audio/0-23629-3.mp3',
#  'processed-audio/4-907230-0.mp3',
#  'processed-audio/9-1999693-1.mp3',
#  'processed-audio/3-693615-0.mp3',
#  'processed-audio/4-914393-3.mp3',
#  'processed-audio/5-1137590-2.mp3',
#  'processed-audio/5-1133382-5.mp3',
#  'processed-audio/3-700268-1.mp3',
#  'processed-audio/1-453077-0.mp3',
#  'processed-audio/2-465487-5.mp3',
#  'processed-audio/4-908145-2.mp3',
#  'processed-audio/1-223874-2.mp3',
#  'processed-audio/9-2015433-0.mp3',
#  'processed-audio/9-2005562-1.mp3',
#  'processed-audio/7-1574438-0.mp3',
#  'processed-audio/6-1337806-1.mp3',
#  'processed-audio/7-1576161-0.mp3',
#  'processed-audio/5-1121383-0.mp3',
#  'processed-audio/4-1779472-2.mp3',
#  'processed-audio/0-12925-4.mp3',
#  'processed-audio/7-1567075-0.mp3',
#  'processed-audio/0-172-1.mp3',
#  'processed-audio/2-461488-3.mp3',
#  'processed-audio/6-1341003-2.mp3',
#  'processed-audio/9-2022744-1.mp3',
#  'processed-audio/6-1339893-0.mp3',
#  'processed-audio/9-2027226-3.mp3',
#  'processed-audio/1-450116-2.mp3',
#  'processed-audio/0-2297-1.mp3',
#  'processed-audio/3-1336724-1.mp3',
#  'processed-audio/4-893357-3.mp3',
#  'processed-audio/9-2002832-1.mp3',
#  'processed-audio/1-250404-2.mp3',
#  'processed-audio/8-1783750-1.mp3',
#  'processed-audio/3-671932-0.mp3',
#  'processed-audio/7-1580859-0.mp3',
#  'processed-audio/1-444907-0.mp3',
#  'processed-audio/4-914268-0.mp3',
#  'processed-audio/9-2025716-0.mp3',
#  'processed-audio/4-1780517-2.mp3',
#  'processed-audio/3-669127-2.mp3',
#  'processed-audio/8-1808176-3.mp3',
#  'processed-audio/5-1119653-1.mp3',
#  'processed-audio/2-470114-2.mp3',
#  'processed-audio/9-2028643-2.mp3',
#  'processed-audio/4-1780679-1.mp3',
#  'processed-audio/9-2015802-0.mp3',
#  'processed-audio/9-2001567-2.mp3',
#  'processed-audio/1-238581-1.mp3',
#  'processed-audio/3-675796-6.mp3',
#  'processed-audio/2-476117-0.mp3',
#  'processed-audio/2-892446-0.mp3',
#  'processed-audio/9-2029196-0.mp3',
#  'processed-audio/0-19420-4.mp3',
#  'processed-audio/6-1336522-0.mp3',
#  'processed-audio/4-888767-1.mp3',
#  'processed-audio/1-234049-0.mp3',
#  'processed-audio/6-1345064-0.mp3',
#  'processed-audio/1-246165-0.mp3',
#  'processed-audio/6-1338135-0.mp3',
#  'processed-audio/2-451670-0.mp3',
#  'processed-audio/6-1338652-0.mp3',
#  'processed-audio/0-35112-1.mp3',
#  'processed-audio/5-1113835-2.mp3',
#  'processed-audio/2-453303-0.mp3',
#  'processed-audio/5-1133351-3.mp3',
#  'processed-audio/1-454591-2.mp3',
#  'processed-audio/3-672474-3.mp3',
#  'processed-audio/8-1797671-1.mp3',
#  'processed-audio/5-1121688-3.mp3',
#  'processed-audio/0-2400-0.mp3',
#  'processed-audio/7-1562853-2.mp3',
#  'processed-audio/8-1796586-0.mp3',
#  'processed-audio/6-1353284-0.mp3',
#  'processed-audio/3-681497-1.mp3',
#  'processed-audio/4-908033-0.mp3',
#  'processed-audio/2-448923-2.mp3',
#  'processed-audio/9-2010041-1.mp3',
#  'processed-audio/1-452700-0.mp3',
#  'processed-audio/0-33104-1.mp3',
#  'processed-audio/1-224774-0.mp3',
#  'processed-audio/3-672158-2.mp3',
#  'processed-audio/8-1785675-0.mp3',
#  'processed-audio/4-1786536-6.mp3',
#  'processed-audio/5-1128753-0.mp3',
#  'processed-audio/4-889614-1.mp3',
#  'processed-audio/1-247240-0.mp3',
#  'processed-audio/7-1557489-5.mp3',
#  'processed-audio/6-1336121-4.mp3',
#  'processed-audio/4-1783618-2.mp3',
#  'processed-audio/5-1129836-0.mp3',
#  'processed-audio/0-6402-0.mp3',
#  'processed-audio/0-8283-7.mp3',
#  'processed-audio/7-1561710-2.mp3',
#  'processed-audio/5-1136924-1.mp3',
#  'processed-audio/4-1778520-3.mp3',
#  'processed-audio/3-675472-0.mp3',
#  'processed-audio/3-695545-0.mp3',
#  'processed-audio/2-471258-2.mp3',
#  'processed-audio/0-32357-2.mp3',
#  'processed-audio/6-1342417-1.mp3',
#  'processed-audio/0-13189-0.mp3',
#  'processed-audio/2-476398-3.mp3',
#  'processed-audio/8-1805830-2.mp3',
#  'processed-audio/0-24795-0.mp3',
#  'processed-audio/9-2021412-1.mp3',
#  'processed-audio/3-683280-0.mp3',
#  'processed-audio/3-690285-4.mp3',
#  'processed-audio/7-1571421-0.mp3',
#  'processed-audio/7-1568190-1.mp3',
#  'processed-audio/1-454973-2.mp3',
#  'processed-audio/2-452802-1.mp3',
#  'processed-audio/5-1126016-3.mp3',
#  'processed-audio/1-246982-1.mp3',
#  'processed-audio/9-2002004-2.mp3',
#  'processed-audio/4-1787781-2.mp3',
#  'processed-audio/3-683683-1.mp3',
#  'processed-audio/5-1115331-2.mp3',
#  'processed-audio/2-477561-1.mp3',
#  'processed-audio/7-1563742-3.mp3',
#  'processed-audio/3-669860-0.mp3',
#  'processed-audio/0-16379-0.mp3',
#  'processed-audio/3-696508-2.mp3',
#  'processed-audio/2-462019-1.mp3',
#  'processed-audio/4-1783562-0.mp3',
#  'processed-audio/4-896866-1.mp3',
#  'processed-audio/1-226546-2.mp3',
#  'processed-audio/0-182-0.mp3',
#  'processed-audio/4-906755-1.mp3',
#  'processed-audio/8-1794215-0.mp3',
#  'processed-audio/5-1115356-0.mp3',
#  'processed-audio/8-1795778-3.mp3',
#  'processed-audio/2-461304-2.mp3',
#  'processed-audio/7-1560335-3.mp3',
#  'processed-audio/4-1786128-2.mp3',
#  'processed-audio/9-2015488-0.mp3',
#  'processed-audio/2-455172-0.mp3',
#  'processed-audio/6-1341101-0.mp3',
#  'processed-audio/5-1138890-2.mp3',
#  'processed-audio/7-1573254-2.mp3',
#  'processed-audio/4-906560-4.mp3',
#  'processed-audio/7-1581923-0.mp3',
#  'processed-audio/9-2017693-3.mp3',
#  'processed-audio/4-911132-1.mp3',
#  'processed-audio/7-1573373-0.mp3',
#  'processed-audio/6-1353336-2.mp3',
#  'processed-audio/1-451990-0.mp3',
#  'processed-audio/5-1124711-0.mp3',
#  'processed-audio/3-1338981-0.mp3',
#  'processed-audio/1-230819-1.mp3',
#  'processed-audio/3-691699-3.mp3',
#  'processed-audio/3-692069-1.mp3',
#  'processed-audio/1-229038-3.mp3',
#  'processed-audio/7-1561548-0.mp3',
#  'processed-audio/8-1803344-0.mp3',
#  'processed-audio/4-903410-0.mp3',
#  'processed-audio/0-15960-0.mp3',
#  'processed-audio/1-243354-3.mp3',
#  'processed-audio/1-451472-0.mp3',
#  'processed-audio/0-8411-0.mp3',
#  'processed-audio/1-241750-0.mp3',
#  'processed-audio/8-1807658-1.mp3',
#  'processed-audio/3-696326-2.mp3',
#  'processed-audio/0-38642-3.mp3',
#  'processed-audio/1-250358-0.mp3',
#  'processed-audio/6-1338584-1.mp3',
#  'processed-audio/6-1341006-1.mp3',
#  'processed-audio/4-917934-2.mp3',
#  'processed-audio/6-1335866-0.mp3',
#  'processed-audio/0-5538-0.mp3',
#  'processed-audio/6-1333924-1.mp3',
#  'processed-audio/8-1788833-4.mp3',
#  'processed-audio/8-1789534-0.mp3',
#  'processed-audio/6-1336578-1.mp3',
#  'processed-audio/4-892971-0.mp3',
#  'processed-audio/1-239094-0.mp3',
#  'processed-audio/2-892396-2.mp3',
#  'processed-audio/4-901876-2.mp3',
#  'processed-audio/6-1356355-1.mp3',
#  'processed-audio/6-1338894-1.mp3',
#  'processed-audio/8-1792508-0.mp3',
#  'processed-audio/8-1792804-0.mp3',
#  'processed-audio/4-1780712-1.mp3',
#  'processed-audio/9-2007411-0.mp3',
#  'processed-audio/3-1339518-0.mp3',
#  'processed-audio/4-891736-0.mp3',
#  'processed-audio/8-1807475-1.mp3',
#  'processed-audio/2-458852-1.mp3',
#  'processed-audio/8-1781702-0.mp3',
#  'processed-audio/8-1779363-3.mp3',
#  'processed-audio/7-1582247-0.mp3',
#  'processed-audio/8-1791765-1.mp3',
#  'processed-audio/7-1581519-0.mp3',
#  'processed-audio/8-1787892-1.mp3',
#  'processed-audio/3-700682-3.mp3',
#  'processed-audio/0-26597-4.mp3',
#  'processed-audio/2-476452-1.mp3',
#  'processed-audio/7-1559037-1.mp3',
#  'processed-audio/4-905933-1.mp3',
#  'processed-audio/9-2012580-0.mp3',
#  'processed-audio/5-1137126-0.mp3',
#  'processed-audio/1-225503-2.mp3',
#  'processed-audio/4-1786676-1.mp3',
#  'processed-audio/7-1574362-1.mp3',
#  'processed-audio/7-1555426-2.mp3',
#  'processed-audio/4-893890-1.mp3',
#  'processed-audio/1-238339-1.mp3',
#  'processed-audio/6-1334454-1.mp3',
#  'processed-audio/0-11575-3.mp3',
#  'processed-audio/1-231850-1.mp3',
#  'processed-audio/0-21832-1.mp3',
#  'processed-audio/7-1561546-3.mp3',
#  'processed-audio/7-1574061-1.mp3',
#  'processed-audio/1-243863-2.mp3',
#  'processed-audio/5-1118983-2.mp3',
#  'processed-audio/3-694446-3.mp3',
#  'processed-audio/0-21182-0.mp3',
#  'processed-audio/9-2013774-2.mp3',
#  'processed-audio/0-7838-1.mp3',
#  'processed-audio/2-892286-2.mp3',
#  'processed-audio/3-695081-0.mp3',
#  'processed-audio/4-1785214-0.mp3',
#  'processed-audio/7-1563521-2.mp3',
#  'processed-audio/7-1561505-1.mp3',
#  'processed-audio/0-24627-2.mp3',
#  'processed-audio/2-444932-2.mp3',
#  'processed-audio/9-2008284-1.mp3',
#  'processed-audio/1-246720-4.mp3',
#  'processed-audio/9-2017560-3.mp3',
#  'processed-audio/9-2024760-5.mp3',
#  'processed-audio/0-35302-2.mp3',
#  'processed-audio/8-1794951-0.mp3',
#  'processed-audio/9-2012590-1.mp3',
#  'processed-audio/9-2011035-0.mp3',
#  'processed-audio/5-1131349-5.mp3',
#  'processed-audio/2-460565-1.mp3',
#  'processed-audio/0-6781-0.mp3',
#  'processed-audio/0-9539-4.mp3',
#  'processed-audio/6-1343430-1.mp3',
#  'processed-audio/9-2005602-1.mp3',
#  'processed-audio/3-689834-3.mp3',
#  'processed-audio/8-1779042-4.mp3',
#  'processed-audio/6-1335233-0.mp3',
#  'processed-audio/8-1794248-0.mp3',
#  'processed-audio/8-1796460-4.mp3',
#  'processed-audio/2-891340-0.mp3',
#  'processed-audio/4-892475-2.mp3',
#  'processed-audio/3-692169-0.mp3',
#  'processed-audio/3-667910-0.mp3',
#  'processed-audio/1-249505-4.mp3',
#  'processed-audio/3-680539-4.mp3',
#  'processed-audio/7-1557711-3.mp3',
#  'processed-audio/0-39264-0.mp3',
#  'processed-audio/3-1334176-2.mp3',
#  'processed-audio/2-478440-3.mp3',
#  'processed-audio/2-892209-2.mp3',
#  'processed-audio/5-1133932-0.mp3',
#  'processed-audio/5-1134326-3.mp3',
#  'processed-audio/1-223285-1.mp3',
#  'processed-audio/3-676472-0.mp3',
#  'processed-audio/6-1358553-1.mp3',
#  'processed-audio/1-450538-1.mp3',
#  'processed-audio/0-31869-0.mp3',
#  'processed-audio/0-10550-0.mp3',
#  'processed-audio/6-1352533-0.mp3',
#  'processed-audio/1-249574-0.mp3',
#  'processed-audio/3-674386-5.mp3',
#  'processed-audio/0-18303-4.mp3',
#  'processed-audio/3-676974-0.mp3',
#  'processed-audio/3-1333912-4.mp3',
#  'processed-audio/0-36504-0.mp3',
#  'processed-audio/4-1780844-2.mp3',
#  'processed-audio/1-250142-3.mp3',
#  'processed-audio/9-2017479-3.mp3',
#  'processed-audio/0-2793-1.mp3',
#  'processed-audio/3-680668-1.mp3',
#  'processed-audio/2-471322-1.mp3',
#  'processed-audio/4-889671-1.mp3',
#  'processed-audio/0-21080-2.mp3',
#  'processed-audio/0-7934-1.mp3',
#  'processed-audio/3-688011-1.mp3',
#  'processed-audio/2-453145-0.mp3',
#  'processed-audio/9-2002036-1.mp3',
#  'processed-audio/2-892668-0.mp3',
#  'processed-audio/0-15924-7.mp3',
#  'processed-audio/1-237231-0.mp3',
#  'processed-audio/3-670686-1.mp3',
#  'processed-audio/2-893493-3.mp3',
#  'processed-audio/4-902033-5.mp3',
#  'processed-audio/9-2007149-0.mp3',
#  'processed-audio/5-1131636-0.mp3',
#  'processed-audio/9-2026623-3.mp3',
#  'processed-audio/4-897045-3.mp3',
#  'processed-audio/9-2016361-0.mp3',
#  'processed-audio/9-2004560-0.mp3',
#  'processed-audio/7-1579071-3.mp3',
#  'processed-audio/4-903160-2.mp3',
#  'processed-audio/4-891450-0.mp3',
#  'processed-audio/2-478377-0.mp3',
#  'processed-audio/0-5598-0.mp3',
#  'processed-audio/3-1336956-0.mp3',
#  'processed-audio/7-1565428-1.mp3',
#  'processed-audio/2-469256-0.mp3',
#  'processed-audio/3-682614-0.mp3',
#  'processed-audio/3-668052-1.mp3',
#  'processed-audio/6-1354574-0.mp3',
#  'processed-audio/2-458903-3.mp3',
#  'processed-audio/4-892276-3.mp3',
#  'processed-audio/2-454210-1.mp3',
#  'processed-audio/4-890170-3.mp3',
#  'processed-audio/2-474537-0.mp3',
#  'processed-audio/5-1124586-4.mp3',
#  'processed-audio/7-1575839-0.mp3',
#  'processed-audio/9-2015278-0.mp3',
#  'processed-audio/5-1139079-4.mp3',
#  'processed-audio/6-1338314-2.mp3',
#  'processed-audio/6-1355472-3.mp3',
#  'processed-audio/9-2005341-3.mp3',
#  'processed-audio/0-30295-3.mp3',
#  'processed-audio/1-245102-1.mp3',
#  'processed-audio/2-889680-0.mp3',
#  'processed-audio/9-2011574-0.mp3',
#  'processed-audio/1-230585-1.mp3',
#  'processed-audio/2-476180-0.mp3',
#  'processed-audio/5-1136184-1.mp3',
#  'processed-audio/4-906075-3.mp3',
#  'processed-audio/3-696720-1.mp3',
#  'processed-audio/2-451701-1.mp3',
#  'processed-audio/9-2013280-0.mp3',
#  'processed-audio/0-26304-0.mp3',
#  'processed-audio/3-694493-1.mp3',
#  'processed-audio/6-1358001-1.mp3',
#  'processed-audio/1-249722-0.mp3',
#  'processed-audio/2-459747-0.mp3',
#  'processed-audio/1-225353-0.mp3',
#  'processed-audio/6-1348873-1.mp3',
#  'processed-audio/7-1582019-0.mp3',
#  'processed-audio/0-24939-0.mp3',
#  'processed-audio/4-917943-1.mp3',
#  'processed-audio/3-673694-0.mp3',
#  'processed-audio/8-1796605-1.mp3',
#  'processed-audio/6-1333572-0.mp3',
#  'processed-audio/7-1577110-2.mp3',
#  'processed-audio/1-222651-1.mp3',
#  'processed-audio/3-1335848-4.mp3',
#  'processed-audio/6-1342099-3.mp3',
#  'processed-audio/0-24367-1.mp3',
#  'processed-audio/1-445553-4.mp3',
#  'processed-audio/8-1796531-0.mp3',
#  'processed-audio/8-1782660-0.mp3',
#  'processed-audio/2-889428-5.mp3',
#  'processed-audio/0-30855-0.mp3',
#  'processed-audio/0-19097-1.mp3',
#  'processed-audio/8-1789486-1.mp3',
#  'processed-audio/6-1345580-3.mp3',
#  'processed-audio/5-1130943-1.mp3',
#  'processed-audio/4-915171-2.mp3',
#  'processed-audio/9-2004946-3.mp3',
#  'processed-audio/2-457614-0.mp3',
#  'processed-audio/5-1112135-2.mp3',
#  'processed-audio/3-695975-2.mp3',
#  'processed-audio/0-837-0.mp3',
#  'processed-audio/7-1559633-2.mp3',
#  'processed-audio/4-889870-4.mp3',
#  'processed-audio/6-1333989-0.mp3',
#  'processed-audio/9-2016033-3.mp3',
#  'processed-audio/0-22893-0.mp3',
#  'processed-audio/4-1788358-0.mp3',
#  'processed-audio/8-1782572-1.mp3',
#  'processed-audio/9-1999786-0.mp3',
#  'processed-audio/8-1783789-0.mp3',
#  'processed-audio/7-1563685-0.mp3',
#  'processed-audio/0-24787-1.mp3',
#  'processed-audio/5-1122363-2.mp3',
#  'processed-audio/3-667715-3.mp3',
#  'processed-audio/5-1133640-2.mp3',
#  'processed-audio/0-32283-3.mp3',
#  'processed-audio/1-234284-0.mp3',
#  'processed-audio/7-1582114-0.mp3',
#  'processed-audio/0-32197-6.mp3',
#  'processed-audio/3-681232-2.mp3',
#  'processed-audio/5-1132444-0.mp3',
#  'processed-audio/0-20845-1.mp3',
#  'processed-audio/5-1132223-2.mp3',
#  'processed-audio/1-247015-0.mp3',
#  'processed-audio/4-891890-2.mp3',
#  'processed-audio/3-699178-0.mp3',
#  'processed-audio/1-249006-0.mp3',
#  'processed-audio/0-20601-1.mp3',
#  'processed-audio/1-227508-1.mp3',
#  'processed-audio/0-37305-0.mp3',
#  'processed-audio/2-465614-0.mp3',
#  'processed-audio/4-893708-1.mp3',
#  'processed-audio/8-1778571-1.mp3',
#  'processed-audio/0-3760-3.mp3',
#  'processed-audio/1-230717-0.mp3',
#  'processed-audio/2-459993-1.mp3',
#  'processed-audio/5-1125570-2.mp3',
#  'processed-audio/1-222423-2.mp3',
#  'processed-audio/7-1567235-1.mp3',
#  'processed-audio/3-677728-0.mp3',
#  'processed-audio/3-696249-2.mp3',
#  'processed-audio/1-242527-3.mp3',
#  'processed-audio/8-1804069-2.mp3',
#  'processed-audio/1-244848-0.mp3',
#  'processed-audio/6-1334051-0.mp3',
#  'processed-audio/1-449893-1.mp3',
#  'processed-audio/1-227156-0.mp3',
#  'processed-audio/0-1366-0.mp3',
#  'processed-audio/5-1122685-1.mp3',
#  'processed-audio/8-1779087-4.mp3',
#  'processed-audio/7-1581903-0.mp3',
#  'processed-audio/1-450023-0.mp3',
#  'processed-audio/9-2021929-0.mp3',
#  'processed-audio/6-1350438-3.mp3',
#  'processed-audio/1-226844-0.mp3',
#  'processed-audio/8-1809637-2.mp3',
#  'processed-audio/0-34-0.mp3',
#  'processed-audio/0-22025-0.mp3',
#  'processed-audio/2-450010-3.mp3',
#  'processed-audio/8-1806323-0.mp3',
#  'processed-audio/3-693242-1.mp3',
#  'processed-audio/8-1781967-1.mp3',
#  'processed-audio/9-2021043-0.mp3',
#  'processed-audio/1-450202-2.mp3',
#  'processed-audio/2-478529-0.mp3',
#  'processed-audio/7-1565546-2.mp3',
#  'processed-audio/1-226777-3.mp3',
#  'processed-audio/2-451967-0.mp3',
#  'processed-audio/6-1335370-2.mp3',
#  'processed-audio/4-889559-0.mp3',
#  'processed-audio/0-6725-3.mp3',
#  'processed-audio/5-1121258-0.mp3',
#  'processed-audio/6-1354709-0.mp3',
#  'processed-audio/7-1582014-1.mp3',
#  'processed-audio/7-1558817-2.mp3',
#  'processed-audio/0-20780-3.mp3',
#  'processed-audio/8-1778959-4.mp3',
#  'processed-audio/2-891320-3.mp3',
#  'processed-audio/2-464613-0.mp3',
#  'processed-audio/9-2015072-0.mp3',
#  'processed-audio/6-1339834-1.mp3',
#  'processed-audio/9-2019526-1.mp3',
#  'processed-audio/0-3005-3.mp3',
#  'processed-audio/4-893362-1.mp3',
#  'processed-audio/3-1334885-2.mp3',
#  'processed-audio/4-1780659-2.mp3',
#  'processed-audio/6-1346580-2.mp3',
#  'processed-audio/5-1129058-6.mp3',
#  'processed-audio/5-1118300-0.mp3',
#  'processed-audio/5-1124898-3.mp3',
#  'processed-audio/3-1334752-4.mp3',
#  'processed-audio/0-8416-2.mp3',
#  'processed-audio/1-230060-0.mp3',
#  'processed-audio/6-1339456-5.mp3',
#  'processed-audio/5-1117474-3.mp3',
#  'processed-audio/2-452806-0.mp3',
#  'processed-audio/2-468915-0.mp3',
#  'processed-audio/1-249440-1.mp3',
#  'processed-audio/7-1563187-2.mp3',
#  'processed-audio/4-903505-1.mp3',
#  'processed-audio/4-899105-0.mp3',
#  'processed-audio/7-1559078-0.mp3',
#  'processed-audio/0-35932-1.mp3',
#  'processed-audio/1-245658-4.mp3',
#  'processed-audio/0-27031-2.mp3',
#  'processed-audio/1-228755-6.mp3',
#  'processed-audio/5-1137457-1.mp3',
#  'processed-audio/0-2565-2.mp3',
#  'processed-audio/7-1576645-0.mp3',
#  'processed-audio/4-903507-0.mp3',
#  'processed-audio/0-19211-1.mp3',
#  'processed-audio/0-7312-4.mp3',
#  'processed-audio/9-2005285-1.mp3',
#  'processed-audio/6-1347662-0.mp3',
#  'processed-audio/2-444549-0.mp3',
#  'processed-audio/9-2023140-0.mp3',
#  'processed-audio/8-1785846-0.mp3',
#  'processed-audio/4-1784460-4.mp3',
#  'processed-audio/8-1789468-0.mp3',
#  'processed-audio/7-1580113-3.mp3',
#  'processed-audio/4-903739-1.mp3',
#  'processed-audio/3-683499-1.mp3',
#  'processed-audio/5-1115981-1.mp3',
#  'processed-audio/8-1782972-0.mp3',
#  'processed-audio/4-913820-1.mp3',
#  'processed-audio/7-1563451-5.mp3',
#  'processed-audio/8-1789777-0.mp3',
#  'processed-audio/6-1357435-0.mp3',
#  'processed-audio/4-1779873-0.mp3',
#  'processed-audio/0-26772-1.mp3',
#  'processed-audio/0-32072-0.mp3',
#  'processed-audio/5-1132774-0.mp3',
#  'processed-audio/1-449579-0.mp3',
#  'processed-audio/5-1125518-0.mp3',
#  'processed-audio/0-9339-0.mp3',
#  'processed-audio/9-2001698-1.mp3',
#  'processed-audio/8-1778516-0.mp3',
#  'processed-audio/1-455423-0.mp3',
#  'processed-audio/0-7719-0.mp3',
#  'processed-audio/1-242742-0.mp3',
#  'processed-audio/4-892440-0.mp3',
#  'processed-audio/6-1358660-0.mp3',
#  'processed-audio/1-222922-2.mp3',
#  'processed-audio/7-1555437-0.mp3',
#  'processed-audio/5-1115703-0.mp3',
#  'processed-audio/9-2005737-0.mp3',
#  'processed-audio/5-1114754-0.mp3',
#  'processed-audio/4-894432-0.mp3',
#  'processed-audio/6-1359824-4.mp3',
#  'processed-audio/0-10950-0.mp3',
#  'processed-audio/7-1569563-0.mp3',
#  'processed-audio/2-454640-0.mp3',
#  'processed-audio/3-1340118-0.mp3',
#  'processed-audio/4-903313-1.mp3',
#  'processed-audio/7-1559528-1.mp3',
#  'processed-audio/1-249598-2.mp3',
#  'processed-audio/2-462488-0.mp3',
#  'processed-audio/4-913678-1.mp3',
#  'processed-audio/0-22392-0.mp3',
#  'processed-audio/7-1559587-1.mp3',
#  'processed-audio/8-1801705-0.mp3',
#  'processed-audio/4-898667-3.mp3',
#  'processed-audio/2-892807-3.mp3',
#  'processed-audio/8-1781213-4.mp3',
#  'processed-audio/2-461233-0.mp3',
#  'processed-audio/1-450553-0.mp3',
#  'processed-audio/9-2025769-0.mp3',
#  'processed-audio/4-917861-0.mp3',
#  'processed-audio/6-1342413-2.mp3',
#  'processed-audio/5-1115716-1.mp3',
#  'processed-audio/7-1583114-2.mp3',
#  'processed-audio/6-1340060-1.mp3',
#  'processed-audio/8-1789936-1.mp3',
#  'processed-audio/3-698282-3.mp3',
#  'processed-audio/6-1343096-0.mp3',
#  'processed-audio/6-1351845-0.mp3',
#  'processed-audio/0-21412-1.mp3',
#  'processed-audio/4-1782552-0.mp3',
#  'processed-audio/4-1779109-1.mp3',
#  'processed-audio/7-1571148-4.mp3',
#  'processed-audio/0-12559-2.mp3',
#  'processed-audio/1-450841-2.mp3',
#  'processed-audio/8-1799464-5.mp3',
#  'processed-audio/3-1339449-4.mp3',
#  'processed-audio/7-1579910-0.mp3',
#  'processed-audio/1-452075-2.mp3',
#  'processed-audio/1-238329-1.mp3',
#  'processed-audio/0-12976-2.mp3',
#  'processed-audio/3-674225-2.mp3',
#  'processed-audio/6-1343992-0.mp3',
#  'processed-audio/2-448378-5.mp3',
#  'processed-audio/6-1341871-0.mp3',
#  'processed-audio/2-467629-1.mp3',
#  'processed-audio/0-21069-3.mp3',
#  'processed-audio/8-1808927-5.mp3',
#  'processed-audio/6-1352558-1.mp3',
#  'processed-audio/3-687199-2.mp3',
#  'processed-audio/7-1583922-1.mp3',
#  'processed-audio/1-223965-0.mp3',
#  'processed-audio/5-1112586-1.mp3',
#  'processed-audio/0-19503-2.mp3',
#  'processed-audio/9-2029041-0.mp3',
#  'processed-audio/8-1799646-4.mp3',
#  'processed-audio/0-13108-0.mp3',
#  'processed-audio/4-903611-1.mp3',
#  'processed-audio/0-21917-1.mp3',
#  'processed-audio/1-239404-1.mp3',
#  'processed-audio/4-902226-0.mp3',
#  'processed-audio/4-899293-2.mp3',
#  'processed-audio/5-1138797-0.mp3',
#  'processed-audio/8-1797422-4.mp3',
#  'processed-audio/7-1580177-2.mp3',
#  'processed-audio/1-226874-1.mp3',
#  'processed-audio/5-1130179-2.mp3',
#  'processed-audio/5-1133266-2.mp3',
#  'processed-audio/4-901014-0.mp3',
#  'processed-audio/7-1577849-1.mp3',
#  'processed-audio/3-699647-4.mp3',
#  'processed-audio/3-680960-4.mp3',
#  'processed-audio/4-1779488-1.mp3',
#  'processed-audio/0-37834-1.mp3',
#  'processed-audio/6-1348920-0.mp3',
#  'processed-audio/4-1783126-2.mp3',
#  'processed-audio/7-1562217-0.mp3',
#  'processed-audio/3-697713-0.mp3',
#  'processed-audio/9-2017925-4.mp3',
#  'processed-audio/6-1347190-1.mp3',
#  'processed-audio/1-238138-0.mp3',
#  'processed-audio/3-680049-2.mp3',
#  'processed-audio/2-452465-3.mp3',
#  'processed-audio/7-1578184-2.mp3',
#  'processed-audio/3-675932-0.mp3',
#  'processed-audio/9-2017508-2.mp3',
#  'processed-audio/5-1135220-0.mp3',
#  'processed-audio/5-1132718-5.mp3',
#  'processed-audio/0-2521-0.mp3',
#  'processed-audio/8-1806664-0.mp3',
#  'processed-audio/0-25787-4.mp3',
#  'processed-audio/0-32620-2.mp3',
#  'processed-audio/4-888774-0.mp3',
#  'processed-audio/4-1779341-0.mp3',
#  'processed-audio/8-1792806-9.mp3',
#  'processed-audio/5-1132533-1.mp3',
#  'processed-audio/6-1336085-0.mp3',
#  'processed-audio/0-16548-0.mp3',
#  'processed-audio/3-1337924-0.mp3',
#  'processed-audio/0-25352-0.mp3',
#  'processed-audio/8-1804202-0.mp3',
#  'processed-audio/4-1785420-0.mp3',
#  'processed-audio/2-470631-0.mp3',
#  'processed-audio/0-25327-3.mp3',
#  'processed-audio/9-2009028-3.mp3',
#  'processed-audio/4-903851-0.mp3',
#  'processed-audio/5-1122569-2.mp3',
#  'processed-audio/4-917745-0.mp3',
#  'processed-audio/1-225949-3.mp3',
#  'processed-audio/4-905829-1.mp3',
#  'processed-audio/4-1781787-0.mp3',
#  'processed-audio/2-464397-0.mp3',
#  'processed-audio/0-16393-3.mp3',
#  'processed-audio/4-1787936-2.mp3',
#  'processed-audio/1-233689-0.mp3',
#  'processed-audio/4-910722-0.mp3',
#  'processed-audio/7-1583992-2.mp3',
#  'processed-audio/7-1573130-1.mp3',
#  'processed-audio/3-669057-1.mp3',
#  'processed-audio/8-1779420-1.mp3',
#  'processed-audio/4-1783634-3.mp3',
#  'processed-audio/3-683474-1.mp3',
#  'processed-audio/3-1335252-0.mp3',
#  'processed-audio/5-1131752-1.mp3',
#  'processed-audio/5-1116192-0.mp3',
#  'processed-audio/9-2005110-2.mp3',
#  'processed-audio/0-30749-0.mp3',
#  'processed-audio/1-245036-0.mp3',
#  'processed-audio/3-1337439-3.mp3',
#  'processed-audio/3-1335069-0.mp3',
#  'processed-audio/0-15500-4.mp3',
#  'processed-audio/8-1789279-3.mp3',
#  'processed-audio/6-1338389-1.mp3',
#  'processed-audio/4-911105-1.mp3',
#  'processed-audio/1-224864-1.mp3',
#  'processed-audio/0-5949-0.mp3',
#  'processed-audio/0-29195-2.mp3',
#  'processed-audio/7-1577800-2.mp3',
#  'processed-audio/8-1800456-2.mp3',
#  'processed-audio/2-893515-1.mp3',
#  'processed-audio/9-2017327-0.mp3',
#  'processed-audio/0-13388-1.mp3',
#  'processed-audio/0-15523-2.mp3',
#  'processed-audio/5-1130866-0.mp3',
#  'processed-audio/2-458665-1.mp3',
#  'processed-audio/0-33106-2.mp3',
#  'processed-audio/5-1129836-5.mp3',
#  'processed-audio/6-1338840-2.mp3',
#  'processed-audio/8-1793119-0.mp3',
#  'processed-audio/9-2008267-1.mp3',
#  'processed-audio/2-893199-5.mp3',
#  'processed-audio/4-1780881-0.mp3',
#  'processed-audio/2-478409-0.mp3',
#  'processed-audio/5-1113265-1.mp3',
#  'processed-audio/4-903838-2.mp3',
#  'processed-audio/4-894607-3.mp3',
#  'processed-audio/6-1338544-1.mp3',
#  'processed-audio/8-1810286-1.mp3',
#  'processed-audio/5-1117821-3.mp3',
#  'processed-audio/0-4521-2.mp3',
#  'processed-audio/2-464167-1.mp3',
#  'processed-audio/4-1788007-0.mp3',
#  'processed-audio/2-472607-1.mp3',
#  'processed-audio/3-686283-3.mp3',
#  'processed-audio/7-1557629-2.mp3',
#  'processed-audio/6-1343167-1.mp3',
#  'processed-audio/7-1567022-0.mp3',
#  'processed-audio/4-1778409-2.mp3',
#  'processed-audio/0-25730-0.mp3',
#  'processed-audio/6-1335910-2.mp3',
#  'processed-audio/3-685501-1.mp3',
#  'processed-audio/8-1792385-0.mp3',
#  'processed-audio/1-236797-2.mp3',
#  'processed-audio/1-249797-0.mp3',
#  'processed-audio/1-238742-0.mp3',
#  'processed-audio/7-1573815-0.mp3',
#  'processed-audio/8-1801402-0.mp3',
#  'processed-audio/5-1118824-1.mp3',
#  'processed-audio/1-450162-1.mp3',
#  'processed-audio/3-691684-1.mp3',
#  'processed-audio/4-1782901-0.mp3',
#  'processed-audio/3-673715-2.mp3',
#  'processed-audio/4-900012-1.mp3',
#  'processed-audio/9-2013533-0.mp3',
#  'processed-audio/8-1809727-1.mp3',
#  'processed-audio/2-466166-0.mp3',
#  'processed-audio/1-241811-0.mp3',
#  'processed-audio/7-1556953-0.mp3',
#  'processed-audio/7-1565454-2.mp3',
#  'processed-audio/1-455083-0.mp3',
#  'processed-audio/7-1563947-0.mp3',
#  'processed-audio/6-1333645-1.mp3',
#  'processed-audio/1-223515-2.mp3',
#  'processed-audio/1-448996-0.mp3',
#  'processed-audio/7-1581717-0.mp3',
#  'processed-audio/0-1544-2.mp3',
#  'processed-audio/3-685479-0.mp3',
#  'processed-audio/1-450423-0.mp3',
#  'processed-audio/9-2021153-2.mp3',
#  'processed-audio/9-2023478-1.mp3',
#  'processed-audio/4-891822-0.mp3',
#  'processed-audio/3-686524-0.mp3',
#  'processed-audio/1-231071-2.mp3',
#  'processed-audio/6-1339557-3.mp3',
#  'processed-audio/6-1341478-3.mp3',
#  'processed-audio/3-678979-1.mp3',
#  'processed-audio/4-1784306-1.mp3',
#  'processed-audio/5-1112116-3.mp3',
#  'processed-audio/5-1136053-0.mp3',
#  'processed-audio/4-908944-2.mp3',
#  'processed-audio/0-35969-2.mp3',
#  'processed-audio/4-896082-3.mp3',
#  'processed-audio/5-1118757-3.mp3',
#  'processed-audio/0-18292-1.mp3',
#  'processed-audio/5-1135528-0.mp3',
#  'processed-audio/0-1617-0.mp3',
#  'processed-audio/9-2005510-5.mp3',
#  'processed-audio/2-893350-0.mp3',
#  'processed-audio/2-448281-2.mp3',
#  'processed-audio/7-1571568-1.mp3',
#  'processed-audio/4-897893-7.mp3',
#  'processed-audio/2-458896-3.mp3',
#  'processed-audio/1-236473-0.mp3',
#  'processed-audio/3-1334156-4.mp3',
#  'processed-audio/1-238949-0.mp3',
#  'processed-audio/0-33626-0.mp3',
#  'processed-audio/0-11877-5.mp3',
#  'processed-audio/1-245409-1.mp3',
#  'processed-audio/4-900131-3.mp3',
#  'processed-audio/4-889524-0.mp3',
#  'processed-audio/2-450032-2.mp3',
#  'processed-audio/1-233141-0.mp3',
#  'processed-audio/8-1807957-1.mp3',
#  'processed-audio/6-1342408-1.mp3',
#  'processed-audio/7-1582662-3.mp3',
#  'processed-audio/7-1584270-1.mp3',
#  'processed-audio/5-1115953-5.mp3',
#  'processed-audio/6-1359851-2.mp3',
#  'processed-audio/9-2001583-3.mp3',
#  'processed-audio/1-452363-0.mp3',
#  'processed-audio/3-694919-2.mp3',
#  'processed-audio/2-459114-0.mp3',
#  'processed-audio/6-1357144-2.mp3',
#  'processed-audio/3-667102-0.mp3',
#  'processed-audio/6-1347171-0.mp3',
#  'processed-audio/4-895169-3.mp3',
#  'processed-audio/0-5074-1.mp3',
#  'processed-audio/5-1135648-0.mp3',
#  'processed-audio/2-466082-0.mp3',
#  'processed-audio/8-1793268-2.mp3',
#  'processed-audio/6-1358526-0.mp3',
#  'processed-audio/8-1786696-3.mp3',
#  'processed-audio/0-13300-4.mp3',
#  'processed-audio/6-1356790-0.mp3',
#  'processed-audio/3-1339798-0.mp3',
#  'processed-audio/0-13625-2.mp3',
#  'processed-audio/5-1118960-1.mp3',
#  'processed-audio/1-231881-1.mp3',
#  'processed-audio/9-2008774-3.mp3',
#  'processed-audio/7-1570806-0.mp3',
#  'processed-audio/0-21360-0.mp3',
#  'processed-audio/3-676610-1.mp3',
#  'processed-audio/5-1125533-4.mp3',
#  'processed-audio/2-445554-2.mp3',
#  'processed-audio/5-1115112-5.mp3',
#  'processed-audio/6-1346059-1.mp3',
#  'processed-audio/3-1337453-5.mp3',
#  'processed-audio/5-1117850-1.mp3',
#  'processed-audio/2-889419-0.mp3',
#  'processed-audio/0-10550-1.mp3',
#  'processed-audio/1-241295-0.mp3',
#  'processed-audio/9-2013272-3.mp3',
#  'processed-audio/8-1796185-2.mp3',
#  'processed-audio/5-1114542-0.mp3',
#  'processed-audio/1-228406-0.mp3',
#  'processed-audio/3-689129-0.mp3',
#  'processed-audio/3-684621-2.mp3',
#  'processed-audio/4-912633-2.mp3',
#  'processed-audio/6-1353306-2.mp3',
#  'processed-audio/1-233135-0.mp3',
#  'processed-audio/9-2003316-2.mp3',
#  'processed-audio/2-892894-1.mp3',
#  'processed-audio/6-1335383-3.mp3',
#  'processed-audio/5-1118379-1.mp3',
#  'processed-audio/0-23270-1.mp3',
#  'processed-audio/5-1129538-2.mp3',
#  'processed-audio/7-1573118-1.mp3',
#  'processed-audio/4-888995-0.mp3',
#  'processed-audio/5-1125134-2.mp3',
#  'processed-audio/6-1360141-1.mp3',
#  'processed-audio/7-1563602-0.mp3',
#  'processed-audio/6-1347332-3.mp3',
#  'processed-audio/1-247481-5.mp3',
#  'processed-audio/2-888959-1.mp3',
#  'processed-audio/0-2729-3.mp3',
#  'processed-audio/7-1561647-0.mp3',
#  'processed-audio/5-1138809-2.mp3',
#  'processed-audio/0-6854-0.mp3',
#  'processed-audio/7-1563774-0.mp3',
#  'processed-audio/1-232751-1.mp3',
#  'processed-audio/5-1112225-1.mp3',
#  'processed-audio/8-1800686-0.mp3',
#  'processed-audio/0-36018-0.mp3',
#  'processed-audio/2-452094-3.mp3',
#  'processed-audio/3-685866-0.mp3',
#  'processed-audio/8-1793806-0.mp3',
#  'processed-audio/9-2013800-1.mp3',
#  'processed-audio/8-1810463-0.mp3',
#  'processed-audio/7-1568560-1.mp3',
#  'processed-audio/4-903673-0.mp3',
#  'processed-audio/0-5275-1.mp3',
#  'processed-audio/5-1132015-0.mp3',
#  'processed-audio/2-455391-1.mp3',
#  'processed-audio/0-1459-5.mp3',
#  'processed-audio/6-1352521-1.mp3',
#  'processed-audio/2-461574-1.mp3',
#  'processed-audio/5-1138489-2.mp3',
#  'processed-audio/0-4952-0.mp3',
#  'processed-audio/0-15505-0.mp3',
#  'processed-audio/1-444701-0.mp3',
#  'processed-audio/0-30187-0.mp3',
#  'processed-audio/3-668845-0.mp3',
#  'processed-audio/1-450532-1.mp3',
#  'processed-audio/3-691570-1.mp3',
#  'processed-audio/5-1134041-1.mp3',
#  'processed-audio/9-2025576-1.mp3',
#  'processed-audio/0-4577-1.mp3',
#  'processed-audio/0-6793-2.mp3',
#  'processed-audio/7-1579781-3.mp3',
#  'processed-audio/1-223727-0.mp3',
#  'processed-audio/0-13445-1.mp3',
#  'processed-audio/0-4224-0.mp3',
#  'processed-audio/5-1130814-0.mp3',
#  'processed-audio/7-1561259-2.mp3',
#  'processed-audio/5-1127941-1.mp3',
#  'processed-audio/2-446020-0.mp3',
#  'processed-audio/9-2017454-1.mp3',
#  'processed-audio/7-1576928-0.mp3',
#  'processed-audio/1-246813-0.mp3',
#  'processed-audio/3-1337991-3.mp3',
#  'processed-audio/8-1810448-1.mp3',
#  'processed-audio/4-900778-0.mp3',
#  'processed-audio/5-1114714-4.mp3',
#  'processed-audio/8-1793752-2.mp3',
#  'processed-audio/2-457115-0.mp3',
#  'processed-audio/2-891732-1.mp3',
#  'processed-audio/0-2198-0.mp3',
#  'processed-audio/8-1788525-0.mp3',
#  'processed-audio/0-31444-0.mp3',
#  'processed-audio/2-892193-3.mp3',
#  'processed-audio/1-448730-3.mp3',
#  'processed-audio/2-473515-0.mp3',
#  'processed-audio/7-1559438-1.mp3',
#  'processed-audio/7-1570329-4.mp3',
#  'processed-audio/6-1337726-1.mp3',
#  'processed-audio/3-689718-0.mp3',
#  'processed-audio/5-1119542-1.mp3',
#  'processed-audio/7-1570787-6.mp3',
#  'processed-audio/3-1339137-0.mp3',
#  'processed-audio/0-6228-1.mp3',
#  'processed-audio/0-26961-0.mp3',
#  'processed-audio/3-682870-0.mp3',
#  'processed-audio/9-2019000-2.mp3',
#  'processed-audio/5-1133032-0.mp3',
#  'processed-audio/2-897179-4.mp3',
#  'processed-audio/6-1353294-2.mp3',
#  'processed-audio/9-2020705-0.mp3',
#  'processed-audio/5-1136098-0.mp3',
#  'processed-audio/3-668226-0.mp3',
#  'processed-audio/2-892057-0.mp3',
#  'processed-audio/9-2019928-0.mp3',
#  'processed-audio/6-1359806-0.mp3',
#  'processed-audio/2-458646-1.mp3',
#  'processed-audio/1-225328-0.mp3',
#  'processed-audio/6-1343067-3.mp3',
#  'processed-audio/4-915839-1.mp3',
#  'processed-audio/8-1791084-3.mp3',
#  'processed-audio/4-1780775-2.mp3',
#  'processed-audio/1-238657-0.mp3',
#  'processed-audio/0-20637-3.mp3',
#  'processed-audio/2-452939-0.mp3',
#  'processed-audio/2-474444-3.mp3',
#  'processed-audio/9-2026459-0.mp3',
#  'processed-audio/0-13946-2.mp3',
#  'processed-audio/9-2021203-5.mp3',
#  'processed-audio/9-2010878-3.mp3',
#  'processed-audio/7-1570998-3.mp3',
#  'processed-audio/0-35226-1.mp3',
#  'processed-audio/6-1349192-0.mp3',
#  'processed-audio/0-37651-2.mp3',
#  'processed-audio/1-230704-2.mp3',
#  'processed-audio/1-242828-0.mp3',
#  'processed-audio/2-478443-3.mp3',
#  'processed-audio/1-238057-0.mp3',
#  'processed-audio/8-1802252-3.mp3',
#  'processed-audio/1-451976-0.mp3',
#  'processed-audio/2-471999-0.mp3',
#  'processed-audio/9-2008687-0.mp3',
#  'processed-audio/2-890689-2.mp3',
#  'processed-audio/4-909267-4.mp3',
#  'processed-audio/2-474646-2.mp3',
#  'processed-audio/2-467119-5.mp3',
#  'processed-audio/3-670411-4.mp3',
#  'processed-audio/1-454430-3.mp3',
#  'processed-audio/1-232444-1.mp3',
#  'processed-audio/6-1343877-2.mp3',
#  'processed-audio/0-33002-0.mp3',
#  'processed-audio/7-1558818-2.mp3',
#  'processed-audio/2-463061-0.mp3',
#  'processed-audio/9-2022677-0.mp3',
#  'processed-audio/6-1339771-2.mp3',
#  'processed-audio/7-1562248-0.mp3',
#  'processed-audio/4-1779149-0.mp3',
#  'processed-audio/8-1783835-0.mp3',
#  'processed-audio/7-1577946-2.mp3',
#  'processed-audio/4-893045-2.mp3',
#  'processed-audio/5-1128490-1.mp3',
#  'processed-audio/8-1784313-1.mp3',
#  'processed-audio/0-12208-0.mp3',
#  'processed-audio/7-1570922-2.mp3',
#  'processed-audio/6-1336821-1.mp3',
#  'processed-audio/7-1559185-1.mp3',
#  'processed-audio/7-1565800-3.mp3',
#  'processed-audio/1-450661-0.mp3',
#  'processed-audio/4-905914-0.mp3',
#  'processed-audio/4-903574-1.mp3',
#  'processed-audio/3-684554-1.mp3',
#  'processed-audio/4-902672-5.mp3',
#  'processed-audio/7-1584540-6.mp3',
#  'processed-audio/4-893319-4.mp3',
#  'processed-audio/5-1127980-1.mp3',
#  'processed-audio/6-1350396-1.mp3',
#  'processed-audio/3-1336044-2.mp3',
#  'processed-audio/1-226081-2.mp3',
#  'processed-audio/2-444721-0.mp3',
#  'processed-audio/1-453639-5.mp3',
#  'processed-audio/5-1118213-1.mp3',
#  'processed-audio/0-12919-0.mp3',
#  'processed-audio/8-1809949-2.mp3',
#  'processed-audio/4-893357-1.mp3',
#  'processed-audio/1-242735-0.mp3',
#  'processed-audio/2-474503-1.mp3',
#  'processed-audio/8-1802008-1.mp3',
#  'processed-audio/2-893044-2.mp3',
#  'processed-audio/0-32950-0.mp3',
#  'processed-audio/1-249290-3.mp3',
#  'processed-audio/5-1137860-0.mp3',
#  'processed-audio/3-693387-7.mp3',
#  'processed-audio/3-692268-0.mp3',
#  'processed-audio/4-894136-3.mp3',
#  'processed-audio/7-1559421-0.mp3',
#  'processed-audio/2-892198-1.mp3',
#  'processed-audio/8-1786111-0.mp3',
#  'processed-audio/8-1793620-2.mp3',
#  'processed-audio/8-1779567-0.mp3',
#  'processed-audio/0-26979-3.mp3',
#  ...]

# %%
import IPython.display as ipd
ipd.Audio('processed-audio/0-13-1.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
glob('processed/*.json')
# Out:
# ['processed/1-225586.json',
#  'processed/5-1112412.json',
#  'processed/9-2012594.json',
#  'processed/3-1337521.json',
#  'processed/6-1349733.json',
#  'processed/6-1358199.json',
#  'processed/3-677734.json',
#  'processed/3-673704.json',
#  'processed/1-235185.json',
#  'processed/8-1805701.json',
#  'processed/3-1338126.json',
#  'processed/7-1576922.json',
#  'processed/0-8643.json',
#  'processed/4-913341.json',
#  'processed/0-34873.json',
#  'processed/2-458642.json',
#  'processed/7-1574638.json',
#  'processed/1-452192.json',
#  'processed/2-895997.json',
#  'processed/7-1558601.json',
#  'processed/0-5303.json',
#  'processed/5-1125353.json',
#  'processed/5-1127980.json',
#  'processed/8-1784099.json',
#  'processed/9-2002200.json',
#  'processed/3-673148.json',
#  'processed/4-905636.json',
#  'processed/2-463300.json',
#  'processed/9-2015489.json',
#  'processed/2-896785.json',
#  'processed/6-1348719.json',
#  'processed/9-2002857.json',
#  'processed/3-679831.json',
#  'processed/0-25332.json',
#  'processed/1-455237.json',
#  'processed/4-1783126.json',
#  'processed/1-222740.json',
#  'processed/6-1342441.json',
#  'processed/9-2005648.json',
#  'processed/9-2026397.json',
#  'processed/0-16082.json',
#  'processed/4-1780489.json',
#  'processed/1-245351.json',
#  'processed/2-450533.json',
#  'processed/1-450299.json',
#  'processed/3-668564.json',
#  'processed/4-889544.json',
#  'processed/4-1780887.json',
#  'processed/2-447355.json',
#  'processed/9-2010171.json',
#  'processed/4-895848.json',
#  'processed/6-1355477.json',
#  'processed/1-225000.json',
#  'processed/7-1558312.json',
#  'processed/4-1788160.json',
#  'processed/5-1117239.json',
#  'processed/5-1118656.json',
#  'processed/2-448216.json',
#  'processed/6-1339267.json',
#  'processed/3-669108.json',
#  'processed/6-1343462.json',
#  'processed/2-453249.json',
#  'processed/1-247838.json',
#  'processed/5-1136994.json',
#  'processed/1-233936.json',
#  'processed/4-915384.json',
#  'processed/6-1354895.json',
#  'processed/4-893060.json',
#  'processed/5-1138187.json',
#  'processed/9-2024776.json',
#  'processed/3-692719.json',
#  'processed/8-1800304.json',
#  'processed/6-1344814.json',
#  'processed/5-1125492.json',
#  'processed/4-893127.json',
#  'processed/1-453079.json',
#  'processed/7-1561445.json',
#  'processed/7-1568883.json',
#  'processed/0-31154.json',
#  'processed/8-1809912.json',
#  'processed/5-1115182.json',
#  'processed/6-1354114.json',
#  'processed/1-244606.json',
#  'processed/3-701177.json',
#  'processed/3-1338919.json',
#  'processed/4-907747.json',
#  'processed/0-17697.json',
#  'processed/4-898802.json',
#  'processed/9-2002466.json',
#  'processed/0-15351.json',
#  'processed/4-890698.json',
#  'processed/1-231308.json',
#  'processed/2-895852.json',
#  'processed/5-1138827.json',
#  'processed/9-2010133.json',
#  'processed/1-244493.json',
#  'processed/2-454753.json',
#  'processed/0-15023.json',
#  'processed/5-1111578.json',
#  'processed/9-2028707.json',
#  'processed/3-695132.json',
#  'processed/5-1138198.json',
#  'processed/2-478431.json',
#  'processed/6-1339593.json',
#  'processed/7-1578333.json',
#  'processed/3-1339590.json',
#  'processed/1-243089.json',
#  'processed/1-240830.json',
#  'processed/9-2021813.json',
#  'processed/6-1360130.json',
#  'processed/2-890529.json',
#  'processed/1-238748.json',
#  'processed/4-890770.json',
#  'processed/4-898782.json',
#  'processed/0-3233.json',
#  'processed/5-1135503.json',
#  'processed/9-2013714.json',
#  'processed/6-1340783.json',
#  'processed/3-681817.json',
#  'processed/3-680960.json',
#  'processed/7-1561085.json',
#  'processed/0-7921.json',
#  'processed/4-906195.json',
#  'processed/2-450336.json',
#  'processed/9-2008162.json',
#  'processed/7-1578521.json',
#  'processed/0-10870.json',
#  'processed/3-1336365.json',
#  'processed/5-1115597.json',
#  'processed/9-2009951.json',
#  'processed/0-16492.json',
#  'processed/8-1790490.json',
#  'processed/9-2027996.json',
#  'processed/6-1341315.json',
#  'processed/1-238832.json',
#  'processed/8-1807500.json',
#  'processed/5-1115211.json',
#  'processed/2-460556.json',
#  'processed/3-684556.json',
#  'processed/3-1333656.json',
#  'processed/5-1136495.json',
#  'processed/8-1779155.json',
#  'processed/1-239777.json',
#  'processed/5-1138088.json',
#  'processed/3-696779.json',
#  'processed/9-2008475.json',
#  'processed/3-695552.json',
#  'processed/2-464807.json',
#  'processed/3-1336998.json',
#  'processed/2-445601.json',
#  'processed/6-1347086.json',
#  'processed/4-917814.json',
#  'processed/7-1570091.json',
#  'processed/1-447983.json',
#  'processed/1-233327.json',
#  'processed/9-2026093.json',
#  'processed/1-248125.json',
#  'processed/4-1778991.json',
#  'processed/5-1111600.json',
#  'processed/7-1559142.json',
#  'processed/7-1581660.json',
#  'processed/5-1136652.json',
#  'processed/2-464343.json',
#  'processed/5-1118110.json',
#  'processed/8-1795763.json',
#  'processed/0-15172.json',
#  'processed/3-671954.json',
#  'processed/8-1790847.json',
#  'processed/6-1340192.json',
#  'processed/2-452804.json',
#  'processed/4-907296.json',
#  'processed/9-2008141.json',
#  'processed/7-1571484.json',
#  'processed/7-1571380.json',
#  'processed/8-1801391.json',
#  'processed/6-1358811.json',
#  'processed/3-697090.json',
#  'processed/9-2003790.json',
#  'processed/8-1778470.json',
#  'processed/7-1573234.json',
#  'processed/3-670293.json',
#  'processed/7-1558549.json',
#  'processed/8-1805417.json',
#  'processed/2-461097.json',
#  'processed/8-1800595.json',
#  'processed/0-25729.json',
#  'processed/3-676941.json',
#  'processed/4-896276.json',
#  'processed/1-229198.json',
#  'processed/9-2004891.json',
#  'processed/8-1781292.json',
#  'processed/4-894431.json',
#  'processed/7-1557385.json',
#  'processed/9-2018122.json',
#  'processed/2-891789.json',
#  'processed/3-1335343.json',
#  'processed/9-2022951.json',
#  'processed/1-223629.json',
#  'processed/8-1806098.json',
#  'processed/8-1779595.json',
#  'processed/0-34599.json',
#  'processed/8-1780501.json',
#  'processed/8-1807984.json',
#  'processed/5-1120879.json',
#  'processed/0-11024.json',
#  'processed/4-889190.json',
#  'processed/6-1346084.json',
#  'processed/4-912880.json',
#  'processed/4-902757.json',
#  'processed/6-1346868.json',
#  'processed/1-238889.json',
#  'processed/4-906522.json',
#  'processed/2-896550.json',
#  'processed/8-1807363.json',
#  'processed/0-32205.json',
#  'processed/9-2016166.json',
#  'processed/4-906868.json',
#  'processed/6-1348767.json',
#  'processed/2-891377.json',
#  'processed/8-1795909.json',
#  'processed/1-229120.json',
#  'processed/3-670790.json',
#  'processed/3-1335722.json',
#  'processed/2-444886.json',
#  'processed/4-916173.json',
#  'processed/2-470492.json',
#  'processed/2-469516.json',
#  'processed/8-1792323.json',
#  'processed/9-2024290.json',
#  'processed/5-1137155.json',
#  'processed/1-244419.json',
#  'processed/8-1780751.json',
#  'processed/1-245551.json',
#  'processed/2-891737.json',
#  'processed/4-895016.json',
#  'processed/0-11224.json',
#  'processed/1-242931.json',
#  'processed/1-235334.json',
#  'processed/6-1349845.json',
#  'processed/3-699684.json',
#  'processed/1-250056.json',
#  'processed/6-1349924.json',
#  'processed/6-1346695.json',
#  'processed/5-1135252.json',
#  'processed/5-1128519.json',
#  'processed/4-1782783.json',
#  'processed/1-455081.json',
#  'processed/4-1783877.json',
#  'processed/2-455703.json',
#  'processed/6-1338787.json',
#  'processed/8-1797532.json',
#  'processed/4-1779887.json',
#  'processed/6-1349756.json',
#  'processed/0-18349.json',
#  'processed/4-900218.json',
#  'processed/2-454735.json',
#  'processed/5-1124817.json',
#  'processed/1-455014.json',
#  'processed/1-224834.json',
#  'processed/1-238611.json',
#  'processed/4-906434.json',
#  'processed/9-2006733.json',
#  'processed/7-1567746.json',
#  'processed/3-1334499.json',
#  'processed/1-223455.json',
#  'processed/5-1137854.json',
#  'processed/4-1787826.json',
#  'processed/8-1801177.json',
#  'processed/1-247992.json',
#  'processed/0-22206.json',
#  'processed/1-233238.json',
#  'processed/7-1558610.json',
#  'processed/9-2005322.json',
#  'processed/0-29980.json',
#  'processed/4-902491.json',
#  'processed/7-1574309.json',
#  'processed/5-1119087.json',
#  'processed/7-1573016.json',
#  'processed/4-1784486.json',
#  'processed/0-4461.json',
#  'processed/4-905784.json',
#  'processed/2-472568.json',
#  'processed/7-1561147.json',
#  'processed/8-1794416.json',
#  'processed/7-1580545.json',
#  'processed/7-1561805.json',
#  'processed/9-2009668.json',
#  'processed/7-1558453.json',
#  'processed/3-679757.json',
#  'processed/1-247152.json',
#  'processed/9-2011193.json',
#  'processed/1-450617.json',
#  'processed/3-678303.json',
#  'processed/1-444950.json',
#  'processed/1-226777.json',
#  'processed/4-898637.json',
#  'processed/4-914036.json',
#  'processed/3-700041.json',
#  'processed/8-1780739.json',
#  'processed/1-239034.json',
#  'processed/6-1340099.json',
#  'processed/4-910790.json',
#  'processed/0-2563.json',
#  'processed/8-1792817.json',
#  'processed/5-1113719.json',
#  'processed/6-1339116.json',
#  'processed/2-890201.json',
#  'processed/3-673720.json',
#  'processed/7-1573937.json',
#  'processed/9-2022663.json',
#  'processed/4-889869.json',
#  'processed/1-243188.json',
#  'processed/6-1356877.json',
#  'processed/1-242113.json',
#  'processed/1-224742.json',
#  'processed/7-1562131.json',
#  'processed/1-222903.json',
#  'processed/0-26948.json',
#  'processed/7-1561095.json',
#  'processed/9-2020269.json',
#  'processed/0-12907.json',
#  'processed/5-1138591.json',
#  'processed/2-891606.json',
#  'processed/7-1555554.json',
#  'processed/8-1796313.json',
#  'processed/1-450399.json',
#  'processed/2-451942.json',
#  'processed/3-690378.json',
#  'processed/1-451342.json',
#  'processed/7-1577374.json',
#  'processed/0-2686.json',
#  'processed/7-1575325.json',
#  'processed/1-239737.json',
#  'processed/5-1124893.json',
#  'processed/1-226811.json',
#  'processed/8-1809767.json',
#  'processed/8-1796275.json',
#  'processed/1-455236.json',
#  'processed/1-243486.json',
#  'processed/8-1807007.json',
#  'processed/8-1793526.json',
#  'processed/9-2011527.json',
#  'processed/5-1116287.json',
#  'processed/3-673815.json',
#  'processed/4-909144.json',
#  'processed/0-14497.json',
#  'processed/7-1583266.json',
#  'processed/3-1335133.json',
#  'processed/7-1561255.json',
#  'processed/4-915933.json',
#  'processed/0-6758.json',
#  'processed/5-1129500.json',
#  'processed/1-248378.json',
#  'processed/7-1558482.json',
#  'processed/2-473789.json',
#  'processed/2-448099.json',
#  'processed/8-1783530.json',
#  'processed/6-1358566.json',
#  'processed/5-1127380.json',
#  'processed/5-1131643.json',
#  'processed/2-892834.json',
#  'processed/6-1335519.json',
#  'processed/1-227276.json',
#  'processed/9-1999862.json',
#  'processed/0-19587.json',
#  'processed/9-2016025.json',
#  'processed/2-461391.json',
#  'processed/3-691804.json',
#  'processed/9-2015936.json',
#  'processed/5-1131237.json',
#  'processed/0-21353.json',
#  'processed/6-1338938.json',
#  'processed/9-2019473.json',
#  'processed/4-911667.json',
#  'processed/8-1779756.json',
#  'processed/0-31870.json',
#  'processed/9-2015433.json',
#  'processed/4-911960.json',
#  'processed/3-676419.json',
#  'processed/8-1796153.json',
#  'processed/9-2010199.json',
#  'processed/0-38980.json',
#  'processed/3-1337417.json',
#  'processed/7-1569320.json',
#  'processed/6-1337930.json',
#  'processed/4-1788044.json',
#  'processed/4-891999.json',
#  'processed/4-893315.json',
#  'processed/0-31740.json',
#  'processed/2-473483.json',
#  'processed/0-35979.json',
#  'processed/5-1132745.json',
#  'processed/7-1555726.json',
#  'processed/8-1808219.json',
#  'processed/3-684846.json',
#  'processed/8-1788298.json',
#  'processed/0-4858.json',
#  'processed/7-1555734.json',
#  'processed/4-1780893.json',
#  'processed/7-1561776.json',
#  'processed/6-1342147.json',
#  'processed/1-222849.json',
#  'processed/6-1342628.json',
#  'processed/1-226281.json',
#  'processed/2-475869.json',
#  'processed/0-32251.json',
#  'processed/3-1336527.json',
#  'processed/6-1349261.json',
#  'processed/8-1799170.json',
#  'processed/0-3037.json',
#  'processed/2-462289.json',
#  'processed/7-1563469.json',
#  'processed/0-23132.json',
#  'processed/0-25767.json',
#  'processed/1-451976.json',
#  'processed/4-915127.json',
#  'processed/2-893360.json',
#  'processed/2-891248.json',
#  'processed/3-669862.json',
#  'processed/6-1339994.json',
#  'processed/4-900586.json',
#  'processed/5-1123624.json',
#  'processed/2-449318.json',
#  'processed/6-1336049.json',
#  'processed/4-914018.json',
#  'processed/0-17996.json',
#  'processed/1-240796.json',
#  'processed/3-700043.json',
#  'processed/3-680051.json',
#  'processed/6-1337840.json',
#  'processed/0-19532.json',
#  'processed/0-4764.json',
#  'processed/3-1333986.json',
#  'processed/2-455050.json',
#  'processed/5-1121135.json',
#  'processed/7-1560194.json',
#  'processed/8-1808785.json',
#  'processed/9-2020493.json',
#  'processed/9-2015291.json',
#  'processed/2-472435.json',
#  'processed/1-237848.json',
#  'processed/3-680778.json',
#  'processed/6-1348546.json',
#  'processed/1-452916.json',
#  'processed/4-902521.json',
#  'processed/2-463531.json',
#  'processed/5-1129527.json',
#  'processed/4-1788061.json',
#  'processed/2-466224.json',
#  'processed/2-473033.json',
#  'processed/1-235994.json',
#  'processed/2-450344.json',
#  'processed/5-1134763.json',
#  'processed/6-1347973.json',
#  'processed/9-2020431.json',
#  'processed/3-694613.json',
#  'processed/3-671887.json',
#  'processed/3-667318.json',
#  'processed/9-2022152.json',
#  'processed/1-454155.json',
#  'processed/1-244926.json',
#  'processed/0-1260.json',
#  'processed/6-1358798.json',
#  'processed/3-685827.json',
#  'processed/6-1352689.json',
#  'processed/7-1563727.json',
#  'processed/7-1572946.json',
#  'processed/9-2008560.json',
#  'processed/7-1573076.json',
#  'processed/1-247656.json',
#  'processed/7-1568952.json',
#  'processed/1-227199.json',
#  'processed/3-1339917.json',
#  'processed/1-222859.json',
#  'processed/2-478401.json',
#  'processed/2-466267.json',
#  'processed/4-903117.json',
#  'processed/0-5155.json',
#  'processed/9-2008020.json',
#  'processed/0-6801.json',
#  'processed/6-1358827.json',
#  'processed/6-1356411.json',
#  'processed/8-1780714.json',
#  'processed/8-1792367.json',
#  'processed/2-449018.json',
#  'processed/0-23263.json',
#  'processed/0-25583.json',
#  'processed/0-30565.json',
#  'processed/2-452773.json',
#  'processed/5-1132623.json',
#  'processed/9-2011726.json',
#  'processed/6-1358190.json',
#  'processed/4-909758.json',
#  'processed/0-10833.json',
#  'processed/4-908153.json',
#  'processed/0-4343.json',
#  'processed/0-32881.json',
#  'processed/3-693276.json',
#  'processed/6-1336361.json',
#  'processed/3-693173.json',
#  'processed/5-1133028.json',
#  'processed/8-1779088.json',
#  'processed/0-34203.json',
#  'processed/5-1117910.json',
#  'processed/4-911112.json',
#  'processed/1-237963.json',
#  'processed/8-1789849.json',
#  'processed/1-454858.json',
#  'processed/3-689619.json',
#  'processed/7-1556838.json',
#  'processed/5-1112227.json',
#  'processed/4-1785192.json',
#  'processed/8-1796482.json',
#  'processed/7-1556869.json',
#  'processed/1-230255.json',
#  'processed/4-906057.json',
#  'processed/2-469901.json',
#  'processed/6-1336146.json',
#  'processed/3-667089.json',
#  'processed/4-910733.json',
#  'processed/0-2349.json',
#  'processed/0-6773.json',
#  'processed/7-1556346.json',
#  'processed/0-21376.json',
#  'processed/1-450646.json',
#  'processed/7-1577827.json',
#  'processed/4-896253.json',
#  'processed/2-476313.json',
#  'processed/4-913516.json',
#  'processed/5-1135843.json',
#  'processed/0-34571.json',
#  'processed/0-14346.json',
#  'processed/8-1793959.json',
#  'processed/5-1129203.json',
#  'processed/0-560.json',
#  'processed/3-686764.json',
#  'processed/5-1127101.json',
#  'processed/9-2007786.json',
#  'processed/8-1797337.json',
#  'processed/2-446088.json',
#  'processed/8-1795018.json',
#  'processed/7-1584242.json',
#  'processed/2-893250.json',
#  'processed/9-2017524.json',
#  'processed/3-686728.json',
#  'processed/0-24791.json',
#  'processed/6-1338180.json',
#  'processed/1-448013.json',
#  'processed/5-1113046.json',
#  'processed/6-1338560.json',
#  'processed/0-9895.json',
#  'processed/0-9741.json',
#  'processed/1-449785.json',
#  'processed/2-468932.json',
#  'processed/7-1580288.json',
#  'processed/7-1560688.json',
#  'processed/4-903200.json',
#  'processed/1-454279.json',
#  'processed/7-1573399.json',
#  'processed/7-1582911.json',
#  'processed/4-1784693.json',
#  'processed/4-905801.json',
#  'processed/8-1807104.json',
#  'processed/2-892472.json',
#  'processed/9-2029504.json',
#  'processed/7-1568755.json',
#  'processed/0-8248.json',
#  'processed/7-1576763.json',
#  'processed/3-689709.json',
#  'processed/9-2021421.json',
#  'processed/2-477048.json',
#  'processed/8-1804904.json',
#  'processed/9-2019017.json',
#  'processed/0-14749.json',
#  'processed/5-1129853.json',
#  'processed/6-1346226.json',
#  'processed/4-1778358.json',
#  'processed/6-1346070.json',
#  'processed/9-2029119.json',
#  'processed/0-35806.json',
#  'processed/9-2017238.json',
#  'processed/0-26689.json',
#  'processed/6-1336360.json',
#  'processed/0-4246.json',
#  'processed/7-1570191.json',
#  'processed/8-1786670.json',
#  'processed/9-2003743.json',
#  'processed/5-1115620.json',
#  'processed/1-453277.json',
#  'processed/3-1338670.json',
#  'processed/9-2013659.json',
#  'processed/0-14665.json',
#  'processed/7-1581865.json',
#  'processed/1-231930.json',
#  'processed/1-244592.json',
#  'processed/7-1579316.json',
#  'processed/3-678421.json',
#  'processed/7-1566173.json',
#  'processed/2-897215.json',
#  'processed/0-2017.json',
#  'processed/3-677629.json',
#  'processed/4-899424.json',
#  'processed/5-1130719.json',
#  'processed/0-15526.json',
#  'processed/2-890151.json',
#  'processed/4-906219.json',
#  'processed/4-913655.json',
#  'processed/9-2013108.json',
#  'processed/0-21114.json',
#  'processed/0-37404.json',
#  'processed/0-22437.json',
#  'processed/1-230654.json',
#  'processed/8-1803524.json',
#  'processed/9-2026994.json',
#  'processed/5-1131355.json',
#  'processed/2-469124.json',
#  'processed/6-1344118.json',
#  'processed/4-1778676.json',
#  'processed/0-2703.json',
#  'processed/1-235374.json',
#  'processed/6-1359197.json',
#  'processed/4-900864.json',
#  'processed/5-1135872.json',
#  'processed/1-451808.json',
#  'processed/5-1124404.json',
#  'processed/5-1118008.json',
#  'processed/4-1787018.json',
#  'processed/0-12997.json',
#  'processed/7-1563836.json',
#  'processed/6-1337243.json',
#  'processed/1-236324.json',
#  'processed/5-1130794.json',
#  'processed/0-35637.json',
#  'processed/3-1334576.json',
#  'processed/9-2017694.json',
#  'processed/6-1335797.json',
#  'processed/1-454089.json',
#  'processed/2-464294.json',
#  'processed/0-21719.json',
#  'processed/7-1561459.json',
#  'processed/2-447691.json',
#  'processed/4-1787827.json',
#  'processed/1-242171.json',
#  'processed/9-2019648.json',
#  'processed/9-2029001.json',
#  'processed/3-1340009.json',
#  'processed/1-222707.json',
#  'processed/2-450327.json',
#  'processed/9-2026637.json',
#  'processed/7-1576064.json',
#  'processed/3-693740.json',
#  'processed/4-912288.json',
#  'processed/5-1122180.json',
#  'processed/1-447342.json',
#  'processed/3-686439.json',
#  'processed/3-700155.json',
#  'processed/2-474312.json',
#  'processed/9-2021834.json',
#  'processed/9-2023529.json',
#  'processed/0-33619.json',
#  'processed/3-1334243.json',
#  'processed/8-1789652.json',
#  'processed/9-2013712.json',
#  'processed/8-1791042.json',
#  'processed/2-465356.json',
#  'processed/2-453224.json',
#  'processed/8-1790841.json',
#  'processed/4-912585.json',
#  'processed/9-2012004.json',
#  'processed/3-693764.json',
#  'processed/2-472486.json',
#  'processed/2-458773.json',
#  'processed/1-236733.json',
#  'processed/0-1459.json',
#  'processed/3-679515.json',
#  'processed/0-14060.json',
#  'processed/6-1340512.json',
#  'processed/4-907748.json',
#  'processed/4-1783033.json',
#  'processed/0-27736.json',
#  'processed/9-2015798.json',
#  'processed/9-2020209.json',
#  'processed/3-671858.json',
#  'processed/7-1566889.json',
#  'processed/6-1336213.json',
#  'processed/4-903647.json',
#  'processed/5-1128706.json',
#  'processed/3-1337762.json',
#  'processed/6-1355612.json',
#  'processed/2-892619.json',
#  'processed/9-2009728.json',
#  'processed/5-1112034.json',
#  'processed/8-1799057.json',
#  'processed/4-911926.json',
#  'processed/0-37925.json',
#  'processed/0-33037.json',
#  'processed/5-1116317.json',
#  'processed/9-2020963.json',
#  'processed/9-2022542.json',
#  'processed/1-235822.json',
#  'processed/7-1562802.json',
#  'processed/0-21993.json',
#  'processed/4-904539.json',
#  'processed/3-1336590.json',
#  'processed/0-8415.json',
#  'processed/6-1337547.json',
#  'processed/5-1135742.json',
#  'processed/5-1118629.json',
#  'processed/4-898820.json',
#  'processed/5-1119771.json',
#  'processed/2-467530.json',
#  'processed/7-1559752.json',
#  'processed/1-247495.json',
#  'processed/3-686501.json',
#  'processed/1-231699.json',
#  'processed/3-696734.json',
#  'processed/9-2029524.json',
#  'processed/4-896340.json',
#  'processed/5-1112221.json',
#  'processed/1-453520.json',
#  'processed/0-14048.json',
#  'processed/3-697422.json',
#  'processed/3-692302.json',
#  'processed/0-36245.json',
#  'processed/3-673191.json',
#  'processed/4-914838.json',
#  'processed/7-1571072.json',
#  'processed/9-2008049.json',
#  'processed/5-1125921.json',
#  'processed/8-1804925.json',
#  'processed/8-1787934.json',
#  'processed/0-2226.json',
#  'processed/0-2618.json',
#  'processed/0-12785.json',
#  'processed/4-895852.json',
#  'processed/0-10035.json',
#  'processed/7-1579435.json',
#  'processed/9-2019922.json',
#  'processed/9-2012455.json',
#  'processed/3-689011.json',
#  'processed/2-464411.json',
#  'processed/1-230128.json',
#  'processed/2-461750.json',
#  'processed/1-447705.json',
#  'processed/9-2008055.json',
#  'processed/9-2005503.json',
#  'processed/2-468007.json',
#  'processed/9-2017525.json',
#  'processed/2-455581.json',
#  'processed/0-5247.json',
#  'processed/1-446435.json',
#  'processed/0-38563.json',
#  'processed/9-2015442.json',
#  'processed/1-250875.json',
#  'processed/6-1333580.json',
#  'processed/5-1116331.json',
#  'processed/1-453881.json',
#  'processed/9-2023670.json',
#  'processed/0-11253.json',
#  'processed/1-226880.json',
#  'processed/1-234947.json',
#  'processed/6-1354942.json',
#  'processed/5-1133323.json',
#  'processed/2-456611.json',
#  'processed/3-1338596.json',
#  'processed/4-892351.json',
#  'processed/5-1125230.json',
#  'processed/2-473814.json',
#  'processed/0-789.json',
#  'processed/0-24880.json',
#  'processed/0-28023.json',
#  'processed/7-1581716.json',
#  'processed/2-890101.json',
#  'processed/5-1130989.json',
#  'processed/9-2027229.json',
#  'processed/1-228424.json',
#  'processed/7-1556581.json',
#  'processed/4-914611.json',
#  'processed/7-1574371.json',
#  'processed/3-670134.json',
#  'processed/8-1783611.json',
#  'processed/9-2010121.json',
#  'processed/6-1352863.json',
#  'processed/3-675606.json',
#  'processed/1-453567.json',
#  'processed/4-899114.json',
#  'processed/4-900677.json',
#  'processed/6-1339521.json',
#  'processed/2-891655.json',
#  'processed/6-1341542.json',
#  'processed/5-1128102.json',
#  'processed/0-9685.json',
#  'processed/2-457147.json',
#  'processed/9-2029325.json',
#  'processed/4-916233.json',
#  'processed/9-2015428.json',
#  'processed/7-1582648.json',
#  'processed/3-692874.json',
#  'processed/6-1350054.json',
#  'processed/6-1352028.json',
#  'processed/8-1796216.json',
#  'processed/9-1999882.json',
#  'processed/2-448222.json',
#  'processed/1-243163.json',
#  'processed/5-1137213.json',
#  'processed/3-694229.json',
#  'processed/3-681734.json',
#  'processed/3-683331.json',
#  'processed/8-1788554.json',
#  'processed/4-896031.json',
#  'processed/7-1566950.json',
#  'processed/8-1796080.json',
#  'processed/4-888743.json',
#  'processed/5-1132836.json',
#  'processed/2-889500.json',
#  'processed/1-236201.json',
#  'processed/7-1579759.json',
#  'processed/8-1779415.json',
#  'processed/2-463082.json',
#  'processed/3-681245.json',
#  'processed/0-5072.json',
#  'processed/3-1338080.json',
#  'processed/7-1583326.json',
#  'processed/6-1348545.json',
#  'processed/8-1779792.json',
#  'processed/0-33028.json',
#  'processed/2-475703.json',
#  'processed/4-907540.json',
#  'processed/8-1802021.json',
#  'processed/8-1803019.json',
#  'processed/8-1778050.json',
#  'processed/5-1131617.json',
#  'processed/4-890184.json',
#  'processed/3-693985.json',
#  'processed/4-889271.json',
#  'processed/0-4222.json',
#  'processed/4-890308.json',
#  'processed/9-2000250.json',
#  'processed/3-670381.json',
#  'processed/7-1570619.json',
#  'processed/6-1352535.json',
#  'processed/8-1791282.json',
#  'processed/9-2005047.json',
#  'processed/5-1132977.json',
#  'processed/5-1111463.json',
#  'processed/9-2004757.json',
#  'processed/4-917957.json',
#  'processed/3-676502.json',
#  'processed/5-1127722.json',
#  'processed/8-1791186.json',
#  'processed/2-473824.json',
#  'processed/2-457472.json',
#  'processed/4-913432.json',
#  'processed/3-693966.json',
#  'processed/5-1121404.json',
#  'processed/4-1778308.json',
#  'processed/3-691568.json',
#  'processed/8-1786147.json',
#  'processed/6-1335500.json',
#  'processed/2-452862.json',
#  'processed/4-910204.json',
#  'processed/0-1265.json',
#  'processed/0-8359.json',
#  'processed/4-908274.json',
#  'processed/4-903020.json',
#  'processed/5-1121275.json',
#  'processed/5-1119881.json',
#  'processed/4-889323.json',
#  'processed/8-1801223.json',
#  'processed/7-1582755.json',
#  'processed/3-672442.json',
#  'processed/5-1115957.json',
#  'processed/1-444918.json',
#  'processed/0-4363.json',
#  'processed/2-473050.json',
#  'processed/7-1571444.json',
#  'processed/7-1578634.json',
#  'processed/1-250141.json',
#  'processed/6-1343018.json',
#  'processed/9-2021275.json',
#  'processed/4-912067.json',
#  'processed/3-1333771.json',
#  'processed/3-674479.json',
#  'processed/4-898854.json',
#  'processed/8-1795096.json',
#  'processed/1-227505.json',
#  'processed/9-2015764.json',
#  'processed/6-1341385.json',
#  'processed/8-1806328.json',
#  'processed/4-904983.json',
#  'processed/9-2002033.json',
#  'processed/2-472829.json',
#  'processed/5-1135379.json',
#  'processed/9-2020561.json',
#  'processed/1-240269.json',
#  'processed/4-1778982.json',
#  'processed/7-1574560.json',
#  'processed/5-1113526.json',
#  'processed/6-1337403.json',
#  'processed/2-897269.json',
#  'processed/1-445816.json',
#  'processed/2-897325.json',
#  'processed/3-666931.json',
#  'processed/4-904259.json',
#  'processed/6-1337246.json',
#  'processed/9-2002133.json',
#  'processed/3-687959.json',
#  'processed/0-801.json',
#  'processed/6-1346814.json',
#  'processed/1-228830.json',
#  'processed/2-476151.json',
#  'processed/5-1127594.json',
#  'processed/1-248654.json',
#  'processed/4-1786009.json',
#  'processed/6-1357222.json',
#  'processed/9-2029218.json',
#  'processed/4-903320.json',
#  'processed/7-1575846.json',
#  'processed/4-917298.json',
#  'processed/0-37675.json',
#  'processed/8-1797221.json',
#  'processed/7-1584723.json',
#  'processed/2-891125.json',
#  'processed/0-994.json',
#  'processed/4-891143.json',
#  'processed/4-893580.json',
#  'processed/8-1787314.json',
#  'processed/0-4006.json',
#  'processed/6-1348435.json',
#  'processed/8-1790577.json',
#  'processed/1-243465.json',
#  'processed/0-19973.json',
#  'processed/2-447993.json',
#  'processed/1-227093.json',
#  'processed/9-2005164.json',
#  'processed/2-452808.json',
#  'processed/4-890110.json',
#  'processed/2-891520.json',
#  'processed/9-2020177.json',
#  'processed/8-1790241.json',
#  'processed/6-1353565.json',
#  'processed/0-23603.json',
#  'processed/3-686429.json',
#  'processed/3-700066.json',
#  'processed/4-903575.json',
#  'processed/7-1563868.json',
#  'processed/4-911874.json',
#  'processed/3-682045.json',
#  'processed/4-889208.json',
#  'processed/5-1114555.json',
#  'processed/4-911527.json',
#  'processed/3-667236.json',
#  'processed/2-477973.json',
#  'processed/6-1335706.json',
#  'processed/0-31869.json',
#  'processed/5-1129049.json',
#  'processed/0-15695.json',
#  'processed/0-9646.json',
#  'processed/3-672000.json',
#  'processed/6-1356581.json',
#  'processed/9-2023145.json',
#  'processed/2-462041.json',
#  'processed/2-454873.json',
#  'processed/0-37128.json',
#  'processed/2-449730.json',
#  'processed/3-692129.json',
#  'processed/0-5283.json',
#  'processed/7-1568242.json',
#  'processed/6-1334752.json',
#  'processed/2-470584.json',
#  'processed/1-225793.json',
#  'processed/8-1806696.json',
#  'processed/0-2776.json',
#  'processed/8-1793780.json',
#  'processed/4-1779090.json',
#  'processed/6-1343258.json',
#  'processed/3-673724.json',
#  'processed/2-451548.json',
#  'processed/4-901624.json',
#  'processed/0-29971.json',
#  'processed/6-1334044.json',
#  'processed/1-239003.json',
#  'processed/0-105.json',
#  'processed/6-1358063.json',
#  'processed/2-445714.json',
#  'processed/1-246148.json',
#  'processed/2-469900.json',
#  'processed/3-670130.json',
#  'processed/1-248011.json',
#  'processed/0-15210.json',
#  'processed/0-2433.json',
#  'processed/6-1353579.json',
#  'processed/7-1574369.json',
#  'processed/2-455621.json',
#  'processed/2-456945.json',
#  'processed/8-1788010.json',
#  'processed/7-1584065.json',
#  'processed/2-451203.json',
#  'processed/0-22958.json',
#  'processed/3-678223.json',
#  ...]

# %%
with open('processed/0-13.json') as fopen:
    data = json.load(fopen)

# %%
data
# Out:
# [{'text': 'dengan kata kata mutiara ni kan adakah itu berdasarkan pengalaman hidup ataupun dia',
#   'start': 2.48,
#   'end': 7.859999999999999,
#   'audio_filename': 'processed-audio/0-13-0.mp3',
#   'original_audio_filename': 'output-audio/1-0-13.mp3'},
#  {'text': 'bar main create satu ayat dan sampaikan kepada orang ramai pula',
#   'start': 7.96,
#   'end': 11.459999999999999,
#   'audio_filename': 'processed-audio/0-13-1.mp3',
#   'original_audio_filename': 'output-audio/1-0-13.mp3'},
#  {'text': 'k yang dah ada dia punya t',
#   'start': 11.68,
#   'end': 13.259999999999998,
#   'audio_filename': 'processed-audio/0-13-2.mp3',
#   'original_audio_filename': 'output-audio/1-0-13.mp3'},
#  {'text': 'demark dah kalau kita nak buat lawak lawak saya okey',
#   'start': 13.24,
#   'end': 15.54,
#   'audio_filename': 'processed-audio/0-13-3.mp3',
#   'original_audio_filename': 'output-audio/1-0-13.mp3'},
#  {'text': 'buat lawak okey tapi kadang kadang saya rasa ramai penonton ataupun',
#   'start': 15.84,
#   'end': 19.02,
#   'audio_filename': 'processed-audio/0-13-4.mp3',
#   'original_audio_filename': 'output-audio/1-0-13.mp3'},
#  {'text': 'kalau ada kata kata yang lagi kena dengan dia orang lagi dia orang sharing',
#   'start': 21.56,
#   'end': 25.26,
#   'audio_filename': 'processed-audio/0-13-5.mp3',
#   'original_audio_filename': 'output-audio/1-0-13.mp3'},
#  {'text': 'yang jadi pada diri saya',
#   'start': 26.16,
#   'end': 27.18,
#   'audio_filename': 'processed-audio/0-13-6.mp3',
#   'original_audio_filename': 'output-audio/1-0-13.mp3'}]

# %%
mp.multiprocessing(filtered, loop, cores = 20, returned = False)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:28:34<00:00, 20.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:01<00:00, 11.48it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:47:39<00:00, 17.20it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:51:15<00:00, 16.64it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:53:22<00:00, 16.33it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:53:43<00:00, 16.28it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:53:52<00:00, 16.26it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:54:11<00:00, 16.21it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:55:49<00:00, 15.99it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:55:52<00:00, 15.98it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:56:10<00:00, 15.94it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:56:20<00:00, 15.91it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:56:29<00:00, 15.90it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:56:59<00:00, 15.83it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:56:48<00:00, 15.85it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:57:09<00:00, 15.80it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:57:21<00:00, 15.78it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:57:35<00:00, 15.75it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:57:43<00:00, 15.73it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [1:59:59<00:00, 15.43it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 111092/111092 [2:00:55<00:00, 15.31it/s]

# %%
processed = glob('processed/*.json')
len(processed)
# Out:
# 1054141

# %%
with open(processed[-1]) as fopen:
    d = json.load(fopen)
d
# Out:
# [{'text': 'tapi rakyat happy ke tak baik kami nak',
#   'start': 1.36,
#   'end': 3.9,
#   'audio_filename': 'processed-audio/17-1964297-0.mp3',
#   'original_audio_filename': 'output-audio/0-9443-49.mp3'},
#  {'text': 'bahawa dua daripada majlis daerah',
#   'start': 4.64,
#   'end': 5.859999999999999,
#   'audio_filename': 'processed-audio/17-1964297-1.mp3',
#   'original_audio_filename': 'output-audio/0-9443-49.mp3'},
#  {'text': 'mana di',
#   'start': 14.24,
#   'end': 15.299999999999999,
#   'audio_filename': 'processed-audio/17-1964297-2.mp3',
#   'original_audio_filename': 'output-audio/0-9443-49.mp3'},
#  {'text': 'harkan juga',
#   'start': 19.0,
#   'end': 20.580000000000002,
#   'audio_filename': 'processed-audio/17-1964297-3.mp3',
#   'original_audio_filename': 'output-audio/0-9443-49.mp3'}]

# %%
import IPython.display as ipd

ipd.Audio('processed-audio/17-1964297-1.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !du -hs processed-audio
# Out:
# 70G	processed-audio

# %%
!~/7zz -v10g a processed-audio.7z processed-audio > /dev/null

# %%
with open('processed.jsonl', 'w') as fopen_l:
    for f in tqdm(processed):
        try:
            with open(f) as fopen:
                data = json.load(fopen)
            fopen_l.write(f'{json.dumps(data)}\n')
        except:
            pass
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 1054141/1054141 [03:16<00:00, 5363.46it/s]

# %%
from huggingface_hub import HfApi
api = HfApi()

# %%
api.upload_file(
    path_or_fileobj='processed.jsonl',
    path_in_repo='processed.jsonl',
    repo_id='mesolitica/pseudostreaming-malaysian-youtube-whisper-large-v3',
    repo_type='dataset',
)
# Out:
# processed.jsonl:   0%|          | 0.00/604M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/mesolitica/pseudostreaming-malaysian-youtube-whisper-large-v3/commit/66eed57011381779feff8de8b6f107d075c73b20', commit_message='Upload processed.jsonl with huggingface_hub', commit_description='', oid='66eed57011381779feff8de8b6f107d075c73b20', pr_url=None, pr_revision=None, pr_num=None)

# %%
files = glob('processed-audio/*.mp3')
len(files)
# Out:
# 2761432

# %%
def loop(files):
    files, _ = files
    total = 0
    for f in tqdm(files):
        y, sr = malaya_speech.load(f)
        total += len(y) / sr
    return [total]

# %%
totals = mp.multiprocessing(files, loop)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 460238/460238 [11:30<00:00, 666.57it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 878.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 460238/460238 [11:31<00:00, 665.99it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 460238/460238 [11:30<00:00, 667.00it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 460238/460238 [11:29<00:00, 667.37it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 460238/460238 [11:31<00:00, 665.21it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 460238/460238 [11:31<00:00, 665.37it/s]

# %%
sum(totals) / 60 / 60
# Out:
# 3407.871277396369

# %%
for f in glob('*7z*'):
    print(f)
    api.upload_file(
        path_or_fileobj=f,
        path_in_repo=f,
        repo_id='mesolitica/pseudostreaming-malaysian-youtube-whisper-large-v3',
        repo_type='dataset',
    )
# Out:
# processed-audio.7z.002
# processed-audio.7z.002:   0%|          | 0.00/10.7G [00:00<?, ?B/s]
# processed-audio.7z.007
# processed-audio.7z.007:   0%|          | 0.00/2.35G [00:00<?, ?B/s]
# processed-audio.7z.005
# processed-audio.7z.005:   0%|          | 0.00/10.7G [00:00<?, ?B/s]
# processed-audio.7z.006
# processed-audio.7z.006:   0%|          | 0.00/10.7G [00:00<?, ?B/s]
# processed-audio.7z.004
# processed-audio.7z.004:   0%|          | 0.00/10.7G [00:00<?, ?B/s]
# processed-audio.7z.003
# processed-audio.7z.003:   0%|          | 0.00/10.7G [00:00<?, ?B/s]
# processed-audio.7z.001
# processed-audio.7z.001:   0%|          | 0.00/10.7G [00:00<?, ?B/s]
