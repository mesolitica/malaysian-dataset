# %%
from glob import glob
from tqdm import tqdm
import json
import numpy as np
import os
from transformers import AutoTokenizer, WhisperConfig
from sklearn.feature_extraction.text import CountVectorizer

config = WhisperConfig.from_pretrained('openai/whisper-large-v3')
maxlen = config.max_length - 3

# %%
tokenizer = AutoTokenizer.from_pretrained('openai/whisper-large-v3')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
from datasets import Audio

sr = 16000
audio = Audio(sampling_rate=sr)

# %%
files = sorted(glob('output/*.json'), key = lambda x: int(x.split('-')[1].replace('.json', '')))
len(files)
# Out:
# 52908

# %%
import re

pattern_pair = r'<\|(\d+\.\d+)\|>(.*?)<\|(\d+\.\d+)\|>'
matches = re.findall(pattern_pair, '<|0.00|> kerajaan persekutuan<|1.46|><|1.46|> dan banyak masalah hubungan<|3.96|><|3.96|> antara kerajaan negeri dan')
matches
# Out:
# [('0.00', ' kerajaan persekutuan', '1.46'),
#  ('1.46', ' dan banyak masalah hubungan', '3.96')]

# %%
import string

punct = set(string.punctuation)

def remove_punct(s):
    return ''.join([c for c in s if c not in punct])

def remove_duplicate(string, n = 3):
    splitted = string.split()
    n = [splitted[i: i + n] for i in range(0, len(splitted), n)]
    already = set()
    dedup = []
    for n_ in n:
        original_n = ' '.join(n_)
        n_ = ' '.join(n_).lower()
        n_ = remove_punct(n_)
        if n_ not in already:
            dedup.append(original_n)
            already.add(n_)
    return ' '.join(dedup)

# %%
import math

def round_to_nearest_0_02(number):
    return round(number * 50) / 50

# %%
selected = [
    'terima kasih kerana menonton',
    'terima kasih',
]

# %%
import mp
import copy

minimum_score = 5

def loop(files):
    files, _ = files
    results = []
    for f in tqdm(files):
        try:
            with open(f) as fopen:
                data = json.load(fopen)
        except:
            continue
        f_split = os.path.split(f)[-1].replace('.json', '')
        for i in range(len(data)):
            
            audio_filename = os.path.join('output-audio', f'{f_split}-{i}.mp3')
            if not os.path.exists(audio_filename):
                continue
                
            y = audio.decode_example(audio.encode_example(audio_filename))['array']
            len_y = len(y) / sr
            if len_y > 30:
                continue
            rounded_num = f'<|{round_to_nearest_0_02(len_y):.2f}|>'
            
            if data[i]['score_ms'] > minimum_score:
                a = np.array(data[i]['predict_ms'])
                a = a[a != 50257].tolist() + [50257]
                t = tokenizer.decode(a, skip_special_tokens = True, decode_with_timestamps = True).strip()
                if t.split('|>')[-1] != '':
                    t += rounded_num
                
                matches = re.findall(pattern_pair, t)
                rs = []
                for match in matches:
                    l = float(match[0])
                    r = float(match[2])
                    t_ = match[1]
                    rt_ = re.sub('[^a-z ]+', '', t_.lower()).strip()
                    if (r - l > 3) and any([s == rt_ for s in selected]):
                        # print(audio_filename, t_)
                        t_ = ''
                    else:
                        try:
                            dense = CountVectorizer(ngram_range = (3,3)).fit_transform([t_]).todense()
                            repeat = (dense > 3).sum() >= 1
                            if repeat:
                                t_ = remove_duplicate(t_)
                        except:
                            if len(t_) > 100:
                                t_ = remove_duplicate(t_)
                    rs.append(f'<|{match[0]}|>{t_}<|{match[2]}|>')
                rs = ''.join(rs)
                t = f'<|startoftranscript|><|ms|><|transcribe|>{rs}<|endoftext|>'
                d = {
                    'new_text': t,
                    'audio_filename': audio_filename,
                }
                results.append(d)
                    
            
            if data[i]['score_en'] > minimum_score:
                a = np.array(data[i]['predict_en'])
                a = a[a != 50257].tolist() + [50257]
                t = tokenizer.decode(a, skip_special_tokens = True, decode_with_timestamps = True).strip()
                if t.split('|>')[-1] != '':
                    t += rounded_num
                
                matches = re.findall(pattern_pair, t)
                rs = []
                for match in matches:
                    l = float(match[0])
                    r = float(match[2])
                    t_ = match[1]
                    rt_ = re.sub('[^a-z ]+', '', t_.lower()).strip()
                    if (r - l > 3) and any([s == rt_ for s in selected]):
                        # print(audio_filename, t_)
                        t_ = ''
                    else:
                        try:
                            dense = CountVectorizer(ngram_range = (3,3)).fit_transform([t_]).todense()
                            repeat = (dense > 3).sum() >= 1
                            if repeat:
                                t_ = remove_duplicate(t_)
                        except:
                            if len(t_) > 100:
                                t_ = remove_duplicate(t_)
                    rs.append(f'<|{match[0]}|>{t_}<|{match[2]}|>')
                rs = ''.join(rs)
                t = f'<|startoftranscript|><|en|><|transcribe|>{rs}<|endoftext|>'
                d = {
                    'new_text': t,
                    'audio_filename': audio_filename,
                }
                results.append(d)
    return results

# %%
results = loop((files[:10], 0))
# Out:
# 100%|██████████| 10/10 [00:18<00:00,  1.90s/it]

# %%
len(results)
# Out:
# 708

# %%
results[:10]
# Out:
# [{'new_text': "<|startoftranscript|><|ms|><|transcribe|><|0.00|> Collab dia tak boleh kerja<|0.88|><|0.88|> Tak boleh<|1.38|><|1.38|> Kena ambil yang business class jugalah<|2.74|><|2.74|> Business class jugak<|3.48|><|3.48|> Faham faham faham<|4.64|><|4.64|> Macam tu<|5.46|><|5.46|> So gaji berbeza<|6.86|><|6.86|> Gaji berbeza<|8.50|><|8.50|> Antara<|8.76|><|8.76|> Kelas-kelas ni<|9.76|><|9.76|> Berbeza<|10.58|><|10.58|> Few thousand jugak lah<|12.58|><|12.58|> Jauh<|12.62|><|12.62|> Jauh beza dia<|13.38|><|13.38|> Beza seribu dua ribu<|14.92|><|14.92|> Macam tu lah<|15.52|><|15.52|> Total<|16.76|><|16.76|> Kalau macam Singapore<|18.76|><|18.76|> Dia macam tu juga<|19.48|><|19.48|> Tapi dia ikut qualification<|20.66|><|20.66|> You diploma business class<|22.02|><|22.02|> Ijazah<|22.96|><|22.96|> Macam tu eh<|23.62|><|23.62|> First class something like that<|24.74|><|24.74|> Dia tengok qualification<|26.20|><|26.20|> Let's say kan<|27.26|><|27.26|> Eh itu gaji gaji<|28.14|><|28.14|> Gaji gaji<|28.70|><|28.70|> Oh itu gaji<|29.24|><|29.24|> Serius eh<|29.80|><|endoftext|>",
#   'audio_filename': 'output-audio/2-0-0.mp3'},
#  {'new_text': "<|startoftranscript|><|en|><|transcribe|><|0.00|> If you don't have a job, you can't work.<|2.00|><|2.00|> You have to take business class.<|4.00|><|4.00|> I understand.<|6.00|><|6.00|> So, the salary is different?<|8.00|><|8.00|> The salary is different.<|10.00|><|10.00|> Between these classes?<|12.00|><|12.00|> It's different.<|14.00|><|14.00|> It's different.<|16.00|><|16.00|> It's like a thousand or two thousand.<|18.00|><|18.00|> If it's like Singapore, it's like that.<|20.00|><|20.00|> But they follow the qualifications.<|22.00|><|22.00|> You have a diploma, business class.<|24.00|><|24.00|> You get a degree.<|26.00|><|26.00|> Something like that.<|28.00|><|endoftext|>",
#   'audio_filename': 'output-audio/2-0-0.mp3'},
#  {'new_text': '<|startoftranscript|><|ms|><|transcribe|><|0.00|> Tapi kerja sama je<|1.46|><|1.46|> If you want to<|2.12|><|2.12|> Singapore airline<|2.84|><|2.84|> I tak sure sangat lah<|4.14|><|4.14|> Tapi Singapore airline<|6.10|><|6.10|> Tough juga sebenarnya<|7.38|><|7.38|> Tak silap dia punya training<|8.88|><|8.88|> Few months<|10.06|><|10.06|> Few months jugalah<|10.80|><|10.80|> Okay<|12.26|><|12.26|> Yang<|12.80|><|12.80|> You kerja EY<|15.32|><|15.32|> Tapi you belajar juga<|16.26|><|16.26|> Business class first class<|17.20|><|17.20|> Tak<|17.48|><|17.48|> Belajar bila kita pergi<|19.38|><|19.38|> Conversion class<|20.28|><|20.28|> Bila kita dah qualified<|21.24|><|21.24|> Untuk join<|22.08|><|22.08|> So apa yang susahnya<|23.00|><|23.00|> Kerja EY<|23.46|><|23.46|> You cakap tadi<|24.06|><|24.06|> Cara<|25.84|><|25.84|> Pegang glass<|27.18|><|27.18|> Cara kita pegang bottle<|28.90|><|endoftext|>',
#   'audio_filename': 'output-audio/2-0-1.mp3'},
#  {'new_text': "<|startoftranscript|><|en|><|transcribe|><|0.00|> But you work in the same field?<|2.00|><|2.00|> I'm not sure about Singapore Airlines.<|4.00|><|4.00|> But Singapore Airlines is tough.<|7.00|><|7.00|> It took a few months to train.<|10.00|><|10.00|> A few months.<|11.00|><|11.00|> Okay. You work at EY but you also learn business class first class?<|17.00|><|17.00|> No. I learn when we go to conversion class.<|20.00|><|20.00|> When we are qualified to join.<|22.00|><|22.00|> So what is the hardest part of working at EY?<|24.00|><|endoftext|>",
#   'audio_filename': 'output-audio/2-0-1.mp3'},
#  {'new_text': '<|startoftranscript|><|ms|><|transcribe|><|0.00|> Semua kena standardize<|2.36|><|2.36|> Dialog<|3.54|><|3.54|> Dialog tak boleh sebarangan<|5.22|><|5.22|> Oh, dialog<|6.60|><|6.60|> Dialog<|7.16|><|7.16|> Kita tak boleh<|8.40|><|8.40|> Say, do you want chicken rice?<|10.02|><|10.12|> Tak boleh<|10.44|><|10.44|> Excuse me, sir<|11.46|><|11.46|> Would you like to join us for dinner?<|13.12|><|13.78|> Wow<|14.14|><|14.14|> We do have chicken rice<|15.64|><|15.64|> Blah, blah, blah<|16.18|><|16.18|> We do have bolognese pasta<|17.44|><|17.44|> And we do have vegetarian<|18.86|><|18.86|> Biryani rice<|20.26|><|20.26|> What would you like to have for tonight?<|21.44|><|22.02|> Kena that kind of full sentence<|23.08|><|23.08|> Kena memorize<|23.72|><|23.72|> Menu particular<|25.64|><|25.64|> Yang panjang nama menu tu pun<|28.32|><|28.32|> Kita kena memorize<|29.92|><|endoftext|>',
17.50|> Tapi prosedur macam tu.<|18.46|><|18.56|> Prosedur macam tu.<|19.44|><|19.74|> Seorang, seorang, seorang tanya.<|21.22|><|21.38|> Yes.<|21.70|><|22.94|> Kalau nak offer air,<|24.88|><|25.34|> what would you like to drink?<|26.08|><|26.14|> Tak boleh.<|26.40|><|27.18|> Excuse me sir,<|27.88|><|27.92|> what would you like to have for beverage?<|29.16|><|endoftext|>',
#   'audio_filename': 'output-audio/2-0-3.mp3'},
#  {'new_text': '<|startoftranscript|><|ms|><|transcribe|><|0.00|> guna perkataan drink.<|0.86|><|1.58|> We do have hot beverage, cold beverage<|4.40|><|4.40|> and alcoholic beverages.<|6.68|><|7.06|> Sebut satu-satu apa yang kita ada.<|8.66|><|9.38|> For example, cold beverage, kita ada<|11.08|><|11.08|> apple juice, orange juice.<|12.22|><|12.80|> Hot, kita ada bla bla bla.<|14.26|><|14.86|> Ni, kita ada spirit, wine.<|18.00|><|18.66|> Satu-satu.<|19.14|><|19.32|> Kalau short flight, macam mana?<|20.36|><|20.90|> Kalau short flight, tak ada servis tu.<|22.18|><|22.34|> Kita ada snack servis sahaja.<|23.54|><|24.62|> I see.<|24.94|><|26.94|> Meal service, yang paling short berapa jam?<|29.42|><|endoftext|>',
#   'audio_filename': 'output-audio/2-0-4.mp3'},
#  {'new_text': '<|startoftranscript|><|ms|><|transcribe|><|0.00|> Sejam suku<|1.88|><|1.88|> Sejam suku<|4.10|><|4.10|> Sejam suku<|4.38|><|4.38|> Sejam setengah lah<|5.34|><|5.34|> Satu zone tu<|6.42|><|6.42|> Berapa ramai<|7.40|><|7.40|> Satu zone eh<|9.36|><|9.36|> Agak-agak je<|10.32|><|10.32|> Dalam satu ada<|11.14|><|11.14|> You kena attend semua<|12.48|><|12.48|> I attend 40<|13.42|><|13.42|> 40 je lah<|14.18|><|14.18|> Satu card<|14.86|><|14.86|> Maximum attend 40<|16.40|><|16.40|> Kita boleh kitar 40 je kan<|18.10|><|18.10|> So you serve 40 je lah<|19.44|><|19.44|> Mana-mana flight pun<|20.52|><|20.52|> Tak kira aircraft apa pun<|22.68|><|22.68|> Ikut juga berapa service ada<|24.46|><|24.46|> Kalau<|24.84|><|24.84|> Long flight to Malaysia<|27.52|><|27.52|> Kita ada breakfast<|28.46|><|endoftext|>',
#   'audio_filename': 'output-audio/2-0-5.mp3'}]

# %%
tokenizer = AutoTokenizer.from_pretrained('openai/whisper-medium')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
results = mp.multiprocessing(files, loop, cores = 100)
# Out:
# 100%|██████████| 529/529 [3:31:04<00:00, 23.94s/it]
# 100%|██████████| 8/8 [03:41<00:00, 27.72s/it]7s/it]
# 100%|██████████| 529/529 [3:38:28<00:00, 24.78s/it]
# 100%|██████████| 529/529 [3:39:07<00:00, 24.85s/it]
# 100%|██████████| 529/529 [3:39:38<00:00, 24.91s/it]
# 100%|██████████| 529/529 [3:39:56<00:00, 24.95s/it]

# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
with open('prepared-pseudolabel.jsonl', 'w') as fopen:
    for r in tqdm(results):
        fopen.write(f'{json.dumps(r)}\n')
# Out:
# 100%|██████████| 3085595/3085595 [00:23<00:00, 133722.14it/s]

# %%
# !ls -lh prepared-pseudolabel.jsonl
# Out:
# -rw-r--r-- 1 ubuntu ubuntu 1.9G Apr 26 05:55 prepared-pseudolabel.jsonl
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
from huggingface_hub import HfApi
api = HfApi()

# %%
api.upload_file(
    path_or_fileobj='prepared-pseudolabel.jsonl',
    path_in_repo='prepared-pseudolabel.jsonl',
    repo_id='mesolitica/pseudolabel-malaysian-youtube-whisper-large-v3-timestamp',
    repo_type='dataset',
)
# Out:
# 'https://huggingface.co/datasets/mesolitica/pseudolabel-malaysian-youtube-whisper-large-v3-timestamp/blob/main/prepared-pseudolabel.jsonl'

# %%
tokenizer = AutoTokenizer.from_pretrained('openai/whisper-medium')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
tokenizer.tokenize(results[-4]['new_text'])
# Out:
# ['<|startoftranscript|>',
#  '<|en|>',
#  '<|transcribe|>',
#  '<|0.02|>',
#  'Ġline',
#  '.',
#  'ĠAlright',
#  '.',
#  'ĠOkay',
#  '.',
#  'ĠDal',
#  'am',
#  'Ġg',
#  'aji',
#  'Ġyang',
#  'Ġbegitu',
#  'Ġting',
#  'gi',
#  'Ġada',
#  'Ġjuga',
#  'Ġdia',
#  'Ġpunya',
#  'Ġkes',
#  'us',
#  'ahan',
#  'Ġdia',
#  'Ġlah',
#  '<|7.86|>',
#  '<|7.86|>',
#  'Ġkan',
#  '.',
#  'ĠSo',
#  'ĠSher',
#  'ry',
#  'ĠI',
#  'brahim',
#  'Ġlah',
#  'Ġcer',
#  'ita',
#  'Ġkat',
#  'Ġsaya',
#  'Ġdia',
#  'Ġpun',
#  'Ġex',
#  'ĠQatar',
#  '.',
#  'ĠDia',
#  'Ġk',
#  'ata',
#  'Ġada',
#  'Ġke',
#  'f',
#  'ew',
#  '.',
#  'ĠBet',
#  'ul',
#  '<|14.32|>',
#  '<|14.32|>',
#  'Ġtak',
#  '?',
#  'ĠKe',
#  'f',
#  'ew',
#  'Ġmak',
#  'n',
#  'anya',
#  'Ġorang',
#  'Ġk',
#  'ata',
#  'Ġyou',
#  'Ġtak',
#  'Ġboleh',
#  'Ġle',
#  'wat',
#  'Ġbal',
#  'ik',
#  'Ġrumah',
#  '.',
#  'ĠYa',
#  'Ġbet',
#  'ul',
#  '.',
#  'ĠSo',
#  'Ġkalau',
#  'Ġada',
#  '<|19.90|>',
#  '<|19.90|>',
#  'Ġke',
#  'f',
#  'ew',
#  'Ġmacam',
#  'Ġyou',
#  'Ġada',
#  'Ġke',
#  'f',
#  'ew',
#  'Ġjuga',
#  'Ġzaman',
#  '?',
#  'ĠAda',
#  '.',
#  'ĠMas',
#  'ih',
#  'Ġada',
#  '?',
#  'ĠS',
#  'amp',
#  'ai',
#  'Ġsekarang',
#  '.',
#  'ĠSi',
#  'apa',
#  'Ġyang',
#  'Ġjag',
#  'a',
#  '<|24.52|>',
#  '<|endoftext|>']
