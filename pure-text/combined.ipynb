# %%
from glob import glob

files = glob('dumping-*.txt')
files
# Out:
# ['dumping-instagram.txt',
#  'dumping-parliament.txt',
#  'dumping-twitter.txt',
#  'dumping-cleaned-common-crawl.txt',
#  'dumping-academia.txt',
#  'dumping-iium.txt',
#  'dumping-wiki.txt',
#  'dumping-news.txt',
#  'dumping-watpadd.txt',
#  'dumping-pdf.txt',
#  'dumping-common-crawl.txt']

# %%
with open('dumping-pdf.txt') as fopen:
    data = fopen.read().split('\n')

# %%
len(data)
# Out:
# 651957

# %%
from tqdm import tqdm

def combined(data):
    results, result = [], []
    for i in tqdm(data):
        if not len(i) and len(result):
            results.append(result)
            result = []
        else:
            result.append(i)
    if len(result):
        results.append(result)
    return results

# %%
from unidecode import unidecode
import re

alphabets = '([A-Za-z])'
prefixes = (
    '(Mr|St|Mrs|Ms|Dr|Prof|Capt|Cpt|Lt|Mt|Puan|puan|Tuan|tuan|sir|Sir)[.]'
)
suffixes = '(Inc|Ltd|Jr|Sr|Co|Mo)'
starters = '(Mr|Mrs|Ms|Dr|He\s|She\s|It\s|They\s|Their\s|Our\s|We\s|But\s|However\s|That\s|This\s|Wherever|Dia|Mereka|Tetapi|Kita|Itu|Ini|Dan|Kami|Beliau|Seri|Datuk|Dato|Datin|Tuan|Puan)'
acronyms = '([A-Z][.][A-Z][.](?:[A-Z][.])?)'
websites = '[.](com|net|org|io|gov|me|edu|my)'
another_websites = '(www|http|https)[.]'
digits = '([0-9])'
before_digits = '([Nn]o|[Nn]ombor|[Nn]umber|[Kk]e|=)'
month = '([Jj]an(?:uari)?|[Ff]eb(?:ruari)?|[Mm]a(?:c)?|[Aa]pr(?:il)?|Mei|[Jj]u(?:n)?|[Jj]ula(?:i)?|[Aa]ug(?:ust)?|[Ss]ept?(?:ember)?|[Oo]kt(?:ober)?|[Nn]ov(?:ember)?|[Dd]is(?:ember)?)'


def split_into_sentences(text, minimum_length = 5):
    text = text.replace('\x97', '\n')
    text = '. '.join([s for s in text.split('\n') if len(s)])
    text = text + '.'
    text = unidecode(text)
    text = ' ' + text + '  '
    text = text.replace('\n', ' ')
    text = re.sub(prefixes, '\\1<prd>', text)
    text = re.sub(websites, '<prd>\\1', text)
    text = re.sub(another_websites, '\\1<prd>', text)
    text = re.sub('[,][.]+', '<prd>', text)
    if '...' in text:
        text = text.replace('...', '<prd><prd><prd>')
    if 'Ph.D' in text:
        text = text.replace('Ph.D.', 'Ph<prd>D<prd>')
    text = re.sub('[.]\s*[,]', '<prd>,', text)
    text = re.sub(before_digits + '\s*[.]\s*' + digits, '\\1<prd>\\2', text)
    text = re.sub(month + '[.]\s*' + digits, '\\1<prd>\\2', text)
    text = re.sub('\s' + alphabets + '[.][ ]+', ' \\1<prd> ', text)
    text = re.sub(acronyms + ' ' + starters, '\\1<stop> \\2', text)
    text = re.sub(
        alphabets + '[.]' + alphabets + '[.]' + alphabets + '[.]',
        '\\1<prd>\\2<prd>\\3<prd>',
        text,
    )
    text = re.sub(
        alphabets + '[.]' + alphabets + '[.]', '\\1<prd>\\2<prd>', text
    )
    text = re.sub(' ' + suffixes + '[.][ ]+' + starters, ' \\1<stop> \\2', text)
    text = re.sub(' ' + suffixes + '[.]', ' \\1<prd>', text)
    text = re.sub(' ' + alphabets + '[.]', ' \\1<prd>', text)
    text = re.sub(digits + '[.]' + digits, '\\1<prd>\\2', text)
    if '”' in text:
        text = text.replace('.”', '”.')
    if '"' in text:
        text = text.replace('."', '".')
    if '!' in text:
        text = text.replace('!"', '"!')
    if '?' in text:
        text = text.replace('?"', '"?')
    text = text.replace('.', '.<stop>')
    text = text.replace('?', '?<stop>')
    text = text.replace('!', '!<stop>')
    text = text.replace('<prd>', '.')
    sentences = text.split('<stop>')
    sentences = sentences[:-1]
    sentences = [s.strip() for s in sentences if len(s) > minimum_length]
    return sentences

split_into_sentences('733 ke . 633 , berlaku penurunan akibat kesan program PMI .')
# Out:
# ['733 ke.633 , berlaku penurunan akibat kesan program PMI .']

# %%
import re

def strip(string):
    string = ' '.join(string)
    string = re.sub(r'[ ]+', ' ', string.replace('\n', ' ').replace('\t', ' ')).strip()
    return split_into_sentences(string)

# %%
results = combined(data)
len(results)
# Out:
# 100%|██████████| 651957/651957 [00:00<00:00, 1546287.51it/s]
# 55538

# %%
output = []

for r in tqdm(results):
    output.extend(strip(r) + [''])
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 2912.06it/s]

# %%
with open('dumping-pdf.txt', 'w') as fopen:
    fopen.write('\n'.join(output))

# %%
with open('dumping-parliament.txt') as fopen:
    data = fopen.read().split('\n')

# %%
results = combined(data)
len(results)
# Out:
# 100%|██████████| 960869/960869 [00:00<00:00, 1856840.93it/s]
# 70046

# %%
results[:100]
# Out:
# [['JAWAPAN-JAWAPAN BAGI PERTANYAAN-PERTANYAAN JAWAB',
#   'LISAN YANG TIDAK DIJAWAB DI DALAM DEWAN'],
#  ['NOTA : [ RUJUK PENYATA RASMI HARIAN ( HANSARD )]',
#   'NURELFIRA BINTI MOHD DAUD',
#   'CAWANGAN PERUNDANGAN',
#   'PARLIMEN MALAYSIA'],
#  ['NO SOALAN : 8',
#   'PEMBERITAHU PERTANYAAN PEWAN RAKYAT',
#   'PERTANYAAN LISAN',
#   'DARIPADA LAKSAMANA PERTAMA MOHAMAD IMRAN',
#   'BIN ABD HAMID ( B )',
#   'Minta MENTERI PERTAHANAN menyatakan apakah respon dan reaksi',
#   'Kementerian terhadap tuntutan lima ( 5 ) perkara oleh NGO PAHLAWAN .'],
#  ['Tuan Yang di-Pertua ,',
#   'Suka saya memaklumkan bahawa pertubuhan ini tidak berdaftar',
#   'dengan Jabatan Hal Ehwal Veteran ATM ( JHEV ) di bawah Akta Veteran',
#   "menyatakan bahawa ' tiada persatuan boleh menjalankan apa-apa aktiviti",
#   'veteran melainkan jika persatuan itu didaftarkan sebagai suatu persatuan',
#   "veteran di bawah akta ini '.",
#   'Persatuan ini tidak pernah mengemukakan sebarang tuntutan rasmi',
#   'kepada Kementerian Pertahanan . Pihak Kementerian hanya mengetahui',
#   'tuntutan yang dibuat oleh Pertubuhan Prihatin Bekas Anggota',
#   'Keselamatan (PAHLAWAN ) ini , melalui media massa dan media sosial',
#   'Tuan Yang di-Pertua ,',
#   'Sebagai makluman Dewan Yang Mulia ini , tindakan yang telah',
#   'dilaksanakan Kementerian berdasarkan salah satu Teras Kementerian',
#   'Pertahanan iaitu kebajikan anggota dan kesejahteraan veteran ATM .',
#   'Antaranya adalah kenaikan kadar pencen sebanyak 2 % setahun semenjak',
#   'tahun 2013 . Kementerian juga melaksanakan pemanjangan tempoh dari 12',
#   'tahun 6 bulan kepada 20 tahun bagi pembayaran pencen ter dan',
#   'bantuan kepada isteri / waris yang dikahwini selepas bersara dan telah',
#   'berkuatkuasa mulai 1 Januari 2012 .',
#   'secara one-off kepada 84,000 veteran .'],
#  ['Kementerian juga melaksanakan Program Baikpulih Rumah Veteran',
#   'ATM 1 Malaysia semenjak 2012 dan masih berjalan sehingga sekarang .',
#   'Pada tahun 2015 sebanyak 620 buah rumah teiah dibina dan dibaik pulih .',
#   'Tahun ini , pihak Kementerian mensasarkan untuk membina 200 buah',
#   'rumah melibatkan 100 buah baik pulih dan 100 buah bina baharu .',
#   'Selain itu , lima skim di bawah Skim Bantuan Kebajikan dan',
#   'Pendidikan telah disediakan . Tahun 2015 , Kementerian telah',
#   'ribu bagi Bantuan Persekolahan , RM304 ribu bagi Bantuan Peralatan',
#   'Pesakit , RM6.9 juta bagi Bantuan Kemasukan Ke Universiti Awam dan',
#   'RM190 ribu bagi Bantuan Bencana Alam . Bantuan Mengurus Jenazah turut',
#   'disediakan bukan sahaja melibatkan veteran , bahkan turut merangkumi',
#   'pasangan dan anak veteran .',
#   'Selain itu , melalui kemudahan Electronic Medical Automated Supply',
#   "System ' atau e-MASS yang disediakan oleh Kementerian melaui JHEV",
#   'membolehkan Veteran ATM mendapatkan bekalan perubatan dan alatan',
#   'bantuan merangkumi lebih 1,500 jenis ubatan atau alatan perubatan bagi',
#   'penyakit-penyakit kronik yang tidak dapat disediakan di Hospital Kerajaan .',
#   'Mereka hanya perlu mendapatkan pengesahan dari hospital kerajaan tanpa',
#   'perlu membuat apa-apa pembayaran untuk mendapatkan keperluan',
#   'tersebut . Buat masa ini , lebih dari 1,087 Farmasi Komuniti dan vendor telah',
#   'berdaftar di bawah sistem ini di seluruh negara melibatkan peruntukan',
#   'sebanyak RM56 juta .',
#   'Semua ini jelas menunjukkan bahawa kerajaan sentiasa berusaha',
#   'menjaga kebajikan dan kesejahteraan Veteran ATM . Tindakan-tindakan',
#   'berkenaan telah lama dilaksanakan sebelum wujudnya tuntutan oleh pihak'],
#  ['PEMBERITAHUAN PERTANYAAN DEWAN RAKYAT',
#   'PERTANYAAN JAWAB LISAN',
#   'DARIPADA TUAN HAJI AHMAD LAI BIN BUJANG [ SIBUTI ]',
#   'SOALAN 9',
#   'Tuan Haji Ahmad Lai bin Bujang [Sibuti ] minta MENTERI KOMUNIKASI DAN',
#   'MULTIMEDIA menyatakan apakah tindakan Kerajaan bagi menangani masalah judi',
#   'online dalam aplikasi telefon pintar , apakah cara menyekat sebarang mesej melalui',
#   'sms dan whatsapps yang mempromosikan judi online tersebut .',
#   'Tuan Yang di-Pertua ,',
#   'Untuk makluman Ahii Yang Berhormat , kegiatan judi dalam talian adalah tidak',
#   'dibenarkan sama sekali di Malaysia dan tiada lesen ataupun permit yang pernah',
#   'dikeluarkan di bawah mana-mana Akta . Poiis Diraja Malaysia ( PDRM ) dalam',
#   'kebanyakan kes perjudian tanpa lesen (haram ), mengambil tindakan',
#   'Penguatkuasaan mengikut peruntukan di bawah Akta Rumah Perjudian Terbuka',
#   'Komunikasi dan Multimedia Malaysia (SKMM ) dan PDRM dijalin dalam',
#   'membanteras kegiatan judi dalam talian yang meliputi aspek-aspek kerjasama',
#   'pemantauan , pengesanan dan perkongsian maklumat serta aspek forensik digital .',
#   'Bagi kegiatan promosi perjudian dalam talian melalui SMS dan aplikasi telefon',
#   'aduan awam bagi tempoh Januari hingga April tahun 2016 ini . Pihak SKMM telah',
#   'mengumpul maklumat yang diterima daripada aduan awam tersebut , mengenal'],
#  ['pasti nombor-nombor telefon yang berkaitan untuk sekatan dan turut',
#   'memanjangkan maklumat-maklumat yang berkaitan untuk siasatan lanjut pihak'],
#  ['Selain daripada aduan awam , Kementerian melalui SKMM juga turut mengambil',
#   'langkah proaktif dengan mengarahkan syarikat-syarikat telekomunikasi untuk',
#   'mengesan dan menamatkan nombor-nombor yang didapati menyebarkan SMS',
#   'berunsur perjudian . Sehingga kini , sebanyak 12,449 nombor telah ditamatkan',
#   'perkhidmatannya sejak bulan Januari hingga April tahun 2016 . Selain itu , syarikat',
#   'telekomunikasi juga turut memberikan kerjasama dengan menyediakan sistem',
#   'tapisan bagi membendung penghantaran SMS yang mempromosikan aktiviti',
#   'perjudian dalam talian .',
#   'Bagi memudahkan pengguna untuk melaporkan isu-isu berkaitan kegiatan promosi',
#   'perjudian dalam talian melalui SMS , pihak SKMM juga telah menyediakan',
#   'perkhidmatan aduan secara terus oleh pengguna melalui nombor telefon khusus',
#   '(016-2206262 ). Pengguna boleh memajukan SMS promosi perjudian dalam talian',
#   'yang diterima secara terus ke nombor telefon tersebut tanpa perlu lagi hadir ke',
#   'SKMM , atau tanpa perlu melaporkannya melalui e-mel .',
#   'Untuk makluman Ahii Yang Berhormat juga , Kementerian ini dan SKMM adalah',
#   'turut terlibat dalam Jawatankuasa Kerja Pindaan Akta Aktiviti Gaming sedia ada di',
#   'bawah kawalan Kementerian Kewangan . Input KKMM dan SKMM telah diberi',
#   '[ Akta 289 ]. Dalam konteks ini , Ahii Yang Berhormat juga sedia maklum bahawa',
#   'YAB Menteri Dalam Negeri semasa menggulung Titah Ucapan SPB YDA pada 21',
#   'Mac 2016 di Dewan Rakyat telah menyentuh tentang isu perjudian dalam talian ini',
#   'dan peranan setiap Kementerian / Agensi dengan panjang lebar serta persetujuan',
#   'beliau supaya dibentuk satu kokus Parlimen bagi menanganinya .'],
#  ['PERTANYAAN DEWAN RAKYAT',
#   'PERTANYAAN LISAN',
#   'YB . TUAN WONG LING BIU',
#   'YB . TUAN WONG LING BIU minta MENTERI KERJA RAYA',
#   'menyatakan apabila membina Lebuh Raya Pan Borneo , adakah',
#   'tempat-tempat kerap berlaku kemalangan akan dibina terlebih dahulu',
#   'seperti jalan raya dari Bukit Sebangkoi ke Pekan Jakar di Sarikei .',
#   'Kalau ada , bila pembinaan akan dimulakan .'],
#  ['Tuan Yang Di-Pertua ;',
#   'Untuk makluman Ahii Yang Berhormat , pelaksanaan projek Lebuh',
#   'Raya Pan Borneo Sarawak telah dipecahkan kepada 11 pakej utama .',
#   'Pakej-pakej yang terlibat itu akan ditender dan dilaksanakan secara',
#   'berperingkat-peringkat bermula dari tahun lalu ( 2015 ). Manakala',
#   'pakej yang terakhir dirancang untuk dimulakan pada bulan November',
#   'Penetapan tempoh pelaksanaan setiap fasa dibuat berasaskan',
#   'kepada faktor-faktor seperti tempoh masa yang diperlukan untuk',
#   'mereka bentuk pakej terlibat ; kadar aliran trafik semasa dan juga',
#   'faktor keselamatan serta keadaan geometri jalan . Bagi laluan dari',
#   'Bukit Sebangkoi ke Pekan Jakar - untuk makluman Ahii Yang',
#   'Berhormat - ia merupakan sebahagian atau termasuk dalam',
#   'cadangan pelaksanaan skop Pakej 6 , Lebuh Raya Pan Borneo',
#   'Sarawak . Pelaksanaan untuk sub-pakej tersebut - iaitu Bukit',
#   'Sebangkoi dari Sg . Awik ke Sg . Paoh sepanjang 37.3km - dirancang',
#   'akan dimulakan pada bulan September 2016 ini .',
#   'Sekian . Terima kasih .'],
#  ['PEMBERITAHUAN PERTANYAAN PEWAN RAKYAT',
#   'PERTANYAAN : LISAN',
#   "DARIPADA : DATO ' AHMAD FAUZI BIN ZAHARI [ SETIAWANGSA ]",
#   'SOALAN •',
#   "Dato ' Ahmad Fauzi bin Zahari [ Setiawangsa ] minta PERDANA MENTERI",
#   'menyatakan berapakah jumlah terkini pelarian pemegang kad UNHCR yang berada di',
#   'Malaysia dan daripada negara manakah pelarian yang tertinggi direkodkan .'],
#  ["JAWAPAN : YB . DATO ' SERI DR . SHAHIDAN BIN KASSIM",
#   'MENTERI DI JABATAN PERDANA MENTERI',
#   'Tuan Yang di-Pertua ,',
#   "'pelarian ' dan pemohpn suaka di Semenanjung Malaysia dari 60 buah buah negara .",
#   "Daripada jumlah tersebut , 'pelarian ' dan pemohon suaka dari negara Myanmar",
#   'mencatatkan jumlah tertinggi iaitu seramai 139,776 atau lebih 90 % daripada jumlah',
#   "keseluruhan 'pelarian ' dan pemohon suaka di Malaysia .",
#   'Sekian . Terima kasih .'],
#  ['PEMBERITAHUAN PERTANYAAN PEWAN RAKYAT', 'PERTANYAAN LISAN', 'DARIPADA %'],
#  ["DATO ' ABDUL MANAN BIN ISMAIL", '[ PAYA BESAR ]'],
#  ["Dato ' Abdul Manan bin Ismail [ Paya Besar ] minta PERDANA MENTERI",
#   'menyatakan statistik pelarian dan pencari suaka politik di bawah Suruhanjaya Tinggi',
#   'Pertubuhan Bangsa-bangsa Bersatu Bagi Pelarian (UNHCR ) Malaysia di antara tahun'],
#  ["JAWAPAN : YB . DATO ' SERI DR . SHAHIDAN BIN KASSIM",
#   'MENTERI DI JABATAN PERDANA MENTERI',
#   'Tuan Yang di-Pertua ,',
#   'Statistik pelarian dan pencari suaka politik di bawah Suruhanjaya Tinggi Pertubuhan',
#   'Bangsa-bangsa Bersatu Bagi Pelarian (UNHCR ) Malaysia di antara tahun 2010 hingga'],
#  ['Sekian . Terima kasih .'],
#  ['PEMBERITAHUAN PERTANYAAN BAGI JAWAPAN LISAN',
#   'MESYUARAT KEDUA . DEWAN RAKYAT',
#   'PENGGAL KEEMPAT . PARLIMEN KETIGA BELAS',
#   'MAJLIS MESYUARAT DEWAN RAYAT',
#   'PERTANYAAN . : LISAN',
#   'DARIPADA : YB RAMKARPAL SINGH A / L KARPAL'],
#  ['YB Ramkarpal Singh a / l Karpal Singh [ Bukit Gelugor ] minta MENTERI',
#   'PEMBANGUNAN WANITA , KELUARGA DAN MASYARAKAT',
#   'menyatakan selain daripada undang-undang berkenaan keselamatan',
#   'kanak-kanak yang sedia ada , apakah tindakan Kerajaan dalam'],
#  ['memastikan semua pihak yang berkenaan , sebagai contoh pihak polis',
#   'sehingga ke tahap hakim , menguatkuasakan (enforce ) perundangan',
#   'tersebut secara tegas .'],
#  ["JAW APAN : YB DATO ' SRI ROHANI ABDUL KAR1M . MENTERI",
#   'PEMBANGUNAN WANITA . KELUARGA DAN',
#   'Tuan Yang di-Pertua',
#   'Kementerian Pembangunan Wanita , Keluarga dan Masyarakat (KPWKM )',
#   'sebagai kementerian yang bertanggungjawab dalam melindungi kanak -',
#   'kanak serta memastikan kebajikan kanak-kanak di Malaysia , teiah',
#   'mengorak satu langkah dalam menambah baik undang-undang sedia ada',
#   'berkaitan perlindungan dan pemeliharaan kanak-kanak . Ini termasuklah',
#   'pengukuhan pelaksanaan undang-undang tersebut di peringkat daerah dan',
#   'negeri dengan melibatkan tindakan pelbagai agensi seperti Polis Diraja',
#   'Malaysia dan Kementerian Kesihatan , orang awam dan Pegawai Kebajikan',
#   'Masyarakat sendiri .',
#   'Antara tindakan pengukuhan Penguatkuasaan perundangan tersebut',
#   'adalah seperti berikut :'],
#  ['Majlis Kebangsaan bagi Kanak-Kanak',
#   'Majlis Kebangsaan bagi Kanak-Kanak ditubuhkan dan distruktur',
#   'semula daripada Majlis Penyelaras bagi Pelindungan Kanak-kanak .',
#   'Ketetapan fungsi dan kuasa Majlis ini antara lain , untuk menasihati',
#   'dan membuat syor kepada Kerajaan mengenai semua isu dan aspek',
#   'yang berhubungan dengan pemeliharaan , perlindungan , pemulihan ,',
#   'perkembangan dan penyertaan kanak-kanak di peringkat',
#   'kebangsaan serantau dan antarabangsa , membolehkan RUUKK',
#   'dapat dikuatkuasakan dengan lebih efektif oleh kerana',
#   'keanggotaannya daripada pelbagai kementerian . aaensi dan individu',
#   '( contohnya polis , Jabatan Peguam Negara dan Jabatan Penjara )',
#   'yang mempunyai pengalaman , pengetahuan dan kepakaran dalam',
#   'bidang kanak-kanak serta wakil kanak-kanak .',
#   'Pasukan Pelindungan Kanak-Kanak',
#   'Di bawah penubuhan Majlis Kebangsaan Bagi Kanak-Kanak , Rang',
#   'Undang-Undang Kanak-Kanak ( Pindaan ) 2015 (RUUKK ) telah',
#   'menambah baik mekanisma Penguatkuasaan Akta Kanak-Kanak'],
#  ['kanak . Pasukan ini dianggotai pelbagai disiplin seperti individu yang',
#   'mempunyai pengalaman , pengetahuan dan kepakaran yang sesuai',
#   'dalam perkara yang berhubungan dengan pemeliharaan dan',
#   'pelindungan kanak-kanak , seorang pegawai perubatan dan seorang',
#   'pegawai polis .',
#   'Penstrukturan semula ini adalah untuk memastikan penyelarasan',
#   'perkhidmatan yang berkesan yang diberikan kepada keluarga dan',
#   'kanak-kanak memerlukan atau disyaki memerlukan pemeliharaan',
#   'dan pelindungan , antaranya kanak-kanak yang dicederakan daripada',
#   'segi fizikal , dianiayai , diabaikan dan dibuang . Dengan pindaan ini',
#   'juga , Pelindung ditugaskan untuk menyelia Pasukan Pelindungan',
#   '• Pasukan Kebajikan Kanak-Kanak .',
#   'Penubuhan Pasukan Kebajikan Kanak-kanak dengan keanggotaan',
#   'seperti individu yang mempunyai pengalaman , pengetahuan dan',
#   'kepakaran yang sesuai dalam perkara yang berhubungan dengan'],
#  ['pelindungan dan pemulihan kanak-kanak , seorang Pegawai',
#   'Pendidikan dan seorang pegawai polis .',
#   'Pasukan ini yang dahulunya dikenali sebagai Jawatankuasa',
#   'Kebajikan Kanak-kanak berfungsi untuk menyelaraskan',
#   'perkhidmatan setempat kepada keluarga dan kanak-kanak jika',
#   'kanak-kanak memerlukan atau disyaki memerlukan pelindungan dan',
#   'pemulihan , antaranya yang terlibat dengan bahaya moral atau jika',
#   'kanak-kanak itu didapati bersalah atas apa-apa kesalahan . Pegawai',
#   'akhlak atau Pelindung ditugaskan untuk menyelia Pasukan Kebajikan',
#   'Struktur keanggotaan kedua-dua pasukan ini membolehkan RUUKK',
#   'dikuatkuasakan dengan lebih berkesan di setiap daerah dan negeri',
#   'memandangkan ianya daripada pelbagai disiplin dan sektor yang',
#   'berkait rapat dengan keperluan dan perkembangan seseorang',
#   '• Penggubalan peraturan , kaedah , garis panduan dan standard',
#   'operating procedure (SOP ) di bawah RUUKK'],
#  ['KPWKM sedang dalam peringkat pemurnian peraturan-peraturan ,',
#   'garis panduan dan standard operating procedure (SOP ) yang sedia',
#   'ada dan penggubalan baharu bagi memastikan peruntukan -',
#   'peruntukan di bawah RUUKK dapat dilaksanakan oleh agensi',
#   'berkaitan seperti poiis dan kehakiman dengan lebih holistik dan',
#   'berkesan di peringkat akar umbi .',
#   '• Pembangunan kapasiti pegawai kehakiman , perundangan dan',
#   'pihak berkuasa .',
#   'Beberapa latihan pembangunan kapasiti telah dilaksanakan bagi',
#   'memantapkan lagi pemahaman pegawai kehakiman , perundangan',
#   'dan pihak berkuasa seperti polis ke atas perundangan dan hak asasi',
#   'berkaitan kanak-kanak seperti berikut :',
#   '1 . Bengkel pematuhan instrumen hak asasi manusia dianjurkan',
#   'oleh Jabatan Peguam Negara (AGC ) kepada pegawai-pegawai',
#   'AGC , badan kehakiman , pertubuhan-pertubuhan bukan',
#   'kerajaan ( NGO ) dan termasuklah KPWKM .'],
#  ['2 . Latihan Kehakiman dan Perundangan di Institut Latihan',
#   'Kehakiman dan Perundangan (ILKAP ) kepada para pegawai',
#   'kehakiman dan perundangan , Jabatan Penjara , Kementerian',
#   'Luar Negeri , polis dan agensi lain yang berkaitan .',
#   '3 . Seminar mengenai Akta Kanak-Kanak 2001 bagi memberikan',
#   'pemahaman yang lebih terhadap Akta tersebut dari aspek',
#   'fungsi dan peranan agensi tertentu seperti polis dan penjara ,',
#   'prosedur dan Penguatkuasaan prosedur .',
#   '4 . Seminar mengenai perundangan dan hak kanak-kanak dan',
#   'wanita kepada pegawai-pegawai polis di Maktab PDRM .'],
#  ['MESYUARAT KEDUA , PENGGAL KEEMPAT ,',
#   'PARLIMEN KETIGA BELAS',
#   'PEMBERITAHUAN PERTANYAAN',
#   'DEWAN RAKYAT MALAYSIA',
#   'PERTANYAAN ■■ JAWAB LISAN',
#   'DARIPADA ■■ DATUK JUSLIE BIN AJIROL',
#   'SOALAN ■■ 13',
#   'Minta MENTERI KEMAJUAN LUAR BANDAR DAN WILAYAH menyatakan',
#   'apakah keutamaan baru yang digariskan oleh Jawatankuasa Induk',
#   'Transformasi Luar Bandar terutama memba soal Program Bantuan',
#   'Rumah (PBR ), bekalan air dan elektrik serta mewujudkan jalan perhubungan',
#   'ke setiap kampung .'],
#  ['Tuan Yang di-Pertua ,',
#   'Selari dengan aspirasi nasional untuk meningkatkan kuaiiti dan',
#   'kesejahteraan rakyat di Iuar bandar , KKLW di bawah agenda Transformasi',
#   'Luar Bandar memberi penekanan memperhebatkan penyediaan kemudahan',
#   'infrastruktur asas Iuar bandar dan meningkatkan aksesibiliti dengan',
#   'keutamaan kepada kawasan-kawasan yang masih kurang liputan',
#   'terutamanya di Sabah dan Sarawak serta kawasan pedalaman di',
#   'Semenanjung termasuk kawasan Orang Asli .',
#   'Bagi tempoh Rolling Plan Pertama RMKe-11 tahun 2016 , disasarkan :-',
#   '( i ) Pembinaan jalan sepanjang 601.5 km meliputi Jalan Luar Bandar',
#   '(JALB ) sepanjang 370 km dan Jalan Perhubungan Desa (JPD )',
#   'sepanjang 231.5 km . Peruntukan yang diluluskan bagi melaksanakan',
#   'projek-projek ini pada tahun 2016 adalah berjumlah RM1.21 bilion ;',
#   '(ii ) Bekalan Air Luar Bandar (BALB ) meliputi 3 , 000 buah rumah dengan',
#   'peruntukan diluluskan bagi tahun 2016 berjumlah RM341.9 juta ;',
#   '(iii ) Bekalan Elektrik Luar Bandar (BELB ) meliputi 9 , 875 buah rumah',
#   'dengan peruntukan diluluskan bagi tahun 2016 berjumlah RM863.0',
#   'juta ; dan',
#   '( iv ) Program Bantuan Rumah (PBR ) meliputi bina baru dan baikpulih',
#   'berjumlah RM274.8 ju ta .'],
#  ['Bagi melaksanakan maksud ini , beberapa pelan tindakan dilaksanakan',
#   'seperti berikut : -',
#   '( i ) Mewujudkan " task force " bagi mengenal pasti kampung-kampung',
#   'kurang keperluan asas ;',
#   '(ii ) Menyediakan pangkalan data ( w ar room ) bagi mengenalpasti',
#   'keperluan infrastruktur asas di Iuar bandar ; dan',
#   '(iii ) Menyediakan jalan perhubungan kepada kampung-kampung yang',
#   'tiada jalan perhubungan .',
#   'Selain itu , bagi membantu mengurangkan beban rakyat khususnya golongan',
#   'belia Iuar bandar untuk memiliki rumah kediaman sendiri , KKLW akan',
#   'melaksanakan projek perumahan mampu milik Generasi Kedua di bawah',
#   'program Rumah Bina Negara yang mana harga rumah yang ditawarkan',
#   'antara RM42 ribu ke RM80 ribu dengan keluasan lantai antara 700 kaki',
#   'persegi ke 1,000 kaki persegi dengan tiga ( 3 ) bilik tidur , dua ( 2 ) bilik air dan',
#   'dilengkapi kemudahan infrastruktur asas perumahan yang lain . Sebanyak',
#   '4,000 unit Rumah Bina Negara disasarkan dibina dalam tempoh RMKe-11 .',
#   'Pelaksanaan kerja-kerja pembangunan perumahan projek Rumah Bina',
#   'Negara ini telahpun bermula pelaksanaannya pada tahun ini melibatkan',
#   '1,381 unit rumah yang mana 263 unit rumah telahpun dimulakan kerja -',
#   'kerja pembinaan , 288 unit telah memperolehi kebenaran merancang dan',
#   'baki 830 unit rumah dalam proses untuk mendapatkan kelulusan kebenaran',
#   'Adalah diharap melalui pelaksanaan keutamaan baru Transformasi Luar',
#   'Bandar ini akan membantu meningkatkan kuaiiti hidup dan kesejahteraan',
#   'rakyat ke arah Malaysia negara maju menjelang tahun 2020 .'],
#  ['PEMBERITAHUAN PERTANYAAN DEWAN RAKYAT',
#   'PERTANYAAN : LISAN',
#   'DARIPADA YANG BERHORMAT TUAN IGNATIUS DORELL',
#   'LEIKING [ PENAMPANG ]',
#   'YB Tuan Ignatius Dorell Leiking [ Penampang ] minta PERDANA',
#   'MENTERI menyatakan jumlah terperinci yang diperuntukkan untuk',
#   'pembangunan , peruntukan sosial dan segala bantuan yang diberi oleh',
#   'Kerajaan Pusat kepada Daerah Penampang antara Januari 2008 hingga ke',
#   'Disember 2015 .'],
#  ["JAWAPAN : YB DATO ' SRI AZALINA BINTI OTHMAN SAID .",
#   'MENTERI DI JABATAN PERDANA MENTERI .',
#   'Tuan Yang di-Pertua ,',
#   'Berdasarkan maklumat Sistem Pemantauan Projek (SPPII ) sehingga 16',
#   'Mei 2016 , Peruntukan Pembangunan di bawah Rancangan Malaysia',
#   'Kesembilan ( RMKe-9 ) dan RMKe-10bagi Parlimen Penampang , Sabah',
#   'yang diberikan oleh Kerajaan Persekutuan mengikut pecahan tahun adalah',
#   'seperti berikut :',
#   'TAHUN PERUNTUKANRM(JUTA ) BIL . PROJEK'],
#  ['Sekian , terima kasih .'],
#  ['PEMBERITAHU PERTANYAAN DEWAN RAKYAT',
#   'PERTANYAAN LISAN',
#   'DARIPADA Y.B . PUAN RUBIAH BINTI HAJI WANG',
#   '[ KOTA SAMARAHAN ]',
#   'Puan Rubiah binti Haji Wang [ Kota Samarahan ] minta MENTERI PENDIDIKAN',
#   'menyatakan adakah Kementerian bercadang untuk membina sekolah khas atau',
#   'khusus bagi pelajar yang menduduki STPM di setiap kawasan Parlimen kerana ini',
#   'dapat membuatkan mereka bersedia sebelum masuk ke alam universiti yang',
#   'sebenar justeru meningkatkan kredibiliti mereka .',
#   'Tuan Yang di-Pertua ,',
#   'Kementerian Pendidikan Malaysia ( KPM ) telah melaksanakan Penjenamaan semula',
#   'Tingkatan Enam melalui inisiatif pemantapan pendidikan Tingkatan Enam di bawah',
#   'Pelan Pembangunan Pendidikan ( PPPM ) 2013-2025 . Langkah ini bertujuan',
#   'memantapkan imej , kuaiiti dan sistem pendidikan Tingkatan Enam sedia ada .',
#   'Melalui inisiatif tersebut , Pelan Pemusatan Tingkatan Enam 2016 - 2020 telah',
#   'disediakan dengan mensasarkan sebanyak 44 buah Kolej Tingkatan Enam yang',
#   'akan beroperasi di seluruh negara menjelang tahun 2020 .',
#   'Untuk makluman Ahii Yang Berhormat , Pelan Pemusatan Tingkatan Enam 2016 -',
#   'institusi pendidikan khusus yang dijenamakan sebagai Kolej Tingkatan Enam .',
#   'Sehingga Mei 2016 , sebanyak sepuluh ( 10 ) buah Kolej Tingkatan Enam telah',
#   'beroperasi di lapan buah negeri .',
#   'Mod 2 puia merujuk kepada pemusatan sekolah yang mempunyai kelas Tingkatan',
#   'Enam di sekolah menengah aliran perdana dengan menempatkan murid Tingkatan'],
#  ['Enam di blok berasingan . Manakala bagi Mod 3 , kelas Tingkatan Enam berkongsi',
#   'bangunan dengan kelas pendidikan menengah aliran perdana di sesebuah sekolah .',
#   'Pelaksanaan ketiga-tiga mod tersebut adalah untuk membolehkan lebih ramai murid',
#   'untuk mengikuti dan menamatkan sistem pendidikan menengah sehingga ke',
#   'Tingkatan Enam . Namun begitu , pembinaan Kolej Tingkatan Enam adalah tertakluk',
#   'kepada kemampuan kewangan negara kerana kebanyakan perancangan tersebut',
#   'melibatkan pembinaan institusi baharu yang melibatkan implikasi kewangan yang',
#   'besar . Sehubungan itu , buat masa ini KPM memberi tumpuan pemusatan Tingkatan',
#   'Enam berdasarkan Mod 2 dan Mod 3 .'],
#  ['JAWAPAN PERTANYAAN LISAN DEWAN RAKYAT',
#   'JAWAPAN OLEH YB DATUK SERI DR . S . SUBRAMANIAM',
#   'MENTERI KESIHATAN MALAYSIA'],
#  ['YB DR . HAJI IZANI BIN HAJI HUSIN',
#   '[ PENGKALAN CHEPA ]',
#   'YB Dr . Haji Izani bin Haji Husin [ Pengkaian Chepa ] minta MENTERI',
#   'KESIHATAN menyatakan apakah langkah kerajaan bagi menangani',
#   'peningkatan kes penyakit cegahan vaksin iaitu batuk kokol , demam',
#   'campak dan difteria yang dikatakan berpunca daripada kesan kempen',
#   'gerakan anti-vaksin .',
#   'Tuan Yang Di Pertua ,',
#   'Kementerian Kesihatan Malaysia ( KKM ) memandang serius kesan yang',
#   'diakibatkan oleh golongan vaksin kepada kesan baik Program Imunisasi',
#   'yang telah kita nikmati sekarang . KKM telah menjalankan pelbagai',
#   'aktiviti bagi dakyah ini . Antaranya :',
#   'i . Penjaga atau individu yang telah dikenalpasti akan diberikan',
#   'kaunseling individu atau berkumpulan ;'],
#  ['ii . Menyediakan informasi berkaitan vaksin dan imunisasi dalam',
#   'pelbagai medium ( bercetak dan elektronik );',
#   'iii . Melantik advokator imunisasi di peringkat klinik bagi meningkatkan',
#   'penerimaan program ini termasuk menggunakan khidmat Panel',
#   'Penasihat Klinik ;',
#   'iv . Mengingkatkan pengetahuan dan memberi latihan kepada',
#   'kakitangan kesihatan khususnya yang terlibat dalam Program',
#   'Imunisasi supaya mereka boleh menjawap persoalan orang ramai',
#   'dengan lebih tepat dan meyakinkan ;',
#   'v . Bekerjasama dengan badan professional lain seperti Malaysian',
#   'Paediatric Association (MPA ) dan Malaysian Society of Infectious',
#   'Disease Chemotherapy mempromosi imunisasi dengan',
#   'mewujudkan laman sesawang',
#   'vi . Mengadakan sambutan Minggu Imunisasi pada setiap minggu',
#   'keempat bulan April ;',
#   'vii . Meningkatkan kerjasama lain-lain agensi terutama semasa pra -',
#   'pendaftaran ke pusat asuhan , pra-sekolah , taska , tadika dan',
#   'sekolah ; dan',
#   'viii . Memperkukuh sistem survelan bagi memantau masalah dan',
#   'impak terhadap masyarakat dan negara .',
#   'KKM telah memperuntukkan sebanyak dua ( 2 ) juta ringgit pada tahun',
#   'sama terus memperkukuhkan sistem penyampaian kesihatan dan',
#   'memperkasakan masyarakat untuk sama-sama bertindak menangani',
#   'isu-isu berkaitan vaksin dan imunisasi .'],
#  ['Tuan Yang Dipertua ,',
#   'Pada masa ini KKM tidak berhasrat untuk mengubal sebarang undang -',
#   'undang mewajibkan imunisasi . Pemerkasaan umat dijangka akan lebih',
#   'memberi kesan baik untuk jangka panjang . Fokus Kementerian akan',
#   'diberikan kepada kumpulan-kumpulan ibubapa muda yang belum atau',
#   'sedang membuat keputusan mengenai imunisasi termasuk mereka',
#   'yang berada di pusat-pusat pengajian tinggi . Manakala Penguatkuasaan',
#   'undang-undang ke atas ibubapa yang menolak imunisasi ini akan',
#   'memberi kesan sosial yang besar seperti anak terpisah daripada',
#   'ibubapa yang dipenjarakan .',
#   'Saya menyeru Yang Berhormat - Yang Berhormat membantu',
#   'menyedarkan masyarakat agar membuat pilihan yang bijak dalam',
#   'penjagaan kesihatan mereka dan anak-anak di bawah tanggungjawab',
#   'mereka , serta sentiasa mendapatkan maklumat perubatan dan',
#   'kesihatan dari sumber-sumber yang sahih .'],
#  ['PEMBERITAHUAN PERTANYAAN DEWAN RAKYAT',
#   'JAWAPAN OLEH YB DATUK SERI DR . S . SUBRAMANIAM',
#   'MENTERI KESIHATAN MALAYSIA'],
#  ['YB DATUK ABD RAHIM BIN BAKRI [ KUDAT ]',
#   'YB Datuk Abd Rahim bin Bakri [ Kudat ] minta MENTERI',
#   'KESIHATAN menyatakan apakah Kementerian berhasrat membuat',
#   'rancangan pembangunan dan perluasan perkhidmatan perubatan pakar',
#   'di Negeri Sabah .',
#   'Tuan Yang di-Pertua ,',
#   'Sehingga 31 Mac 2016 , terdapat 2,560 jawatan Pegawai Perubatan di',
#   'negeri Sabah dengan jumlah pengisian sebanyak 2,554 atau 99.8',
#   'peratus . Daripada jumlah tersebut , seramai 229 orang adalah Pegawai',
#   'orang Pegawai Perubatan Siswazah .',
#   'Dari jumlah 229 orang pegawai perubatan pakar berkenaan , 198 orang',
#   'adalah pakar klinikal yang ditempatkan di lapan ( 8 ) buah hospital',
#   'berpakar di Sabah seperti berikut :'],
#  ['BIL . HOSPITAL JAWATAN ISI KOSONG',
#   '1 . Hospital Queen Elizabeth 102 107 - 5 *',
#   '2 . Hospital Queen Elizabeth II 7 6 1',
#   '3 . Hospital Tawau 15 16 - 1 *',
#   '4 . Hospital Duchess of Kent Sandakan 19 20 - 1 *',
#   '5 . Hospital Wanita & Kanak-kanak Likas 40 36 4',
#   '6 . Hospital Lahad Datu 7 5 2',
#   '7 . Hospital Keningau 5 4 1',
#   '8 . Hospital Mesra Bukit Padang 5 4 1',
#   "' Menunggu perjawatan baru diwujudkan",
#   'Tuan Yang di-Pertua ,',
#   'Kementerian Kesihatan Malaysia ( KKM ) prihatin dan sentiasa',
#   'memantapkan usaha bagi meningkatkan lagi bilangan Pegawai',
#   'Perubatan Pakar untuk memberikan perkhidmatan kepada rakyat',
#   'termasuklah bagi hospital kerajaan di Sabah . Antara usaha yang telah',
#   'diambil adalah seperti berikut :',
#   'i . Pewujudan jawatan baru bagi Pegawai Perubatan Pakar secara',
#   'tukar ganti mengambilkira keperluan perkhidmatan dan fasiliti',
#   'sedia ada serta tidak melibatkan implikasi kewangan tambahan ;',
#   'ii . Peningkatan slot tajaan biasiswa Hadiah Latihan Persekutuan',
#   'untuk program sarjana kepakaran dari 800 slot bagi tahun',
#   'sebelumnya kepada 1000 slot mulai tahun 2015 ;',
#   'iii . Menggalakkan pegawai perubatan untuk mendapatkan kepakaran',
#   'dengan mengikuti program laluan parallel ( tajaan sendiri );',
#   'iv . Melantik semula (renewal , dengan izin ) Pegawai Perubatan Pakar',
#   'yang telah tamat kontrak untuk berkhidmat dengan KKM mengikut'],
#  ['v . Melantik semula secara kontrak Pegawai Perubatan Pakar',
#   'warganegara yang telah bersara wajib untuk berkhidmat dengan',
#   'KKM mengikut keperluan ;',
#   'vi . Mendapatkan perkhidmatan kepakaran dari pihak swasta untuk',
#   'berkhidmat secara sessional ; dan',
#   'vii . Menggalakkan Pegawai Perubatan Pakar warganegara Malaysia',
#   'yang berkhidmat di Iuar Negara untuk pulang ke tanah air .',
#   'Selain itu , bagi meningkatkan perkhidmatan kepakaran di Sabah , pihak',
#   'KKM telah memanjangkan tempoh penempatan Pegawai Perubatan',
#   'Pakar daripada enam ( 6 ) bulan kepada minima satu ( 1 ) tahun .',
#   'KKM juga sedang mengkaji dan di mana bersesuaian akan',
#   'mencadangkan beberapa lagi faedah dalam bentuk elaun dan insentif',
#   'Pegawai Perubatan Pakar yang bertugas di Sabah tertakluk kepada',
#   'persetujuan Agensi Pusat .'],
#  ['PEMBERITAHUAN PERTANYAAN BAGI JAWAPAN LISAN',
#   'MESYUARAT KEDUA . DEWAN RAKYAT',
#   'PENGGAL KEEMPAT . PARLIMEN KETIGA BELAS',
#   'MAJLIS MESYUARAT DEWAN RAKYAT',
#   'PERTANYAAN : JAWAB LISAN',
#   'DARIPADA Puan Hajah Zuraida binti Kamaruddin',
#   '[ Ampang ]',
#   'Puan Hajah Zuraida binti Kamaruddin [ Ampang ] minta MENTERI',
#   'PEMBANGUNAN WANITA , KELUARGA DAN MASYARAKAT',
#   'menyatakan bagaimanakah seseorang kanak-kanak boleh dikenalpasti',
#   'atau dicalonkan sebagai sesorang yang boleh dilantik ke dalam Majlis',
#   'kebangsaan bagi Kanak-Kanak .'],
#  ["JAWAPAN : YB DATO ' SRI ROHANI ABDUL KARIM . MENTERI",
#   'PEMBANGUNAN WANITA . KELUARGA PAN',
#   'Tuan Yang di-Pertua ,',
#   'Kementerian Pembangunan Wanita , Keluarga dan Masyarakat',
#   '(KPWKM ) melalui Jabatan Kebajikan Masyarakat (JKM ) telah menubuhkan',
#   'Majlis Perwakilan Kanak-Kanak (MPKK ) peringkat Kebangsaan dan Negeri',
#   'pada 22 Oktober 2011 . Majlis Perwakilan Kanak-Kanak berfungsi sebagai',
#   'landasan bagi kanak - kanak untuk membincangkan perkara yang',
#   'berkaitan dengan kehidupan , pembangunan , penyertaan dan perlindungan',
#   'kanak-kanak secara menyeluruh .',
#   'Kanak-kanak yang dipilih untuk menganggotai Majlis Kebangsaan',
#   'Bagi Kanak-Kanak adalah terdiri daripada kanak-kanak yang',
#   'menganggotai Majlis Perwakilan Kanak-Kanak di negeri-negeri .',
#   'Keanggotaan mereka di dalam Majlis ini adalah mengikut giliran bagi setiap',
#   'kali mesyuarat diadakan .'],
#  ['Pemilihan juga adalah berdasarkan perwatakan dan kebolehan',
#   'kanak-kanak tersebut dalam menyuarakan pendapat . Buat masa ini ,',
#   'penyertaan kanak-kanak di dalam Majlis Penyelaras Bagi Pelindungan',
#   'Kanak-Kanak adalah terdiri dari kalangan yang berumur anatara 16 hingga'],
#  ['PEMBERITAHU PERTANYAAN DEWAN RAKYAT',
#   'PERTANYAAN LISAN',
#   "DARIPADA Y.B . DATO ' ABD . AZIZ BIN HAJI SHEIKH",
#   'FADZIR [ KULIM BANDAR BAHARU ]',
#   "Dato ' Abd . Aziz bln Haji Sheikh Fadzir [ Kulim Bandar Baharu ] minta MENTERI",
#   'PENDIDIKAN menyatakan apakah status Pelan Pembangunan Pendidikan',
#   'Malaysia ( PPPM ) telah dicapai mengikut perancangan sejak dilaksanakan pada',
#   'tahun 2013 sehingga kini dan adakah sistem yang melibatkan pendidikan akan',
#   'sentiasa berubah apabila berlaku pertukaran Menteri sehingga memberi kesan tidak',
#   'baik kepada proses pembelajaran dan pengajaran .',
#   'Tuan Yang di-Pertua ,',
#   'Gelombang 1 (2013-2015 ) Pelan Pembangunan Pendidikan Malaysia ( PPPM ) telah',
#   'menunjukkan peningkatan dalam semua aspirasi sistem yang sasaran iaitu Kualiti ,',
#   'Akses , Kecekapan , Ekuiti dan Perpaduan .',
#   'Dari segi peningkatan kuaiiti pendidikan , bagi program LINUS 2.0 , daripada',
#   '1,313,752 murid yang melalui proses saringan , sebanyak 98.7 % murid Tahun 3',
#   'berjaya menguasai literasi asas Bahasa Melayu , 99.0 % menguasai numerasi asas',
#   'dan 78.3 % murid Tahun 2 berjaya menguasai literasi asas Bahasa Inggeris . Selaras',
#   'dengan usaha KPM untuk meningkatkan kuaiiti pendidikan setanding dengan sistem',
#   'pendidikan terbaik pada peringkat antarabangsa , maka aplikasi Kemahiran Berfikir',
#   'Aras Tinggi (KBAT ) diterapkan secara menyeluruh di dalam kurikulum , pedagogi',
#   'dan pentaksiran . Untuk itu , seramai 15,768 guru Sains , 16,123 guru Matematik dan',
#   '50,957 guru subjek lain telah melalui latihan pedagogi dan pentaksiran untuk KBAT .',
#   'Pada tahun lepas juga , sebanyak 62 modul intervensi Trends in International',
#   'Mathematics and Science Study (TIMSS ) dan Programme for International S tudent'],
#  ['Assessment (PISA ) dibangunkan sebagai langkah jangka panjang bagi memastikan',
#   'standard kurikulum dan penilaian kebangsaan adalah setara dengan TIMSS dan'],
#  ['guru Bahasa Inggeris telah dilatih semula di bawah Programme for English',
#   'Language Teachers atau ProELT . Program intervensi merangkumi Komponen',
#   'dalam Bilik Darjah dengan bantuan SISC + dan Ketua-Ketua Panitia , manakala bagi',
#   'Komponen Luar Bilik Darjah ataupun ko-kurikulum puia , Kementerian telah',
#   'menjalankan usaha sama dengan pelbagai agensi termasuk Kedutaan Amerika',
#   'Syarikat dan akademi tempatan .',
#   'Dalam usaha untuk memartabatkan profesion keguruan seperti yang dihasratkan di',
#   'bawah Anjakan 4 PPPM , syarat kemasukan guru baharu telah diperketatkan . Pada',
#   'dalam peperiksaan SPM , manakala mereka yang mendaftar untuk program',
#   'Pengajaran Bahasa Inggeris sebagai Bahasa Kedua atau TESL mendapat gred A',
#   'untuk subjek Bahasa Inggeris . Kualiti pemimpin sekolah juga menjadi keutamaan',
#   'kepada Kementerian . Di bawah inisiatif Piagam Pemimpin , lebih 2000 pemimpin',
#   'sekolah telah memperolehi sijil National Professional Qualification for Educational',
#   'Leaders atau NPQEL , dengan 63 % daripada mereka memperolehi CGPA 3.75 ke',
#   'atas . Pelbagai program telah dijalankan bagi memastikan pemimpin pelapis sentiasa',
#   'bersedia untuk meneruskan kepimpinan sedia ada . Maklumat lengkap pencapaian',
#   'Gelombang 1 PPPM akan diter bersekali dengan Laporan Tahunan PPPM',
#   'Segala pencapaian yang tersebut di atas , merupakan hasil usaha gigih serta',
#   'dedikasi pelbagai pihak berkepentingan , khususnya warga KPM dalam menjayakan',
#   'transformasi pendidikan negara . Pastinya usaha ini akan dipertingkatkan lagi kerana',
#   'kita sedang melangkah ke ambang Gelombang Dua , 2016 hingga 2020 .'],
#  ['PEMBERITAHU PERTANYAAN DEWAN RAKYAT',
#   'PERTANYAAN LISAN',
#   'DARIPADA Y.B . TUAN WONG LING BIU [ SARIKEI ]',
#   'Tuan Wong Llng Biu [ Sarikei ] minta MENTERI PENDIDIKAN menyatakan',
#   'sudahkah Kerajaan Sarawak secara rasminya meminta hak autonomi dalam bidang',
#   'pendidikan bagi negeri Sarawak . Adakah ia semestinya memerlukan Kerajaan bagi',
#   'meminda Akta Pendidikan 1996 untuk tujuan tersebut .',
#   'Tuan Yang di-Pertua ,',
#   'Sepertimana Ahli-Ahli Yang Berhormat sedia maklum , negara kita melaksanakan',
#   'sistem pendidikan berpusat . Semua institusi pendidikan Kementerian Pendidikan',
#   'Malaysia ( KPM ) adalah tertakluk kepada Akta Pendidikan 1996 [ Akta 550 ] iaitu di',
#   'bawah bidang kuasa Menteri Pendidikan . Akta 550 merupakan dokumen',
#   'perundangan yang menjadi rujukan berhubung apa-apa perkara yang berkait',
#   'dengan pendidikan di semua institusi pendidikan dalam Sistem Pendidikan',
#   'Kebangsaan . Akta 550 ini juga telah mengkanunkan segala hasrat dan aspirasi',
#   'negara yang ingin dicapai melalui pelaksanaan Dasar Pendidikan Kebangsaan yang',
#   'berpaksikan Falsafah Pendidikan Kebangsaan . Justeru , Kerajaan tidak bercadang',
#   'untuk meminda Akta Pendidikan 1996 [ Akta 550 ] bagi apa jua tujuan sehingga kini .'],
#  ['NO . SOALAN : 21',
#   'PERTANYAAN LISAN',
#   'DARIPADA TUAN M . KULASEGARAN [ IPOH BARAT ]'],
#  ['Tuan M . Kulasegaran [ Ipoh Barat ] minta MENTERI DALAM NEGERI',
#   '( a ) jumlah orang tahanan yang telah meninggal dunia di dalam lokap',
#   'disebabkan oleh masalah kesihatan ; dan',
#   '( b ) nyatakan secara terperinci siasatan dan pendakwaan mulai tahun',
#   'PEMBERITAHUAN PERTANYAAN BAGI JAWAB LISAN',
#   'DEWAN RAKYAT'],
#  ['Tuan Yang di-Pertua ,',
#   'Bagi menjawab soalan ( a ), Kerajaan memandang serius kes-kes kematian',
#   'semasa dalam tahanan pihak polis . Pihak polis akan menjalankan siasatan',
#   'dengan secara terperinci samada kematian tersebut disebabkan oleh',
#   'kecuaian atau kematian disebabkan oleh penyakit .',
#   'sehingga April 2016 disebabkan punca penyakit mengikut negeri adalah',
#   'seperti berikut :-',
#   'BIL PUNCA KEMATIAN PER KED PNG PRK SEL KL N.S MLK JHR PHG TRG KLN SBH SRWK JUM',
#   '1 . HIV 7 7 4 1 1 10 5 1 36',
#   '2 . SAKIT ASMA 1 3 2 6',
#   '3 . SAKIT JANTUNG 2 1 3 4 2 4 1 1 2 20'],
#  ['LAIN-LAIN PENYAKIT', '(USUS , HATI , KUNING ,', 'ULSER , PARU-PARU ,'],
#  ['Bagi menjawab soalan ( b ), statistik keseluruhan kematian dalam tahanan',
#   'bagi tahun 2000 sehingga April 2016 yang dijalankan siasatan dan',
#   'pendakwaan adalah seperti berikut : -'],
#  ['PENDAKWAAN MASIHINKUES', 'TIADA INKUES', 'DIRUJUK DPP DIRUJUKMAJISTRET'],
#  ['* DNAA : Discharge Not Amounting to an Acquittal',
#   '* A&D : Acquitted & Discharge'],
#  ['NO SOALAN : 22',
#   'PEMBERITAHUAN PERTANYAAN',
#   'DEWAN RAKYAT , MALAYSIA',
#   'DARIPADA : Y . B . DATUK HAJAH NORAH BINTI ABD',
#   '( TANJONG MANIS )',
#   'PERTANYAAN : LISAN',
#   'Y.B . DATUK HAJAH NORAH BINTI ABD RAHMAN [ TANJONG',
#   'MANIS ] minta MENTERI KEWANGAN menyatakan sama ada',
#   'pengukuhan mata wang Ringgit Malaysia ( RM ) berbanding mata wang',
#   'USD adalah dari sebab kemasukan dana USD5.5 bilion ke dalam',
#   'saham-saham di Bursa Malaysia dalam suku pertama tahun 2016 dan',
#   "bukan berdasarkan asas 'fundamental ' ekonomi Malaysia .",
#   'Tuan Yang di-Pertua ,',
#   '1 . Pengukuhan mata wang ringgit berbanding dolar AS adalah',
#   'bergantung kepada pelbagai faktor dan bukannya semata -'],
#  ['mata bergantung kepada kemasukan dana ke dalam saham -',
#   'saham di Bursa Malaysia .',
#   '2 . Untuk makluman Ahli-Ahli Yang Berhormat , berdasarkan',
#   'perkembangan mata wang terkini , ringgit telah menambah',
#   'pada 17 Mei 2016 berbanding RM4.2920 pada 31 Disember',
#   'wang ringgit adalah , pertama , aliran masuk modal ke dalam',
#   'pasaran ekuiti dan bon Malaysia . Pelabur bukan Pemastautin',
#   'menyumbang aliran masuk sebanyak RM5.9bilion dan',
#   'RM14.5bilion masing-masing kepada pasaran ekuiti dan bon',
#   'pada April 2016 . Perkembangan ini adalah berikutan',
#   'peningkatan minat pelabur terhadap aset kewangan ringgit',
#   'yang dipengaruhi oleh perkembangan Iuar dan dalam negara .',
#   'Dari segi perkembangan Iuar negara , kadar faedah yang',
#   'rendah atau negatif dalam beberapa ekonomi utama telah',
#   'meningkatkan insentif pelabur untuk mencari hasil yang lebih',
#   'tinggi . Ini telah mendorong aliran masuk modal yang tinggi ke',
#   'arah ekonomi yang pesat membangun , termasuk Malaysia .',
#   '3 . Kedua , dari segi asas fundamental ekonomi , sentimen pelabur',
#   'turut disokong dengan keupayaan Kerajaan dalam mengurus',
#   'ekonomi yang pragmatik . Meskipun persekitaran global yang',
#   'tidak menentu , term asuk pertumbuhan ekonomi dan'],
#  ['perdagangan antarabangsa yang perlahan , negara masih',
#   'dapat m encatat pertumbuhan prestasi ekonomi yang',
#   'menggalakkan dengan Keluaran Dalam Negara Kasar (KDNK )',
#   'pada suku pertama tahun 2016 sebanyak 4.2 % yang disokong',
#   'terutamanya oleh kecergasan aktiviti permintaan domestik .',
#   '4 . Selain itu , pemulihan harga minyak mentah Brent sejak akhir -',
#   'akhir ini turut memberi sokongan kepada mata wang negara -',
#   'negara Pengeksport komoditi termasuk Malaysia , di mana',
#   'harga minyak mentah dunia telah melepasi paras USD40',
#   'setong dan berada pada paras USD48 setong pada 17 Mei',
#   'komitmen Kerajaan dalam melaksanakan konsolidasi fiskal',
#   'termasuk pelaksanaan GST dan rationalisasi subsidi yang turut',
#   'mempengaruhi kedudukan penarafan yang positif diberikan',
#   'oleh syarikat-syarikat penarafan utama termasuk Standard &',
#   "Poor's (S&P ) dan Fitch Ratings .",
#   '5 . Justeru , penunjuk data-data ekonomi yang lebih baik daripada',
#   'jangkaan telah membantu sentimen pelabur dan menyokong',
#   'aliran masuk dana portfolio .',
#   'Tuan Yang di-Pertua ,'],
#  ['6.Adalah jelas bahawa pengukuhan nilai mata wang ringgit',
#   'adalah disebabkan oleh pelbagai faktor luaran dan dalaman',
#   'negara dan bukan semata-mata bergantung kepada kemasukan',
#   'dana ke dalam saham-saham di Bursa Malaysia .'],
#  ['NO SOALAN : 23',
#   'PEMBERITAHU PERTANYAAN PEWAN RAKYAT',
#   'PERTANYAAN LISAN',
#   "DARIPADA YB RAJA DATO ' KAMARUL",
#   'BAHRIN SHAH',
#   '( KUALA TERENGGANU )',
#   'Minta MENTERI PERTAHANAN menyatakan apakah rasional dan justifikasi',
#   'Kerajaan menyertai latihan ketenteraan " northern thunder " di utara Arab',
#   'Saudi pada awal tahun 2016 baru-baru ini .'],
#  ['Tuan Yang di-Pertua ,',
#   'Sebagai sebuah angkatan yang bertanggungjawab menentukan',
#   'keutuhan kedaulatan negara , Angkatan Tentera Malaysia ( ATM ) akan terus',
#   'melengkapkan dan meningkatkan keupayaan angkatannya . Bagi memenuhi',
#   'hasrat ini , ATM perlu menggunakan semua peluang yang ada untuk',
#   'menyertai latihan-latihan ketenteraan sama ada di dalam mahupun Iuar',
#   'negara . Ke arah ini , ATM telah menerima jemputan Kerajaan Arab Saudi',
#   'untuk turut terlibat dalam latihan ketenteraan ini mengambil peluang',
#   'kehadiran trup bagi menjalankan misi evakuasi baki rakyat Malaysia di',
#   'Melalui latihan tersebut , trup ATM telah dapat menimba pengalaman',
#   'latihan ketenteraan dalam suasana yang amat berlainan dengan di',
#   'Malaysia . Justeru , penyertaan ATM dalam latihan ini pastinya memberi',
#   'manfaat yang besar dan pengalaman yang amat berguna kepada ATM pada',
#   'masa hadapan .',
#   'Selain itu , latihan ini juga memberi peluang kepada ATM untuk lebih',
#   'memahami prosedur-prosedur berkaitan bantuan kemanusian dan bencana',
#   '(HADR ) dan interoperability yang mungkin dilaksanakan kelak khususnya',
#   'dalam operasi menyelamat dan membawa keluar warga Malaysia sekiranya',
#   'berlaku konflik di rantau tersebut .',
#   'Dalam usaha ATM untuk menjadi sebuah angkatan yang kredibel di',
#   'rantau ini , ATM akan sentiasa mengambil kesempatan dan peluang untuk',
#   'melatih warganya dalam pelbagai situasi dan suasana serta membolehkan',
#   'ATM beroperasi dalam multi-terrain . Ini adalah sejajar dan seiringan',
#   'dengan visi ATM .'],
#  ['PEMBERITAHUAN PERTANYAAN DEWAN RAKYAT',
#   'PERTANYAAN JAWAB LISAN',
#   "DARIPADA DATO ' SERI TIONG KING SING",
#   '[ BINTULU ]',
#   'SOALAN 24',
#   "Dato ' Seri Tiong King Sing [ Bintulu ] minta MENTERI KOMUNIKASI DAN",
#   'MULTIMEDIA menyatakan :',
#   '( a ) adakah pihak Kementerian berhasrat untuk melaksanakan serta',
#   'memperluaskan program Kampung Tanpa Wayar (KTW ) di negeri',
#   'Sarawak dalam masa terdekat ini memandangkan terdapatnya banyak',
#   'permintaan selepas PRU ke-13 ini ; dan',
#   '( b ) berapakah kos yang melibatkan projek Program Kampung Tanpa Wayar',
#   'ini dan berapakah kos yang telah dibelanjakan oleh pihak Kerajaan dalam',
#   'melaksanakan program ini semenjak ia diperkenalkan .',
#   'Tuan Yang di-Pertua ,',
#   '( a ) Untuk makluman Ahii Yang Berhormat , Kementerian melalui Suruhanjaya',
#   'Komunikasi dan Multimedia Malaysia (SKMM ) telah melaksanakan projek',
#   'Wi-Fi Komuniti (WK ) yang dahulu dikenali sebagai Kampung Tanpa',
#   'Wayar 1 Malaysia sejak tahun 2011 , bertujuan menyediakan',
#   'perkhidmatan WiFi secara hotspot kepada penduduk setempat di Iuar'],
#  ['Projek WK merupakan satu inisiatif bersifat sementara di mana',
#   'objektifnya ialah akses permulaan secara kolektif kepada komuniti dalam',
#   'memupuk minat rakyat terhadap penggunaan Internet terutamanya di',
#   'kawasan Iuar bandar dalam penggunaan perkhidmatan Internet .',
#   'Perkhidmatan WK diberikan sehingga tamat tempoh kontrak secara',
#   'berperingkat mulai tahun 2015 mengikut fasa terutamanya kawasan yang',
#   'sudah mempunyai liputan selular seperti 3G .',
#   'Kementerian tidak berhasrat untuk meneruskan program ini dan akan',
#   'memberi fokus kepada pembangunan infrastruktur komunikasi yang',
#   'menjadi keperluan asas kepada penyediaan perkhidmatan jalur lebar',
#   'yang lebih stabil , berkualiti dan bersifat jangka masa panjang .',
#   'Projek-projek pembangunan infrastruktur sebegini adalah penting untuk',
#   'dilaksanakan bagi memastikan perkhidmatan komunikasi dan capaian',
#   'Internet yang lebih baik dan berkualiti kepada rakyat khususnya yang',
#   'tinggal di kawasan-kawasan Iuar bandar dapat disediakan selaras dengan',
#   'hasrat Kerajaan untuk mencapai status negara pintar menjelang tahun',
#   '( b ) Kos anggaran bagi pelaksanaan sebuah WK ialah RM105 ribu bagi',
#   'tempoh 3 tahun . Semenjak mula dilaksanakan pada tahun 2011 ,',
#   'dianggarkan sejumlah RM871 juta telah dibelanjakan bagi pelaksanaan',
#   'projek WK .'],
#  ['NO SOALAN : 25',
#   'PEMBERITAHUAN PERTANYAAN',
#   'DEWAN RAKYAT , MALAYSIA',
#   'DARIPADA : Y.B . PUAN SITI ZAILAH BINTI MOHD YUSOFF',
#   '( RANTAU PANJANG )',
#   'PERTANYAAN : LISAN',
#   'Y.B . PUAN SITI ZA ILA H BINTI MOHD YU SO FF [ RANTAU',
#   'PANJANG ] minta MENTERI KEWANGAN menyatakan sejauhmana',
#   'langkah dibuat terhadap penyeludupan barangan bersubsidi minyak',
#   'm asak , tepung gandum dan bahan api serta tin d a ka n',
#   'Tuan Yang Dipertua ,',
#   'Untuk makluman Ahii Yang Berhormat , Kerajaan mengambil',
#   'pendekatan yang menyeluruh melibatkan kerjasama di antara'],
#  ['beberapa Kementerian dan agensi-agensi Penguatkuasaan dalam',
#   'usaha menangani penyeludupan barang bersubsidi seperti minyak',
#   'masak , tepung gandum dan bahan api . Secara amnya , barangan',
#   'bersubsidi dikawal dari segi Pelesenan di bawah Akta Kawalan',
#   'Bekalan 1961 dan Akta Kemajuan Petroleum 1974 untuk memantau',
#   'rapi kuantiti kuota subsidi yang telah ditentukan . Minyak diesel dan',
#   'tepung gandum juga merupakan barang-barang yang diwartakan di',
#   'bawah Perintah Larangan Eksport dibawah Peraturan-Peraturan',
#   'Kawalan Bekalan ( Larangan Eksport ) 2011 yang berkuatkuasa mulai',
#   'tahun 2011 .',
#   'Bagi mengawal dan membanteras aktiviti penyeludupan barangan',
#   'bersubsidi daripada diseludup ke negara jiran , berbagai langkah telah',
#   'diambil termasuklah langkah utama seperti berikut :',
#   'i . Pendekatan Pengurusan Risiko',
#   'Pendekatan menggunakan pengurusan risiko diambil oleh Pusat',
#   'Risikan Jabatan Kastam Diraja Malaysia (JKDM ). Melalui inisiatif ini ,',
#   'kawasan berisiko tinggi dikenalpasti dan profil penyeludup dan',
#   'sindiket dibangunkan melalui kaedah risikan seperti pengawasan ,',
#   'penjejakkan dan pemerhatian . Pendekatan ini membolehkan aktiviti',
#   'Penguatkuasaan dijalankan dengan lebih berkesan , termasuklah',
#   'menyekat penyeludupan barang-barang bersubsidi melalui pelabuhan',
#   'dan pintu keluar - masuk negara .'],
#  ['ii . Operasi Penguatkuasaan Bersepadu',
#   'Dari aspek Penguatkuasaan di dalam negara , operasi bersepadu',
#   'dijalankan oleh JKDM , Kementerian Perdagangan Dalam Negeri ,',
#   'Koperasi dan Kepenggunaan (KPDNKK ) dan Lembaga Minyak Sawit',
#   'Malaysia ( MPOB ) dengan menggempur hotspot penyelewengan',
#   'barang kawalan bersubsidi secara berterusan di seluruh negara dan',
#   'mengambil tindakan undang-undang di bawah Akta Kawalan Bekalan',
#   'iii . Operasi Penguatkuasaan Berkala',
#   'Operasi secara berkala di sempadan negara dan pintu keluar - masuk',
#   'yang sah turut dijalankan oleh JKDM dengan lain-lain agensi seperti',
#   'KPDNKK , Unit Pencegah Penyeludupan (UPP ), Polis Diraja Malaysia',
#   '( PDRM ), Angkatan Tentera Malaysia ( ATM ), Agensi Penguatkuasaan',
#   'Maritim Malaysia (APMM ), Jabatan Im igresen dan Jabatan',
#   'Pengangkutan Jalan (JPJ ). Antara operasi yang dijalankan adalah',
#   'seperti Ops Sekat Bukit Kayu Hitam dan Ops Lautan Biru di sempadan',
#   'Kelantan - Thailand . Pemantauan berterusan juga dilaksanakan di',
#   'tem pat-tem pat s tra teg ik yang sering dijadikan laluan oleh',
#   'penyeludup termasuk kawasan-kawasan pendaratan dan lorong -',
#   'lorong tikus .',
#   'iv . Rampasan dan Pembekuan Peralatan Yang Terlibat'],
#  ['Dalam Aktiviti Penyeludupan',
#   'Melalui operasi yang dijaiankan , semua peralatan yang digunakan',
#   'dalam perlakuan jenayah seperti kapal dan lori akan dirampas bagi',
#   'mencegah kegiatan jenayah berulang . Selain itu , akaun dan aset',
#   'penjenayah yang diperolehi dari sumber haram seperti kegiatan',
#   'penyelewengan dan penyeludupan bahan petroleum bersubsidi akan',
# ...
#   'Untuk makluman Ahii Yang Berhormat , kewujudan , matlamat ,',
#   'fungsi dan kuasa Bank Negara Malaysia telah diperuntukkan dengan',
#   'jelas di bawah Akta Bank Negara Malaysia 2009 (ABNM ). Akta ini',
#   'telah memberi kuasa dan autonomi kepada Bank Negara Malaysia',
#   'untuk terus melaksanakan mandatnya dengan berkesan , penuh'],
#  ['tanggungjawab dan telus .'],
#  ['PARLIMEN MALAYSIA',
#   'PEMBERITAHU PERTANYAAN DEWAN RAKYAT',
#   'PERTANYAAN : LISAN',
#   "DARIPADA : Dato ' Haji Mohd Fasiah bin Haji Mohd Fakeh [ Sabak",
#   'Bernam ]',
#   "SOALAN : Dato ' Haji Mohd Fasiah bin Haji Mohd Fakeh minta",
#   'MENTERI PERTANIAN DAN INDUSTRI ASAS TANI',
#   'menyatakan langkah Kementerian bagi mengatasi masalah',
#   'kekeringan air sawah padi masa kini kesan fenomena El Nino',
#   'yang melanda negara sekarang yang menyebabkan jadual',
#   'penanaman padi terpaksa ditangguhkan beberapa kali .',
#   'Tuan Yang Dipertua ,',
#   'Bagi mengatasi masalah kekeringan air sawah padi masa kini , pihak',
#   'Kementerian berusaha memastikan ke arah pengurusan air yang baik . Secara',
#   'umurnya , kawalan pengurusan air adalah seperti berikut :-',
#   'i . Mempraktikkan giliran air mengikut kawasan dan kompatmen ; dan',
#   'ii . Mengawal bekalan air masuk ke blok-blok pengairan secara berperingkat .',
#   'Seterusnya,langkah-langkah lain yang telah diambil adalah seperti berikut :-',
#   'i . Menggalakkan pelaksanaan kaedah tanaman secara konsep "tabur-terus -',
#   'ii . Menambah pembelian pam dan meningkatkan penyelenggaraan pam bagi',
#   'tujuan pengairan ; dan',
#   'iii . Semakan semula Jadual Penanaman Padi untuk melewatkan jadual',
#   'sekiranya keadaan memerlukan .',
#   'Pemantauan di peringkat Kementerian dan agensi-agensi yang terlibat dibuat',
#   'dari masa ke semasa dengan lebih kerap bagi memastikan kesan fenomena El',
#   'Nino ini dapat ditangani dengan kadar segera turut dilaksanakan .'],
#  ['NO . SOALAN : 31',
#   'PEMBERITAHUAN PERTANYAAN BAGI JAWAB LISAN',
#   'DEWAN RAKYAT',
#   'PERTANYAAN LISAN',
#   'DARIPADA UST . DATUK DR . MOHD . KHAIRUDDIN',
#   'BIN AMAN RAZALI [ KUALA NERUS ]',
#   'Ust . Datuk Dr . Mohd . Khairuddin bin Aman Razali [ Kuala Nerus ] minta',
#   'MENTERI DALAM NEGERI menyatakan jumlah dan kategori kes jenayah yang',
#   'melibatkan pelajar sekolah sejak 2013 hingga sekarang dan faktor-faktor',
#   'kewujudan tingkahlaku ganas dan jenayah dalam kalangan pelajar .'],
#  ['Tuan Yang di-Pertua ,',
#   'Kegiatan jenayah yang melibatkan pelajar-pelajar sekolah masih lagi kecil',
#   'ketika ini jika diukur daripada keseluruhan pelajar dalam negara ini . Namun',
#   'demikian , gejala ini perlu dibendung segera dari terus merebak dan',
#   'menjadi masalah yang rumit . Pihak polis dengan Kementerian Pendidikan',
#   'sentiasa berhubung rapat dan bekerjasama untuk menangani masalah',
#   'tersebut . Antara langkah yang telah diambil adalah seperti berikut :-',
#   'i ) Melantik Pegawai Perhubungan Sekolah (PPS ) di semua sekolah',
#   'rendah dan menengah di seluruh negara ;',
#   'ii ) Mewajibkan pelajar-pelajar sekolah menyertai aktiviti kokurikulum',
#   'seperti pasukan kadet polis , bomba , tentera dan sebagainya supaya',
#   'mereka tidak terdedah dengan gejala yang tidak sihat ; dan',
#   'iii ) Persatuan Ibu Bapa dan Guru (PIBG ), yang digabungkan dalam',
#   'Majlis Permuafakatan Nasional diminta untuk lebih agresif membantu',
#   'pihak sekolah .'],
#  ['sehingga Mac 2016 dalam jenayah indeks adalah seperti berikut : -'],
#  ['JENAYAH KEKERASAN / HARTABENDA :',
#   '1 . BUNUH 15 8 13 5',
#   '2 . ROGOL 199 232 201 28',
#   '3 . SAMUN BERKAWAN BERS / API - - 0 0',
#   '4 . SAMUN BERKAWAN TANPA BERS / API 89 120 137 18',
#   '5 . SAMUN BERSENJATAPI - - 0 0',
#   '6 . SAMUN TANPA S / API 108 15 18 2',
#   '7 . MENCEDERAKAN 265 269 257 77',
#   '8 . CURI 278 384 326 66',
#   '9 . CURI MOTOKAR 34 18 14 2',
#   "11 . CURI VAN / LORI / J'BERAT 13 4 1 0",
#   '12 . CURI RAGUT 29 8 12 2',
#   '13 . PECAH RUMAH DAN CURI 346 206 180 45',
#   'Dalam siasatan yang dijalankan oleh pihak polis antara faktor-faktor yang',
#   'dikenalpasti mendorong pelajar-pelajar terjerumus dalam perlakuan',
#   'jenayah adalah seperti berikut :-',
#   'i ) Pengaruh rakan-rakan ;',
#   'ii ) Pergaulan yang bebas ;',
#   'iii ) Kurang kasih sayang keluarga ;',
#   'iv ) Pengaruh daripada Internet ;',
#   'v ) Tekanan hidup ;',
#   'vi ) Sikap materialistic ; dan',
#   'vii ) Kurang pengetahuan agama .'],
#  ['PEMBERITAHUAN PERTANYAAN DEWAN RAKYAT',
#   'JAWAPAN OLEH YB DATUK SERI DR . S . SUBRAMANIAM',
#   'MENTERI KESIHATAN MALAYSIA',
#   'PERTANYAAN : LISAN',
#   'DARIPADA YB PUAN HAJAH NORMALA BINTI',
#   'ABDUL SAMAD [ PASIR GUDANG ]',
#   'YB Puan Hajah Normals binti Abdul Samad [ Pasir Gudang ]',
#   'minta MENTERI KESIHATAN menyatakan status permohonan',
#   'Klinik 1 Malaysia di kawasan Plentong dan adakah pihak',
#   'Kementerian bercadang untuk menambah bilangan Klinik',
#   'yang sememangnya merupakan kawasan yang mempunyai',
#   'populasi penduduk yang tinggi serta golongan yang',
#   'berpendapatan rendah',
#   'Tuan Yang di-Pertua ,',
#   'Penubuhan Klinik 1 Malaysia bertujuan untuk untuk menyediakan',
#   'perkhidmatan kesihatan kepada golongan berpendapatan rendah',
#   'serta kurang berkemampuan di kawasan Bandar , dengan',
#   'menyediakan rawatan dan prosedur ringan berhampiran dengan',
#   'tempat tinggal mereka . Oleh itu , lokasi di kawasan rumah pangsa',
#   'kos rendah dan sederhana sememangnya menjadi pilihan utama'],
#  ['bagi penubuhan K1M . Namun ianya turut terikat dengan kekangan',
#   'ruang yang sesuai serta kerjasama dengan agensi lain , termasuk',
#   'pihak berkuasa tempatan ( PBT ) yang menjadi pengurus',
#   'bangunan , khususnya Rumah Pangsa Kos Rendah dan PPR .',
#   'Di daerah Johor Bahru , dari 13 K1M , tujuh ( 7 ) daripadanya terletak',
#   'di dalam kompleks perumahan PPR dan kos rendah manakala',
#   'selebihnya terletak berhampiran dengan penempatan penduduk',
#   'berpendapatan sederhana dan rendah . Keluasan minima bagi',
#   'K1M dengan perkhidmatan asas adalah 1400 kaki persegi . Ini bagi',
#   'memastikan wujudnya ruang peredaran udara yang cukup bagi',
#   'mengelakkan berlakunya jangkitan silang .',
#   'Mengenai status permohonan Klinik 1 Malaysia di Plentong .',
#   'Kementerian telah meluluskan penubuhannya di Taman Plentong',
#   'Baru dan kini sedang dalam proses mendapatkan kelulusan',
#   'Penyewaan Ruang Pejabat oleh Pejabat Belanjawan Negara ,',
#   'Kementerian Kewangan Malaysia .'],
#  ['PEMBERITAHUAN PERTANYAAN',
#   'DEWAN RAKYAT MALAYSIA',
#   'PERTANYAAN LISAN',
#   'DARIPADA YB TUAN TEO KOK SEONG',
#   'KAWASAN RASAH',
#   'NO . SOALAN 33',
#   'YB Tuan Teo Kok Seong minta MENTERI PERDAGANGAN ANTARABANGSA',
#   'DAN INDUSTRI menyatakan :-',
#   '( a ) jumlah bantuan kewangan yang diberikan kepada PROTON sejak ia',
#   'ditubuhkan ; dan',
#   '( b ) mengapakah PROTON gagal walaupun telah menerima banyak bantuan',
#   'daripada Kerajaan',
#   'Tuan Yang di-Pertua ,',
#   'PROTON telah ditubuhkan pada tahun 1985 dengan tujuan untuk menggalakkan',
#   'proses perindustrian sektor automotif dan meningkatkan keupayaan rakyat tempatan',
#   'dalam sektor berkenaan .',
#   'Sejak penubuhannya , pihak Kerajaan telah memberikan pelbagai bantuan kepada',
#   'PROTON untuk memastikan syarikat berkenaan kekal berdaya saing dalam',
#   'mengharungi cabaran industri yang amat kompetitif ini . Secara keseluruhannya ,',
#   'Kerajaan telah memberi bantuan berjumlah RM13.9 bilion yang merangkumi geran ,',
#   'pengecualian cukai termasuk bantuan-bantuan lain bukan fiskal .'],
#  ['Tuan Yang Di Pertua',
#   'Adalah tidak benar untuk mengatakan bahawa PROTON adalah syarikat yang',
#   'gagal . Ini kerana , sejak penubuhannya PROTON juga telah banyak menyumbang',
#   'kepada negara dan memberi manfaat yang besar kepada industri serta seluruh',
#   'rantaian ekosistem di mana 12,000 rakyat tempatan sedang bekerja dengan',
#   'PROTON dan sebanyak 130,000 orang yang lain terlibat secara tidak langsung',
#   'dalam industri automotif tempatan .',
#   'PROTON misalnya telah menyumbang sebanyak RM24 bilion dalam bentuk kutipan',
#   'cukai sejak penubuhannya pada tahun 1985 . Selain itu , kewujudan PROTON juga',
#   'turut menggalakkan lebih 500 usahawan tempatan untuk terlibat sebagai syarikat',
#   'pengeluar komponen dan alat ganti , pengedar , pusat jualan serta pengusaha',
#   'Kerajaan akan terus komited untuk memastikan , perkembangan dan pembangunan',
#   'berterusan industri automotif tempatan yang turut melibatkan transformasi PROTON',
#   'dan ekosistemnya .'],
#  ['PEMBERITAHUAN PERTANYAAN DEWAN RAKYAT',
#   'PERTANYAAN JAWAB LISAN',
#   'DARIPADA TUAN WILSON UGAK KUMBONG',
#   '[ HULU RAJANG ]',
#   'SOALAN 34',
#   'Tuan Wilson Ugak Kumbong [ Hulu Rajang ] minta MENTERI KOMUNIKASI DAN',
#   'MULTIMEDIA menyatakan :',
#   '( a ) bilangan Kampung Tanpa Wayar di Sarawak ; dan',
#   '( b ) bilangan Kampung Tanpa Wayar yang masih beroperasi di Sarawak .',
#   'Tuan Yang di-Pertua ,',
#   '( a ) Untuk makluman Ahii Yang Berhormat , sehingga 30 April 2016 sebanyak',
#   '1,331 WiFi Komuniti - WK ( dahulu dikenali sebagai Kampung Tanpa',
#   'Wayar - KTW ) telah dipasang di negeri Sarawak .',
#   '( b ) Kesemua 1,331 WK yang telah dipasang di negeri Sarawak masih',
#   'beroperasi sehingga kini .'],
#  ['PEMBERITAHUAN PERTANYAAN DEWAN RAKYAT', 'PERTANYAAN :'],
#  ["DATO ' JOHARI BIN ABDUL [ Sungai Petani ]"],
#  ["Dato ' Johari bin Abdul [ Sungai Petani ] minta MENTERI PENDIDIKAN",
#   'TINGGI menyatakan adakah pelajar dari Iuar negara yang menuntut di',
#   'kolej dan universiti tajaan Kerajaan membayar yuran kadar yang sama',
#   'seperti yang dikenakan kepada pelajar tempatan . Jika ada perbezaan ,',
#   'berapa peratus perbezaan tersebut .',
#   'Tuan Yang di-Pertua',
#   'Untuk makluman Ahii Yang Berhormat , tidak ada suatu kaedah yang',
#   'seragam dalam menetapkan yuran pengajian di kalangan Universiti',
#   'Awam ( UA ) di Malaysia . Penetapan yuran pengajian dipengaruhi oleh',
#   'pelbagai faktor termasuk kos langsung dan tidak langsung , Nilai Sepadan',
#   'Pelajar Sepenuh Masa ( Equivalent Full Time Student ), nisbah tenaga',
#   'pengajar / pelajar , mod kerja kursus atau penyelidikan , daya saing dan',
#   'sebagainya . Bagi sesetengah UA , penetapan yuran pengajian adalah',
#   'berdasarkan kepada semester / pakej dan ada yang berdasarkan jam',
#   'kredit / unit yang diambil .',
#   'Bagi pelajar tempatan , penetapan yuran adalah tertakluk kepada faktor -',
#   'faktor penetapan yuran oleh UA , namun dengan adanya pemberian',
#   'subsidi oleh kerajaan , kadar yuran yang perlu dibayar adalah jauh lebih',
#   'rendah daripada kadar yuran oleh pelajar dari Luar Negara yang terpaksa',
#   'membayar mengikut kadar yuran sebenar .'],
#  ['NO . SOALAN : 36',
#   'PEMBERITAHUAN PERTANYAAN BAGI JAWAB LISAN',
#   'DEWAN RAKYAT',
#   'PERTANYAAN LISAN',
#   'DARIPADA TUAN HAJI AHMAD LAI BIN BUJANG',
#   '[ SIBUTI ]',
#   'Tuan Haji Ahmad Lai bin Bujang [ Sibuti ] minta MENTERI DALAM NEGERI',
#   'menyatakan berapa ramai bekas rakyat Malaysia yang kembali semula ke',
#   'Malaysia dan memohon semula kerakyatan sejak 10 tahun lepas .',
#   'Tuan Yang di-Pertua ,',
#   'Permohonan semula untuk menjadi warganegara Malaysia ini adalah dalam',
#   'kalangan bekas warganegara yang telah diambil tindakan pelucutan',
#   'kewarganegaraan atau pun yang telah membuat pelepasan',
#   'kewarganegaraan . Oleh itu , berdasarkan rekod Jabatan Pendaftaran',
#   'Negara ( JPN ), dari tahun 2006 sehingga April 2016 terdapat seramai 75',
#   'orang telah memohon semula kewarganegaraan Malaysia .'],
#  ['NO . SOALAN : 37',
#   'PEMBERITAHUAN PERTANYAAN BAGI JAWAB LISAN',
#   'DEWAN RAKYAT',
#   'PERTANYAAN LISAN',
#   'DARIPADA TUAN SIM TZE TZIN [ BAYAN BARU ]',
#   'Tuan Sim Tze Tzin [ Bayan Baru ] minta MENTERI DALAM NEGERI menyatakan',
#   'kenapa bekas Menteri Besar Selangor , Khir Toyo dibenarkan menjalani hukuman parol',
#   'di rumah kediaman tetapi bekas Ketua Pembangkang , Datuk Seri Anwar Ibrahim tidak',
#   'boleh diletakkan di bawah " house arrest ". Mengapa ada double standard .'],
#  ['Tuan Yang di-Pertua ,',
#   'Dimaklumkan bahawa pertanyaan oleh Yang Berhormat yang menyifatkan',
#   'layanan yang double standard adalah tidak tepat sama sekali . Juga dimaklumkan',
#   "bahawa ' Sistem Parol ' dan ' house arrest ' adalah dua perkara yang berbeza .",
#   'Sepertimana kelayakan dan pertimbangan yang diberikan untuk semua banduan ,',
#   'asas utama pertimbangan oleh Lembaga Parol untuk seseorang menjalani parol',
#   'adalah bergantung kepada jenis kesalahan , pencapaian pemulihan dan tempoh',
#   'Bagi Dr . Khir Toyo , berdasarkan pencapaiannya dan rekod penjara , Lembaga',
#   'Parol telah mendapati bahawa beliau telah berjaya mencapai tahap pemulihan',
#   'yang baik , disamping memenuhi kriteria yang ditetapkan untuk menjalani',
#   'pemulihan secara parol .',
#   "Bagi ' house arrest ' sepertimana yang dinyatakan oleh Yang Berhormat , adalah",
#   'dinyatakan bahawa ianya tidak dilaksanakan untuk mana-mana banduan di',
#   'Malaysia pada masa kini . Oleh itu adalah tidak wajar dirumuskan bahawa ianya',
#   'adalah double standard .'],
#  ['SOALAN N O : 38',
#   'PEMBERITAHUAN PERTANYAAN DEWAN RAKYAT',
#   'PERTANYAAN JAWAB LISAN',
#   'DARIPADA DATUK AARON AGO ANAK DAGANG',
#   '[ K A N O W IT ]',
#   'SOALAN 38',
#   'Datuk Aaron Ago anak Dagang [ Kanowit ] minta MENTERI KOMUNIKASI DAN',
#   'MULTIMEDIA menyatakan program dan langkah-langkah Kementerian bagi',
#   'memberi perkhidmatan dan liputan (coverage ) telefon dan internet ( wifi ) yang lebih',
#   'meluas kepada kawasan Iuar bandar di Sarawak dan Sabah .',
#   'Tuan Yang di-Pertua ,',
#   'Bagi memberi perkhidmatan dan liputan telekomunikasi yang lebih meluas kepada',
#   'kawasan Iuar bandar di negeri Sarawak dan Sabah , Kementerian melalui',
#   'Suruhanjaya Komunikasi dan Multimedia Malaysia (SKMM ) dan Telekom Malaysia',
#   'telah melaksanakan pelbagai inisiatif baharu di negeri Sarawak dan Sabah seperti',
#   '( i ) Ibu sawat di pinggir bandar di naik taraf melalui projek Jalur Lebar Pinggir',
#   'Bandar (SUBB ) bagi meningkatkan kelajuan Internet sehingga 20Mbps',
#   'yang melibatkan 53 sambungan port di negeri Sarawak dan 23',
#   'sambungan port di negeri Sabah dengan jumlah keseluruhan sambungan',
#   'port adalah sebanyak 44,460 port dan dilaksanakan secara berperingkat',
#   'mulai tahun 2015 hingga 2019 ;'],
#  ['(ii ) menyediakan perkhidmatan jalur lebar sehingga 4Mbps di bawah projek',
#   'sambungan port di negeri Sarawak dan Sabah dengan menaik taraf 2',
#   'buah ibu sawat di negeri Sarawak dan 13 buah ibu sawat di negeri',
#   '(iii ) melaksanakan Projek Menaik Taraf Liputan Jalur Lebar Mudah Alih 3G di',
#   'bawah program Peluasan Liputan Perkhidmatan Selular melibatkan',
#   'sebanyak 349 lokasi di negeri Sarawak dan 442 lokasi di negeri Sabah ;',
#   '( iv ) pembinaan 392 buah menara komunikasi ( 203 baharu dan 189 dalam',
#   'pembinaan ) di negeri Sarawak dan 371 buah menara ( 212 baharu dan',
#   '( v ) menyediakan capaian Internet secara kolektif kepada komuniti setempat',
#   'melalui projek Pusat Internet 1 Malaysia (PI1M ) iaitu sebanyak 95 buah',
#   'PI1M telah dilaksanakan di negeri Sarawak dan 86 buah PI1M di negeri',
#   'Sabah . Pada masa yang sama , sebanyak 29 dan 22 buah PI1M masih',
#   'dalam peringkat pelaksanaan di negeri Sarawak dan Sabah masing -',
#   'masing ; dan',
#   '(vi ) menyediakan perkhidmatan streamyx sehingga mencecah kelajuan lapan',
#   'megabits per second (8Mbps ) serta UniFi sehingga seratus megabits per',
#   'second (100Mbps ).',
#   'Dengan terlaksanakannya kesemua projek-projek ini , capaian Internet jalur lebar',
#   'dan liputan selular di Sarawak dan Sabah akan dapat dipertingkatkan seiring dengan',
#   'negeri-negeri di Semenanjung demi kemudahan dan kesenangan rakyat .'],
#  ['NO . SOALAN : 39', 'PEMBERITAHUAN PERTANYAAN PEWAN RAKYAT'],
#  ['DARIPADA DATUK HAJI DATU NASRUN BIN',
#   'DATU MANSUR [ SILAM ]',
#   'SOALAN 39',
#   'Tuan Datuk Haji Datu Nasrun Bin Datu Mansur [ Silam ]',
#   'minta PERDANA MENTERI menyatakan apakah Malaysia',
#   'dan Filipina mempunyai kerjasama dalam pemberian kuasa',
#   'mengejar ( Hot Pursuit ), apakah Intipati kerjasama dan',
#   'siapakah yang bertangungjawab melaksanakan tugas']]

# %%
output = []

for r in tqdm(results):
    output.extend(strip(r) + [''])
# Out:
# 100%|██████████| 70046/70046 [00:24<00:00, 2910.76it/s]

# %%
output[:100]
# Out:
# ['JAWAPAN-JAWAPAN BAGI PERTANYAAN-PERTANYAAN JAWAB LISAN YANG TIDAK DIJAWAB DI DALAM DEWAN.',
#  '',
#  'NOTA : [ RUJUK PENYATA RASMI HARIAN ( HANSARD )] NURELFIRA BINTI MOHD DAUD CAWANGAN PERUNDANGAN PARLIMEN MALAYSIA.',
#  '',
#  'NO SOALAN : 8 PEMBERITAHU PERTANYAAN PEWAN RAKYAT PERTANYAAN LISAN DARIPADA LAKSAMANA PERTAMA MOHAMAD IMRAN BIN ABD HAMID ( B ) Minta MENTERI PERTAHANAN menyatakan apakah respon dan reaksi Kementerian terhadap tuntutan lima ( 5 ) perkara oleh NGO PAHLAWAN .',
#  '',
#  "Tuan Yang di-Pertua , Suka saya memaklumkan bahawa pertubuhan ini tidak berdaftar dengan Jabatan Hal Ehwal Veteran ATM ( JHEV ) di bawah Akta Veteran menyatakan bahawa ' tiada persatuan boleh menjalankan apa-apa aktiviti veteran melainkan jika persatuan itu didaftarkan sebagai suatu persatuan veteran di bawah akta ini '.",
#  'Persatuan ini tidak pernah mengemukakan sebarang tuntutan rasmi kepada Kementerian Pertahanan .',
#  'Pihak Kementerian hanya mengetahui tuntutan yang dibuat oleh Pertubuhan Prihatin Bekas Anggota Keselamatan (PAHLAWAN ) ini , melalui media massa dan media sosial Tuan Yang di-Pertua , Sebagai makluman Dewan Yang Mulia ini , tindakan yang telah dilaksanakan Kementerian berdasarkan salah satu Teras Kementerian Pertahanan iaitu kebajikan anggota dan kesejahteraan veteran ATM .',
#  'Antaranya adalah kenaikan kadar pencen sebanyak 2 % setahun semenjak tahun 2013 .',
#  'Kementerian juga melaksanakan pemanjangan tempoh dari 12 tahun 6 bulan kepada 20 tahun bagi pembayaran pencen ter dan bantuan kepada isteri / waris yang dikahwini selepas bersara dan telah berkuatkuasa mulai 1 Januari 2012 .',
#  'secara one-off kepada 84,000 veteran .',
#  '',
#  'Kementerian juga melaksanakan Program Baikpulih Rumah Veteran ATM 1 Malaysia semenjak 2012 dan masih berjalan sehingga sekarang .',
#  'Pada tahun 2015 sebanyak 620 buah rumah teiah dibina dan dibaik pulih .',
#  'Tahun ini , pihak Kementerian mensasarkan untuk membina 200 buah rumah melibatkan 100 buah baik pulih dan 100 buah bina baharu .',
#  'Selain itu , lima skim di bawah Skim Bantuan Kebajikan dan Pendidikan telah disediakan .',
#  'Tahun 2015 , Kementerian telah ribu bagi Bantuan Persekolahan , RM304 ribu bagi Bantuan Peralatan Pesakit , RM6.9 juta bagi Bantuan Kemasukan Ke Universiti Awam dan RM190 ribu bagi Bantuan Bencana Alam .',
#  'Bantuan Mengurus Jenazah turut disediakan bukan sahaja melibatkan veteran , bahkan turut merangkumi pasangan dan anak veteran .',
#  "Selain itu , melalui kemudahan Electronic Medical Automated Supply System ' atau e-MASS yang disediakan oleh Kementerian melaui JHEV membolehkan Veteran ATM mendapatkan bekalan perubatan dan alatan bantuan merangkumi lebih 1,500 jenis ubatan atau alatan perubatan bagi penyakit-penyakit kronik yang tidak dapat disediakan di Hospital Kerajaan .",
#  'Mereka hanya perlu mendapatkan pengesahan dari hospital kerajaan tanpa perlu membuat apa-apa pembayaran untuk mendapatkan keperluan tersebut .',
#  'Buat masa ini , lebih dari 1,087 Farmasi Komuniti dan vendor telah berdaftar di bawah sistem ini di seluruh negara melibatkan peruntukan sebanyak RM56 juta .',
#  'Semua ini jelas menunjukkan bahawa kerajaan sentiasa berusaha menjaga kebajikan dan kesejahteraan Veteran ATM .',
#  'Tindakan-tindakan berkenaan telah lama dilaksanakan sebelum wujudnya tuntutan oleh pihak.',
#  '',
#  'PEMBERITAHUAN PERTANYAAN DEWAN RAKYAT PERTANYAAN JAWAB LISAN DARIPADA TUAN HAJI AHMAD LAI BIN BUJANG [ SIBUTI ] SOALAN 9 Tuan Haji Ahmad Lai bin Bujang [Sibuti ] minta MENTERI KOMUNIKASI DAN MULTIMEDIA menyatakan apakah tindakan Kerajaan bagi menangani masalah judi online dalam aplikasi telefon pintar , apakah cara menyekat sebarang mesej melalui sms dan whatsapps yang mempromosikan judi online tersebut .',
#  'Tuan Yang di-Pertua , Untuk makluman Ahii Yang Berhormat , kegiatan judi dalam talian adalah tidak dibenarkan sama sekali di Malaysia dan tiada lesen ataupun permit yang pernah dikeluarkan di bawah mana-mana Akta .',
#  'Poiis Diraja Malaysia ( PDRM ) dalam kebanyakan kes perjudian tanpa lesen (haram ), mengambil tindakan Penguatkuasaan mengikut peruntukan di bawah Akta Rumah Perjudian Terbuka Komunikasi dan Multimedia Malaysia (SKMM ) dan PDRM dijalin dalam membanteras kegiatan judi dalam talian yang meliputi aspek-aspek kerjasama pemantauan , pengesanan dan perkongsian maklumat serta aspek forensik digital .',
#  'Bagi kegiatan promosi perjudian dalam talian melalui SMS dan aplikasi telefon aduan awam bagi tempoh Januari hingga April tahun 2016 ini .',
#  'Pihak SKMM telah mengumpul maklumat yang diterima daripada aduan awam tersebut , mengenal.',
#  '',
#  'pasti nombor-nombor telefon yang berkaitan untuk sekatan dan turut memanjangkan maklumat-maklumat yang berkaitan untuk siasatan lanjut pihak.',
#  '',
#  'Selain daripada aduan awam , Kementerian melalui SKMM juga turut mengambil langkah proaktif dengan mengarahkan syarikat-syarikat telekomunikasi untuk mengesan dan menamatkan nombor-nombor yang didapati menyebarkan SMS berunsur perjudian .',
#  'Sehingga kini , sebanyak 12,449 nombor telah ditamatkan perkhidmatannya sejak bulan Januari hingga April tahun 2016 .',
#  'Selain itu , syarikat telekomunikasi juga turut memberikan kerjasama dengan menyediakan sistem tapisan bagi membendung penghantaran SMS yang mempromosikan aktiviti perjudian dalam talian .',
#  'Bagi memudahkan pengguna untuk melaporkan isu-isu berkaitan kegiatan promosi perjudian dalam talian melalui SMS , pihak SKMM juga telah menyediakan perkhidmatan aduan secara terus oleh pengguna melalui nombor telefon khusus (016-2206262 ).',
#  'Pengguna boleh memajukan SMS promosi perjudian dalam talian yang diterima secara terus ke nombor telefon tersebut tanpa perlu lagi hadir ke SKMM , atau tanpa perlu melaporkannya melalui e-mel .',
#  'Untuk makluman Ahii Yang Berhormat juga , Kementerian ini dan SKMM adalah turut terlibat dalam Jawatankuasa Kerja Pindaan Akta Aktiviti Gaming sedia ada di bawah kawalan Kementerian Kewangan .',
#  'Input KKMM dan SKMM telah diberi [ Akta 289 ].',
#  'Dalam konteks ini , Ahii Yang Berhormat juga sedia maklum bahawa YAB Menteri Dalam Negeri semasa menggulung Titah Ucapan SPB YDA pada 21 Mac 2016 di Dewan Rakyat telah menyentuh tentang isu perjudian dalam talian ini dan peranan setiap Kementerian / Agensi dengan panjang lebar serta persetujuan beliau supaya dibentuk satu kokus Parlimen bagi menanganinya .',
#  '',
#  'PERTANYAAN DEWAN RAKYAT PERTANYAAN LISAN YB .',
#  'TUAN WONG LING BIU YB .',
#  'TUAN WONG LING BIU minta MENTERI KERJA RAYA menyatakan apabila membina Lebuh Raya Pan Borneo , adakah tempat-tempat kerap berlaku kemalangan akan dibina terlebih dahulu seperti jalan raya dari Bukit Sebangkoi ke Pekan Jakar di Sarikei .',
#  'Kalau ada , bila pembinaan akan dimulakan .',
#  '',
#  'Tuan Yang Di-Pertua ; Untuk makluman Ahii Yang Berhormat , pelaksanaan projek Lebuh Raya Pan Borneo Sarawak telah dipecahkan kepada 11 pakej utama .',
#  'Pakej-pakej yang terlibat itu akan ditender dan dilaksanakan secara berperingkat-peringkat bermula dari tahun lalu ( 2015 ).',
#  'Manakala pakej yang terakhir dirancang untuk dimulakan pada bulan November Penetapan tempoh pelaksanaan setiap fasa dibuat berasaskan kepada faktor-faktor seperti tempoh masa yang diperlukan untuk mereka bentuk pakej terlibat ; kadar aliran trafik semasa dan juga faktor keselamatan serta keadaan geometri jalan .',
#  'Bagi laluan dari Bukit Sebangkoi ke Pekan Jakar - untuk makluman Ahii Yang Berhormat - ia merupakan sebahagian atau termasuk dalam cadangan pelaksanaan skop Pakej 6 , Lebuh Raya Pan Borneo Sarawak .',
#  'Pelaksanaan untuk sub-pakej tersebut - iaitu Bukit Sebangkoi dari Sg .',
#  'Awik ke Sg .',
#  'Paoh sepanjang 37.3km - dirancang akan dimulakan pada bulan September 2016 ini .',
#  'Sekian .',
#  'Terima kasih .',
#  '',
#  "PEMBERITAHUAN PERTANYAAN PEWAN RAKYAT PERTANYAAN : LISAN DARIPADA : DATO ' AHMAD FAUZI BIN ZAHARI [ SETIAWANGSA ] SOALAN * Dato ' Ahmad Fauzi bin Zahari [ Setiawangsa ] minta PERDANA MENTERI menyatakan berapakah jumlah terkini pelarian pemegang kad UNHCR yang berada di Malaysia dan daripada negara manakah pelarian yang tertinggi direkodkan .",
#  '',
#  'JAWAPAN : YB .',
#  "DATO ' SERI DR .",
#  "SHAHIDAN BIN KASSIM MENTERI DI JABATAN PERDANA MENTERI Tuan Yang di-Pertua , 'pelarian ' dan pemohpn suaka di Semenanjung Malaysia dari 60 buah buah negara .",
#  "Daripada jumlah tersebut , 'pelarian ' dan pemohon suaka dari negara Myanmar mencatatkan jumlah tertinggi iaitu seramai 139,776 atau lebih 90 % daripada jumlah keseluruhan 'pelarian ' dan pemohon suaka di Malaysia .",
#  'Sekian .',
#  'Terima kasih .',
#  '',
#  'PEMBERITAHUAN PERTANYAAN PEWAN RAKYAT PERTANYAAN LISAN DARIPADA %.',
#  '',
#  "DATO ' ABDUL MANAN BIN ISMAIL [ PAYA BESAR ].",
#  '',
#  "Dato ' Abdul Manan bin Ismail [ Paya Besar ] minta PERDANA MENTERI menyatakan statistik pelarian dan pencari suaka politik di bawah Suruhanjaya Tinggi Pertubuhan Bangsa-bangsa Bersatu Bagi Pelarian (UNHCR ) Malaysia di antara tahun.",
#  '',
#  'JAWAPAN : YB .',
#  "DATO ' SERI DR .",
#  'SHAHIDAN BIN KASSIM MENTERI DI JABATAN PERDANA MENTERI Tuan Yang di-Pertua , Statistik pelarian dan pencari suaka politik di bawah Suruhanjaya Tinggi Pertubuhan Bangsa-bangsa Bersatu Bagi Pelarian (UNHCR ) Malaysia di antara tahun 2010 hingga.',
#  '',
#  'Sekian .',
#  'Terima kasih .',
#  '',
#  'PEMBERITAHUAN PERTANYAAN BAGI JAWAPAN LISAN MESYUARAT KEDUA .',
#  'DEWAN RAKYAT PENGGAL KEEMPAT .',
#  'PARLIMEN KETIGA BELAS MAJLIS MESYUARAT DEWAN RAYAT PERTANYAAN .',
#  ': LISAN DARIPADA : YB RAMKARPAL SINGH A / L KARPAL.',
#  '',
#  'YB Ramkarpal Singh a / l Karpal Singh [ Bukit Gelugor ] minta MENTERI PEMBANGUNAN WANITA , KELUARGA DAN MASYARAKAT menyatakan selain daripada undang-undang berkenaan keselamatan kanak-kanak yang sedia ada , apakah tindakan Kerajaan dalam.',
#  '',
#  'memastikan semua pihak yang berkenaan , sebagai contoh pihak polis sehingga ke tahap hakim , menguatkuasakan (enforce ) perundangan tersebut secara tegas .',
#  '',
#  "JAW APAN : YB DATO ' SRI ROHANI ABDUL KAR1M .",
#  'MENTERI PEMBANGUNAN WANITA .',
#  'KELUARGA DAN Tuan Yang di-Pertua Kementerian Pembangunan Wanita , Keluarga dan Masyarakat (KPWKM ) sebagai kementerian yang bertanggungjawab dalam melindungi kanak - kanak serta memastikan kebajikan kanak-kanak di Malaysia , teiah mengorak satu langkah dalam menambah baik undang-undang sedia ada berkaitan perlindungan dan pemeliharaan kanak-kanak .',
#  'Ini termasuklah pengukuhan pelaksanaan undang-undang tersebut di peringkat daerah dan negeri dengan melibatkan tindakan pelbagai agensi seperti Polis Diraja Malaysia dan Kementerian Kesihatan , orang awam dan Pegawai Kebajikan Masyarakat sendiri .',
#  'Antara tindakan pengukuhan Penguatkuasaan perundangan tersebut adalah seperti berikut :.',
#  '',
#  'Majlis Kebangsaan bagi Kanak-Kanak Majlis Kebangsaan bagi Kanak-Kanak ditubuhkan dan distruktur semula daripada Majlis Penyelaras bagi Pelindungan Kanak-kanak .',
#  'Ketetapan fungsi dan kuasa Majlis ini antara lain , untuk menasihati dan membuat syor kepada Kerajaan mengenai semua isu dan aspek yang berhubungan dengan pemeliharaan , perlindungan , pemulihan , perkembangan dan penyertaan kanak-kanak di peringkat kebangsaan serantau dan antarabangsa , membolehkan RUUKK dapat dikuatkuasakan dengan lebih efektif oleh kerana keanggotaannya daripada pelbagai kementerian .',
#  'aaensi dan individu ( contohnya polis , Jabatan Peguam Negara dan Jabatan Penjara ) yang mempunyai pengalaman , pengetahuan dan kepakaran dalam bidang kanak-kanak serta wakil kanak-kanak .',
#  'Pasukan Pelindungan Kanak-Kanak Di bawah penubuhan Majlis Kebangsaan Bagi Kanak-Kanak , Rang Undang-Undang Kanak-Kanak ( Pindaan ) 2015 (RUUKK ) telah menambah baik mekanisma Penguatkuasaan Akta Kanak-Kanak.',
#  '',
#  'kanak .']

# %%
with open('dumping-parliament.txt', 'w') as fopen:
    fopen.write('\n'.join(output))
