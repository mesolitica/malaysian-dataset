# %%
import json
import pandas as pd
from bs4 import BeautifulSoup

# %%
with open('johor.json') as fopen:
    johor = json.load(fopen)

# %%
res = []

for j in johor:
    s = BeautifulSoup(j)
    s.tbody.table.decompose()
    table_rows = s.tbody.find_all('tr')
    for tr in table_rows:
        td = tr.find_all('td')
        row = [tr.text.strip() for tr in td if tr.text.strip()]
        if row:
            res.append(row)

# %%
df = pd.DataFrame(res)
df
# Out:
#                    0                    1  \
# 0               lohe              [lo.he]
# 1              leweh             [le.weh]
# 2              kudut             [ku.dut]
# 3               ampa              [Am.pA]
# 4              amben             [Am.ben]
# 5         ambek ngap         [Am.be/ NAp]
# 6            ala ale          [A.lA A.le]
# 7                aji              [A.dZi]
# 8          ae jarang         [Ae dZA.ÄAN]
# 9         ade petemu      [A.d« p«.t«.mu]
# 10              acik             [A.tSi/]
# 11             abang              [A.bAN]
# 12      pencok nenas    [p«n.tSo/ n«.nAs]
# 13         lontong I            [lon.toN]
# 14             kebak             [k«.bA/]
# 15             kebak             [k«.bA/]
# 16     beketuntang I      [b«.k«.tun.tAN]
# 17     beketuntang I      [b«.k«.tun.tAN]
# 18  kurus kedengkeng  [ku.Äus k«.d«N.keN]
# 19   kurus kedengkek  [ku.Äus k«.d«N.ke/]
#
#                                                     2  \
# 0                                       kata adjektif
# 1                                       kata adjektif
# 2                                       kata adjektif
# 3                                           kata nama
# 4                                           kata nama
# 5    berhenti sebentar atau berehat daripada bekerja.
# 6         berkenaan cara berpakaian yang tidak kemas.
# 7                                           kata nama
# 8        air masak yang disejukkan, air mati; hampak.
# 9                                          ada jodoh.
# 10                                          kata nama
# 11                                          kata nama
# 12  1. , timun, dan lada yang dihiris halus dan di...
# 13                                          kata nama
# 14                                         kata kerja
# 15                                         kata kerja
# 16                                         kata kerja
# 17                                         kata kerja
# 18         kecil dan kurus; kudut 1, kurus kedengkek.
# 19         kecil dan kurus; kudut 1, kurus kedengkeng
#
#                                                     3  \
# 0   1. sangat longgar; leweh 2. 2. tidak boleh dig...
# 1   1. berkenaan cakap yang lambat dan berlagu (ti...
# 2   1. kecil dan kurus; kurus kedengkek, kurus ked...
# 3                                   permaidani; ampo.
# 4   sejenis lantai tinggi yang berkaki, lazimnya t...
# 5   Sejak datang mando baru, nak ambek ngap pon ta...
# 6   Pakai betol-betol seluwo tu, jangan ala ale aj...
# 7    kata ganti diri kedua, anda, kamu, awak, engkau.
# 8        Kawan suke minom ae jarang bandeng ae manes.
# 9   Kalau anak-anak kite ade petemu, bebesanlah kite.
# 10                         panggilan anak pra bongsu.
# 11                                       kakak sulung
# 12                                               None
# 13  1. sejenis makanan berkuah yang mengandungi na...
# 14                    2. mengambil barang orang lain.
# 15  1. mencangkul tanah menjadi bongkah-bongkah be...
# 16                           2. melonjak kegembiraan.
# 17                  1. kelam kabut; kangkang kiyap I.
# 18           Badan kurus kedengkeng, nak angkat besi.
# 19            Badan kurus kedengkek, nak angkat besi.
#
#                                                     4  \
# 0   1. Lohe bena suwanye sampai nampak tak kemas. ...
# 1   1. Cakapnye leweh buwat orang malas nak denga....
# 2   1.Kudut saje budak tu. Macam tak cukop makan. ...
# 3                 Tido atas ampa tu sedap tapi gatal.
# 4       Mari dok atas amben ni jangan dok kat lantai.
# 5   [s«.dZA/ dA.tAN mAn.do bA.Äu nA/ Am.be/ NAp po...
# 6   [pA.kAj b«.tol.b«.tol s«.lu.w tu dZA.NAn A.lA...
# 7                                      Bele aji tebe?
# 8   [kA.wAn su.k« mi.nom Ae dZA.ÄAN bAn.deN Ae mA....
# 9   [kA.lAw A.nA/.A.nA/ ki.t« A.d« p«.t«.mu b«.b«....
# 10                                               None
# 11  Pekare tu mesti beritau abang Jah, kalau tak, ...
# 12                                               None
# 13                                               None
# 14          Itu dah peel die suke kebak barang orang.
# 15  Belom buat batas, kene kebak dulu tanah kat ke...
# 16             Bile dapat nombo satu beketuntang die.
# 17          Beketuntang kawan nak siapkan keje rumah.
# 18        [bA.dAn ku.Äus k«.d«N.keN nA/ AN.kAt b«.si]
# 19        [bA.dAn ku.Äus k«.d«N.ke/ nA/ AN.kAt b«.si]
#
#                                                     5  \
# 0   [lo.he b«.nA su.wA.ø« sAm.pAj nAm.pA/ tA/ k«.m...
# 1   [tSA.kAp.ø« le.weh bu.wAt o.ÄAN mA.lAs nA/ d«....
# 2   1. [ku.dut sA.dZ« bu.dA/ tu mA.tSAm tA/ tSu.ko...
# 3          [ti.do A.tAs Am.pA tu s«.dAp tA.pi gA.tAl]
# 4   [mA.Äi do/ A.tAs Am.ben ni dZA.NAn do/ kAt lAn...
# 5   Sejak datang mandur baru, semua orang tidak ad...
# 6   Pakailah seluar itu betul-betul, jangan nampak...
# 7                                 [be.l« A.dZi te.b«]
# 8   Saya suka minum air masak sejuk jika dibanding...
# 9    Kalau anak-anak kita ada jodoh berbesanlah kita.
# 10                                               None
# 11  [p«.kA.Ä« tu m«s.ti b«.Äi.tAu A.bAN dZAh kA.lA...
# 12                                               None
# 13                                               None
# 14  [i.tu dAh pe/.el di.j« su.k« ke.bA/ bA.ÄAN o.ÄAN]
# 15  [b«.lom bu.wAt bA.tAs k«.n« k«.bA/ du.lu tA.nA...
# 16    [bi.l« dA.pAt nom.bo sA.tu b«.k«.tun.tAN di.j«]
# 17  [b«.k«.tun.tAN kA.wAn nA/ si.jAp.kAn k«.dZ« Äu...
# 18            Badan kurus kering, hendak angkat besi.
# 19            Badan kurus kering, hendak angkat besi.
#
#                                                     6
# 0   1. Longgar benar seluarnya hingga kelihatan ti...
# 1   1. Cakapnya yang lambat menyebabkan orang mala...
# 2   1. Budak itu sangat kurus. Macam tidak cukup m...
# 3   Tidur di atas permaidani itu selesa tetapi ber...
# 4   Marilah duduk di atas amben ini jangan duduk d...
# 5                                                None
# 6                                                None
# 7                                Bilakah kamu sampai?
# 8                                                None
# 9                                                None
# 10                                               None
# 11  Perkara itu mesti diberitahu kepada kak long J...
# 12                                               None
# 13                                               None
# 14  Itu sudah menjadi kebiasaannya, suka mengambil...
# 15  Sebelum membuat batas, kenalah mencangkul tana...
# 16  Apabila mendapat nombor satu, dia melonjak keg...
# 17    Kelam kabut saya hendak menyiapkan kerja rumah.
# 18                                               None
# 19                                               None

# %%
df.to_csv('johor.csv', index = False)
